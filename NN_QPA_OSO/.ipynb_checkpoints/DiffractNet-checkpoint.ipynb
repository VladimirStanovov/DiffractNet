# %%
import os
import struct
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, WeightedRandomSampler
import torch.optim.lr_scheduler as lr_scheduler
import time
import csv
import glob
from diffraction_utils import load_experimental_data
from load_xml_phases import *
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
difr_dir = "../../nn_data/"
os.makedirs(difr_dir, exist_ok=True)

# Автовыбор вычислительного устройства
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('device =', device)

# Вычисляем размер входа для свертки
input_size = 4001
num_phases = 12

xml_name = 'OSO'
model_ver = 'light_3'
wghts_fname = f'weights3_{xml_name}_{model_ver}.pth'
csv_res_fname = f"{xml_name}_{model_ver}.csv"

inp_data = []
out_data = []

PHASES_INFO = []

experiment_folder = 'XY_OSO_midKO'
# Out:
# device = cuda:0

# %%
# Создаем словарь для сопоставления имен файлов и целевых значений
target_values = {
    'Бо1125_180121.xy': np.array([0.42, 0.25, 42.72, 44.65, 2.22, 8.05, 0.00, 1.40, 0.28, 0.00, 0.01, 0.00]),
    'Бо2074_200121.xy': np.array([0.50, 0.24, 58.48, 27.85, 2.88, 7.90, 0.05, 1.62, 0.48, 0.00, 0.01, 0.00]),
    'Бо2077_200121.xy': np.array([0.40, 0.93, 67.24, 18.25, 3.63, 7.51, 0.03, 1.60, 0.42, 0.00, 0.00, 0.00]),
    'Бр1026_181220.xy': np.array([2.72, 2.78, 47.84, 28.73, 1.20, 14.57, 0.07, 2.06, 0.03, 0.00, 0.00, 0.00]),
    'Бр1071_241220.xy': np.array([1.22, 0.63, 50.30, 30.39, 1.60, 13.97, 0.06, 1.84, 0.00, 0.00, 0.00, 0.00]),
    'Бр1307_2_181220.xy': np.array([0.68, 1.17, 86.07, 0.94, 3.65, 1.29, 4.55, 0.31, 0.79, 0.05, 0.52, 0.00]),
    'Бр1356_251220.xy': np.array([1.67, 2.21, 78.72, 2.34, 7.51, 3.22, 2.43, 1.09, 0.51, 0.28, 0.02, 0.00]),
    'Бр1425_241220.xy': np.array([0.90, 1.56, 81.95, 1.43, 6.32, 2.76, 3.40, 0.85, 0.68, 0.16, 0.00, 0.00]),
    'Бр1428_241220.xy': np.array([1.07, 2.47, 63.14, 15.82, 0.80, 14.47, 0.66, 1.58, 0.00, 0.00, 0.00, 0.00]),
    'Бр1566_281220.xy': np.array([0.72, 3.95, 70.88, 5.65, 6.65, 9.87, 0.12, 2.14, 0.00, 0.00, 0.01, 0.00]),
    'В506_140121.xy': np.array([2.11, 2.59, 54.29, 21.35, 2.26, 15.51, 0.06, 1.59, 0.24, 0.00, 0.01, 0.00]),
    'В508_140121.xy': np.array([2.12, 3.48, 48.43, 27.17, 1.62, 15.24, 0.05, 1.63, 0.26, 0.00, 0.01, 0.00]),
    'В549_150121.xy': np.array([1.01, 3.74, 78.07, 0.43, 13.37, 0.44, 1.63, 0.24, 0.17, 0.00, 0.89, 0.00]),
    'В574_150121.xy': np.array([0.52, 1.16, 52.24, 24.86, 1.70, 16.05, 0.03, 3.32, 0.11, 0.00, 0.00, 0.00]),
    'В583_180121.xy': np.array([0.45, 1.25, 52.71, 24.86, 2.10, 16.14, 0.06, 2.38, 0.04, 0.00, 0.01, 0.00]),
    'И103_291220.xy': np.array([1.02, 3.74, 53.23, 30.05, 1.25, 5.35, 4.20, 1.05, 0.00, 0.11, 0.00, 0.00]),
    'И128_120121.xy': np.array([1.16, 3.16, 59.49, 23.44, 1.06, 7.46, 2.84, 1.33, 0.00, 0.06, 0.00, 0.00]),
    'И538_110121.xy': np.array([1.42, 0.97, 72.78, 9.48, 2.78, 10.23, 0.42, 1.19, 0.00, 0.72, 0.00, 0.00]),
    'И644_110121.xy': np.array([1.24, 4.00, 73.64, 6.08, 7.94, 4.33, 1.11, 0.93, 0.00, 0.63, 0.00, 0.00]),
    'И743_211220.xy': np.array([0.39, 1.37, 88.97, 0.92, 2.73, 0.32, 4.03, 0.12, 0.42, 0.28, 0.44, 0.00]),
    'И9085_130121.xy': np.array([0.48, 0.14, 42.95, 44.21, 1.04, 10.34, 0.07, 0.71, 0.06, 0.00, 0.00, 0.00]),
    'К173_210121.xy': np.array([0.68, 2.13, 45.16, 36.51, 1.06, 10.94, 0.07, 2.73, 0.29, 0.43, 0.00, 0.00]),
    'К1898_270121.xy': np.array([1.89, 1.83, 55.79, 17.94, 2.05, 13.11, 0.43, 2.62, 0.14, 4.21, 0.00, 0.00]),
    'К2019_270121.xy': np.array([1.30, 3.43, 67.70, 7.81, 2.77, 10.36, 0.05, 2.19, 0.40, 4.00, 0.00, 0.00]),
    'К2022_280121.xy': np.array([1.18, 1.49, 58.94, 15.68, 2.12, 13.57, 0.08, 2.58, 0.46, 3.91, 0.00, 0.00]),
    'К2035_280121.xy': np.array([0.99, 1.88, 57.56, 16.03, 2.68, 12.59, 0.11, 2.36, 0.43, 5.37, 0.00, 0.00]),
    'К2041_280121.xy': np.array([0.95, 2.44, 49.16, 25.80, 1.25, 13.73, 0.07, 2.76, 0.22, 3.62, 0.00, 0.00]),
    'К2042_290121.xy': np.array([0.87, 0.92, 83.39, 0.71, 0.34, 0.11, 6.30, 0.00, 0.24, 4.62, 2.51, 0.00]),
    'С152_161220.xy': np.array([0.26, 1.65, 33.93, 52.38, 0.73, 9.34, 0.27, 0.99, 0.04, 0.38, 0.04, 0.00]),
    'С207_181220.xy': np.array([0.32, 0.61, 42.08, 44.57, 0.83, 9.56, 0.29, 1.31, 0.00, 0.42, 0.00, 0.00]),
    'С294_211220.xy': np.array([0.77, 2.01, 57.04, 26.08, 2.25, 8.96, 0.34, 1.74, 0.00, 0.83, 0.00, 0.00]),
    'С343_221220.xy': np.array([1.84, 1.80, 51.13, 33.75, 1.11, 7.74, 0.75, 1.31, 0.00, 0.56, 0.00, 0.00]),
    'С367_231220.xy': np.array([0.47, 1.94, 56.72, 26.99, 1.58, 9.51, 0.39, 1.60, 0.00, 0.81, 0.00, 0.00]),
    'С455_171220.xy': np.array([0.20, 2.09, 32.42, 53.03, 0.80, 9.33, 0.46, 1.01, 0.00, 0.28, 0.38, 0.00]),
    'С479_231220.xy': np.array([0.73, 1.32, 53.55, 31.52, 1.41, 9.09, 0.29, 1.45, 0.00, 0.63, 0.00, 0.00]),
    'С490_231220.xy': np.array([1.05, 2.49, 55.01, 30.80, 1.07, 4.45, 3.10, 1.48, 0.01, 0.55, 0.00, 0.00]),
    'дБо2058д_240521.xy': np.array([0.00, 0.74, 10.33, 59.61, 2.16, 5.09, 0.13, 21.81, 0.15, 0.00, 0.00, 0.00]),
    'дБо2082д_280521.xy': np.array([0.62, 0.35, 85.91, 0.00, 0.00, 0.00, 3.22, 0.00, 9.42, 0.06, 0.17, 0.00]),
    'дБр1307д_220421.xy': np.array([0.93, 0.36, 85.71, 0.39, 0.35, 0.03, 9.36, 0.00, 0.24, 0.00, 1.22, 1.43]),
    'дБр1552д_020621.xy': np.array([0.89, 0.00, 85.48, 0.25, 0.34, 0.00, 6.05, 0.03, 0.58, 0.00, 0.37, 6.00]),
    'дК1132д_180521.xy': np.array([2.42, 1.47, 75.98, 0.48, 0.61, 0.17, 9.58, 0.06, 4.70, 0.16, 2.08, 2.28]),
    'дК1585д_170521.xy': np.array([0.43, 1.17, 84.69, 0.00, 0.00, 0.00, 9.71, 0.00, 1.83, 1.65, 0.46, 0.00]),
    'дК180д_290421.xy': np.array([0.19, 1.93, 26.94, 42.17, 4.99, 17.44, 0.06, 5.90, 0.00, 0.40, 0.00, 0.00]),
    'дС132д_210421.xy': np.array([0.29, 2.38, 26.13, 41.49, 2.17, 16.56, 0.10, 10.58, 0.27, 0.03, 0.00, 0.00]),
    'дС321д_120521.xy': np.array([0.42, 1.90, 20.31, 38.45, 3.73, 20.36, 0.10, 14.56, 0.00, 0.02, 0.16, 0.00]),
    'дС323д_170521.xy': np.array([0.17, 1.65, 21.48, 30.25, 7.69, 19.54, 0.03, 18.75, 0.14, 0.07, 0.24, 0.00])
}

# %%
def predict_experimental_data(model, experimental_data, input_size):
    predictions = []
    total_difference = 0.0
    exp_samples_nb = 0

    diff_by_phases = []
    for i in range(num_phases):
        diff_by_phases.append(0)

    for filename, intensities in experimental_data.items():

        interpolated_intensities = torch.tensor(intensities, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)[:,:,1:]
        model.eval()
        with torch.no_grad():
            predicted_weights = model(interpolated_intensities)

        # Умножаем предсказанные веса на 100
        #predicted_weights *= 100
        
        predictions.append((filename, predicted_weights.squeeze().cpu().numpy()))

        # Сравнение с целевыми значениями, если они есть
        if filename in target_values:
            target = target_values[filename]
            curr_phases = np.square(predicted_weights.squeeze().cpu().numpy() - target*0.01)
            total_difference += curr_phases.sum()
            diff_by_phases += curr_phases  # Аккумулируем разности для каждой фазы
            exp_samples_nb += 1

    if exp_samples_nb > 0:
        total_difference = (total_difference / exp_samples_nb) / num_phases
        diff_by_phases /= exp_samples_nb  # Вычисляем средние значения для каждой фазы
    else:
        total_difference = 0.0
        diff_by_phases = np.zeros(num_phases)

    return total_difference, diff_by_phases, exp_samples_nb

def load_batch_inp_file(file_name):
    if os.path.exists(file_name):
        with open(file_name, 'rb') as f:
            while True:
                data = f.read(struct.calcsize(f'{input_size}f'))
                if not data:
                    break
                inp = struct.unpack(f'{input_size}f', data)
                inp_data.append(np.array(inp))


def load_batch_out_file(file_name):
    if os.path.exists(file_name):
        with open(file_name, 'rb') as f:
            while True:
                data = f.read(struct.calcsize(f'{num_phases}f'))
                if not data:
                    break
                out = struct.unpack(f'{num_phases}f', data)
                out_data.append(np.array(out))

# %%
# Загрузка данных
inp_files = glob.glob(f"{difr_dir}batch_inp_{xml_name}_{num_phases}ph_p*.bin")
out_files = glob.glob(f"{difr_dir}batch_out_{xml_name}_{num_phases}ph_p*.bin")

print('inp_files',inp_files)

for file in inp_files:
    load_batch_inp_file(file)

for file in out_files:
    load_batch_out_file(file)

print(f"Размер массива out_data: {len(out_data)}\n")

if len(out_data) < 1:
    print("Внимание - нет данных для обучения !")

lim_len = 500000
if len(inp_data) > lim_len:
    inp_data = inp_data[-lim_len:]
if len(out_data) > lim_len:
    out_data = out_data[-lim_len:]
# Out:
# inp_files ['../../nn_data/batch_inp_OSO_12ph_p1_50000.bin', '../../nn_data/batch_inp_OSO_12ph_p3_50000.bin', '../../nn_data/batch_inp_OSO_12ph_p2_50000.bin', '../../nn_data/batch_inp_OSO_12ph_p4_50000.bin']
# Размер массива out_data: 200000

# %%
out_data[0]
# Out:
# array([4.06117998e-02, 1.57209322e-01, 1.03501059e-01, 9.29933041e-02,
#        7.91798532e-02, 8.51616561e-02, 1.94989756e-01, 1.89948182e-08,
#        1.64288893e-01, 3.76141361e-06, 6.67450503e-02, 1.53155345e-02])

# %%
# Определение класса для датасета
class CandleDataset(Dataset):
    def __init__(self, inputs, outputs):
        self.inputs = inputs
        self.outputs = outputs

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        # Возвращаем данные без изменения формы
        return torch.tensor(self.inputs[idx], dtype=torch.float32).unsqueeze(0), torch.tensor(self.outputs[idx], dtype=torch.float32)

# %%
# Разделение данных на тренировочную и тестовую выборки
indices = list(range(len(inp_data)))
indices = np.array(indices)
np.random.shuffle(indices)
#test_indices = indices[::11]
#train_indices = [i for i in indices if i not in test_indices]
test_indices = indices[:int(0.1*len(indices))]
train_indices = indices[int(0.1*len(indices)):]

train_inputs = [inp_data[i] for i in train_indices]
train_outputs = [out_data[i] for i in train_indices]
test_inputs = [inp_data[i] for i in test_indices]
test_outputs = [out_data[i] for i in test_indices]

train_inputs_np = np.array(train_inputs)[:,1:]
test_inputs_np = np.array(test_inputs)[:,1:]

train_dataset = CandleDataset(train_inputs_np, train_outputs)
test_dataset = CandleDataset(test_inputs_np, test_outputs)

# %%
# Загружаем фазы из файлов .phase
sample_info, PHASES_INFO = parse_xml('XRD_Data/OSO_Topas_2022_stidy.tshx')
num_phases = len(PHASES_INFO)

# Загружаем экспериментальные данные
experimental_data = load_experimental_data(experiment_folder)
#print(f'Loaded {len(experimental_data)} experimental diffraction patterns.')
# Out:
# {'Name': 'alpha-Al2O3', 'SpaceGroup': 'R-3cH', 'CellPar': {'a': {'min': 4.755, 'max': 4.77, 'value': 4.7698}, 'b': {'min': None, 'max': None, 'value': 4.7698}, 'c': {'min': 13.0, 'max': 13.05, 'value': 13.0243}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 120.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 45.0, 'max': 150.0, 'value': 100.0}, 'Strain': {'min': 0.01, 'max': 0.35, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.35231}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O2-', 'X': {'min': None, 'max': None, 'value': 0.6936}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'gamma-Al2O3', 'SpaceGroup': 'Fd-3mZ', 'CellPar': {'a': {'min': 7.9, 'max': 7.937, 'value': 7.911}, 'b': {'min': None, 'max': None, 'value': 7.911}, 'c': {'min': None, 'max': None, 'value': 7.911}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 45.0, 'max': 300.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.35, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.2547}, 'Y': {'min': None, 'max': None, 'value': 0.2547}, 'Z': {'min': None, 'max': None, 'value': 0.2547}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 0.58}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.125}, 'Y': {'min': None, 'max': None, 'value': 0.125}, 'Z': {'min': None, 'max': None, 'value': 0.125}, 'Occ': {'min': None, 'max': None, 'value': 0.84}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0272}, 'Y': {'min': None, 'max': None, 'value': 0.0272}, 'Z': {'min': None, 'max': None, 'value': 0.0272}, 'Occ': {'min': None, 'max': None, 'value': 0.17}}], 'RIR': -1}
#
# {'Name': 'Cryolite', 'SpaceGroup': 'P121/c1', 'CellPar': {'a': {'min': 5.35095, 'max': 5.45905, 'value': 5.405}, 'b': {'min': 5.5242, 'max': 5.6358, 'value': 5.58}, 'c': {'min': 9.351936, 'max': 9.540864000000001, 'value': 9.4464}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': 123.51933, 'max': 126.01467, 'value': 124.767}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 70.0, 'max': 500.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [{'name': '1 1 1', 'min': 0.95, 'max': 1.1, 'value': 1.0}], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': 0.2638, 'max': 0.27, 'value': 0.2656}, 'Y': {'min': 0.448, 'max': 0.456, 'value': 0.448}, 'Z': {'min': 0.2501, 'max': 0.257, 'value': 0.2518}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.114, 'max': 0.12, 'value': 0.1152}, 'Y': {'min': 0.042, 'max': 0.05, 'value': 0.0436}, 'Z': {'min': 0.214, 'max': 0.223, 'value': 0.2182}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.22, 'max': 0.229, 'value': 0.2285}, 'Y': {'min': 0.73, 'max': 0.738, 'value': 0.7285}, 'Z': {'min': 0.057, 'max': 0.064, 'value': 0.0638}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.307, 'max': 0.319, 'value': 0.3215}, 'Y': {'min': 0.166, 'max': 0.18, 'value': 0.1765}, 'Z': {'min': 0.037, 'max': 0.048, 'value': 0.047}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Chiolite', 'SpaceGroup': 'P4/mnc', 'CellPar': {'a': {'min': 7.02, 'max': 7.06, 'value': 7.0138}, 'b': {'min': None, 'max': None, 'value': 7.0138}, 'c': {'min': 10.36, 'max': 10.403, 'value': 10.402}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 80.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [{'name': '0 0 1', 'min': 0.93, 'max': 1.0, 'value': 1.0}], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.277}, 'Y': {'min': None, 'max': None, 'value': 0.777}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': 0.17, 'max': 0.177, 'value': 0.1711}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.058, 'max': 0.064, 'value': 0.0642}, 'Y': {'min': 0.245, 'max': 0.252, 'value': 0.2477}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.176, 'max': 0.182, 'value': 0.1794}, 'Y': {'min': 0.532, 'max': 0.54, 'value': 0.5364}, 'Z': {'min': 0.118, 'max': 0.121, 'value': 0.1198}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'NaCa(AlF6)', 'SpaceGroup': 'P121/c1', 'CellPar': {'a': {'min': 8.715, 'max': 8.795, 'value': 8.7423}, 'b': {'min': 5.145, 'max': 5.21, 'value': 5.1927}, 'c': {'min': 20.3, 'max': 20.46, 'value': 20.35139}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': 90.85, 'max': 91.5, 'value': 91.499}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 30.0, 'max': 150.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Na1+', 'X': {'min': 0.9668, 'max': 0.9868, 'value': 0.9768}, 'Y': {'min': 0.2443, 'max': 0.2643, 'value': 0.2543}, 'Z': {'min': 0.1681, 'max': 0.1881, 'value': 0.1781}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': 0.9581, 'max': 0.9781, 'value': 0.9681}, 'Y': {'min': 0.2634, 'max': 0.2834, 'value': 0.2734}, 'Z': {'min': 0.4313, 'max': 0.4513, 'value': 0.4413}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Ca2+', 'X': {'min': 0.6303, 'max': 0.6503, 'value': 0.6403}, 'Y': {'min': 0.2275, 'max': 0.2475, 'value': 0.2375}, 'Z': {'min': 0.3008, 'max': 0.3208, 'value': 0.3108}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Ca2+', 'X': {'min': 0.6257, 'max': 0.6457, 'value': 0.6357}, 'Y': {'min': 0.3119, 'max': 0.3319, 'value': 0.3219}, 'Z': {'min': 0.5523, 'max': 0.5723, 'value': 0.5623}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': 0.2488, 'max': 0.2688, 'value': 0.2588}, 'Y': {'min': 0.2461, 'max': 0.2661, 'value': 0.2561}, 'Z': {'min': 0.3089, 'max': 0.3289, 'value': 0.3189}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': 0.2428, 'max': 0.2628, 'value': 0.2528}, 'Y': {'min': 0.1803, 'max': 0.2003, 'value': 0.1903}, 'Z': {'min': 0.5588, 'max': 0.5788, 'value': 0.5688}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.629}, 'Y': {'min': None, 'max': None, 'value': 0.6261}, 'Z': {'min': None, 'max': None, 'value': 0.4777}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.5863}, 'Y': {'min': None, 'max': None, 'value': 0.6137}, 'Z': {'min': None, 'max': None, 'value': 0.6397}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.7338}, 'Y': {'min': None, 'max': None, 'value': 0.0827}, 'Z': {'min': None, 'max': None, 'value': 0.4824}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.3809}, 'Y': {'min': None, 'max': None, 'value': 0.1003}, 'Z': {'min': None, 'max': None, 'value': 0.2626}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1625}, 'Y': {'min': None, 'max': None, 'value': -0.0247}, 'Z': {'min': None, 'max': None, 'value': 0.6328}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1643}, 'Y': {'min': None, 'max': None, 'value': 0.4377}, 'Z': {'min': None, 'max': None, 'value': 0.3814}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.2357}, 'Y': {'min': None, 'max': None, 'value': 0.4669}, 'Z': {'min': None, 'max': None, 'value': 0.6229}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.5786}, 'Y': {'min': None, 'max': None, 'value': 0.5944}, 'Z': {'min': None, 'max': None, 'value': 0.8821}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.9132}, 'Y': {'min': None, 'max': None, 'value': 0.6404}, 'Z': {'min': None, 'max': None, 'value': 0.226}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.7403}, 'Y': {'min': None, 'max': None, 'value': 0.0217}, 'Z': {'min': None, 'max': None,  ...
#
# {'Name': 'Na2Ca3Al2F14', 'SpaceGroup': 'I213', 'CellPar': {'a': {'min': 10.242, 'max': 10.254, 'value': 10.257}, 'b': {'min': None, 'max': None, 'value': 10.257}, 'c': {'min': None, 'max': None, 'value': 10.257}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 65.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [{'name': '1 1 1', 'min': 0.72, 'max': 1.0, 'value': 1.0}], 'Atoms': [{'Type': 'Ca2+', 'X': {'min': None, 'max': None, 'value': 0.4667}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.2482}, 'Y': {'min': None, 'max': None, 'value': 0.2482}, 'Z': {'min': None, 'max': None, 'value': 0.2482}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.0847}, 'Y': {'min': None, 'max': None, 'value': 0.0847}, 'Z': {'min': None, 'max': None, 'value': 0.0847}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1387}, 'Y': {'min': None, 'max': None, 'value': 0.3062}, 'Z': {'min': None, 'max': None, 'value': 0.1206}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.364}, 'Y': {'min': None, 'max': None, 'value': 0.3627}, 'Z': {'min': None, 'max': None, 'value': 0.1873}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.4614}, 'Y': {'min': None, 'max': None, 'value': 0.4614}, 'Z': {'min': None, 'max': None, 'value': 0.4614}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Fluorite', 'SpaceGroup': 'Fm-3m', 'CellPar': {'a': {'min': 5.463, 'max': 5.469, 'value': 5.462}, 'b': {'min': None, 'max': None, 'value': 5.462}, 'c': {'min': None, 'max': None, 'value': 5.462}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 60.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.38, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Ca2+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Weberite', 'SpaceGroup': 'Imma', 'CellPar': {'a': {'min': 7.05, 'max': 7.072, 'value': 7.05}, 'b': {'min': 9.98, 'max': 10.02, 'value': 9.979}, 'c': {'min': 7.29, 'max': 7.31, 'value': 7.297}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 150.0, 'max': 500.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.35, 'value': 0.1}}, 'MDtexDir': [{'name': '0 1 1', 'min': 0.9, 'max': 1.0, 'value': 1.0}], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.75}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Mg2+', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.1362}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.4144}, 'Z': {'min': None, 'max': None, 'value': 0.7213}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1845}, 'Y': {'min': None, 'max': None, 'value': 0.3874}, 'Z': {'min': None, 'max': None, 'value': 0.4304}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Neighborite', 'SpaceGroup': 'Pnma', 'CellPar': {'a': {'min': 5.488, 'max': 5.5, 'value': 5.4928}, 'b': {'min': 7.665, 'max': 7.69, 'value': 7.71}, 'c': {'min': 5.36, 'max': 5.387, 'value': 5.37645}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 100.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.3, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.03975}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.488}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Mg2+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.4547}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.58705}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.29105}, 'Y': {'min': None, 'max': None, 'value': 0.04897}, 'Z': {'min': None, 'max': None, 'value': 0.21265}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Elpasolite', 'SpaceGroup': 'Fm-3m', 'CellPar': {'a': {'min': 8.095, 'max': 8.112, 'value': 8.093}, 'b': {'min': None, 'max': None, 'value': 8.093}, 'c': {'min': None, 'max': None, 'value': 8.093}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 60.0, 'max': 200.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'K', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F', 'X': {'min': None, 'max': None, 'value': 0.2225}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'K1.58Al11O17', 'SpaceGroup': 'R-3mH', 'CellPar': {'a': {'min': 5.585, 'max': 5.62, 'value': 5.63}, 'b': {'min': None, 'max': None, 'value': 5.63}, 'c': {'min': 33.89, 'max': 34.17, 'value': 34.01}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 120.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 45.0, 'max': 150.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.37, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.16712}, 'Y': {'min': None, 'max': None, 'value': -0.16712}, 'Z': {'min': None, 'max': None, 'value': 0.9298}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.34988}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.44935}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.16419}, 'Y': {'min': None, 'max': None, 'value': -0.16419}, 'Z': {'min': None, 'max': None, 'value': 0.23615}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.15396}, 'Y': {'min': None, 'max': None, 'value': -0.15396}, 'Z': {'min': None, 'max': None, 'value': 0.03384}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.09512}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.2952}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'K', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': -0.17086}, 'Occ': {'min': None, 'max': None, 'value': 0.31}}, {'Type': 'K', 'X': {'min': None, 'max': None, 'value': 0.08717}, 'Y': {'min': None, 'max': None, 'value': -0.08717}, 'Z': {'min': None, 'max': None, 'value': -0.16784}, 'Occ': {'min': None, 'max': None, 'value': 0.16}}], 'RIR': -1}
#
# {'Name': 'Villiaumite', 'SpaceGroup': 'Fm-3m', 'CellPar': {'a': {'min': 4.633, 'max': 4.64, 'value': 4.634}, 'b': {'min': None, 'max': None, 'value': 4.634}, 'c': {'min': None, 'max': None, 'value': 4.634}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 90.0, 'max': 170.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.38, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Na', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}

# %%
#small
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()
        
        # Сверточные слои: уменьшены более агрессивно (в ~2.5 раза)
        self.conv_layers = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=32, kernel_size=7, stride=1, padding=3),  # Было 64
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=32, out_channels=64, kernel_size=5, stride=1, padding=2),  # Было 128
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1), # Было 256
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2)
        )
        
        reduced_size = input_size // 8
        
        # Трансформер: один слой + уменьшенная размерность
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=500, nhead=10, dim_feedforward=256, dropout=0.1, batch_first=True), # d_model и dim_feedforward уменьшены
            num_layers=1  # Один слой
        )
        
        # Полносвязные слои: значительно уменьшены
        self.fc_layers = nn.Sequential(
            nn.Linear(128 * reduced_size, 256),  # Было 1024
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(256, num_phases)
        )
    
    def forward(self, x):
        x = self.conv_layers(x)
        #x = x.permute(0, 2, 1)  # Критичный шаг сохранён
        x = self.transformer(x)
        x = x.reshape(x.size(0), -1)
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)
        return x

# %%
#big
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super(DiffractionNet, self).__init__()
        
        # Сверточные слои для извлечения локальных признаков
        self.conv_layers = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=64, kernel_size=7, stride=1, padding=3),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=64, out_channels=128, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2)
        )
        
        # Размер выхода после сверточных слоев
        reduced_size = input_size // 8  # Поскольку мы делаем три пулинга с шагом 2
        
        # Трансформер для глобального понимания
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=256, nhead=8, dim_feedforward=512, dropout=0.1, batch_first=True),
            num_layers=2
        )
        
        # Полносвязные слои для получения итогового предсказания
        self.fc_layers = nn.Sequential(
            nn.Linear(256 * reduced_size, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(1024, num_phases)
        )
    
    def forward(self, x):
        x = self.conv_layers(x)
        x = x.permute(0, 2, 1)  # Изменяем форму для трансформера (batch_size, sequence_length, features)
        x = self.transformer(x)
        x = x.reshape(x.size(0), -1)  # Флэттенинг с использованием reshape
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)  # Нормированные доли
        return x

# %%
#FFN
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()        
        
        # Полносвязные слои: значительно уменьшены
        self.fc_layers = nn.Sequential(
            nn.Linear(4001, 2048),  # Было 1024
            #nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(2048,1024),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(1024,256),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(256, num_phases)
        )
    
    def forward(self, x):
        #x = self.conv_layers(x)
        #x = x.permute(0, 2, 1)  # Критичный шаг сохранён
        #x = self.transformer(x)
        #x = x.reshape(x.size(0), -1)
        x = x.view(-1,4001)
        #print(x.shape)
        x = self.fc_layers(x)
        #print(x.shape)
        x = F.softmax(x, dim=1)
        #print(x.shape)
        return x

# %%
#conv_ff
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()
        self.fc_layers = nn.Sequential(            
            nn.Linear(4001, 256),
            nn.ReLU(),
            nn.Linear(256, num_phases)
        )
    
    def forward(self, x):
        x = x.reshape(x.size(0), -1)
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)
        return x

# %%
#ff_40_100
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()
        self.fc_layers = nn.Sequential(            
            nn.Linear(4040, num_phases)
        )
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=40, nhead=2, dim_feedforward=128, dropout=0.0, batch_first=True),
            num_layers=1
        )
        self.positional_embedding=nn.Parameter(torch.randn(1, 1, 40))
    
    def forward(self, x):
        x = x.view(-1,40,100).permute(0, 2, 1)
        positional_embeddings = self.positional_embedding.expand(x.shape[0], 1, 40)
        x = torch.cat((positional_embeddings, x), dim=1)
        x = self.transformer(x)
        x = x.view(-1,4040)
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)
        return x

# %%
# Создание экземпляра модели
model = DiffractionNet(input_size, num_phases).to(device)
print(model)
pytorch_total_params = sum(p.numel() for p in model.parameters())
print(pytorch_total_params)
# Out:
# DiffractionNet(
#   (fc_layers): Sequential(
#     (0): Linear(in_features=4040, out_features=12, bias=True)
#   )
#   (transformer): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=40, out_features=40, bias=True)
#         )
#         (linear1): Linear(in_features=40, out_features=128, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=128, out_features=40, bias=True)
#         (norm1): LayerNorm((40,), eps=1e-05, elementwise_affine=True, bias=True)
#         (norm2): LayerNorm((40,), eps=1e-05, elementwise_affine=True, bias=True)
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (dropout2): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
# )
# 65660

# %%
print('Start training')
learn_rate = 1E-4
# Определяем критерий потерь и оптимизатор
criterion = nn.MSELoss(reduction='none')  # Используем reduction='none' для получения ошибки для каждого элемента в батче
optimizer = optim.AdamW(model.parameters(), lr=learn_rate, weight_decay=learn_rate*0.1)
def find_index_of_max(float_array):
    max_index = np.argmax(float_array)
    return max_index

# Определяем категории для балансировки данных
def get_category(out):
    min_val = np.min(out)
    max_val = np.max(out)
    delta = min_val / max_val if max_val > 0 else 0.0
    if delta < 0.001:
        return 0
    elif 0.001 <= delta < 0.01:
        return 1
    elif 0.01 <= delta < 0.1:
        return 2
    else:
        return 3
# Определяем метки классов для балансировки
train_labels = np.array([find_index_of_max(out) for out in train_outputs])
print('train_labels',train_labels)
class_counts = np.bincount(train_labels.astype(np.int64))
print(f'Category class_counts = {class_counts}')
# Добавляем сглаживание для предотвращения деления на ноль
#smoothing_factor = 1e-3
#class_weights = 1. / (class_counts + smoothing_factor)
class_weights = 1. / class_counts
sample_weights = class_weights[train_labels]
sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(sample_weights), replacement=True)
# Загрузка данных
train_dataloader = DataLoader(train_dataset, batch_size=128, sampler=sampler)
test_dataloader = DataLoader(test_dataset, batch_size=128, shuffle=False)

n_train_iter = len(train_dataloader)
n_test_iter = len(test_dataloader)
print(f'train_iter: {n_train_iter}, test_iter: {n_test_iter}')
# Инициализация списков для хранения значений потерь
train_losses = []
test_losses = []

# Инициализация списков для хранения значений потерь для каждого параметра
train_param_losses = [[] for _ in range(num_phases)]
test_param_losses = [[] for _ in range(num_phases)]

# Создание и запись заголовков в CSV-файл
with open(csv_res_fname, mode='w', newline='') as file:
    writer = csv.writer(file, delimiter=';')
    header = ['Time', 'Epoch', 'Train Loss', 'Test Loss', 'Exp_Diff'] + \
             [f'Train_{i + 1}' for i in range(num_phases)] + \
             [f'Test_{i + 1}' for i in range(num_phases)] + \
             [f'Exp_{i + 1}' for i in range(num_phases)]
    writer.writerow(header)

num_epochs = 300

total_exp_diff = 0.0
ph_exp_diff = []

pre_fitness = 1E6

train_all_losses = []
test_all_losses = []
train_batch_losses = []
test_batch_losses = []
experimental_losses = []

scheduler = lr_scheduler.CosineAnnealingWarmRestarts(optimizer,T_0=30)
# Out:
# Start training
# train_labels [3 6 4 ... 0 4 4]
# Category class_counts = [15019 14892 14981 14978 14926 14793 14891 15077 15094 15085 15256 15008]
# train_iter: 1407, test_iter: 157

# %%
start_time = time.time()  # Запоминаем время начала обучения

for epoch in range(num_epochs):
    model.train()
    running_train_loss = 0.0
    running_train_param_losses = [0.0 for _ in range(num_phases)]
    iters = 0
    #train_batch_losses = []
    for inputs, outputs in train_dataloader:
        inputs, outputs = inputs.to(device), outputs.to(device)
        optimizer.zero_grad()
        predictions = model(inputs)        
        loss = criterion(predictions, outputs)
        loss.mean().backward()  # Средняя ошибка по всем элементам в батче
        # Градиенты масштабируются, если их общая норма > 1.0
        #torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        #running_train_loss += loss.mean().item()
        #for i in range(num_phases):
        #    running_train_param_losses[i] += loss[:, i].mean().item()
        iters += 1
        #train_batch_losses.append(loss.mean(axis=1).cpu().detach().numpy())

        if iters % 500 == 0:
            print(f"Iteration {iters}")
    #train_all_losses.append(np.array(train_batch_losses[:-1]))

    #train_loss = running_train_loss / n_train_iter
    #train_losses.append(train_loss)
    #for i in range(num_phases):
    #    train_param_losses[i].append(running_train_param_losses[i] / n_train_iter)

    if n_test_iter > 0:
        
        train_batch_losses = []
        model.eval()
        running_train_param_losses = [0.0 for _ in range(num_phases)]
        with torch.no_grad():
            for inputs, outputs in train_dataloader:
                inputs, outputs = inputs.to(device), outputs.to(device)
                predictions = model(inputs)
                loss = criterion(predictions, outputs)
                running_train_loss += loss.mean().item()
                for i in range(num_phases):
                    running_train_param_losses[i] += loss[:, i].mean().item()
                train_batch_losses.append(loss.mean(axis=1).cpu().detach().numpy())
        train_loss = running_train_loss / n_train_iter
        train_losses.append(train_loss)
        for i in range(num_phases):
            train_param_losses[i].append(running_train_param_losses[i] / n_train_iter)
        train_all_losses.append(np.array(train_batch_losses[:-1]))
        

        
        test_batch_losses = []
        model.eval()
        running_test_loss = 0.0
        running_test_param_losses = [0.0 for _ in range(num_phases)]
        with torch.no_grad():
            for inputs, outputs in test_dataloader:
                inputs, outputs = inputs.to(device), outputs.to(device)
                predictions = model(inputs)
                loss = criterion(predictions, outputs)
                running_test_loss += loss.mean().item()
                for i in range(num_phases):
                    running_test_param_losses[i] += loss[:, i].mean().item()
                test_batch_losses.append(loss.mean(axis=1).cpu().detach().numpy())
        test_loss = running_test_loss / n_test_iter
        test_losses.append(test_loss)
        for i in range(num_phases):
            test_param_losses[i].append(running_test_param_losses[i] / n_test_iter)
        test_all_losses.append(np.array(test_batch_losses[:-1]))

        

        total_exp_diff, ph_exp_diff, exp_samples_nb = predict_experimental_data(model, experimental_data, input_size)
        experimental_losses.append(total_exp_diff)

        # Вывод средней разницы, если были найдены соответствия
        if exp_samples_nb > 0:
            if total_exp_diff < pre_fitness:
                #torch.save(model.state_dict(), wghts_fname)
                #print(f'*** Weights are saved to {wghts_fname} after epoch {epoch + 1}')
                pre_fitness = total_exp_diff
            print(f' >>> Средняя разница между предсказанными и OSO: {total_exp_diff:.5g}')
        else:
            total_exp_diff = 0.0
            print('Нет соответствий для подсчета разницы.')

    else:
        test_loss = 0.0
        test_losses.append(test_loss)

    #print(f'Epoch [{epoch + 1}/{num_epochs}], learn_rate: {scheduler.get_last_lr()}, Train Loss: {100 * np.sqrt(train_loss):.5f}, Test Loss: {100 * np.sqrt(test_loss):.5f}')
    print(f'Epoch [{epoch + 1}/{num_epochs}], learn_rate: {scheduler.get_last_lr()}, Train Loss: {1 * (train_loss):.5g}, Test Loss: {1 * (test_loss):.5g}')

    # Вывод ошибок для каждого параметра
    for i in range(num_phases):
        print(f'Фаза {i + 1}: Train: {1 * (train_param_losses[i][-1]):.5g}, Test: {1 * (test_param_losses[i][-1]):.5g}')

    # Форматирование прошедшего времени в "hh:mm:ss"
    elapsed_time = time.time() - start_time  # Вычисляем прошедшее время
    hours, rem = divmod(elapsed_time, 3600)
    minutes, seconds = divmod(rem, 60)
    formatted_time = f"{int(hours):02d}:{int(minutes):02d}:{int(seconds):02d}"

    # Запись данных в CSV-файл
    with open(csv_res_fname, mode='a', newline='') as file:
        writer = csv.writer(file, delimiter=';')
        row = [formatted_time, epoch + 1, 100 * np.sqrt(train_loss), 100 * np.sqrt(test_loss), total_exp_diff] + \
              [100 * np.sqrt(train_param_losses[i][-1]) for i in range(num_phases)] + \
              [100 * np.sqrt(test_param_losses[i][-1]) for i in range(num_phases)] + \
              ph_exp_diff.tolist()
        writer.writerow(row)

    print(f'Прошло времени: {formatted_time}\n')

    scheduler.step()
# Out:
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00048949
# Epoch [1/300], learn_rate: [0.0001], Train Loss: 0.00036216, Test Loss: 0.00036475
# Фаза 1: Train: 0.00033111, Test: 0.00033573
# Фаза 2: Train: 0.00037766, Test: 0.00037709
# Фаза 3: Train: 0.00062218, Test: 0.00061827
# Фаза 4: Train: 0.00038731, Test: 0.00039149
# Фаза 5: Train: 0.00042858, Test: 0.00043593
# Фаза 6: Train: 0.00033049, Test: 0.00032971
# Фаза 7: Train: 0.00018174, Test: 0.00019773
# Фаза 8: Train: 0.00042288, Test: 0.00042272
# Фаза 9: Train: 0.0003996, Test: 0.00039705
# Фаза 10: Train: 0.0002322, Test: 0.00023904
# Фаза 11: Train: 0.00040285, Test: 0.00040155
# Фаза 12: Train: 0.00022931, Test: 0.0002307
# Прошло времени: 00:00:04
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00024731
# Epoch [2/300], learn_rate: [9.972609476841367e-05], Train Loss: 0.00021915, Test Loss: 0.00022086
# Фаза 1: Train: 0.00026812, Test: 0.00027202
# Фаза 2: Train: 0.00024558, Test: 0.00024559
# Фаза 3: Train: 0.00033841, Test: 0.00033639
# Фаза 4: Train: 0.0002004, Test: 0.00020016
# Фаза 5: Train: 0.00022226, Test: 0.00022231
# Фаза 6: Train: 0.00021586, Test: 0.00021775
# Фаза 7: Train: 0.00012514, Test: 0.00013292
# Фаза 8: Train: 0.00023323, Test: 0.00022982
# Фаза 9: Train: 0.00024841, Test: 0.00024859
# Фаза 10: Train: 0.00015147, Test: 0.00015544
# Фаза 11: Train: 0.00022559, Test: 0.00023034
# Фаза 12: Train: 0.00015537, Test: 0.00015895
# Прошло времени: 00:00:09
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00024927
# Epoch [3/300], learn_rate: [9.890738003669029e-05], Train Loss: 0.00016387, Test Loss: 0.00016549
# Фаза 1: Train: 0.00014584, Test: 0.00015012
# Фаза 2: Train: 0.00017966, Test: 0.00018034
# Фаза 3: Train: 0.00026912, Test: 0.00027287
# Фаза 4: Train: 0.00014418, Test: 0.0001444
# Фаза 5: Train: 0.00017272, Test: 0.00017355
# Фаза 6: Train: 0.00014729, Test: 0.00015175
# Фаза 7: Train: 0.00011568, Test: 0.0001169
# Фаза 8: Train: 0.00018647, Test: 0.00018404
# Фаза 9: Train: 0.00021983, Test: 0.00021908
# Фаза 10: Train: 0.00010264, Test: 0.00010638
# Фаза 11: Train: 0.0001526, Test: 0.00015347
# Фаза 12: Train: 0.00013045, Test: 0.00013297
# Прошло времени: 00:00:14
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00015185
# Epoch [4/300], learn_rate: [9.755282581475769e-05], Train Loss: 0.00014183, Test Loss: 0.00014323
# Фаза 1: Train: 0.00011226, Test: 0.00011296
# Фаза 2: Train: 0.00015509, Test: 0.00015587
# Фаза 3: Train: 0.00018502, Test: 0.00018814
# Фаза 4: Train: 0.00018728, Test: 0.00018605
# Фаза 5: Train: 0.00012283, Test: 0.00012473
# Фаза 6: Train: 0.00012814, Test: 0.00013163
# Фаза 7: Train: 0.00011991, Test: 0.00012338
# Фаза 8: Train: 0.00016496, Test: 0.00016357
# Фаза 9: Train: 0.00016249, Test: 0.00016178
# Фаза 10: Train: 8.9831e-05, Test: 9.188e-05
# Фаза 11: Train: 0.00012367, Test: 0.00012581
# Фаза 12: Train: 0.00015046, Test: 0.00015301
# Прошло времени: 00:00:19
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00013311
# Epoch [5/300], learn_rate: [9.567727288213005e-05], Train Loss: 0.00013061, Test Loss: 0.00013178
# Фаза 1: Train: 0.00010039, Test: 0.00010277
# Фаза 2: Train: 0.00015966, Test: 0.00015947
# Фаза 3: Train: 0.0001527, Test: 0.00015582
# Фаза 4: Train: 0.00015123, Test: 0.00015109
# Фаза 5: Train: 0.00011391, Test: 0.00011599
# Фаза 6: Train: 0.00017695, Test: 0.00017584
# Фаза 7: Train: 0.00011472, Test: 0.00011602
# Фаза 8: Train: 0.00014375, Test: 0.00014283
# Фаза 9: Train: 0.00014055, Test: 0.00013947
# Фаза 10: Train: 0.00010619, Test: 0.00011007
# Фаза 11: Train: 0.00010347, Test: 0.00010479
# Фаза 12: Train: 0.00010378, Test: 0.00010718
# Прошло времени: 00:00:24
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00020544
# Epoch [6/300], learn_rate: [9.330127018922194e-05], Train Loss: 0.00010759, Test Loss: 0.00010812
# Фаза 1: Train: 8.8292e-05, Test: 8.885e-05
# Фаза 2: Train: 0.00015903, Test: 0.00015714
# Фаза 3: Train: 0.00012854, Test: 0.00013017
# Фаза 4: Train: 0.00013654, Test: 0.0001357
# Фаза 5: Train: 0.00012026, Test: 0.00012095
# Фаза 6: Train: 9.3579e-05, Test: 9.4399e-05
# Фаза 7: Train: 8.1595e-05, Test: 8.4327e-05
# Фаза 8: Train: 0.00011785, Test: 0.00011663
# Фаза 9: Train: 0.00012689, Test: 0.00012591
# Фаза 10: Train: 6.3792e-05, Test: 6.5344e-05
# Фаза 11: Train: 9.8495e-05, Test: 9.9234e-05
# Фаза 12: Train: 7.625e-05, Test: 7.8747e-05
# Прошло времени: 00:00:30
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 9.8233e-05
# Epoch [7/300], learn_rate: [9.045084971874738e-05], Train Loss: 8.6921e-05, Test Loss: 8.8041e-05
# Фаза 1: Train: 8.0395e-05, Test: 8.3131e-05
# Фаза 2: Train: 0.00010663, Test: 0.00010722
# Фаза 3: Train: 0.00011786, Test: 0.00012028
# Фаза 4: Train: 7.8692e-05, Test: 7.8814e-05
# Фаза 5: Train: 7.2333e-05, Test: 7.352e-05
# Фаза 6: Train: 8.47e-05, Test: 8.564e-05
# Фаза 7: Train: 7.505e-05, Test: 7.754e-05
# Фаза 8: Train: 0.00010236, Test: 0.00010211
# Фаза 9: Train: 0.00013015, Test: 0.00013056
# Фаза 10: Train: 5.2687e-05, Test: 5.3116e-05
# Фаза 11: Train: 7.4283e-05, Test: 7.4946e-05
# Фаза 12: Train: 6.7908e-05, Test: 6.9622e-05
# Прошло времени: 00:00:35
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00010464
# Epoch [8/300], learn_rate: [8.715724127386972e-05], Train Loss: 8.9521e-05, Test Loss: 9.0248e-05
# Фаза 1: Train: 0.00010343, Test: 0.00010434
# Фаза 2: Train: 9.817e-05, Test: 9.8588e-05
# Фаза 3: Train: 0.00013561, Test: 0.00013649
# Фаза 4: Train: 7.8718e-05, Test: 7.8754e-05
# Фаза 5: Train: 7.0445e-05, Test: 7.2423e-05
# Фаза 6: Train: 8.0543e-05, Test: 8.0747e-05
# Фаза 7: Train: 5.9755e-05, Test: 6.168e-05
# Фаза 8: Train: 0.00010528, Test: 0.00010476
# Фаза 9: Train: 0.00013459, Test: 0.00013541
# Фаза 10: Train: 5.248e-05, Test: 5.3228e-05
# Фаза 11: Train: 8.7785e-05, Test: 8.8273e-05
# Фаза 12: Train: 6.7447e-05, Test: 6.8292e-05
# Прошло времени: 00:00:40
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 9.6062e-05
# Epoch [9/300], learn_rate: [8.345653031794292e-05], Train Loss: 7.3798e-05, Test Loss: 7.479e-05
# Фаза 1: Train: 6.2334e-05, Test: 6.3811e-05
# Фаза 2: Train: 9.4746e-05, Test: 9.4631e-05
# Фаза 3: Train: 9.476e-05, Test: 9.6883e-05
# Фаза 4: Train: 6.9662e-05, Test: 7.0908e-05
# Фаза 5: Train: 6.4713e-05, Test: 6.6345e-05
# Фаза 6: Train: 6.4622e-05, Test: 6.6159e-05
# Фаза 7: Train: 5.9533e-05, Test: 6.1255e-05
# Фаза 8: Train: 0.00010127, Test: 0.00010129
# Фаза 9: Train: 9.3249e-05, Test: 9.3584e-05
# Фаза 10: Train: 5.2345e-05, Test: 5.1681e-05
# Фаза 11: Train: 6.0314e-05, Test: 6.0224e-05
# Фаза 12: Train: 6.8021e-05, Test: 7.0712e-05
# Прошло времени: 00:00:46
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 8.0683e-05
# Epoch [10/300], learn_rate: [7.938926261462366e-05], Train Loss: 7.0418e-05, Test Loss: 7.1735e-05
# Фаза 1: Train: 6.458e-05, Test: 6.745e-05
# Фаза 2: Train: 9.4428e-05, Test: 9.3998e-05
# Фаза 3: Train: 8.9529e-05, Test: 9.1886e-05
# Фаза 4: Train: 7.0586e-05, Test: 7.304e-05
# Фаза 5: Train: 7.6076e-05, Test: 7.6684e-05
# Фаза 6: Train: 5.6162e-05, Test: 5.7044e-05
# Фаза 7: Train: 4.6662e-05, Test: 4.9393e-05
# Фаза 8: Train: 9.0915e-05, Test: 8.9636e-05
# Фаза 9: Train: 9.6202e-05, Test: 9.74e-05
# Фаза 10: Train: 4.1451e-05, Test: 4.3355e-05
# Фаза 11: Train: 6.1552e-05, Test: 6.2386e-05
# Фаза 12: Train: 5.6869e-05, Test: 5.8543e-05
# Прошло времени: 00:00:51
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 8.3637e-05
# Epoch [11/300], learn_rate: [7.500000000000001e-05], Train Loss: 6.8916e-05, Test Loss: 6.9948e-05
# Фаза 1: Train: 5.4156e-05, Test: 5.5446e-05
# Фаза 2: Train: 0.00010663, Test: 0.0001046
# Фаза 3: Train: 9.2948e-05, Test: 9.4242e-05
# Фаза 4: Train: 5.7771e-05, Test: 5.9487e-05
# Фаза 5: Train: 7.4377e-05, Test: 7.5912e-05
# Фаза 6: Train: 5.6707e-05, Test: 5.7178e-05
# Фаза 7: Train: 5.0667e-05, Test: 5.3034e-05
# Фаза 8: Train: 8.4253e-05, Test: 8.5597e-05
# Фаза 9: Train: 7.7904e-05, Test: 7.9319e-05
# Фаза 10: Train: 5.096e-05, Test: 5.1901e-05
# Фаза 11: Train: 5.4689e-05, Test: 5.4333e-05
# Фаза 12: Train: 6.5933e-05, Test: 6.8332e-05
# Прошло времени: 00:00:56
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 9.8337e-05
# Epoch [12/300], learn_rate: [7.033683215379002e-05], Train Loss: 6.2866e-05, Test Loss: 6.4097e-05
# Фаза 1: Train: 5.0166e-05, Test: 5.2145e-05
# Фаза 2: Train: 8.7848e-05, Test: 8.7512e-05
# Фаза 3: Train: 7.9921e-05, Test: 8.1557e-05
# Фаза 4: Train: 6.4274e-05, Test: 6.5868e-05
# Фаза 5: Train: 7.2678e-05, Test: 7.542e-05
# Фаза 6: Train: 5.0265e-05, Test: 5.1042e-05
# Фаза 7: Train: 5.4093e-05, Test: 5.5867e-05
# Фаза 8: Train: 8.033e-05, Test: 8.0846e-05
# Фаза 9: Train: 7.6177e-05, Test: 7.6617e-05
# Фаза 10: Train: 4.129e-05, Test: 4.253e-05
# Фаза 11: Train: 4.905e-05, Test: 4.9406e-05
# Фаза 12: Train: 4.8301e-05, Test: 5.0355e-05
# Прошло времени: 00:01:02
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 9.4689e-05
# Epoch [13/300], learn_rate: [6.545084971874738e-05], Train Loss: 5.9475e-05, Test Loss: 6.042e-05
# Фаза 1: Train: 4.6517e-05, Test: 4.8187e-05
# Фаза 2: Train: 7.757e-05, Test: 7.7793e-05
# Фаза 3: Train: 9.0444e-05, Test: 9.1271e-05
# Фаза 4: Train: 7.7868e-05, Test: 7.8188e-05
# Фаза 5: Train: 4.8477e-05, Test: 4.9384e-05
# Фаза 6: Train: 5.0484e-05, Test: 5.0994e-05
# Фаза 7: Train: 3.7253e-05, Test: 3.9547e-05
# Фаза 8: Train: 7.2643e-05, Test: 7.2176e-05
# Фаза 9: Train: 8.1684e-05, Test: 8.2589e-05
# Фаза 10: Train: 3.307e-05, Test: 3.4397e-05
# Фаза 11: Train: 4.7413e-05, Test: 4.8269e-05
# Фаза 12: Train: 5.028e-05, Test: 5.2239e-05
# Прошло времени: 00:01:07
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 8.2774e-05
# Epoch [14/300], learn_rate: [6.0395584540887963e-05], Train Loss: 5.7489e-05, Test Loss: 5.8752e-05
# Фаза 1: Train: 6.1947e-05, Test: 6.4665e-05
# Фаза 2: Train: 7.3348e-05, Test: 7.3742e-05
# Фаза 3: Train: 7.1969e-05, Test: 7.3109e-05
# Фаза 4: Train: 5.0562e-05, Test: 5.3064e-05
# Фаза 5: Train: 4.8689e-05, Test: 5.0645e-05
# Фаза 6: Train: 5.1472e-05, Test: 5.1793e-05
# Фаза 7: Train: 4.2243e-05, Test: 4.3642e-05
# Фаза 8: Train: 8.2499e-05, Test: 8.3541e-05
# Фаза 9: Train: 7.5804e-05, Test: 7.6354e-05
# Фаза 10: Train: 3.7923e-05, Test: 3.9262e-05
# Фаза 11: Train: 4.9023e-05, Test: 4.9355e-05
# Фаза 12: Train: 4.4393e-05, Test: 4.5854e-05
# Прошло времени: 00:01:13
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 7.9809e-05
# Epoch [15/300], learn_rate: [5.522642316338268e-05], Train Loss: 5.9109e-05, Test Loss: 6.0204e-05
# Фаза 1: Train: 4.6188e-05, Test: 4.8016e-05
# Фаза 2: Train: 7.3716e-05, Test: 7.4425e-05
# Фаза 3: Train: 7.4826e-05, Test: 7.5786e-05
# Фаза 4: Train: 5.6988e-05, Test: 5.7418e-05
# Фаза 5: Train: 6.941e-05, Test: 7.163e-05
# Фаза 6: Train: 5.3824e-05, Test: 5.3519e-05
# Фаза 7: Train: 4.6662e-05, Test: 4.8524e-05
# Фаза 8: Train: 6.6182e-05, Test: 6.6387e-05
# Фаза 9: Train: 7.6042e-05, Test: 7.7782e-05
# Фаза 10: Train: 3.4115e-05, Test: 3.5203e-05
# Фаза 11: Train: 6.8936e-05, Test: 6.8974e-05
# Фаза 12: Train: 4.2421e-05, Test: 4.4785e-05
# Прошло времени: 00:01:18
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 8.203e-05
# Epoch [16/300], learn_rate: [5.0000000000000016e-05], Train Loss: 5.3587e-05, Test Loss: 5.4667e-05
# Фаза 1: Train: 4.2856e-05, Test: 4.455e-05
# Фаза 2: Train: 7.4168e-05, Test: 7.4729e-05
# Фаза 3: Train: 8.1349e-05, Test: 8.1926e-05
# Фаза 4: Train: 4.9572e-05, Test: 5.133e-05
# Фаза 5: Train: 4.6953e-05, Test: 4.925e-05
# Фаза 6: Train: 4.4306e-05, Test: 4.4551e-05
# Фаза 7: Train: 4.2335e-05, Test: 4.4245e-05
# Фаза 8: Train: 6.6567e-05, Test: 6.6576e-05
# Фаза 9: Train: 7.0169e-05, Test: 7.1539e-05
# Фаза 10: Train: 3.3973e-05, Test: 3.5009e-05
# Фаза 11: Train: 4.6167e-05, Test: 4.6569e-05
# Фаза 12: Train: 4.4631e-05, Test: 4.5735e-05
# Прошло времени: 00:01:23
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.5925e-05
# Epoch [17/300], learn_rate: [4.477357683661734e-05], Train Loss: 5.0472e-05, Test Loss: 5.1743e-05
# Фаза 1: Train: 4.0619e-05, Test: 4.2032e-05
# Фаза 2: Train: 6.5872e-05, Test: 6.6192e-05
# Фаза 3: Train: 6.8213e-05, Test: 6.9243e-05
# Фаза 4: Train: 4.7664e-05, Test: 4.9303e-05
# Фаза 5: Train: 4.0247e-05, Test: 4.2121e-05
# Фаза 6: Train: 4.9222e-05, Test: 5.0241e-05
# Фаза 7: Train: 4.4037e-05, Test: 4.6019e-05
# Фаза 8: Train: 7.015e-05, Test: 7.1577e-05
# Фаза 9: Train: 6.7601e-05, Test: 6.8317e-05
# Фаза 10: Train: 3.0688e-05, Test: 3.1906e-05
# Фаза 11: Train: 4.1965e-05, Test: 4.2379e-05
# Фаза 12: Train: 3.9386e-05, Test: 4.159e-05
# Прошло времени: 00:01:29
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.6543e-05
# Epoch [18/300], learn_rate: [3.9604415459112035e-05], Train Loss: 4.9686e-05, Test Loss: 5.1025e-05
# Фаза 1: Train: 4.7028e-05, Test: 4.9512e-05
# Фаза 2: Train: 6.3629e-05, Test: 6.4712e-05
# Фаза 3: Train: 6.0857e-05, Test: 6.2137e-05
# Фаза 4: Train: 4.6131e-05, Test: 4.7764e-05
# Фаза 5: Train: 4.3194e-05, Test: 4.5806e-05
# Фаза 6: Train: 3.9856e-05, Test: 4.0277e-05
# Фаза 7: Train: 4.2417e-05, Test: 4.4366e-05
# Фаза 8: Train: 5.8863e-05, Test: 5.943e-05
# Фаза 9: Train: 6.283e-05, Test: 6.3619e-05
# Фаза 10: Train: 3.1099e-05, Test: 3.2235e-05
# Фаза 11: Train: 4.1845e-05, Test: 4.2144e-05
# Фаза 12: Train: 5.8486e-05, Test: 6.0299e-05
# Прошло времени: 00:01:34
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.5263e-05
# Epoch [19/300], learn_rate: [3.4549150281252636e-05], Train Loss: 4.7129e-05, Test Loss: 4.8092e-05
# Фаза 1: Train: 3.8886e-05, Test: 4.037e-05
# Фаза 2: Train: 6.2274e-05, Test: 6.2242e-05
# Фаза 3: Train: 6.2741e-05, Test: 6.362e-05
# Фаза 4: Train: 4.4871e-05, Test: 4.6836e-05
# Фаза 5: Train: 5.3164e-05, Test: 5.5016e-05
# Фаза 6: Train: 3.79e-05, Test: 3.8499e-05
# Фаза 7: Train: 3.6392e-05, Test: 3.8356e-05
# Фаза 8: Train: 5.9162e-05, Test: 5.8774e-05
# Фаза 9: Train: 6.0065e-05, Test: 6.0966e-05
# Фаза 10: Train: 3.4625e-05, Test: 3.5357e-05
# Фаза 11: Train: 3.8796e-05, Test: 3.8491e-05
# Фаза 12: Train: 3.667e-05, Test: 3.8582e-05
# Прошло времени: 00:01:39
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.1199e-05
# Epoch [20/300], learn_rate: [2.9663167846209998e-05], Train Loss: 4.6616e-05, Test Loss: 4.7881e-05
# Фаза 1: Train: 3.5565e-05, Test: 3.767e-05
# Фаза 2: Train: 7.0091e-05, Test: 7.0643e-05
# Фаза 3: Train: 5.9015e-05, Test: 6.0268e-05
# Фаза 4: Train: 4.7146e-05, Test: 4.8901e-05
# Фаза 5: Train: 4.7995e-05, Test: 4.9807e-05
# Фаза 6: Train: 3.8446e-05, Test: 3.8898e-05
# Фаза 7: Train: 2.9188e-05, Test: 3.1721e-05
# Фаза 8: Train: 5.8164e-05, Test: 5.8923e-05
# Фаза 9: Train: 6.0845e-05, Test: 6.1627e-05
# Фаза 10: Train: 3.9892e-05, Test: 4.0655e-05
# Фаза 11: Train: 3.8005e-05, Test: 3.8677e-05
# Фаза 12: Train: 3.5034e-05, Test: 3.6786e-05
# Прошло времени: 00:01:44
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.8715e-05
# Epoch [21/300], learn_rate: [2.500000000000001e-05], Train Loss: 4.4063e-05, Test Loss: 4.5394e-05
# Фаза 1: Train: 3.6929e-05, Test: 3.9182e-05
# Фаза 2: Train: 6.0491e-05, Test: 6.0531e-05
# Фаза 3: Train: 5.7326e-05, Test: 5.8789e-05
# Фаза 4: Train: 4.5017e-05, Test: 4.6954e-05
# Фаза 5: Train: 3.997e-05, Test: 4.2031e-05
# Фаза 6: Train: 3.557e-05, Test: 3.6304e-05
# Фаза 7: Train: 3.0572e-05, Test: 3.303e-05
# Фаза 8: Train: 6.7754e-05, Test: 6.8883e-05
# Фаза 9: Train: 5.7125e-05, Test: 5.7966e-05
# Фаза 10: Train: 2.5925e-05, Test: 2.6988e-05
# Фаза 11: Train: 3.6796e-05, Test: 3.7417e-05
# Фаза 12: Train: 3.5286e-05, Test: 3.6649e-05
# Прошло времени: 00:01:50
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.5232e-05
# Epoch [22/300], learn_rate: [2.061073738537635e-05], Train Loss: 4.3046e-05, Test Loss: 4.4355e-05
# Фаза 1: Train: 3.4903e-05, Test: 3.6782e-05
# Фаза 2: Train: 5.8669e-05, Test: 5.9187e-05
# Фаза 3: Train: 5.7631e-05, Test: 5.954e-05
# Фаза 4: Train: 4.5933e-05, Test: 4.7435e-05
# Фаза 5: Train: 3.8395e-05, Test: 4.0737e-05
# Фаза 6: Train: 3.4375e-05, Test: 3.5055e-05
# Фаза 7: Train: 2.7897e-05, Test: 2.984e-05
# Фаза 8: Train: 5.5188e-05, Test: 5.5828e-05
# Фаза 9: Train: 6.8816e-05, Test: 6.9776e-05
# Фаза 10: Train: 2.5252e-05, Test: 2.6443e-05
# Фаза 11: Train: 3.5069e-05, Test: 3.5725e-05
# Фаза 12: Train: 3.443e-05, Test: 3.5917e-05
# Прошло времени: 00:01:55
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.2185e-05
# Epoch [23/300], learn_rate: [1.6543469682057106e-05], Train Loss: 4.2974e-05, Test Loss: 4.4185e-05
# Фаза 1: Train: 3.4731e-05, Test: 3.6389e-05
# Фаза 2: Train: 5.8296e-05, Test: 5.8518e-05
# Фаза 3: Train: 5.6466e-05, Test: 5.7613e-05
# Фаза 4: Train: 4.3611e-05, Test: 4.6001e-05
# Фаза 5: Train: 3.6865e-05, Test: 3.8687e-05
# Фаза 6: Train: 3.6036e-05, Test: 3.6423e-05
# Фаза 7: Train: 2.916e-05, Test: 3.0973e-05
# Фаза 8: Train: 5.9061e-05, Test: 6.0344e-05
# Фаза 9: Train: 6.4414e-05, Test: 6.5404e-05
# Фаза 10: Train: 2.5851e-05, Test: 2.6509e-05
# Фаза 11: Train: 3.5739e-05, Test: 3.6437e-05
# Фаза 12: Train: 3.5457e-05, Test: 3.692e-05
# Прошло времени: 00:02:00
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.2857e-05
# Epoch [24/300], learn_rate: [1.2842758726130299e-05], Train Loss: 4.1612e-05, Test Loss: 4.2912e-05
# Фаза 1: Train: 3.3849e-05, Test: 3.538e-05
# Фаза 2: Train: 5.64e-05, Test: 5.6926e-05
# Фаза 3: Train: 5.5984e-05, Test: 5.7525e-05
# Фаза 4: Train: 4.175e-05, Test: 4.4367e-05
# Фаза 5: Train: 3.6146e-05, Test: 3.8006e-05
# Фаза 6: Train: 3.9959e-05, Test: 4.0576e-05
# Фаза 7: Train: 2.8582e-05, Test: 3.0546e-05
# Фаза 8: Train: 5.3552e-05, Test: 5.4677e-05
# Фаза 9: Train: 5.7048e-05, Test: 5.8161e-05
# Фаза 10: Train: 2.5968e-05, Test: 2.7252e-05
# Фаза 11: Train: 3.7184e-05, Test: 3.7251e-05
# Фаза 12: Train: 3.2918e-05, Test: 3.4271e-05
# Прошло времени: 00:02:05
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.0151e-05
# Epoch [25/300], learn_rate: [9.549150281252633e-06], Train Loss: 4.0869e-05, Test Loss: 4.1965e-05
# Фаза 1: Train: 3.357e-05, Test: 3.5181e-05
# Фаза 2: Train: 5.6264e-05, Test: 5.6299e-05
# Фаза 3: Train: 5.5845e-05, Test: 5.7188e-05
# Фаза 4: Train: 4.4159e-05, Test: 4.5771e-05
# Фаза 5: Train: 3.444e-05, Test: 3.5838e-05
# Фаза 6: Train: 3.3979e-05, Test: 3.4457e-05
# Фаза 7: Train: 2.8742e-05, Test: 3.0718e-05
# Фаза 8: Train: 5.1896e-05, Test: 5.2777e-05
# Фаза 9: Train: 5.8132e-05, Test: 5.8902e-05
# Фаза 10: Train: 2.6404e-05, Test: 2.7592e-05
# Фаза 11: Train: 3.4051e-05, Test: 3.4318e-05
# Фаза 12: Train: 3.2944e-05, Test: 3.4536e-05
# Прошло времени: 00:02:11
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.2407e-05
# Epoch [26/300], learn_rate: [6.698729810778065e-06], Train Loss: 4.0221e-05, Test Loss: 4.1393e-05
# Фаза 1: Train: 3.2925e-05, Test: 3.4164e-05
# Фаза 2: Train: 5.6388e-05, Test: 5.6726e-05
# Фаза 3: Train: 5.3814e-05, Test: 5.4881e-05
# Фаза 4: Train: 3.9999e-05, Test: 4.2393e-05
# Фаза 5: Train: 3.6774e-05, Test: 3.8739e-05
# Фаза 6: Train: 3.6586e-05, Test: 3.7016e-05
# Фаза 7: Train: 2.7055e-05, Test: 2.9038e-05
# Фаза 8: Train: 5.2842e-05, Test: 5.3811e-05
# Фаза 9: Train: 5.2808e-05, Test: 5.3704e-05
# Фаза 10: Train: 2.7214e-05, Test: 2.7777e-05
# Фаза 11: Train: 3.3725e-05, Test: 3.4431e-05
# Фаза 12: Train: 3.2525e-05, Test: 3.4035e-05
# Прошло времени: 00:02:16
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.6083e-05
# Epoch [27/300], learn_rate: [4.322727117869951e-06], Train Loss: 3.9964e-05, Test Loss: 4.1304e-05
# Фаза 1: Train: 3.2719e-05, Test: 3.4235e-05
# Фаза 2: Train: 5.6848e-05, Test: 5.7154e-05
# Фаза 3: Train: 5.5498e-05, Test: 5.6837e-05
# Фаза 4: Train: 3.9645e-05, Test: 4.1926e-05
# Фаза 5: Train: 3.48e-05, Test: 3.6925e-05
# Фаза 6: Train: 3.2929e-05, Test: 3.3529e-05
# Фаза 7: Train: 2.6998e-05, Test: 2.928e-05
# Фаза 8: Train: 5.6068e-05, Test: 5.7301e-05
# Фаза 9: Train: 5.2856e-05, Test: 5.407e-05
# Фаза 10: Train: 2.4931e-05, Test: 2.5924e-05
# Фаза 11: Train: 3.5132e-05, Test: 3.5434e-05
# Фаза 12: Train: 3.1143e-05, Test: 3.3028e-05
# Прошло времени: 00:02:21
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.0951e-05
# Epoch [28/300], learn_rate: [2.4471741852423237e-06], Train Loss: 3.9548e-05, Test Loss: 4.0776e-05
# Фаза 1: Train: 3.2018e-05, Test: 3.3724e-05
# Фаза 2: Train: 5.6076e-05, Test: 5.6458e-05
# Фаза 3: Train: 5.352e-05, Test: 5.4851e-05
# Фаза 4: Train: 3.9471e-05, Test: 4.2124e-05
# Фаза 5: Train: 3.3938e-05, Test: 3.569e-05
# Фаза 6: Train: 3.4065e-05, Test: 3.4375e-05
# Фаза 7: Train: 2.7595e-05, Test: 2.9834e-05
# Фаза 8: Train: 5.2135e-05, Test: 5.2934e-05
# Фаза 9: Train: 5.269e-05, Test: 5.3383e-05
# Фаза 10: Train: 2.4584e-05, Test: 2.5746e-05
# Фаза 11: Train: 3.5267e-05, Test: 3.5552e-05
# Фаза 12: Train: 3.3218e-05, Test: 3.4645e-05
# Прошло времени: 00:02:26
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.1274e-05
# Epoch [29/300], learn_rate: [1.0926199633097157e-06], Train Loss: 3.942e-05, Test Loss: 4.061e-05
# Фаза 1: Train: 3.2073e-05, Test: 3.3655e-05
# Фаза 2: Train: 5.5658e-05, Test: 5.578e-05
# Фаза 3: Train: 5.3479e-05, Test: 5.4483e-05
# Фаза 4: Train: 4.1282e-05, Test: 4.3492e-05
# Фаза 5: Train: 3.5313e-05, Test: 3.7267e-05
# Фаза 6: Train: 3.3626e-05, Test: 3.4063e-05
# Фаза 7: Train: 2.7248e-05, Test: 2.8719e-05
# Фаза 8: Train: 5.1732e-05, Test: 5.2971e-05
# Фаза 9: Train: 5.3373e-05, Test: 5.4694e-05
# Фаза 10: Train: 2.4182e-05, Test: 2.5186e-05
# Фаза 11: Train: 3.375e-05, Test: 3.4157e-05
# Фаза 12: Train: 3.1322e-05, Test: 3.2855e-05
# Прошло времени: 00:02:32
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.1044e-05
# Epoch [30/300], learn_rate: [2.7390523158633e-07], Train Loss: 3.9293e-05, Test Loss: 4.0493e-05
# Фаза 1: Train: 3.2561e-05, Test: 3.408e-05
# Фаза 2: Train: 5.5236e-05, Test: 5.5388e-05
# Фаза 3: Train: 5.3428e-05, Test: 5.4744e-05
# Фаза 4: Train: 3.9835e-05, Test: 4.2212e-05
# Фаза 5: Train: 3.3679e-05, Test: 3.5722e-05
# Фаза 6: Train: 3.3996e-05, Test: 3.4512e-05
# Фаза 7: Train: 2.7512e-05, Test: 2.9245e-05
# Фаза 8: Train: 5.1674e-05, Test: 5.2757e-05
# Фаза 9: Train: 5.3528e-05, Test: 5.4474e-05
# Фаза 10: Train: 2.4391e-05, Test: 2.5269e-05
# Фаза 11: Train: 3.4114e-05, Test: 3.4381e-05
# Фаза 12: Train: 3.1564e-05, Test: 3.3134e-05
# Прошло времени: 00:02:37
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.4441e-05
# Epoch [31/300], learn_rate: [0.0001], Train Loss: 4.6481e-05, Test Loss: 4.7673e-05
# Фаза 1: Train: 4.292e-05, Test: 4.5218e-05
# Фаза 2: Train: 5.7502e-05, Test: 5.8203e-05
# Фаза 3: Train: 5.8262e-05, Test: 5.979e-05
# Фаза 4: Train: 4.5942e-05, Test: 4.8228e-05
# Фаза 5: Train: 4.067e-05, Test: 4.2355e-05
# Фаза 6: Train: 5.9513e-05, Test: 5.9117e-05
# Фаза 7: Train: 3.1041e-05, Test: 3.3126e-05
# Фаза 8: Train: 6.12e-05, Test: 6.1412e-05
# Фаза 9: Train: 5.8376e-05, Test: 5.9354e-05
# Фаза 10: Train: 2.7301e-05, Test: 2.8046e-05
# Фаза 11: Train: 3.949e-05, Test: 3.9823e-05
# Фаза 12: Train: 3.555e-05, Test: 3.7406e-05
# Прошло времени: 00:02:42
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00010491
# Epoch [32/300], learn_rate: [9.972609476841367e-05], Train Loss: 5.094e-05, Test Loss: 5.1972e-05
# Фаза 1: Train: 3.7202e-05, Test: 3.8221e-05
# Фаза 2: Train: 5.7602e-05, Test: 5.8403e-05
# Фаза 3: Train: 9.7911e-05, Test: 9.7719e-05
# Фаза 4: Train: 4.4958e-05, Test: 4.7836e-05
# Фаза 5: Train: 4.7721e-05, Test: 4.847e-05
# Фаза 6: Train: 3.6732e-05, Test: 3.6678e-05
# Фаза 7: Train: 3.1488e-05, Test: 3.3149e-05
# Фаза 8: Train: 5.1943e-05, Test: 5.285e-05
# Фаза 9: Train: 6.0378e-05, Test: 6.0868e-05
# Фаза 10: Train: 4.5648e-05, Test: 4.63e-05
# Фаза 11: Train: 5.5695e-05, Test: 5.7359e-05
# Фаза 12: Train: 4.4001e-05, Test: 4.581e-05
# Прошло времени: 00:02:48
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 9.9232e-05
# Epoch [33/300], learn_rate: [9.890738003669029e-05], Train Loss: 4.4908e-05, Test Loss: 4.5929e-05
# Фаза 1: Train: 4.2297e-05, Test: 4.4459e-05
# Фаза 2: Train: 6.4727e-05, Test: 6.392e-05
# Фаза 3: Train: 6.5635e-05, Test: 6.6092e-05
# Фаза 4: Train: 4.3173e-05, Test: 4.6211e-05
# Фаза 5: Train: 3.7109e-05, Test: 3.9193e-05
# Фаза 6: Train: 3.5346e-05, Test: 3.5402e-05
# Фаза 7: Train: 3.1205e-05, Test: 3.3235e-05
# Фаза 8: Train: 5.5758e-05, Test: 5.512e-05
# Фаза 9: Train: 5.4455e-05, Test: 5.5754e-05
# Фаза 10: Train: 2.8869e-05, Test: 3.0434e-05
# Фаза 11: Train: 4.0219e-05, Test: 4.0192e-05
# Фаза 12: Train: 4.0098e-05, Test: 4.1135e-05
# Прошло времени: 00:02:53
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 8.7859e-05
# Epoch [34/300], learn_rate: [9.755282581475769e-05], Train Loss: 4.9922e-05, Test Loss: 5.1252e-05
# Фаза 1: Train: 3.3445e-05, Test: 3.4737e-05
# Фаза 2: Train: 5.597e-05, Test: 5.7085e-05
# Фаза 3: Train: 5.5412e-05, Test: 5.6384e-05
# Фаза 4: Train: 4.3116e-05, Test: 4.5132e-05
# Фаза 5: Train: 6.9551e-05, Test: 7.1268e-05
# Фаза 6: Train: 6.3413e-05, Test: 6.4929e-05
# Фаза 7: Train: 4.6784e-05, Test: 4.9941e-05
# Фаза 8: Train: 5.7317e-05, Test: 5.7937e-05
# Фаза 9: Train: 5.522e-05, Test: 5.5839e-05
# Фаза 10: Train: 4.2952e-05, Test: 4.3829e-05
# Фаза 11: Train: 3.5291e-05, Test: 3.5807e-05
# Фаза 12: Train: 4.0596e-05, Test: 4.2132e-05
# Прошло времени: 00:02:58
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.9753e-05
# Epoch [35/300], learn_rate: [9.567727288213005e-05], Train Loss: 4.0191e-05, Test Loss: 4.1204e-05
# Фаза 1: Train: 3.9033e-05, Test: 4.1328e-05
# Фаза 2: Train: 5.6937e-05, Test: 5.5924e-05
# Фаза 3: Train: 5.3105e-05, Test: 5.4124e-05
# Фаза 4: Train: 4.1254e-05, Test: 4.2605e-05
# Фаза 5: Train: 3.4416e-05, Test: 3.6381e-05
# Фаза 6: Train: 3.5109e-05, Test: 3.4951e-05
# Фаза 7: Train: 2.9364e-05, Test: 3.103e-05
# Фаза 8: Train: 4.9409e-05, Test: 5.0353e-05
# Фаза 9: Train: 5.265e-05, Test: 5.3222e-05
# Фаза 10: Train: 2.5999e-05, Test: 2.684e-05
# Фаза 11: Train: 3.4341e-05, Test: 3.5124e-05
# Фаза 12: Train: 3.0671e-05, Test: 3.2566e-05
# Прошло времени: 00:03:03
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00013399
# Epoch [36/300], learn_rate: [9.330127018922194e-05], Train Loss: 4.4548e-05, Test Loss: 4.5553e-05
# Фаза 1: Train: 3.0558e-05, Test: 3.1911e-05
# Фаза 2: Train: 7.2242e-05, Test: 7.112e-05
# Фаза 3: Train: 6.2573e-05, Test: 6.3022e-05
# Фаза 4: Train: 5.2317e-05, Test: 5.4605e-05
# Фаза 5: Train: 4.1723e-05, Test: 4.2286e-05
# Фаза 6: Train: 3.6279e-05, Test: 3.6626e-05
# Фаза 7: Train: 2.5169e-05, Test: 2.7005e-05
# Фаза 8: Train: 5.8792e-05, Test: 6.0074e-05
# Фаза 9: Train: 5.9521e-05, Test: 6.0342e-05
# Фаза 10: Train: 2.5606e-05, Test: 2.7137e-05
# Фаза 11: Train: 3.3018e-05, Test: 3.3787e-05
# Фаза 12: Train: 3.6777e-05, Test: 3.8724e-05
# Прошло времени: 00:03:09
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.7934e-05
# Epoch [37/300], learn_rate: [9.045084971874738e-05], Train Loss: 4.1144e-05, Test Loss: 4.1902e-05
# Фаза 1: Train: 2.8696e-05, Test: 3.0044e-05
# Фаза 2: Train: 7.1249e-05, Test: 6.9166e-05
# Фаза 3: Train: 4.8046e-05, Test: 4.8413e-05
# Фаза 4: Train: 3.8505e-05, Test: 4.0487e-05
# Фаза 5: Train: 4.1805e-05, Test: 4.3066e-05
# Фаза 6: Train: 3.0152e-05, Test: 3.0369e-05
# Фаза 7: Train: 2.6637e-05, Test: 2.8545e-05
# Фаза 8: Train: 5.0125e-05, Test: 5.0576e-05
# Фаза 9: Train: 4.5814e-05, Test: 4.6831e-05
# Фаза 10: Train: 2.2461e-05, Test: 2.3625e-05
# Фаза 11: Train: 5.7776e-05, Test: 5.7495e-05
# Фаза 12: Train: 3.2459e-05, Test: 3.4211e-05
# Прошло времени: 00:03:14
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 7.5659e-05
# Epoch [38/300], learn_rate: [8.715724127386972e-05], Train Loss: 4.8281e-05, Test Loss: 4.9771e-05
# Фаза 1: Train: 2.9496e-05, Test: 3.1956e-05
# Фаза 2: Train: 5.1989e-05, Test: 5.2188e-05
# Фаза 3: Train: 5.8103e-05, Test: 5.9182e-05
# Фаза 4: Train: 4.0938e-05, Test: 4.2946e-05
# Фаза 5: Train: 5.6224e-05, Test: 5.9271e-05
# Фаза 6: Train: 4.8729e-05, Test: 4.9714e-05
# Фаза 7: Train: 4.3822e-05, Test: 4.5536e-05
# Фаза 8: Train: 9.0152e-05, Test: 9.0987e-05
# Фаза 9: Train: 5.3571e-05, Test: 5.4689e-05
# Фаза 10: Train: 3.2584e-05, Test: 3.4954e-05
# Фаза 11: Train: 3.8141e-05, Test: 3.9254e-05
# Фаза 12: Train: 3.5628e-05, Test: 3.6576e-05
# Прошло времени: 00:03:19
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 8.9391e-05
# Epoch [39/300], learn_rate: [8.345653031794292e-05], Train Loss: 3.8019e-05, Test Loss: 3.9157e-05
# Фаза 1: Train: 4.7261e-05, Test: 4.9027e-05
# Фаза 2: Train: 5.2266e-05, Test: 5.181e-05
# Фаза 3: Train: 5.1633e-05, Test: 5.2363e-05
# Фаза 4: Train: 3.9209e-05, Test: 4.1741e-05
# Фаза 5: Train: 3.413e-05, Test: 3.5496e-05
# Фаза 6: Train: 2.727e-05, Test: 2.7624e-05
# Фаза 7: Train: 2.5636e-05, Test: 2.7806e-05
# Фаза 8: Train: 4.4722e-05, Test: 4.5736e-05
# Фаза 9: Train: 4.4841e-05, Test: 4.5551e-05
# Фаза 10: Train: 3.2589e-05, Test: 3.4276e-05
# Фаза 11: Train: 3.1099e-05, Test: 3.1365e-05
# Фаза 12: Train: 2.5568e-05, Test: 2.7083e-05
# Прошло времени: 00:03:24
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 7.5016e-05
# Epoch [40/300], learn_rate: [7.938926261462366e-05], Train Loss: 3.7384e-05, Test Loss: 3.8477e-05
# Фаза 1: Train: 3.0011e-05, Test: 3.1366e-05
# Фаза 2: Train: 4.7695e-05, Test: 4.7618e-05
# Фаза 3: Train: 4.9732e-05, Test: 5.0666e-05
# Фаза 4: Train: 3.5038e-05, Test: 3.7645e-05
# Фаза 5: Train: 3.4186e-05, Test: 3.6063e-05
# Фаза 6: Train: 2.7522e-05, Test: 2.8024e-05
# Фаза 7: Train: 2.4389e-05, Test: 2.6588e-05
# Фаза 8: Train: 5.3774e-05, Test: 5.4072e-05
# Фаза 9: Train: 5.3089e-05, Test: 5.4393e-05
# Фаза 10: Train: 2.9361e-05, Test: 3.0163e-05
# Фаза 11: Train: 3.7011e-05, Test: 3.7013e-05
# Фаза 12: Train: 2.6796e-05, Test: 2.8112e-05
# Прошло времени: 00:03:30
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.7089e-05
# Epoch [41/300], learn_rate: [7.500000000000001e-05], Train Loss: 3.557e-05, Test Loss: 3.6461e-05
# Фаза 1: Train: 2.6199e-05, Test: 2.7622e-05
# Фаза 2: Train: 6.8333e-05, Test: 6.6835e-05
# Фаза 3: Train: 4.4151e-05, Test: 4.4989e-05
# Фаза 4: Train: 4.4854e-05, Test: 4.5755e-05
# Фаза 5: Train: 2.8118e-05, Test: 2.9654e-05
# Фаза 6: Train: 2.7532e-05, Test: 2.8045e-05
# Фаза 7: Train: 2.1358e-05, Test: 2.3031e-05
# Фаза 8: Train: 4.1851e-05, Test: 4.2455e-05
# Фаза 9: Train: 4.3244e-05, Test: 4.4513e-05
# Фаза 10: Train: 2.0738e-05, Test: 2.1971e-05
# Фаза 11: Train: 3.4275e-05, Test: 3.4702e-05
# Фаза 12: Train: 2.6191e-05, Test: 2.7961e-05
# Прошло времени: 00:03:35
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.9699e-05
# Epoch [42/300], learn_rate: [7.033683215379002e-05], Train Loss: 3.5799e-05, Test Loss: 3.6726e-05
# Фаза 1: Train: 2.6524e-05, Test: 2.7942e-05
# Фаза 2: Train: 5.9102e-05, Test: 5.8098e-05
# Фаза 3: Train: 4.3851e-05, Test: 4.526e-05
# Фаза 4: Train: 3.4786e-05, Test: 3.6072e-05
# Фаза 5: Train: 3.9834e-05, Test: 4.1714e-05
# Фаза 6: Train: 2.7439e-05, Test: 2.7926e-05
# Фаза 7: Train: 2.2123e-05, Test: 2.3416e-05
# Фаза 8: Train: 4.3939e-05, Test: 4.4083e-05
# Фаза 9: Train: 5.3224e-05, Test: 5.4094e-05
# Фаза 10: Train: 1.9845e-05, Test: 2.0964e-05
# Фаза 11: Train: 2.6967e-05, Test: 2.7348e-05
# Фаза 12: Train: 3.1955e-05, Test: 3.3798e-05
# Прошло времени: 00:03:40
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 7.7706e-05
# Epoch [43/300], learn_rate: [6.545084971874738e-05], Train Loss: 3.4345e-05, Test Loss: 3.5554e-05
# Фаза 1: Train: 2.6891e-05, Test: 2.8053e-05
# Фаза 2: Train: 4.4608e-05, Test: 4.5602e-05
# Фаза 3: Train: 4.161e-05, Test: 4.2766e-05
# Фаза 4: Train: 4.2376e-05, Test: 4.368e-05
# Фаза 5: Train: 2.8681e-05, Test: 3.0201e-05
# Фаза 6: Train: 2.5859e-05, Test: 2.6503e-05
# Фаза 7: Train: 2.1325e-05, Test: 2.3406e-05
# Фаза 8: Train: 5.6573e-05, Test: 5.7571e-05
# Фаза 9: Train: 4.5509e-05, Test: 4.7092e-05
# Фаза 10: Train: 2.3161e-05, Test: 2.4536e-05
# Фаза 11: Train: 2.8694e-05, Test: 2.9134e-05
# Фаза 12: Train: 2.6854e-05, Test: 2.8098e-05
# Прошло времени: 00:03:45
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.7477e-05
# Epoch [44/300], learn_rate: [6.0395584540887963e-05], Train Loss: 3.3198e-05, Test Loss: 3.445e-05
# Фаза 1: Train: 3.0108e-05, Test: 3.2638e-05
# Фаза 2: Train: 4.1755e-05, Test: 4.1973e-05
# Фаза 3: Train: 4.8867e-05, Test: 5.0031e-05
# Фаза 4: Train: 3.4068e-05, Test: 3.6244e-05
# Фаза 5: Train: 3.0942e-05, Test: 3.2049e-05
# Фаза 6: Train: 3.2038e-05, Test: 3.3312e-05
# Фаза 7: Train: 2.5415e-05, Test: 2.7484e-05
# Фаза 8: Train: 4.0408e-05, Test: 4.1691e-05
# Фаза 9: Train: 4.3353e-05, Test: 4.3912e-05
# Фаза 10: Train: 1.9618e-05, Test: 2.0737e-05
# Фаза 11: Train: 2.6235e-05, Test: 2.6398e-05
# Фаза 12: Train: 2.5569e-05, Test: 2.6933e-05
# Прошло времени: 00:03:51
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.9498e-05
# Epoch [45/300], learn_rate: [5.522642316338268e-05], Train Loss: 3.2327e-05, Test Loss: 3.319e-05
# Фаза 1: Train: 2.3439e-05, Test: 2.4964e-05
# Фаза 2: Train: 4.381e-05, Test: 4.4102e-05
# Фаза 3: Train: 3.9006e-05, Test: 3.9854e-05
# Фаза 4: Train: 3.4175e-05, Test: 3.5721e-05
# Фаза 5: Train: 2.5898e-05, Test: 2.7031e-05
# Фаза 6: Train: 2.4941e-05, Test: 2.5296e-05
# Фаза 7: Train: 3.2208e-05, Test: 3.4079e-05
# Фаза 8: Train: 3.8022e-05, Test: 3.7833e-05
# Фаза 9: Train: 4.5843e-05, Test: 4.5901e-05
# Фаза 10: Train: 2.0176e-05, Test: 2.1539e-05
# Фаза 11: Train: 2.7537e-05, Test: 2.7918e-05
# Фаза 12: Train: 3.2872e-05, Test: 3.4042e-05
# Прошло времени: 00:03:56
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.4101e-05
# Epoch [46/300], learn_rate: [5.0000000000000016e-05], Train Loss: 3.4655e-05, Test Loss: 3.5627e-05
# Фаза 1: Train: 2.3521e-05, Test: 2.5002e-05
# Фаза 2: Train: 6.1431e-05, Test: 6.0074e-05
# Фаза 3: Train: 4.264e-05, Test: 4.3746e-05
# Фаза 4: Train: 3.3842e-05, Test: 3.5447e-05
# Фаза 5: Train: 2.7719e-05, Test: 2.8733e-05
# Фаза 6: Train: 3.1372e-05, Test: 3.2338e-05
# Фаза 7: Train: 1.956e-05, Test: 2.1645e-05
# Фаза 8: Train: 3.6502e-05, Test: 3.6894e-05
# Фаза 9: Train: 4.9465e-05, Test: 5.0212e-05
# Фаза 10: Train: 3.163e-05, Test: 3.3053e-05
# Фаза 11: Train: 2.5301e-05, Test: 2.6009e-05
# Фаза 12: Train: 3.2872e-05, Test: 3.437e-05
# Прошло времени: 00:04:01
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.7697e-05
# Epoch [47/300], learn_rate: [4.477357683661734e-05], Train Loss: 3.0169e-05, Test Loss: 3.1286e-05
# Фаза 1: Train: 2.5452e-05, Test: 2.7098e-05
# Фаза 2: Train: 3.7101e-05, Test: 3.7541e-05
# Фаза 3: Train: 3.8873e-05, Test: 3.9683e-05
# Фаза 4: Train: 3.1395e-05, Test: 3.294e-05
# Фаза 5: Train: 3.434e-05, Test: 3.5673e-05
# Фаза 6: Train: 2.2718e-05, Test: 2.3151e-05
# Фаза 7: Train: 2.3437e-05, Test: 2.5517e-05
# Фаза 8: Train: 3.6188e-05, Test: 3.6578e-05
# Фаза 9: Train: 4.5388e-05, Test: 4.6082e-05
# Фаза 10: Train: 1.8145e-05, Test: 1.9593e-05
# Фаза 11: Train: 2.5581e-05, Test: 2.6655e-05
# Фаза 12: Train: 2.3407e-05, Test: 2.4922e-05
# Прошло времени: 00:04:07
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 7.6578e-05
# Epoch [48/300], learn_rate: [3.9604415459112035e-05], Train Loss: 3.4862e-05, Test Loss: 3.6073e-05
# Фаза 1: Train: 3.0747e-05, Test: 3.2794e-05
# Фаза 2: Train: 4.4503e-05, Test: 4.4412e-05
# Фаза 3: Train: 5.0252e-05, Test: 5.1335e-05
# Фаза 4: Train: 3.5673e-05, Test: 3.7783e-05
# Фаза 5: Train: 4.706e-05, Test: 4.8382e-05
# Фаза 6: Train: 2.3709e-05, Test: 2.4387e-05
# Фаза 7: Train: 2.159e-05, Test: 2.3437e-05
# Фаза 8: Train: 3.7139e-05, Test: 3.7556e-05
# Фаза 9: Train: 5.4847e-05, Test: 5.5939e-05
# Фаза 10: Train: 2.0266e-05, Test: 2.1515e-05
# Фаза 11: Train: 2.8972e-05, Test: 2.9804e-05
# Фаза 12: Train: 2.3581e-05, Test: 2.5527e-05
# Прошло времени: 00:04:12
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.9239e-05
# Epoch [49/300], learn_rate: [3.4549150281252636e-05], Train Loss: 2.9669e-05, Test Loss: 3.0615e-05
# Фаза 1: Train: 2.248e-05, Test: 2.3918e-05
# Фаза 2: Train: 3.7658e-05, Test: 3.8198e-05
# Фаза 3: Train: 4.2728e-05, Test: 4.3538e-05
# Фаза 4: Train: 4.3545e-05, Test: 4.477e-05
# Фаза 5: Train: 2.4286e-05, Test: 2.5545e-05
# Фаза 6: Train: 2.1541e-05, Test: 2.198e-05
# Фаза 7: Train: 2.1346e-05, Test: 2.2989e-05
# Фаза 8: Train: 3.6855e-05, Test: 3.6959e-05
# Фаза 9: Train: 3.7737e-05, Test: 3.8971e-05
# Фаза 10: Train: 1.9058e-05, Test: 1.9952e-05
# Фаза 11: Train: 2.4305e-05, Test: 2.5024e-05
# Фаза 12: Train: 2.4491e-05, Test: 2.554e-05
# Прошло времени: 00:04:17
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.5088e-05
# Epoch [50/300], learn_rate: [2.9663167846209998e-05], Train Loss: 2.8728e-05, Test Loss: 2.971e-05
# Фаза 1: Train: 2.1701e-05, Test: 2.2823e-05
# Фаза 2: Train: 4.3632e-05, Test: 4.3556e-05
# Фаза 3: Train: 3.7066e-05, Test: 3.8023e-05
# Фаза 4: Train: 3.2455e-05, Test: 3.3914e-05
# Фаза 5: Train: 2.3608e-05, Test: 2.4753e-05
# Фаза 6: Train: 2.1343e-05, Test: 2.1956e-05
# Фаза 7: Train: 1.8338e-05, Test: 2.0293e-05
# Фаза 8: Train: 3.5063e-05, Test: 3.5672e-05
# Фаза 9: Train: 4.4247e-05, Test: 4.4652e-05
# Фаза 10: Train: 2.0663e-05, Test: 2.1617e-05
# Фаза 11: Train: 2.2845e-05, Test: 2.3471e-05
# Фаза 12: Train: 2.3773e-05, Test: 2.5787e-05
# Прошло времени: 00:04:23
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.0479e-05
# Epoch [51/300], learn_rate: [2.500000000000001e-05], Train Loss: 2.775e-05, Test Loss: 2.8848e-05
# Фаза 1: Train: 2.1714e-05, Test: 2.3403e-05
# Фаза 2: Train: 4.1725e-05, Test: 4.1517e-05
# Фаза 3: Train: 3.5966e-05, Test: 3.6946e-05
# Фаза 4: Train: 3.0337e-05, Test: 3.2218e-05
# Фаза 5: Train: 2.3303e-05, Test: 2.4575e-05
# Фаза 6: Train: 2.624e-05, Test: 2.6833e-05
# Фаза 7: Train: 1.7412e-05, Test: 1.9416e-05
# Фаза 8: Train: 3.9722e-05, Test: 4.0451e-05
# Фаза 9: Train: 3.6286e-05, Test: 3.705e-05
# Фаза 10: Train: 1.6897e-05, Test: 1.8228e-05
# Фаза 11: Train: 2.2902e-05, Test: 2.3439e-05
# Фаза 12: Train: 2.0502e-05, Test: 2.2102e-05
# Прошло времени: 00:04:28
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.2301e-05
# Epoch [52/300], learn_rate: [2.061073738537635e-05], Train Loss: 2.7177e-05, Test Loss: 2.8099e-05
# Фаза 1: Train: 2.1156e-05, Test: 2.2293e-05
# Фаза 2: Train: 3.9944e-05, Test: 4.0006e-05
# Фаза 3: Train: 3.6237e-05, Test: 3.7256e-05
# Фаза 4: Train: 3.3197e-05, Test: 3.4504e-05
# Фаза 5: Train: 2.5599e-05, Test: 2.6714e-05
# Фаза 6: Train: 2.175e-05, Test: 2.2166e-05
# Фаза 7: Train: 1.7046e-05, Test: 1.9116e-05
# Фаза 8: Train: 3.4794e-05, Test: 3.4674e-05
# Фаза 9: Train: 3.5839e-05, Test: 3.6906e-05
# Фаза 10: Train: 1.8111e-05, Test: 1.9045e-05
# Фаза 11: Train: 2.1887e-05, Test: 2.2453e-05
# Фаза 12: Train: 2.0561e-05, Test: 2.2059e-05
# Прошло времени: 00:04:33
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.2574e-05
# Epoch [53/300], learn_rate: [1.6543469682057106e-05], Train Loss: 2.722e-05, Test Loss: 2.812e-05
# Фаза 1: Train: 2.1318e-05, Test: 2.249e-05
# Фаза 2: Train: 3.5947e-05, Test: 3.596e-05
# Фаза 3: Train: 3.5643e-05, Test: 3.6374e-05
# Фаза 4: Train: 3.0842e-05, Test: 3.2583e-05
# Фаза 5: Train: 2.3563e-05, Test: 2.4388e-05
# Фаза 6: Train: 2.1113e-05, Test: 2.1572e-05
# Фаза 7: Train: 1.9388e-05, Test: 2.0976e-05
# Фаза 8: Train: 3.3301e-05, Test: 3.38e-05
# Фаза 9: Train: 3.7645e-05, Test: 3.8446e-05
# Фаза 10: Train: 1.8195e-05, Test: 1.9255e-05
# Фаза 11: Train: 2.1924e-05, Test: 2.2475e-05
# Фаза 12: Train: 2.7757e-05, Test: 2.9126e-05
# Прошло времени: 00:04:38
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.3728e-05
# Epoch [54/300], learn_rate: [1.2842758726130299e-05], Train Loss: 2.6156e-05, Test Loss: 2.7271e-05
# Фаза 1: Train: 2.0498e-05, Test: 2.1832e-05
# Фаза 2: Train: 3.4618e-05, Test: 3.5268e-05
# Фаза 3: Train: 3.5353e-05, Test: 3.6094e-05
# Фаза 4: Train: 3.1391e-05, Test: 3.3245e-05
# Фаза 5: Train: 2.3649e-05, Test: 2.4747e-05
# Фаза 6: Train: 2.1338e-05, Test: 2.1833e-05
# Фаза 7: Train: 1.6724e-05, Test: 1.8682e-05
# Фаза 8: Train: 3.4697e-05, Test: 3.5518e-05
# Фаза 9: Train: 3.4308e-05, Test: 3.559e-05
# Фаза 10: Train: 1.7388e-05, Test: 1.8492e-05
# Фаза 11: Train: 2.1328e-05, Test: 2.199e-05
# Фаза 12: Train: 2.2583e-05, Test: 2.3961e-05
# Прошло времени: 00:04:44
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.6301e-05
# Epoch [55/300], learn_rate: [9.549150281252633e-06], Train Loss: 2.6436e-05, Test Loss: 2.7475e-05
# Фаза 1: Train: 2.448e-05, Test: 2.6161e-05
# Фаза 2: Train: 3.4451e-05, Test: 3.5015e-05
# Фаза 3: Train: 3.6113e-05, Test: 3.7067e-05
# Фаза 4: Train: 3.3738e-05, Test: 3.484e-05
# Фаза 5: Train: 2.1779e-05, Test: 2.2929e-05
# Фаза 6: Train: 2.1121e-05, Test: 2.1799e-05
# Фаза 7: Train: 1.7256e-05, Test: 1.9072e-05
# Фаза 8: Train: 3.2575e-05, Test: 3.3007e-05
# Фаза 9: Train: 3.5794e-05, Test: 3.6786e-05
# Фаза 10: Train: 1.7485e-05, Test: 1.8582e-05
# Фаза 11: Train: 2.2237e-05, Test: 2.2914e-05
# Фаза 12: Train: 2.0205e-05, Test: 2.1528e-05
# Прошло времени: 00:04:49
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.2975e-05
# Epoch [56/300], learn_rate: [6.698729810778065e-06], Train Loss: 2.6028e-05, Test Loss: 2.6998e-05
# Фаза 1: Train: 2.3169e-05, Test: 2.4325e-05
# Фаза 2: Train: 3.5445e-05, Test: 3.5878e-05
# Фаза 3: Train: 3.659e-05, Test: 3.7097e-05
# Фаза 4: Train: 2.9371e-05, Test: 3.1253e-05
# Фаза 5: Train: 2.2265e-05, Test: 2.3473e-05
# Фаза 6: Train: 2.0308e-05, Test: 2.0782e-05
# Фаза 7: Train: 1.7468e-05, Test: 1.9361e-05
# Фаза 8: Train: 3.3229e-05, Test: 3.3411e-05
# Фаза 9: Train: 3.4568e-05, Test: 3.525e-05
# Фаза 10: Train: 1.6635e-05, Test: 1.7649e-05
# Фаза 11: Train: 2.1812e-05, Test: 2.2519e-05
# Фаза 12: Train: 2.147e-05, Test: 2.2972e-05
# Прошло времени: 00:04:54
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.1738e-05
# Epoch [57/300], learn_rate: [4.322727117869951e-06], Train Loss: 2.5447e-05, Test Loss: 2.6458e-05
# Фаза 1: Train: 1.9769e-05, Test: 2.1111e-05
# Фаза 2: Train: 3.4086e-05, Test: 3.4469e-05
# Фаза 3: Train: 3.5995e-05, Test: 3.6582e-05
# Фаза 4: Train: 2.9287e-05, Test: 3.1055e-05
# Фаза 5: Train: 2.3779e-05, Test: 2.4857e-05
# Фаза 6: Train: 1.9823e-05, Test: 2.0442e-05
# Фаза 7: Train: 1.6978e-05, Test: 1.8729e-05
# Фаза 8: Train: 3.2807e-05, Test: 3.3457e-05
# Фаза 9: Train: 3.4116e-05, Test: 3.5227e-05
# Фаза 10: Train: 1.6411e-05, Test: 1.7576e-05
# Фаза 11: Train: 2.226e-05, Test: 2.247e-05
# Фаза 12: Train: 2.0047e-05, Test: 2.1519e-05
# Прошло времени: 00:04:59
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.3652e-05
# Epoch [58/300], learn_rate: [2.4471741852423237e-06], Train Loss: 2.5326e-05, Test Loss: 2.6371e-05
# Фаза 1: Train: 2.055e-05, Test: 2.1651e-05
# Фаза 2: Train: 3.3829e-05, Test: 3.4331e-05
# Фаза 3: Train: 3.494e-05, Test: 3.5672e-05
# Фаза 4: Train: 2.9062e-05, Test: 3.0821e-05
# Фаза 5: Train: 2.2275e-05, Test: 2.3341e-05
# Фаза 6: Train: 2.104e-05, Test: 2.1786e-05
# Фаза 7: Train: 1.7321e-05, Test: 1.9103e-05
# Фаза 8: Train: 3.2627e-05, Test: 3.3267e-05
# Фаза 9: Train: 3.4142e-05, Test: 3.507e-05
# Фаза 10: Train: 1.6736e-05, Test: 1.7829e-05
# Фаза 11: Train: 2.1786e-05, Test: 2.2573e-05
# Фаза 12: Train: 1.9604e-05, Test: 2.1014e-05
# Прошло времени: 00:05:05
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.0733e-05
# Epoch [59/300], learn_rate: [1.0926199633097157e-06], Train Loss: 2.5209e-05, Test Loss: 2.6231e-05
# Фаза 1: Train: 2.0097e-05, Test: 2.1525e-05
# Фаза 2: Train: 3.3902e-05, Test: 3.4558e-05
# Фаза 3: Train: 3.5174e-05, Test: 3.6086e-05
# Фаза 4: Train: 3.0253e-05, Test: 3.1776e-05
# Фаза 5: Train: 2.2115e-05, Test: 2.2809e-05
# Фаза 6: Train: 2.0643e-05, Test: 2.1117e-05
# Фаза 7: Train: 1.6338e-05, Test: 1.8191e-05
# Фаза 8: Train: 3.2401e-05, Test: 3.2898e-05
# Фаза 9: Train: 3.406e-05, Test: 3.5156e-05
# Фаза 10: Train: 1.6489e-05, Test: 1.7361e-05
# Фаза 11: Train: 2.1572e-05, Test: 2.215e-05
# Фаза 12: Train: 1.946e-05, Test: 2.1144e-05
# Прошло времени: 00:05:10
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.2639e-05
# Epoch [60/300], learn_rate: [2.7390523158633e-07], Train Loss: 2.5162e-05, Test Loss: 2.616e-05
# Фаза 1: Train: 2.0389e-05, Test: 2.1467e-05
# Фаза 2: Train: 3.4257e-05, Test: 3.4553e-05
# Фаза 3: Train: 3.4675e-05, Test: 3.5465e-05
# Фаза 4: Train: 2.8998e-05, Test: 3.0567e-05
# Фаза 5: Train: 2.2346e-05, Test: 2.32e-05
# Фаза 6: Train: 2.0296e-05, Test: 2.0965e-05
# Фаза 7: Train: 1.6495e-05, Test: 1.8312e-05
# Фаза 8: Train: 3.2384e-05, Test: 3.3141e-05
# Фаза 9: Train: 3.4669e-05, Test: 3.55e-05
# Фаза 10: Train: 1.6163e-05, Test: 1.7392e-05
# Фаза 11: Train: 2.1645e-05, Test: 2.208e-05
# Фаза 12: Train: 1.9625e-05, Test: 2.1277e-05
# Прошло времени: 00:05:15
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 7.3073e-05
# Epoch [61/300], learn_rate: [0.0001], Train Loss: 3.813e-05, Test Loss: 3.9259e-05
# Фаза 1: Train: 7.6804e-05, Test: 7.8783e-05
# Фаза 2: Train: 3.9396e-05, Test: 3.9631e-05
# Фаза 3: Train: 4.4767e-05, Test: 4.4897e-05
# Фаза 4: Train: 4.016e-05, Test: 4.1881e-05
# Фаза 5: Train: 3.6694e-05, Test: 3.8764e-05
# Фаза 6: Train: 2.8061e-05, Test: 2.8451e-05
# Фаза 7: Train: 3.3811e-05, Test: 3.5662e-05
# Фаза 8: Train: 4.0603e-05, Test: 4.0899e-05
# Фаза 9: Train: 3.6825e-05, Test: 3.7476e-05
# Фаза 10: Train: 2.6866e-05, Test: 2.8741e-05
# Фаза 11: Train: 2.792e-05, Test: 2.8931e-05
# Фаза 12: Train: 2.5654e-05, Test: 2.6989e-05
# Прошло времени: 00:05:20
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.4802e-05
# Epoch [62/300], learn_rate: [9.972609476841367e-05], Train Loss: 3.2154e-05, Test Loss: 3.3358e-05
# Фаза 1: Train: 2.668e-05, Test: 2.8301e-05
# Фаза 2: Train: 4.7384e-05, Test: 4.7164e-05
# Фаза 3: Train: 4.8243e-05, Test: 5.0004e-05
# Фаза 4: Train: 3.1127e-05, Test: 3.2625e-05
# Фаза 5: Train: 2.4924e-05, Test: 2.6315e-05
# Фаза 6: Train: 2.4393e-05, Test: 2.4697e-05
# Фаза 7: Train: 2.0041e-05, Test: 2.1354e-05
# Фаза 8: Train: 4.4431e-05, Test: 4.5159e-05
# Фаза 9: Train: 5.0237e-05, Test: 5.2221e-05
# Фаза 10: Train: 1.8156e-05, Test: 1.9412e-05
# Фаза 11: Train: 2.743e-05, Test: 2.8559e-05
# Фаза 12: Train: 2.2797e-05, Test: 2.4484e-05
# Прошло времени: 00:05:26
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 7.9506e-05
# Epoch [63/300], learn_rate: [9.890738003669029e-05], Train Loss: 3.3513e-05, Test Loss: 3.4486e-05
# Фаза 1: Train: 2.5862e-05, Test: 2.679e-05
# Фаза 2: Train: 3.5837e-05, Test: 3.5549e-05
# Фаза 3: Train: 3.7866e-05, Test: 3.8706e-05
# Фаза 4: Train: 3.3183e-05, Test: 3.4653e-05
# Фаза 5: Train: 2.7948e-05, Test: 2.8785e-05
# Фаза 6: Train: 3.1206e-05, Test: 3.1586e-05
# Фаза 7: Train: 2.3859e-05, Test: 2.6094e-05
# Фаза 8: Train: 5.361e-05, Test: 5.4461e-05
# Фаза 9: Train: 3.9472e-05, Test: 4.0418e-05
# Фаза 10: Train: 2.2209e-05, Test: 2.284e-05
# Фаза 11: Train: 4.4033e-05, Test: 4.4047e-05
# Фаза 12: Train: 2.7074e-05, Test: 2.9905e-05
# Прошло времени: 00:05:31
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.9956e-05
# Epoch [64/300], learn_rate: [9.755282581475769e-05], Train Loss: 2.8986e-05, Test Loss: 2.9974e-05
# Фаза 1: Train: 2.5354e-05, Test: 2.6753e-05
# Фаза 2: Train: 4.1897e-05, Test: 4.1629e-05
# Фаза 3: Train: 3.7593e-05, Test: 3.8543e-05
# Фаза 4: Train: 3.4482e-05, Test: 3.6219e-05
# Фаза 5: Train: 2.3962e-05, Test: 2.4972e-05
# Фаза 6: Train: 3.5306e-05, Test: 3.5675e-05
# Фаза 7: Train: 1.7701e-05, Test: 1.9662e-05
# Фаза 8: Train: 3.3001e-05, Test: 3.351e-05
# Фаза 9: Train: 3.4741e-05, Test: 3.5767e-05
# Фаза 10: Train: 1.8911e-05, Test: 2.0271e-05
# Фаза 11: Train: 2.3659e-05, Test: 2.4017e-05
# Фаза 12: Train: 2.122e-05, Test: 2.2667e-05
# Прошло времени: 00:05:36
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.5316e-05
# Epoch [65/300], learn_rate: [9.567727288213005e-05], Train Loss: 3.3044e-05, Test Loss: 3.3807e-05
# Фаза 1: Train: 2.1932e-05, Test: 2.3043e-05
# Фаза 2: Train: 3.8613e-05, Test: 3.8702e-05
# Фаза 3: Train: 3.8378e-05, Test: 3.8281e-05
# Фаза 4: Train: 5.0885e-05, Test: 5.209e-05
# Фаза 5: Train: 2.9708e-05, Test: 3.1089e-05
# Фаза 6: Train: 2.6976e-05, Test: 2.684e-05
# Фаза 7: Train: 2.3784e-05, Test: 2.5458e-05
# ...
# Фаза 5: Train: 1.4687e-05, Test: 1.5454e-05
# Фаза 6: Train: 1.4522e-05, Test: 1.5254e-05
# Фаза 7: Train: 1.1232e-05, Test: 1.2871e-05
# Фаза 8: Train: 2.0809e-05, Test: 2.1438e-05
# Фаза 9: Train: 2.2762e-05, Test: 2.4185e-05
# Фаза 10: Train: 1.1172e-05, Test: 1.2081e-05
# Фаза 11: Train: 1.4281e-05, Test: 1.4852e-05
# Фаза 12: Train: 1.2407e-05, Test: 1.3755e-05
# Прошло времени: 00:10:06
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.6964e-05
# Epoch [116/300], learn_rate: [6.698729810778065e-06], Train Loss: 1.6683e-05, Test Loss: 1.7627e-05
# Фаза 1: Train: 1.3166e-05, Test: 1.4138e-05
# Фаза 2: Train: 2.0202e-05, Test: 2.0553e-05
# Фаза 3: Train: 2.3952e-05, Test: 2.4417e-05
# Фаза 4: Train: 2.3086e-05, Test: 2.4653e-05
# Фаза 5: Train: 1.5082e-05, Test: 1.5835e-05
# Фаза 6: Train: 1.3047e-05, Test: 1.3762e-05
# Фаза 7: Train: 1.0771e-05, Test: 1.2333e-05
# Фаза 8: Train: 2.2139e-05, Test: 2.2733e-05
# Фаза 9: Train: 2.2382e-05, Test: 2.3599e-05
# Фаза 10: Train: 1.0762e-05, Test: 1.1808e-05
# Фаза 11: Train: 1.3596e-05, Test: 1.4241e-05
# Фаза 12: Train: 1.2012e-05, Test: 1.3454e-05
# Прошло времени: 00:10:12
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.5875e-05
# Epoch [117/300], learn_rate: [4.322727117869951e-06], Train Loss: 1.6447e-05, Test Loss: 1.7311e-05
# Фаза 1: Train: 1.3116e-05, Test: 1.4183e-05
# Фаза 2: Train: 2.0513e-05, Test: 2.09e-05
# Фаза 3: Train: 2.3826e-05, Test: 2.422e-05
# Фаза 4: Train: 2.2219e-05, Test: 2.3615e-05
# Фаза 5: Train: 1.4776e-05, Test: 1.5274e-05
# Фаза 6: Train: 1.2983e-05, Test: 1.3422e-05
# Фаза 7: Train: 1.002e-05, Test: 1.1669e-05
# Фаза 8: Train: 2.0162e-05, Test: 2.0661e-05
# Фаза 9: Train: 2.2724e-05, Test: 2.391e-05
# Фаза 10: Train: 1.0713e-05, Test: 1.1636e-05
# Фаза 11: Train: 1.3573e-05, Test: 1.4134e-05
# Фаза 12: Train: 1.2745e-05, Test: 1.4107e-05
# Прошло времени: 00:10:17
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.7548e-05
# Epoch [118/300], learn_rate: [2.4471741852423237e-06], Train Loss: 1.6342e-05, Test Loss: 1.7277e-05
# Фаза 1: Train: 1.3024e-05, Test: 1.396e-05
# Фаза 2: Train: 2.0127e-05, Test: 2.0649e-05
# Фаза 3: Train: 2.4333e-05, Test: 2.4876e-05
# Фаза 4: Train: 2.1655e-05, Test: 2.3255e-05
# Фаза 5: Train: 1.456e-05, Test: 1.5219e-05
# Фаза 6: Train: 1.272e-05, Test: 1.34e-05
# Фаза 7: Train: 9.9225e-06, Test: 1.1551e-05
# Фаза 8: Train: 1.9522e-05, Test: 2.0221e-05
# Фаза 9: Train: 2.2751e-05, Test: 2.382e-05
# Фаза 10: Train: 1.1486e-05, Test: 1.2369e-05
# Фаза 11: Train: 1.3356e-05, Test: 1.3984e-05
# Фаза 12: Train: 1.2649e-05, Test: 1.4024e-05
# Прошло времени: 00:10:22
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.7149e-05
# Epoch [119/300], learn_rate: [1.0926199633097157e-06], Train Loss: 1.6295e-05, Test Loss: 1.7186e-05
# Фаза 1: Train: 1.2764e-05, Test: 1.3569e-05
# Фаза 2: Train: 2.0132e-05, Test: 2.0573e-05
# Фаза 3: Train: 2.4201e-05, Test: 2.4784e-05
# Фаза 4: Train: 2.1641e-05, Test: 2.3224e-05
# Фаза 5: Train: 1.481e-05, Test: 1.5383e-05
# Фаза 6: Train: 1.2906e-05, Test: 1.353e-05
# Фаза 7: Train: 9.8218e-06, Test: 1.1392e-05
# Фаза 8: Train: 1.9878e-05, Test: 2.0434e-05
# Фаза 9: Train: 2.2659e-05, Test: 2.3848e-05
# Фаза 10: Train: 1.0876e-05, Test: 1.1761e-05
# Фаза 11: Train: 1.3651e-05, Test: 1.4215e-05
# Фаза 12: Train: 1.2205e-05, Test: 1.3518e-05
# Прошло времени: 00:10:28
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.6449e-05
# Epoch [120/300], learn_rate: [2.7390523158633e-07], Train Loss: 1.6198e-05, Test Loss: 1.7167e-05
# Фаза 1: Train: 1.2649e-05, Test: 1.3785e-05
# Фаза 2: Train: 1.9868e-05, Test: 2.0522e-05
# Фаза 3: Train: 2.3675e-05, Test: 2.4451e-05
# Фаза 4: Train: 2.1704e-05, Test: 2.3347e-05
# Фаза 5: Train: 1.484e-05, Test: 1.5495e-05
# Фаза 6: Train: 1.2778e-05, Test: 1.3358e-05
# Фаза 7: Train: 9.7636e-06, Test: 1.1448e-05
# Фаза 8: Train: 1.9939e-05, Test: 2.0511e-05
# Фаза 9: Train: 2.2395e-05, Test: 2.3747e-05
# Фаза 10: Train: 1.0904e-05, Test: 1.1698e-05
# Фаза 11: Train: 1.3442e-05, Test: 1.4019e-05
# Фаза 12: Train: 1.2418e-05, Test: 1.3623e-05
# Прошло времени: 00:10:33
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00010743
# Epoch [121/300], learn_rate: [0.0001], Train Loss: 2.7181e-05, Test Loss: 2.8094e-05
# Фаза 1: Train: 3.1983e-05, Test: 3.3428e-05
# Фаза 2: Train: 2.3778e-05, Test: 2.4353e-05
# Фаза 3: Train: 3.09e-05, Test: 3.1026e-05
# Фаза 4: Train: 4.9898e-05, Test: 5.101e-05
# Фаза 5: Train: 1.8521e-05, Test: 1.9348e-05
# Фаза 6: Train: 1.729e-05, Test: 1.7694e-05
# Фаза 7: Train: 1.7711e-05, Test: 1.9656e-05
# Фаза 8: Train: 4.1457e-05, Test: 4.2149e-05
# Фаза 9: Train: 2.6751e-05, Test: 2.811e-05
# Фаза 10: Train: 1.8283e-05, Test: 1.9257e-05
# Фаза 11: Train: 3.0816e-05, Test: 3.0808e-05
# Фаза 12: Train: 1.8779e-05, Test: 2.0294e-05
# Прошло времени: 00:10:38
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.5721e-05
# Epoch [122/300], learn_rate: [9.972609476841367e-05], Train Loss: 2.4072e-05, Test Loss: 2.4772e-05
# Фаза 1: Train: 1.5959e-05, Test: 1.6573e-05
# Фаза 2: Train: 2.6057e-05, Test: 2.5745e-05
# Фаза 3: Train: 2.7444e-05, Test: 2.7524e-05
# Фаза 4: Train: 2.7574e-05, Test: 2.8878e-05
# Фаза 5: Train: 2.8373e-05, Test: 2.9324e-05
# Фаза 6: Train: 1.5145e-05, Test: 1.568e-05
# Фаза 7: Train: 3.533e-05, Test: 3.6306e-05
# Фаза 8: Train: 2.3525e-05, Test: 2.3893e-05
# Фаза 9: Train: 2.6057e-05, Test: 2.7304e-05
# Фаза 10: Train: 1.8464e-05, Test: 1.9149e-05
# Фаза 11: Train: 2.3553e-05, Test: 2.4122e-05
# Фаза 12: Train: 2.138e-05, Test: 2.2762e-05
# Прошло времени: 00:10:43
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.3558e-05
# Epoch [123/300], learn_rate: [9.890738003669029e-05], Train Loss: 2.3327e-05, Test Loss: 2.4274e-05
# Фаза 1: Train: 2.3362e-05, Test: 2.5102e-05
# Фаза 2: Train: 2.3143e-05, Test: 2.3361e-05
# Фаза 3: Train: 2.9614e-05, Test: 3.016e-05
# Фаза 4: Train: 2.3572e-05, Test: 2.468e-05
# Фаза 5: Train: 1.984e-05, Test: 2.01e-05
# Фаза 6: Train: 1.7264e-05, Test: 1.7932e-05
# Фаза 7: Train: 1.09e-05, Test: 1.238e-05
# Фаза 8: Train: 3.4719e-05, Test: 3.5468e-05
# Фаза 9: Train: 2.9681e-05, Test: 3.1034e-05
# Фаза 10: Train: 3.2251e-05, Test: 3.3192e-05
# Фаза 11: Train: 1.9288e-05, Test: 1.9908e-05
# Фаза 12: Train: 1.6295e-05, Test: 1.7971e-05
# Прошло времени: 00:10:49
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.0693e-05
# Epoch [124/300], learn_rate: [9.755282581475769e-05], Train Loss: 2.4369e-05, Test Loss: 2.4995e-05
# Фаза 1: Train: 1.7428e-05, Test: 1.8298e-05
# Фаза 2: Train: 2.3785e-05, Test: 2.4017e-05
# Фаза 3: Train: 2.6607e-05, Test: 2.6521e-05
# Фаза 4: Train: 2.9268e-05, Test: 3.0611e-05
# Фаза 5: Train: 2.2243e-05, Test: 2.2361e-05
# Фаза 6: Train: 1.9144e-05, Test: 1.9473e-05
# Фаза 7: Train: 1.7048e-05, Test: 1.813e-05
# Фаза 8: Train: 2.7154e-05, Test: 2.8038e-05
# Фаза 9: Train: 2.5828e-05, Test: 2.7091e-05
# Фаза 10: Train: 1.991e-05, Test: 2.0378e-05
# Фаза 11: Train: 2.4859e-05, Test: 2.4902e-05
# Фаза 12: Train: 3.9157e-05, Test: 4.0118e-05
# Прошло времени: 00:10:54
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 4.7524e-05
# Epoch [125/300], learn_rate: [9.567727288213005e-05], Train Loss: 2.1316e-05, Test Loss: 2.2122e-05
# Фаза 1: Train: 1.9687e-05, Test: 2.0255e-05
# Фаза 2: Train: 2.5689e-05, Test: 2.5707e-05
# Фаза 3: Train: 3.544e-05, Test: 3.6114e-05
# Фаза 4: Train: 2.6741e-05, Test: 2.8931e-05
# Фаза 5: Train: 1.7831e-05, Test: 1.8617e-05
# Фаза 6: Train: 1.9402e-05, Test: 2.0066e-05
# Фаза 7: Train: 1.9541e-05, Test: 2.0843e-05
# Фаза 8: Train: 2.1164e-05, Test: 2.1444e-05
# Фаза 9: Train: 2.3926e-05, Test: 2.5161e-05
# Фаза 10: Train: 1.4996e-05, Test: 1.5494e-05
# Фаза 11: Train: 1.7318e-05, Test: 1.7597e-05
# Фаза 12: Train: 1.4058e-05, Test: 1.5236e-05
# Прошло времени: 00:10:59
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.9541e-05
# Epoch [126/300], learn_rate: [9.330127018922194e-05], Train Loss: 1.9805e-05, Test Loss: 2.0648e-05
# Фаза 1: Train: 1.4659e-05, Test: 1.5418e-05
# Фаза 2: Train: 2.2214e-05, Test: 2.273e-05
# Фаза 3: Train: 3.0588e-05, Test: 3.1215e-05
# Фаза 4: Train: 2.9112e-05, Test: 3.004e-05
# Фаза 5: Train: 2.5265e-05, Test: 2.5795e-05
# Фаза 6: Train: 1.35e-05, Test: 1.416e-05
# Фаза 7: Train: 1.1332e-05, Test: 1.3203e-05
# Фаза 8: Train: 2.244e-05, Test: 2.3056e-05
# Фаза 9: Train: 2.4982e-05, Test: 2.626e-05
# Фаза 10: Train: 1.3885e-05, Test: 1.4435e-05
# Фаза 11: Train: 1.6321e-05, Test: 1.6877e-05
# Фаза 12: Train: 1.3357e-05, Test: 1.4588e-05
# Прошло времени: 00:11:05
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.4908e-05
# Epoch [127/300], learn_rate: [9.045084971874738e-05], Train Loss: 1.9742e-05, Test Loss: 2.0528e-05
# Фаза 1: Train: 1.6692e-05, Test: 1.7597e-05
# Фаза 2: Train: 2.2685e-05, Test: 2.3255e-05
# Фаза 3: Train: 2.4211e-05, Test: 2.4396e-05
# Фаза 4: Train: 2.3995e-05, Test: 2.5235e-05
# Фаза 5: Train: 1.6281e-05, Test: 1.682e-05
# Фаза 6: Train: 1.3598e-05, Test: 1.408e-05
# Фаза 7: Train: 1.0865e-05, Test: 1.2329e-05
# Фаза 8: Train: 2.3647e-05, Test: 2.3999e-05
# Фаза 9: Train: 2.5963e-05, Test: 2.6933e-05
# Фаза 10: Train: 1.3604e-05, Test: 1.4383e-05
# Фаза 11: Train: 1.4731e-05, Test: 1.5259e-05
# Фаза 12: Train: 3.0627e-05, Test: 3.2049e-05
# Прошло времени: 00:11:10
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 8.4971e-05
# Epoch [128/300], learn_rate: [8.715724127386972e-05], Train Loss: 1.9816e-05, Test Loss: 2.066e-05
# Фаза 1: Train: 1.5006e-05, Test: 1.6231e-05
# Фаза 2: Train: 2.2755e-05, Test: 2.3087e-05
# Фаза 3: Train: 3.3696e-05, Test: 3.3941e-05
# Фаза 4: Train: 2.5294e-05, Test: 2.6522e-05
# Фаза 5: Train: 1.7392e-05, Test: 1.8193e-05
# Фаза 6: Train: 2.232e-05, Test: 2.2666e-05
# Фаза 7: Train: 1.1551e-05, Test: 1.317e-05
# Фаза 8: Train: 2.0972e-05, Test: 2.1463e-05
# Фаза 9: Train: 2.493e-05, Test: 2.5949e-05
# Фаза 10: Train: 1.1646e-05, Test: 1.2644e-05
# Фаза 11: Train: 1.4895e-05, Test: 1.5658e-05
# Фаза 12: Train: 1.7331e-05, Test: 1.8398e-05
# Прошло времени: 00:11:15
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.536e-05
# Epoch [129/300], learn_rate: [8.345653031794292e-05], Train Loss: 2.3475e-05, Test Loss: 2.4338e-05
# Фаза 1: Train: 2.7292e-05, Test: 2.8367e-05
# Фаза 2: Train: 2.1501e-05, Test: 2.2013e-05
# Фаза 3: Train: 2.7171e-05, Test: 2.7684e-05
# Фаза 4: Train: 2.311e-05, Test: 2.4317e-05
# Фаза 5: Train: 1.7979e-05, Test: 1.8338e-05
# Фаза 6: Train: 2.6158e-05, Test: 2.6397e-05
# Фаза 7: Train: 1.5889e-05, Test: 1.7453e-05
# Фаза 8: Train: 2.0091e-05, Test: 2.0051e-05
# Фаза 9: Train: 2.9285e-05, Test: 3.0589e-05
# Фаза 10: Train: 1.7738e-05, Test: 1.8328e-05
# Фаза 11: Train: 2.5285e-05, Test: 2.5957e-05
# Фаза 12: Train: 3.0203e-05, Test: 3.2558e-05
# Прошло времени: 00:11:20
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.9827e-05
# Epoch [130/300], learn_rate: [7.938926261462366e-05], Train Loss: 2.1589e-05, Test Loss: 2.2467e-05
# Фаза 1: Train: 1.4682e-05, Test: 1.5852e-05
# Фаза 2: Train: 2.5299e-05, Test: 2.5304e-05
# Фаза 3: Train: 2.8225e-05, Test: 2.9178e-05
# Фаза 4: Train: 2.8149e-05, Test: 2.9342e-05
# Фаза 5: Train: 3.0795e-05, Test: 3.1222e-05
# Фаза 6: Train: 1.532e-05, Test: 1.5787e-05
# Фаза 7: Train: 1.2021e-05, Test: 1.3767e-05
# Фаза 8: Train: 2.6614e-05, Test: 2.7335e-05
# Фаза 9: Train: 2.4783e-05, Test: 2.5682e-05
# Фаза 10: Train: 2.3585e-05, Test: 2.439e-05
# Фаза 11: Train: 1.5124e-05, Test: 1.5564e-05
# Фаза 12: Train: 1.447e-05, Test: 1.6184e-05
# Прошло времени: 00:11:26
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 4.7025e-05
# Epoch [131/300], learn_rate: [7.500000000000001e-05], Train Loss: 1.9463e-05, Test Loss: 2.0423e-05
# Фаза 1: Train: 1.4087e-05, Test: 1.4839e-05
# Фаза 2: Train: 2.5581e-05, Test: 2.6004e-05
# Фаза 3: Train: 3.0034e-05, Test: 3.0982e-05
# Фаза 4: Train: 2.8672e-05, Test: 3.049e-05
# Фаза 5: Train: 1.5427e-05, Test: 1.6016e-05
# Фаза 6: Train: 1.7171e-05, Test: 1.7549e-05
# Фаза 7: Train: 1.0874e-05, Test: 1.2525e-05
# Фаза 8: Train: 2.1241e-05, Test: 2.1975e-05
# Фаза 9: Train: 2.3053e-05, Test: 2.417e-05
# Фаза 10: Train: 1.3632e-05, Test: 1.4413e-05
# Фаза 11: Train: 1.9004e-05, Test: 1.9855e-05
# Фаза 12: Train: 1.4774e-05, Test: 1.6257e-05
# Прошло времени: 00:11:31
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 4.9376e-05
# Epoch [132/300], learn_rate: [7.033683215379002e-05], Train Loss: 2.0816e-05, Test Loss: 2.162e-05
# Фаза 1: Train: 1.7449e-05, Test: 1.8204e-05
# Фаза 2: Train: 2.5613e-05, Test: 2.6442e-05
# Фаза 3: Train: 2.8291e-05, Test: 2.8729e-05
# Фаза 4: Train: 2.1901e-05, Test: 2.3256e-05
# Фаза 5: Train: 2.971e-05, Test: 2.998e-05
# Фаза 6: Train: 1.5116e-05, Test: 1.5501e-05
# Фаза 7: Train: 1.7668e-05, Test: 1.9076e-05
# Фаза 8: Train: 1.945e-05, Test: 1.9893e-05
# Фаза 9: Train: 2.2524e-05, Test: 2.3873e-05
# Фаза 10: Train: 1.2392e-05, Test: 1.3187e-05
# Фаза 11: Train: 1.5257e-05, Test: 1.5527e-05
# Фаза 12: Train: 2.4422e-05, Test: 2.5767e-05
# Прошло времени: 00:11:36
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.4984e-05
# Epoch [133/300], learn_rate: [6.545084971874738e-05], Train Loss: 1.7194e-05, Test Loss: 1.7961e-05
# Фаза 1: Train: 1.6086e-05, Test: 1.6847e-05
# Фаза 2: Train: 2.0161e-05, Test: 2.0474e-05
# Фаза 3: Train: 2.4621e-05, Test: 2.5314e-05
# Фаза 4: Train: 2.2045e-05, Test: 2.3363e-05
# Фаза 5: Train: 1.5751e-05, Test: 1.5938e-05
# Фаза 6: Train: 1.3762e-05, Test: 1.4186e-05
# Фаза 7: Train: 1.052e-05, Test: 1.2293e-05
# Фаза 8: Train: 2.0285e-05, Test: 2.0351e-05
# Фаза 9: Train: 2.3496e-05, Test: 2.4591e-05
# Фаза 10: Train: 1.1536e-05, Test: 1.2178e-05
# Фаза 11: Train: 1.4738e-05, Test: 1.5327e-05
# Фаза 12: Train: 1.3322e-05, Test: 1.467e-05
# Прошло времени: 00:11:41
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.4122e-05
# Epoch [134/300], learn_rate: [6.0395584540887963e-05], Train Loss: 1.9162e-05, Test Loss: 2.0156e-05
# Фаза 1: Train: 1.5081e-05, Test: 1.6091e-05
# Фаза 2: Train: 2.2366e-05, Test: 2.2786e-05
# Фаза 3: Train: 2.458e-05, Test: 2.5213e-05
# Фаза 4: Train: 2.5e-05, Test: 2.6473e-05
# Фаза 5: Train: 1.758e-05, Test: 1.805e-05
# Фаза 6: Train: 1.3953e-05, Test: 1.4452e-05
# Фаза 7: Train: 1.5501e-05, Test: 1.7289e-05
# Фаза 8: Train: 2.3989e-05, Test: 2.5081e-05
# Фаза 9: Train: 2.4392e-05, Test: 2.5683e-05
# Фаза 10: Train: 1.1358e-05, Test: 1.2167e-05
# Фаза 11: Train: 1.5137e-05, Test: 1.5983e-05
# Фаза 12: Train: 2.1011e-05, Test: 2.26e-05
# Прошло времени: 00:11:46
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.982e-05
# Epoch [135/300], learn_rate: [5.522642316338268e-05], Train Loss: 1.7408e-05, Test Loss: 1.8157e-05
# Фаза 1: Train: 1.5699e-05, Test: 1.6878e-05
# Фаза 2: Train: 1.8805e-05, Test: 1.9118e-05
# Фаза 3: Train: 2.5686e-05, Test: 2.5709e-05
# Фаза 4: Train: 2.1324e-05, Test: 2.283e-05
# Фаза 5: Train: 1.4531e-05, Test: 1.5049e-05
# Фаза 6: Train: 1.5027e-05, Test: 1.5228e-05
# Фаза 7: Train: 1.3616e-05, Test: 1.4679e-05
# Фаза 8: Train: 2.0787e-05, Test: 2.1051e-05
# Фаза 9: Train: 2.2153e-05, Test: 2.3125e-05
# Фаза 10: Train: 1.1916e-05, Test: 1.2915e-05
# Фаза 11: Train: 1.6782e-05, Test: 1.7586e-05
# Фаза 12: Train: 1.2569e-05, Test: 1.3721e-05
# Прошло времени: 00:11:51
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.2793e-05
# Epoch [136/300], learn_rate: [5.0000000000000016e-05], Train Loss: 1.7767e-05, Test Loss: 1.8658e-05
# Фаза 1: Train: 1.3126e-05, Test: 1.3927e-05
# Фаза 2: Train: 1.8512e-05, Test: 1.9052e-05
# Фаза 3: Train: 2.362e-05, Test: 2.4158e-05
# Фаза 4: Train: 2.6042e-05, Test: 2.7438e-05
# Фаза 5: Train: 2.0494e-05, Test: 2.1052e-05
# Фаза 6: Train: 1.4946e-05, Test: 1.5538e-05
# Фаза 7: Train: 9.9512e-06, Test: 1.1325e-05
# Фаза 8: Train: 1.9367e-05, Test: 2.0184e-05
# Фаза 9: Train: 2.9263e-05, Test: 3.0242e-05
# Фаза 10: Train: 1.2032e-05, Test: 1.3222e-05
# Фаза 11: Train: 1.3419e-05, Test: 1.4181e-05
# Фаза 12: Train: 1.2432e-05, Test: 1.3583e-05
# Прошло времени: 00:11:56
#
# Iteration 500
# Iteration 1000

# %%
np_train_all_losses = np.array(train_all_losses)
np_test_all_losses = np.array(test_all_losses)

# %%
np_train_all_losses.shape
# Out:
# (90, 1406, 128)

# %%
np_test_all_losses.shape
# Out:
# (90, 156, 128)

# %%
len_train = np_train_all_losses.shape[1]*np_train_all_losses.shape[2]
print(len_train)
len_test = np_test_all_losses.shape[1]*np_test_all_losses.shape[2]
print(len_test)
# Out:
# 179968
# 19968

# %%
np_train_all_losses = np_train_all_losses.reshape(np_train_all_losses.shape[0],len_train)
np_test_all_losses = np_test_all_losses.reshape(np_train_all_losses.shape[0],len_test)

# %%
inter1 = 89

# %%
print(np.mean(np_train_all_losses[inter1]))
print(np.std(np_train_all_losses[inter1]))
print(np.median(np_train_all_losses[inter1]))
print(np.mean(np_test_all_losses[inter1]))
print(np.std(np_test_all_losses[inter1]))
print(np.median(np_test_all_losses[inter1]))
# Out:
# 1.9426041e-05
# 1.3905768e-05
# 1.5963797e-05
# 2.0491738e-05
# 1.5454978e-05
# 1.6512651e-05

# %%
x_scaled = np.arange(len_test)*len_train/len_test
print(x_scaled)
# Out:
# [0.00000000e+00 9.01282051e+00 1.80256410e+01 ... 1.79940962e+05
#  1.79949974e+05 1.79958987e+05]

# %%
plt.plot(np.sort(np_train_all_losses[inter1]))
plt.plot(x_scaled,np.sort(np_test_all_losses[inter1]),linestyle='-.')
plt.show()

# %%
plt.plot(train_losses,label='train_loss')
plt.plot(test_losses,label='test_loss')
plt.plot(experimental_losses,label='experimental_losses')
plt.legend()
plt.yscale('log')
plt.show()

# %%
total_exp_diff
# Out:
# np.float64(2.083497464985141)

# %%
ph_exp_diff
# Out:
# array([0.84043431, 0.88694988, 3.81381666, 4.1681766 , 1.18502402,
#        3.92548832, 1.11403623, 1.56812977, 2.89230732, 1.4214449 ,
#        1.76875685, 1.41740472])

# %%
exp_samples_nb
# Out:
# 41
