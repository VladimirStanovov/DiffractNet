# %%
import os
import struct
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, WeightedRandomSampler
import torch.optim.lr_scheduler as lr_scheduler
import time
import csv
import glob
from diffraction_utils import load_experimental_data
from load_xml_phases import *
import torch.nn.functional as F
import matplotlib.pyplot as plt
import pandas as pd

# %%
difr_dir = "../../nn_data_2.5/"
os.makedirs(difr_dir, exist_ok=True)

# Автовыбор вычислительного устройства
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('device =', device)

# Вычисляем размер входа для свертки
input_size = 4001
num_phases = 12

xml_name = 'OSO'
model_ver = 'light_3'
wghts_fname = f'weights3_{xml_name}_{model_ver}.pth'
csv_res_fname = f"{xml_name}_{model_ver}.csv"

inp_data = []
out_data = []

PHASES_INFO = []

experiment_folder = 'XY_OSO_midKO'
# Out:
# device = cuda:0

# %%
# Создаем словарь для сопоставления имен файлов и целевых значений
target_values = {
    'Бо1125_180121.xy': np.array([0.42, 0.25, 42.72, 44.65, 2.22, 8.05, 0.00, 1.40, 0.28, 0.00, 0.01, 0.00]),
    'Бо2074_200121.xy': np.array([0.50, 0.24, 58.48, 27.85, 2.88, 7.90, 0.05, 1.62, 0.48, 0.00, 0.01, 0.00]),
    'Бо2077_200121.xy': np.array([0.40, 0.93, 67.24, 18.25, 3.63, 7.51, 0.03, 1.60, 0.42, 0.00, 0.00, 0.00]),
    'Бр1026_181220.xy': np.array([2.72, 2.78, 47.84, 28.73, 1.20, 14.57, 0.07, 2.06, 0.03, 0.00, 0.00, 0.00]),
    'Бр1071_241220.xy': np.array([1.22, 0.63, 50.30, 30.39, 1.60, 13.97, 0.06, 1.84, 0.00, 0.00, 0.00, 0.00]),
    'Бр1307_2_181220.xy': np.array([0.68, 1.17, 86.07, 0.94, 3.65, 1.29, 4.55, 0.31, 0.79, 0.05, 0.52, 0.00]),
    'Бр1356_251220.xy': np.array([1.67, 2.21, 78.72, 2.34, 7.51, 3.22, 2.43, 1.09, 0.51, 0.28, 0.02, 0.00]),
    'Бр1425_241220.xy': np.array([0.90, 1.56, 81.95, 1.43, 6.32, 2.76, 3.40, 0.85, 0.68, 0.16, 0.00, 0.00]),
    'Бр1428_241220.xy': np.array([1.07, 2.47, 63.14, 15.82, 0.80, 14.47, 0.66, 1.58, 0.00, 0.00, 0.00, 0.00]),
    'Бр1566_281220.xy': np.array([0.72, 3.95, 70.88, 5.65, 6.65, 9.87, 0.12, 2.14, 0.00, 0.00, 0.01, 0.00]),
    'В506_140121.xy': np.array([2.11, 2.59, 54.29, 21.35, 2.26, 15.51, 0.06, 1.59, 0.24, 0.00, 0.01, 0.00]),
    'В508_140121.xy': np.array([2.12, 3.48, 48.43, 27.17, 1.62, 15.24, 0.05, 1.63, 0.26, 0.00, 0.01, 0.00]),
    'В549_150121.xy': np.array([1.01, 3.74, 78.07, 0.43, 13.37, 0.44, 1.63, 0.24, 0.17, 0.00, 0.89, 0.00]),
    'В574_150121.xy': np.array([0.52, 1.16, 52.24, 24.86, 1.70, 16.05, 0.03, 3.32, 0.11, 0.00, 0.00, 0.00]),
    'В583_180121.xy': np.array([0.45, 1.25, 52.71, 24.86, 2.10, 16.14, 0.06, 2.38, 0.04, 0.00, 0.01, 0.00]),
    'И103_291220.xy': np.array([1.02, 3.74, 53.23, 30.05, 1.25, 5.35, 4.20, 1.05, 0.00, 0.11, 0.00, 0.00]),
    'И128_120121.xy': np.array([1.16, 3.16, 59.49, 23.44, 1.06, 7.46, 2.84, 1.33, 0.00, 0.06, 0.00, 0.00]),
    'И538_110121.xy': np.array([1.42, 0.97, 72.78, 9.48, 2.78, 10.23, 0.42, 1.19, 0.00, 0.72, 0.00, 0.00]),
    'И644_110121.xy': np.array([1.24, 4.00, 73.64, 6.08, 7.94, 4.33, 1.11, 0.93, 0.00, 0.63, 0.00, 0.00]),
    'И743_211220.xy': np.array([0.39, 1.37, 88.97, 0.92, 2.73, 0.32, 4.03, 0.12, 0.42, 0.28, 0.44, 0.00]),
    'И9085_130121.xy': np.array([0.48, 0.14, 42.95, 44.21, 1.04, 10.34, 0.07, 0.71, 0.06, 0.00, 0.00, 0.00]),
    'К173_210121.xy': np.array([0.68, 2.13, 45.16, 36.51, 1.06, 10.94, 0.07, 2.73, 0.29, 0.43, 0.00, 0.00]),
    'К1898_270121.xy': np.array([1.89, 1.83, 55.79, 17.94, 2.05, 13.11, 0.43, 2.62, 0.14, 4.21, 0.00, 0.00]),
    'К2019_270121.xy': np.array([1.30, 3.43, 67.70, 7.81, 2.77, 10.36, 0.05, 2.19, 0.40, 4.00, 0.00, 0.00]),
    'К2022_280121.xy': np.array([1.18, 1.49, 58.94, 15.68, 2.12, 13.57, 0.08, 2.58, 0.46, 3.91, 0.00, 0.00]),
    'К2035_280121.xy': np.array([0.99, 1.88, 57.56, 16.03, 2.68, 12.59, 0.11, 2.36, 0.43, 5.37, 0.00, 0.00]),
    'К2041_280121.xy': np.array([0.95, 2.44, 49.16, 25.80, 1.25, 13.73, 0.07, 2.76, 0.22, 3.62, 0.00, 0.00]),
    'К2042_290121.xy': np.array([0.87, 0.92, 83.39, 0.71, 0.34, 0.11, 6.30, 0.00, 0.24, 4.62, 2.51, 0.00]),
    'С152_161220.xy': np.array([0.26, 1.65, 33.93, 52.38, 0.73, 9.34, 0.27, 0.99, 0.04, 0.38, 0.04, 0.00]),
    'С207_181220.xy': np.array([0.32, 0.61, 42.08, 44.57, 0.83, 9.56, 0.29, 1.31, 0.00, 0.42, 0.00, 0.00]),
    'С294_211220.xy': np.array([0.77, 2.01, 57.04, 26.08, 2.25, 8.96, 0.34, 1.74, 0.00, 0.83, 0.00, 0.00]),
    'С343_221220.xy': np.array([1.84, 1.80, 51.13, 33.75, 1.11, 7.74, 0.75, 1.31, 0.00, 0.56, 0.00, 0.00]),
    'С367_231220.xy': np.array([0.47, 1.94, 56.72, 26.99, 1.58, 9.51, 0.39, 1.60, 0.00, 0.81, 0.00, 0.00]),
    'С455_171220.xy': np.array([0.20, 2.09, 32.42, 53.03, 0.80, 9.33, 0.46, 1.01, 0.00, 0.28, 0.38, 0.00]),
    'С479_231220.xy': np.array([0.73, 1.32, 53.55, 31.52, 1.41, 9.09, 0.29, 1.45, 0.00, 0.63, 0.00, 0.00]),
    'С490_231220.xy': np.array([1.05, 2.49, 55.01, 30.80, 1.07, 4.45, 3.10, 1.48, 0.01, 0.55, 0.00, 0.00]),
    'дБо2058д_240521.xy': np.array([0.00, 0.74, 10.33, 59.61, 2.16, 5.09, 0.13, 21.81, 0.15, 0.00, 0.00, 0.00]),
    'дБо2082д_280521.xy': np.array([0.62, 0.35, 85.91, 0.00, 0.00, 0.00, 3.22, 0.00, 9.42, 0.06, 0.17, 0.00]),
    'дБр1307д_220421.xy': np.array([0.93, 0.36, 85.71, 0.39, 0.35, 0.03, 9.36, 0.00, 0.24, 0.00, 1.22, 1.43]),
    'дБр1552д_020621.xy': np.array([0.89, 0.00, 85.48, 0.25, 0.34, 0.00, 6.05, 0.03, 0.58, 0.00, 0.37, 6.00]),
    'дК1132д_180521.xy': np.array([2.42, 1.47, 75.98, 0.48, 0.61, 0.17, 9.58, 0.06, 4.70, 0.16, 2.08, 2.28]),
    'дК1585д_170521.xy': np.array([0.43, 1.17, 84.69, 0.00, 0.00, 0.00, 9.71, 0.00, 1.83, 1.65, 0.46, 0.00]),
    'дК180д_290421.xy': np.array([0.19, 1.93, 26.94, 42.17, 4.99, 17.44, 0.06, 5.90, 0.00, 0.40, 0.00, 0.00]),
    'дС132д_210421.xy': np.array([0.29, 2.38, 26.13, 41.49, 2.17, 16.56, 0.10, 10.58, 0.27, 0.03, 0.00, 0.00]),
    'дС321д_120521.xy': np.array([0.42, 1.90, 20.31, 38.45, 3.73, 20.36, 0.10, 14.56, 0.00, 0.02, 0.16, 0.00]),
    'дС323д_170521.xy': np.array([0.17, 1.65, 21.48, 30.25, 7.69, 19.54, 0.03, 18.75, 0.14, 0.07, 0.24, 0.00])
}

# %%
def predict_experimental_data(model, experimental_data, input_size):
    predictions = []
    total_difference = 0.0
    exp_samples_nb = 0

    diff_by_phases = []
    for i in range(num_phases):
        diff_by_phases.append(0)

    for filename, intensities in experimental_data.items():

        interpolated_intensities = torch.tensor(intensities, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)[:,:,1:]
        model.eval()
        with torch.no_grad():
            predicted_weights = model(interpolated_intensities)

        # Умножаем предсказанные веса на 100
        #predicted_weights *= 100
        
        predictions.append((filename, predicted_weights.squeeze().cpu().numpy()))

        # Сравнение с целевыми значениями, если они есть
        if filename in target_values:
            target = target_values[filename]
            curr_phases = np.square(predicted_weights.squeeze().cpu().numpy() - target*0.01)
            total_difference += curr_phases.sum()
            diff_by_phases += curr_phases  # Аккумулируем разности для каждой фазы
            exp_samples_nb += 1

    if exp_samples_nb > 0:
        total_difference = (total_difference / exp_samples_nb) / num_phases
        diff_by_phases /= exp_samples_nb  # Вычисляем средние значения для каждой фазы
    else:
        total_difference = 0.0
        diff_by_phases = np.zeros(num_phases)

    return total_difference, diff_by_phases, exp_samples_nb

def load_batch_inp_file(file_name):
    if os.path.exists(file_name):
        with open(file_name, 'rb') as f:
            while True:
                data = f.read(struct.calcsize(f'{input_size}f'))
                if not data:
                    break
                inp = struct.unpack(f'{input_size}f', data)
                inp_data.append(np.array(inp))


def load_batch_out_file(file_name):
    if os.path.exists(file_name):
        with open(file_name, 'rb') as f:
            while True:
                data = f.read(struct.calcsize(f'{num_phases}f'))
                if not data:
                    break
                out = struct.unpack(f'{num_phases}f', data)
                out_data.append(np.array(out))

# %%
# Загрузка данных
inp_files = glob.glob(f"{difr_dir}batch_inp_{xml_name}_sd2.5_{num_phases}ph_p*.bin")
out_files = glob.glob(f"{difr_dir}batch_out_{xml_name}_sd2.5_{num_phases}ph_p*.bin")

print('inp_files',inp_files)

for file in inp_files:
    load_batch_inp_file(file)

for file in out_files:
    load_batch_out_file(file)

print(f"Размер массива out_data: {len(out_data)}\n")

if len(out_data) < 1:
    print("Внимание - нет данных для обучения !")

lim_len = 500000
if len(inp_data) > lim_len:
    inp_data = inp_data[-lim_len:]
if len(out_data) > lim_len:
    out_data = out_data[-lim_len:]
# Out:
# inp_files ['../../nn_data_2.5/batch_inp_OSO_sd2.5_12ph_p4_25000.bin', '../../nn_data_2.5/batch_inp_OSO_sd2.5_12ph_p2_25000.bin', '../../nn_data_2.5/batch_inp_OSO_sd2.5_12ph_p3_25000.bin', '../../nn_data_2.5/batch_inp_OSO_sd2.5_12ph_p1_25000.bin']
# Размер массива out_data: 100000

# %%
out_data[0]
# Out:
# array([3.26506999e-08, 9.93896928e-03, 0.00000000e+00, 6.04183599e-02,
#        1.73202887e-01, 8.31474259e-04, 1.99009031e-01, 0.00000000e+00,
#        6.24747053e-02, 1.34024754e-01, 1.35469731e-04, 3.59964311e-01])

# %%
# Определение класса для датасета
class CandleDataset(Dataset):
    def __init__(self, inputs, outputs):
        self.inputs = inputs
        self.outputs = outputs

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        # Возвращаем данные без изменения формы
        return torch.tensor(self.inputs[idx], dtype=torch.float32).unsqueeze(0), torch.tensor(self.outputs[idx], dtype=torch.float32)

# %%
# Разделение данных на тренировочную и тестовую выборки
indices = list(range(len(inp_data)))
indices = np.array(indices)
np.random.shuffle(indices)
#test_indices = indices[::11]
#train_indices = [i for i in indices if i not in test_indices]
test_indices = indices[:int(0.1*len(indices))]
train_indices = indices[int(0.1*len(indices)):]

train_inputs = [inp_data[i] for i in train_indices]
train_outputs = [out_data[i] for i in train_indices]
test_inputs = [inp_data[i] for i in test_indices]
test_outputs = [out_data[i] for i in test_indices]

train_inputs_np = np.array(train_inputs)[:,1:]
test_inputs_np = np.array(test_inputs)[:,1:]

train_dataset = CandleDataset(train_inputs_np, train_outputs)
test_dataset = CandleDataset(test_inputs_np, test_outputs)

# %%
# Загружаем фазы из файлов .phase
sample_info, PHASES_INFO = parse_xml('XRD_Data/OSO_Topas_2022_stidy.tshx')
num_phases = len(PHASES_INFO)

# Загружаем экспериментальные данные
experimental_data = load_experimental_data(experiment_folder)
#print(f'Loaded {len(experimental_data)} experimental diffraction patterns.')
# Out:
# {'Name': 'alpha-Al2O3', 'SpaceGroup': 'R-3cH', 'CellPar': {'a': {'min': 4.755, 'max': 4.77, 'value': 4.7698}, 'b': {'min': None, 'max': None, 'value': 4.7698}, 'c': {'min': 13.0, 'max': 13.05, 'value': 13.0243}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 120.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 45.0, 'max': 150.0, 'value': 100.0}, 'Strain': {'min': 0.01, 'max': 0.35, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.35231}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O2-', 'X': {'min': None, 'max': None, 'value': 0.6936}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'gamma-Al2O3', 'SpaceGroup': 'Fd-3mZ', 'CellPar': {'a': {'min': 7.9, 'max': 7.937, 'value': 7.911}, 'b': {'min': None, 'max': None, 'value': 7.911}, 'c': {'min': None, 'max': None, 'value': 7.911}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 45.0, 'max': 300.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.35, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.2547}, 'Y': {'min': None, 'max': None, 'value': 0.2547}, 'Z': {'min': None, 'max': None, 'value': 0.2547}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 0.58}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.125}, 'Y': {'min': None, 'max': None, 'value': 0.125}, 'Z': {'min': None, 'max': None, 'value': 0.125}, 'Occ': {'min': None, 'max': None, 'value': 0.84}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0272}, 'Y': {'min': None, 'max': None, 'value': 0.0272}, 'Z': {'min': None, 'max': None, 'value': 0.0272}, 'Occ': {'min': None, 'max': None, 'value': 0.17}}], 'RIR': -1}
#
# {'Name': 'Cryolite', 'SpaceGroup': 'P121/c1', 'CellPar': {'a': {'min': 5.35095, 'max': 5.45905, 'value': 5.405}, 'b': {'min': 5.5242, 'max': 5.6358, 'value': 5.58}, 'c': {'min': 9.351936, 'max': 9.540864000000001, 'value': 9.4464}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': 123.51933, 'max': 126.01467, 'value': 124.767}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 70.0, 'max': 500.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [{'name': '1 1 1', 'min': 0.95, 'max': 1.1, 'value': 1.0}], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': 0.2638, 'max': 0.27, 'value': 0.2656}, 'Y': {'min': 0.448, 'max': 0.456, 'value': 0.448}, 'Z': {'min': 0.2501, 'max': 0.257, 'value': 0.2518}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.114, 'max': 0.12, 'value': 0.1152}, 'Y': {'min': 0.042, 'max': 0.05, 'value': 0.0436}, 'Z': {'min': 0.214, 'max': 0.223, 'value': 0.2182}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.22, 'max': 0.229, 'value': 0.2285}, 'Y': {'min': 0.73, 'max': 0.738, 'value': 0.7285}, 'Z': {'min': 0.057, 'max': 0.064, 'value': 0.0638}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.307, 'max': 0.319, 'value': 0.3215}, 'Y': {'min': 0.166, 'max': 0.18, 'value': 0.1765}, 'Z': {'min': 0.037, 'max': 0.048, 'value': 0.047}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Chiolite', 'SpaceGroup': 'P4/mnc', 'CellPar': {'a': {'min': 7.02, 'max': 7.06, 'value': 7.0138}, 'b': {'min': None, 'max': None, 'value': 7.0138}, 'c': {'min': 10.36, 'max': 10.403, 'value': 10.402}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 80.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [{'name': '0 0 1', 'min': 0.93, 'max': 1.0, 'value': 1.0}], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.277}, 'Y': {'min': None, 'max': None, 'value': 0.777}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': 0.17, 'max': 0.177, 'value': 0.1711}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.058, 'max': 0.064, 'value': 0.0642}, 'Y': {'min': 0.245, 'max': 0.252, 'value': 0.2477}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.176, 'max': 0.182, 'value': 0.1794}, 'Y': {'min': 0.532, 'max': 0.54, 'value': 0.5364}, 'Z': {'min': 0.118, 'max': 0.121, 'value': 0.1198}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'NaCa(AlF6)', 'SpaceGroup': 'P121/c1', 'CellPar': {'a': {'min': 8.715, 'max': 8.795, 'value': 8.7423}, 'b': {'min': 5.145, 'max': 5.21, 'value': 5.1927}, 'c': {'min': 20.3, 'max': 20.46, 'value': 20.35139}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': 90.85, 'max': 91.5, 'value': 91.499}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 30.0, 'max': 150.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Na1+', 'X': {'min': 0.9668, 'max': 0.9868, 'value': 0.9768}, 'Y': {'min': 0.2443, 'max': 0.2643, 'value': 0.2543}, 'Z': {'min': 0.1681, 'max': 0.1881, 'value': 0.1781}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': 0.9581, 'max': 0.9781, 'value': 0.9681}, 'Y': {'min': 0.2634, 'max': 0.2834, 'value': 0.2734}, 'Z': {'min': 0.4313, 'max': 0.4513, 'value': 0.4413}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Ca2+', 'X': {'min': 0.6303, 'max': 0.6503, 'value': 0.6403}, 'Y': {'min': 0.2275, 'max': 0.2475, 'value': 0.2375}, 'Z': {'min': 0.3008, 'max': 0.3208, 'value': 0.3108}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Ca2+', 'X': {'min': 0.6257, 'max': 0.6457, 'value': 0.6357}, 'Y': {'min': 0.3119, 'max': 0.3319, 'value': 0.3219}, 'Z': {'min': 0.5523, 'max': 0.5723, 'value': 0.5623}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': 0.2488, 'max': 0.2688, 'value': 0.2588}, 'Y': {'min': 0.2461, 'max': 0.2661, 'value': 0.2561}, 'Z': {'min': 0.3089, 'max': 0.3289, 'value': 0.3189}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': 0.2428, 'max': 0.2628, 'value': 0.2528}, 'Y': {'min': 0.1803, 'max': 0.2003, 'value': 0.1903}, 'Z': {'min': 0.5588, 'max': 0.5788, 'value': 0.5688}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.629}, 'Y': {'min': None, 'max': None, 'value': 0.6261}, 'Z': {'min': None, 'max': None, 'value': 0.4777}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.5863}, 'Y': {'min': None, 'max': None, 'value': 0.6137}, 'Z': {'min': None, 'max': None, 'value': 0.6397}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.7338}, 'Y': {'min': None, 'max': None, 'value': 0.0827}, 'Z': {'min': None, 'max': None, 'value': 0.4824}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.3809}, 'Y': {'min': None, 'max': None, 'value': 0.1003}, 'Z': {'min': None, 'max': None, 'value': 0.2626}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1625}, 'Y': {'min': None, 'max': None, 'value': -0.0247}, 'Z': {'min': None, 'max': None, 'value': 0.6328}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1643}, 'Y': {'min': None, 'max': None, 'value': 0.4377}, 'Z': {'min': None, 'max': None, 'value': 0.3814}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.2357}, 'Y': {'min': None, 'max': None, 'value': 0.4669}, 'Z': {'min': None, 'max': None, 'value': 0.6229}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.5786}, 'Y': {'min': None, 'max': None, 'value': 0.5944}, 'Z': {'min': None, 'max': None, 'value': 0.8821}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.9132}, 'Y': {'min': None, 'max': None, 'value': 0.6404}, 'Z': {'min': None, 'max': None, 'value': 0.226}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.7403}, 'Y': {'min': None, 'max': None, 'value': 0.0217}, 'Z': {'min': None, 'max': None,  ...
#
# {'Name': 'Na2Ca3Al2F14', 'SpaceGroup': 'I213', 'CellPar': {'a': {'min': 10.242, 'max': 10.254, 'value': 10.257}, 'b': {'min': None, 'max': None, 'value': 10.257}, 'c': {'min': None, 'max': None, 'value': 10.257}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 65.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [{'name': '1 1 1', 'min': 0.72, 'max': 1.0, 'value': 1.0}], 'Atoms': [{'Type': 'Ca2+', 'X': {'min': None, 'max': None, 'value': 0.4667}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.2482}, 'Y': {'min': None, 'max': None, 'value': 0.2482}, 'Z': {'min': None, 'max': None, 'value': 0.2482}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.0847}, 'Y': {'min': None, 'max': None, 'value': 0.0847}, 'Z': {'min': None, 'max': None, 'value': 0.0847}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1387}, 'Y': {'min': None, 'max': None, 'value': 0.3062}, 'Z': {'min': None, 'max': None, 'value': 0.1206}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.364}, 'Y': {'min': None, 'max': None, 'value': 0.3627}, 'Z': {'min': None, 'max': None, 'value': 0.1873}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.4614}, 'Y': {'min': None, 'max': None, 'value': 0.4614}, 'Z': {'min': None, 'max': None, 'value': 0.4614}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Fluorite', 'SpaceGroup': 'Fm-3m', 'CellPar': {'a': {'min': 5.463, 'max': 5.469, 'value': 5.462}, 'b': {'min': None, 'max': None, 'value': 5.462}, 'c': {'min': None, 'max': None, 'value': 5.462}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 60.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.38, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Ca2+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Weberite', 'SpaceGroup': 'Imma', 'CellPar': {'a': {'min': 7.05, 'max': 7.072, 'value': 7.05}, 'b': {'min': 9.98, 'max': 10.02, 'value': 9.979}, 'c': {'min': 7.29, 'max': 7.31, 'value': 7.297}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 150.0, 'max': 500.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.35, 'value': 0.1}}, 'MDtexDir': [{'name': '0 1 1', 'min': 0.9, 'max': 1.0, 'value': 1.0}], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.75}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Mg2+', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.1362}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.4144}, 'Z': {'min': None, 'max': None, 'value': 0.7213}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1845}, 'Y': {'min': None, 'max': None, 'value': 0.3874}, 'Z': {'min': None, 'max': None, 'value': 0.4304}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Neighborite', 'SpaceGroup': 'Pnma', 'CellPar': {'a': {'min': 5.488, 'max': 5.5, 'value': 5.4928}, 'b': {'min': 7.665, 'max': 7.69, 'value': 7.71}, 'c': {'min': 5.36, 'max': 5.387, 'value': 5.37645}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 100.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.3, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.03975}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.488}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Mg2+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.4547}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.58705}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.29105}, 'Y': {'min': None, 'max': None, 'value': 0.04897}, 'Z': {'min': None, 'max': None, 'value': 0.21265}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Elpasolite', 'SpaceGroup': 'Fm-3m', 'CellPar': {'a': {'min': 8.095, 'max': 8.112, 'value': 8.093}, 'b': {'min': None, 'max': None, 'value': 8.093}, 'c': {'min': None, 'max': None, 'value': 8.093}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 60.0, 'max': 200.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'K', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F', 'X': {'min': None, 'max': None, 'value': 0.2225}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'K1.58Al11O17', 'SpaceGroup': 'R-3mH', 'CellPar': {'a': {'min': 5.585, 'max': 5.62, 'value': 5.63}, 'b': {'min': None, 'max': None, 'value': 5.63}, 'c': {'min': 33.89, 'max': 34.17, 'value': 34.01}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 120.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 45.0, 'max': 150.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.37, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.16712}, 'Y': {'min': None, 'max': None, 'value': -0.16712}, 'Z': {'min': None, 'max': None, 'value': 0.9298}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.34988}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.44935}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.16419}, 'Y': {'min': None, 'max': None, 'value': -0.16419}, 'Z': {'min': None, 'max': None, 'value': 0.23615}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.15396}, 'Y': {'min': None, 'max': None, 'value': -0.15396}, 'Z': {'min': None, 'max': None, 'value': 0.03384}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.09512}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.2952}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'K', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': -0.17086}, 'Occ': {'min': None, 'max': None, 'value': 0.31}}, {'Type': 'K', 'X': {'min': None, 'max': None, 'value': 0.08717}, 'Y': {'min': None, 'max': None, 'value': -0.08717}, 'Z': {'min': None, 'max': None, 'value': -0.16784}, 'Occ': {'min': None, 'max': None, 'value': 0.16}}], 'RIR': -1}
#
# {'Name': 'Villiaumite', 'SpaceGroup': 'Fm-3m', 'CellPar': {'a': {'min': 4.633, 'max': 4.64, 'value': 4.634}, 'b': {'min': None, 'max': None, 'value': 4.634}, 'c': {'min': None, 'max': None, 'value': 4.634}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 90.0, 'max': 170.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.38, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Na', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}

# %%
#small
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()
        
        # Сверточные слои: уменьшены более агрессивно (в ~2.5 раза)
        self.conv_layers = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=32, kernel_size=7, stride=1, padding=3),  # Было 64
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=32, out_channels=64, kernel_size=5, stride=1, padding=2),  # Было 128
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1), # Было 256
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2)
        )
        
        reduced_size = input_size // 8
        
        # Трансформер: один слой + уменьшенная размерность
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=500, nhead=10, dim_feedforward=256, dropout=0.1, batch_first=True), # d_model и dim_feedforward уменьшены
            num_layers=1  # Один слой
        )
        
        # Полносвязные слои: значительно уменьшены
        self.fc_layers = nn.Sequential(
            nn.Linear(128 * reduced_size, 256),  # Было 1024
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(256, num_phases)
        )
    
    def forward(self, x):
        x = self.conv_layers(x)
        #x = x.permute(0, 2, 1)  # Критичный шаг сохранён
        x = self.transformer(x)
        x = x.reshape(x.size(0), -1)
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)
        return x

# %%
#big
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super(DiffractionNet, self).__init__()
        
        # Сверточные слои для извлечения локальных признаков
        self.conv_layers = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=64, kernel_size=7, stride=1, padding=3),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=64, out_channels=128, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2)
        )
        
        # Размер выхода после сверточных слоев
        reduced_size = input_size // 8  # Поскольку мы делаем три пулинга с шагом 2
        
        # Трансформер для глобального понимания
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=256, nhead=8, dim_feedforward=512, dropout=0.1, batch_first=True),
            num_layers=2
        )
        
        # Полносвязные слои для получения итогового предсказания
        self.fc_layers = nn.Sequential(
            nn.Linear(256 * reduced_size, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(1024, num_phases)
        )
    
    def forward(self, x):
        x = self.conv_layers(x)
        x = x.permute(0, 2, 1)  # Изменяем форму для трансформера (batch_size, sequence_length, features)
        x = self.transformer(x)
        x = x.reshape(x.size(0), -1)  # Флэттенинг с использованием reshape
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)  # Нормированные доли
        return x

# %%
#FFN
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()        
        
        # Полносвязные слои: значительно уменьшены
        self.fc_layers = nn.Sequential(
            nn.Linear(4001, 2048),  # Было 1024
            #nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(2048,1024),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(1024,256),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(256, num_phases)
        )
    
    def forward(self, x):
        #x = self.conv_layers(x)
        #x = x.permute(0, 2, 1)  # Критичный шаг сохранён
        #x = self.transformer(x)
        #x = x.reshape(x.size(0), -1)
        x = x.view(-1,4001)
        #print(x.shape)
        x = self.fc_layers(x)
        #print(x.shape)
        x = F.softmax(x, dim=1)
        #print(x.shape)
        return x

# %%
#conv_ff
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()
        self.fc_layers = nn.Sequential(            
            nn.Linear(4000, 256),
            nn.ReLU(),
            nn.Linear(256, num_phases)
        )
    
    def forward(self, x):
        x = x.reshape(x.size(0), -1)
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)
        return x

# %%
#ff_40_100
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()
        self.fc_layers = nn.Sequential(            
            nn.Linear(4040, num_phases)
        )
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=40, nhead=8, dim_feedforward=256, dropout=0.1, batch_first=True),
            num_layers=2
        )
        self.positional_embedding=nn.Parameter(torch.randn(1, 1, 40))
    
    def forward(self, x):
        x = x.view(-1,40,100).permute(0, 2, 1)
        positional_embeddings = self.positional_embedding.expand(x.shape[0], 1, 40)
        x = torch.cat((positional_embeddings, x), dim=1)
        x = self.transformer(x)
        x = x.view(-1,4040)
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)
        return x

# %%
#ff_40_100
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()
        self.fc_layers = nn.Sequential(            
            nn.Linear(4040, num_phases)
        )
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=40, nhead=8, dim_feedforward=256, dropout=0.1, batch_first=True),
            num_layers=2
        )
        self.positional_embedding=nn.Parameter(torch.randn(1, 1, 40))
    
    def forward(self, x):
        x = x.view(-1,40,100).permute(0, 2, 1)
        positional_embeddings = self.positional_embedding.expand(x.shape[0], 1, 40)
        x = torch.cat((positional_embeddings, x), dim=1)
        x = self.transformer(x)
        x = x.view(-1,4040)
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)
        return x

# %%
#ff_CNN_40_100
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()
        self.conv_layers = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=40, kernel_size=40, stride=20, padding=10),         
            nn.ReLU(),
        )
        self.fc_layers = nn.Sequential(            
            nn.Linear(8040, num_phases)
        )
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=40, nhead=8, dim_feedforward=256, dropout=0.1, batch_first=True),
            num_layers=2
        )
        self.positional_embedding=nn.Parameter(torch.randn(1, 1, 40))
    
    def forward(self, x):
        x = self.conv_layers(x)
        x = x.permute(0, 2, 1)
        positional_embeddings = self.positional_embedding.expand(x.shape[0], 1, 40)
        x = torch.cat((positional_embeddings, x), dim=1)
        x = self.transformer(x)
        x = x.view(-1,8040)
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)
        return x

# %%
#ff_CNN_40_100_stride1
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()
        self.conv_layers = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=1, kernel_size=40, stride=1, padding=20),         
            nn.ReLU(),
        )
        self.fc_layers = nn.Sequential(            
            nn.Linear(4040, num_phases)
        )
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=40, nhead=8, dim_feedforward=256, dropout=0.1, batch_first=True),
            num_layers=2
        )
        self.positional_embedding=nn.Parameter(torch.randn(1, 1, 40))
    
    def forward(self, x):
        x = self.conv_layers(x)
        #print(x.shape)
        #x = x.permute(0, 2, 1)
        x = x[:,:,1:]
        #print(x.shape)
        x = x.view(-1,40,100).permute(0, 2, 1)
        #print(x.shape)
        positional_embeddings = self.positional_embedding.expand(x.shape[0], 1, 40)
        x = torch.cat((positional_embeddings, x), dim=1)
        x = self.transformer(x)
        x = x.view(-1,4040)
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)
        return x

# %%
# Создание экземпляра модели
model = DiffractionNet(input_size, num_phases).to(device)
print(model)
pytorch_total_params = sum(p.numel() for p in model.parameters())
print(pytorch_total_params)
# Out:
# DiffractionNet(
#   (fc_layers): Sequential(
#     (0): Linear(in_features=4040, out_features=12, bias=True)
#   )
#   (transformer): TransformerEncoder(
#     (layers): ModuleList(
#       (0-1): 2 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=40, out_features=40, bias=True)
#         )
#         (linear1): Linear(in_features=40, out_features=256, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=256, out_features=40, bias=True)
#         (norm1): LayerNorm((40,), eps=1e-05, elementwise_affine=True, bias=True)
#         (norm2): LayerNorm((40,), eps=1e-05, elementwise_affine=True, bias=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
# )
# 103524

# %%
print('Start training')
learn_rate = 1E-4
# Определяем критерий потерь и оптимизатор
criterion = nn.MSELoss(reduction='none')  # Используем reduction='none' для получения ошибки для каждого элемента в батче
optimizer = optim.AdamW(model.parameters(), lr=learn_rate, weight_decay=learn_rate*0.1)
def find_index_of_max(float_array):
    max_index = np.argmax(float_array)
    return max_index

# Определяем категории для балансировки данных
def get_category(out):
    min_val = np.min(out)
    max_val = np.max(out)
    delta = min_val / max_val if max_val > 0 else 0.0
    if delta < 0.001:
        return 0
    elif 0.001 <= delta < 0.01:
        return 1
    elif 0.01 <= delta < 0.1:
        return 2
    else:
        return 3
# Определяем метки классов для балансировки
train_labels = np.array([find_index_of_max(out) for out in train_outputs])
print('train_labels',train_labels)
class_counts = np.bincount(train_labels.astype(np.int64))
print(f'Category class_counts = {class_counts}')
# Добавляем сглаживание для предотвращения деления на ноль
#smoothing_factor = 1e-3
#class_weights = 1. / (class_counts + smoothing_factor)
class_weights = 1. / class_counts
sample_weights = class_weights[train_labels]
sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(sample_weights), replacement=True)
# Загрузка данных
train_dataloader = DataLoader(train_dataset, batch_size=128, sampler=sampler)
test_dataloader = DataLoader(test_dataset, batch_size=128, shuffle=False)

n_train_iter = len(train_dataloader)
n_test_iter = len(test_dataloader)
print(f'train_iter: {n_train_iter}, test_iter: {n_test_iter}')
# Инициализация списков для хранения значений потерь
train_losses = []
test_losses = []

# Инициализация списков для хранения значений потерь для каждого параметра
train_param_losses = [[] for _ in range(num_phases)]
test_param_losses = [[] for _ in range(num_phases)]

# Создание и запись заголовков в CSV-файл
with open(csv_res_fname, mode='w', newline='') as file:
    writer = csv.writer(file, delimiter=';')
    header = ['Time', 'Epoch', 'Train Loss', 'Test Loss', 'Exp_Diff'] + \
             [f'Train_{i + 1}' for i in range(num_phases)] + \
             [f'Test_{i + 1}' for i in range(num_phases)] + \
             [f'Exp_{i + 1}' for i in range(num_phases)]
    writer.writerow(header)

num_epochs = 600

total_exp_diff = 0.0
ph_exp_diff = []

pre_fitness = 1E6

train_all_losses = []
test_all_losses = []
train_batch_losses = []
test_batch_losses = []
experimental_losses = []

scheduler = lr_scheduler.CosineAnnealingWarmRestarts(optimizer,T_0=30)
# Out:
# Start training
# train_labels [10  4  5 ...  6  5  2]
# Category class_counts = [7574 7431 7463 7575 7525 7567 7521 7383 7456 7566 7537 7402]
# train_iter: 704, test_iter: 79

# %%
start_time = time.time()  # Запоминаем время начала обучения

for epoch in range(num_epochs):
    model.train()
    running_train_loss = 0.0
    running_train_param_losses = [0.0 for _ in range(num_phases)]
    iters = 0
    #train_batch_losses = []
    for inputs, outputs in train_dataloader:
        inputs, outputs = inputs.to(device), outputs.to(device)
        optimizer.zero_grad()
        predictions = model(inputs)        
        loss = criterion(predictions, outputs)
        loss.mean().backward()  # Средняя ошибка по всем элементам в батче
        # Градиенты масштабируются, если их общая норма > 1.0
        #torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        #running_train_loss += loss.mean().item()
        #for i in range(num_phases):
        #    running_train_param_losses[i] += loss[:, i].mean().item()
        iters += 1
        #train_batch_losses.append(loss.mean(axis=1).cpu().detach().numpy())

        if iters % 500 == 0:
            print(f"Iteration {iters}")
    #train_all_losses.append(np.array(train_batch_losses[:-1]))

    #train_loss = running_train_loss / n_train_iter
    #train_losses.append(train_loss)
    #for i in range(num_phases):
    #    train_param_losses[i].append(running_train_param_losses[i] / n_train_iter)

    if n_test_iter > 0:
        
        train_batch_losses = []
        model.eval()
        running_train_param_losses = [0.0 for _ in range(num_phases)]
        with torch.no_grad():
            for inputs, outputs in train_dataloader:
                inputs, outputs = inputs.to(device), outputs.to(device)
                predictions = model(inputs)
                loss = criterion(predictions, outputs)
                running_train_loss += loss.mean().item()
                for i in range(num_phases):
                    running_train_param_losses[i] += loss[:, i].mean().item()
                train_batch_losses.append(loss.mean(axis=1).cpu().detach().numpy())
        train_loss = running_train_loss / n_train_iter
        train_losses.append(train_loss)
        for i in range(num_phases):
            train_param_losses[i].append(running_train_param_losses[i] / n_train_iter)
        train_all_losses.append(np.array(train_batch_losses[:-1]))
        

        
        test_batch_losses = []
        model.eval()
        running_test_loss = 0.0
        running_test_param_losses = [0.0 for _ in range(num_phases)]
        with torch.no_grad():
            for inputs, outputs in test_dataloader:
                inputs, outputs = inputs.to(device), outputs.to(device)
                predictions = model(inputs)
                loss = criterion(predictions, outputs)
                running_test_loss += loss.mean().item()
                for i in range(num_phases):
                    running_test_param_losses[i] += loss[:, i].mean().item()
                test_batch_losses.append(loss.mean(axis=1).cpu().detach().numpy())
        test_loss = running_test_loss / n_test_iter
        test_losses.append(test_loss)
        for i in range(num_phases):
            test_param_losses[i].append(running_test_param_losses[i] / n_test_iter)
        test_all_losses.append(np.array(test_batch_losses[:-1]))

        

        total_exp_diff, ph_exp_diff, exp_samples_nb = predict_experimental_data(model, experimental_data, input_size)
        experimental_losses.append(total_exp_diff)

        # Вывод средней разницы, если были найдены соответствия
        if exp_samples_nb > 0:
            if total_exp_diff < pre_fitness:
                #torch.save(model.state_dict(), wghts_fname)
                #print(f'*** Weights are saved to {wghts_fname} after epoch {epoch + 1}')
                pre_fitness = total_exp_diff
            print(f' >>> Средняя разница между предсказанными и OSO: {total_exp_diff:.5g}')
        else:
            total_exp_diff = 0.0
            print('Нет соответствий для подсчета разницы.')

    else:
        test_loss = 0.0
        test_losses.append(test_loss)

    #print(f'Epoch [{epoch + 1}/{num_epochs}], learn_rate: {scheduler.get_last_lr()}, Train Loss: {100 * np.sqrt(train_loss):.5f}, Test Loss: {100 * np.sqrt(test_loss):.5f}')
    print(f'Epoch [{epoch + 1}/{num_epochs}], learn_rate: {scheduler.get_last_lr()}, Train Loss: {1 * (train_loss):.5g}, Test Loss: {1 * (test_loss):.5g}')

    # Вывод ошибок для каждого параметра
    for i in range(num_phases):
        print(f'Фаза {i + 1}: Train: {1 * (train_param_losses[i][-1]):.5g}, Test: {1 * (test_param_losses[i][-1]):.5g}')

    # Форматирование прошедшего времени в "hh:mm:ss"
    elapsed_time = time.time() - start_time  # Вычисляем прошедшее время
    hours, rem = divmod(elapsed_time, 3600)
    minutes, seconds = divmod(rem, 60)
    formatted_time = f"{int(hours):02d}:{int(minutes):02d}:{int(seconds):02d}"

    # Запись данных в CSV-файл
    with open(csv_res_fname, mode='a', newline='') as file:
        writer = csv.writer(file, delimiter=';')
        row = [formatted_time, epoch + 1, 100 * np.sqrt(train_loss), 100 * np.sqrt(test_loss), total_exp_diff] + \
              [100 * np.sqrt(train_param_losses[i][-1]) for i in range(num_phases)] + \
              [100 * np.sqrt(test_param_losses[i][-1]) for i in range(num_phases)] + \
              ph_exp_diff.tolist()
        writer.writerow(row)

    print(f'Прошло времени: {formatted_time}\n')

    scheduler.step()
# Out:
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0079227
# Epoch [1/600], learn_rate: [0.0001], Train Loss: 0.012911, Test Loss: 0.012975
# Фаза 1: Train: 0.013252, Test: 0.013125
# Фаза 2: Train: 0.012887, Test: 0.013919
# Фаза 3: Train: 0.012804, Test: 0.012055
# Фаза 4: Train: 0.012617, Test: 0.012373
# Фаза 5: Train: 0.013053, Test: 0.012347
# Фаза 6: Train: 0.012693, Test: 0.01278
# Фаза 7: Train: 0.012987, Test: 0.013238
# Фаза 8: Train: 0.013047, Test: 0.013729
# Фаза 9: Train: 0.012927, Test: 0.013606
# Фаза 10: Train: 0.012657, Test: 0.013514
# Фаза 11: Train: 0.012855, Test: 0.012665
# Фаза 12: Train: 0.013157, Test: 0.012352
# Прошло времени: 00:00:06
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.010237
# Epoch [2/600], learn_rate: [9.972609476841367e-05], Train Loss: 0.012777, Test Loss: 0.012911
# Фаза 1: Train: 0.013039, Test: 0.012885
# Фаза 2: Train: 0.012691, Test: 0.013903
# Фаза 3: Train: 0.012932, Test: 0.011947
# Фаза 4: Train: 0.012502, Test: 0.012371
# Фаза 5: Train: 0.012786, Test: 0.01237
# Фаза 6: Train: 0.012836, Test: 0.012661
# Фаза 7: Train: 0.012794, Test: 0.012827
# Фаза 8: Train: 0.01283, Test: 0.013779
# Фаза 9: Train: 0.012744, Test: 0.013625
# Фаза 10: Train: 0.012694, Test: 0.013571
# Фаза 11: Train: 0.012935, Test: 0.012686
# Фаза 12: Train: 0.012547, Test: 0.012309
# Прошло времени: 00:00:13
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0058684
# Epoch [3/600], learn_rate: [9.890738003669029e-05], Train Loss: 0.012732, Test Loss: 0.012839
# Фаза 1: Train: 0.012832, Test: 0.012885
# Фаза 2: Train: 0.012638, Test: 0.01384
# Фаза 3: Train: 0.01264, Test: 0.011855
# Фаза 4: Train: 0.012838, Test: 0.012357
# Фаза 5: Train: 0.012805, Test: 0.012394
# Фаза 6: Train: 0.012718, Test: 0.012615
# Фаза 7: Train: 0.012615, Test: 0.012844
# Фаза 8: Train: 0.01275, Test: 0.013301
# Фаза 9: Train: 0.012823, Test: 0.013614
# Фаза 10: Train: 0.012736, Test: 0.01347
# Фаза 11: Train: 0.012744, Test: 0.012573
# Фаза 12: Train: 0.01264, Test: 0.012315
# Прошло времени: 00:00:19
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0068625
# Epoch [4/600], learn_rate: [9.755282581475769e-05], Train Loss: 0.012852, Test Loss: 0.012993
# Фаза 1: Train: 0.013008, Test: 0.01283
# Фаза 2: Train: 0.012814, Test: 0.014044
# Фаза 3: Train: 0.012569, Test: 0.011732
# Фаза 4: Train: 0.012717, Test: 0.012422
# Фаза 5: Train: 0.012761, Test: 0.012329
# Фаза 6: Train: 0.012564, Test: 0.01266
# Фаза 7: Train: 0.013186, Test: 0.012858
# Фаза 8: Train: 0.012636, Test: 0.013384
# Фаза 9: Train: 0.012932, Test: 0.014022
# Фаза 10: Train: 0.012946, Test: 0.013725
# Фаза 11: Train: 0.013096, Test: 0.013152
# Фаза 12: Train: 0.012994, Test: 0.012765
# Прошло времени: 00:00:25
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0055726
# Epoch [5/600], learn_rate: [9.567727288213005e-05], Train Loss: 0.012753, Test Loss: 0.012821
# Фаза 1: Train: 0.012721, Test: 0.012671
# Фаза 2: Train: 0.012594, Test: 0.013827
# Фаза 3: Train: 0.013, Test: 0.011824
# Фаза 4: Train: 0.012881, Test: 0.012215
# Фаза 5: Train: 0.012906, Test: 0.012416
# Фаза 6: Train: 0.012663, Test: 0.012534
# Фаза 7: Train: 0.012622, Test: 0.012737
# Фаза 8: Train: 0.012663, Test: 0.013306
# Фаза 9: Train: 0.012766, Test: 0.013626
# Фаза 10: Train: 0.012593, Test: 0.013605
# Фаза 11: Train: 0.012645, Test: 0.012622
# Фаза 12: Train: 0.012976, Test: 0.012472
# Прошло времени: 00:00:32
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0079989
# Epoch [6/600], learn_rate: [9.330127018922194e-05], Train Loss: 0.012776, Test Loss: 0.012867
# Фаза 1: Train: 0.012667, Test: 0.0126
# Фаза 2: Train: 0.013101, Test: 0.013916
# Фаза 3: Train: 0.012786, Test: 0.0117
# Фаза 4: Train: 0.013157, Test: 0.01247
# Фаза 5: Train: 0.012656, Test: 0.0123
# Фаза 6: Train: 0.012724, Test: 0.012583
# Фаза 7: Train: 0.012498, Test: 0.012722
# Фаза 8: Train: 0.013146, Test: 0.013881
# Фаза 9: Train: 0.012631, Test: 0.013646
# Фаза 10: Train: 0.012714, Test: 0.013653
# Фаза 11: Train: 0.01246, Test: 0.012682
# Фаза 12: Train: 0.012774, Test: 0.012257
# Прошло времени: 00:00:39
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0069354
# Epoch [7/600], learn_rate: [9.045084971874738e-05], Train Loss: 0.012723, Test Loss: 0.012781
# Фаза 1: Train: 0.01286, Test: 0.012631
# Фаза 2: Train: 0.01292, Test: 0.013817
# Фаза 3: Train: 0.012999, Test: 0.01174
# Фаза 4: Train: 0.012528, Test: 0.012142
# Фаза 5: Train: 0.012717, Test: 0.012257
# Фаза 6: Train: 0.012732, Test: 0.012606
# Фаза 7: Train: 0.012401, Test: 0.012794
# Фаза 8: Train: 0.012488, Test: 0.013368
# Фаза 9: Train: 0.012718, Test: 0.013549
# Фаза 10: Train: 0.013008, Test: 0.013472
# Фаза 11: Train: 0.012418, Test: 0.012573
# Фаза 12: Train: 0.012891, Test: 0.012427
# Прошло времени: 00:00:45
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0078154
# Epoch [8/600], learn_rate: [8.715724127386972e-05], Train Loss: 0.0127, Test Loss: 0.012805
# Фаза 1: Train: 0.012408, Test: 0.012588
# Фаза 2: Train: 0.012955, Test: 0.013906
# Фаза 3: Train: 0.012633, Test: 0.011648
# Фаза 4: Train: 0.012885, Test: 0.012337
# Фаза 5: Train: 0.013081, Test: 0.012381
# Фаза 6: Train: 0.012704, Test: 0.012612
# Фаза 7: Train: 0.012316, Test: 0.012838
# Фаза 8: Train: 0.01252, Test: 0.013414
# Фаза 9: Train: 0.012665, Test: 0.013626
# Фаза 10: Train: 0.012817, Test: 0.013499
# Фаза 11: Train: 0.012645, Test: 0.012532
# Фаза 12: Train: 0.012771, Test: 0.012284
# Прошло времени: 00:00:53
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0070824
# Epoch [9/600], learn_rate: [8.345653031794292e-05], Train Loss: 0.012627, Test Loss: 0.012811
# Фаза 1: Train: 0.012602, Test: 0.012846
# Фаза 2: Train: 0.012559, Test: 0.013762
# Фаза 3: Train: 0.012424, Test: 0.011662
# Фаза 4: Train: 0.012473, Test: 0.01224
# Фаза 5: Train: 0.013034, Test: 0.012512
# Фаза 6: Train: 0.012773, Test: 0.012706
# Фаза 7: Train: 0.012749, Test: 0.012788
# Фаза 8: Train: 0.012278, Test: 0.013355
# Фаза 9: Train: 0.012712, Test: 0.013582
# Фаза 10: Train: 0.01296, Test: 0.013483
# Фаза 11: Train: 0.012284, Test: 0.012542
# Фаза 12: Train: 0.012676, Test: 0.012257
# Прошло времени: 00:00:59
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0080245
# Epoch [10/600], learn_rate: [7.938926261462366e-05], Train Loss: 0.012637, Test Loss: 0.012791
# Фаза 1: Train: 0.012712, Test: 0.012711
# Фаза 2: Train: 0.012259, Test: 0.01373
# Фаза 3: Train: 0.012533, Test: 0.011629
# Фаза 4: Train: 0.012486, Test: 0.012159
# Фаза 5: Train: 0.012713, Test: 0.012301
# Фаза 6: Train: 0.012802, Test: 0.012635
# Фаза 7: Train: 0.012288, Test: 0.012765
# Фаза 8: Train: 0.012832, Test: 0.013445
# Фаза 9: Train: 0.012613, Test: 0.013519
# Фаза 10: Train: 0.012613, Test: 0.0135
# Фаза 11: Train: 0.012757, Test: 0.01272
# Фаза 12: Train: 0.013033, Test: 0.012385
# Прошло времени: 00:01:06
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0062001
# Epoch [11/600], learn_rate: [7.500000000000001e-05], Train Loss: 0.012659, Test Loss: 0.012806
# Фаза 1: Train: 0.012617, Test: 0.012714
# Фаза 2: Train: 0.012595, Test: 0.013749
# Фаза 3: Train: 0.012342, Test: 0.011678
# Фаза 4: Train: 0.012354, Test: 0.012171
# Фаза 5: Train: 0.012795, Test: 0.012154
# Фаза 6: Train: 0.012716, Test: 0.012525
# Фаза 7: Train: 0.012695, Test: 0.013082
# Фаза 8: Train: 0.012728, Test: 0.01333
# Фаза 9: Train: 0.012632, Test: 0.013668
# Фаза 10: Train: 0.012824, Test: 0.013451
# Фаза 11: Train: 0.012804, Test: 0.012773
# Фаза 12: Train: 0.012806, Test: 0.012373
# Прошло времени: 00:01:13
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0075056
# Epoch [12/600], learn_rate: [7.033683215379002e-05], Train Loss: 0.012622, Test Loss: 0.012832
# Фаза 1: Train: 0.012496, Test: 0.012568
# Фаза 2: Train: 0.012606, Test: 0.01405
# Фаза 3: Train: 0.012671, Test: 0.011649
# Фаза 4: Train: 0.012635, Test: 0.012188
# Фаза 5: Train: 0.012994, Test: 0.01229
# Фаза 6: Train: 0.012432, Test: 0.012564
# Фаза 7: Train: 0.012396, Test: 0.012843
# Фаза 8: Train: 0.012611, Test: 0.0133
# Фаза 9: Train: 0.012672, Test: 0.01353
# Фаза 10: Train: 0.0125, Test: 0.013512
# Фаза 11: Train: 0.012493, Test: 0.012634
# Фаза 12: Train: 0.012964, Test: 0.012859
# Прошло времени: 00:01:20
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0065408
# Epoch [13/600], learn_rate: [6.545084971874738e-05], Train Loss: 0.012667, Test Loss: 0.012811
# Фаза 1: Train: 0.012777, Test: 0.012799
# Фаза 2: Train: 0.012535, Test: 0.013802
# Фаза 3: Train: 0.012562, Test: 0.011696
# Фаза 4: Train: 0.012455, Test: 0.012149
# Фаза 5: Train: 0.012917, Test: 0.012219
# Фаза 6: Train: 0.012316, Test: 0.012577
# Фаза 7: Train: 0.012758, Test: 0.013286
# Фаза 8: Train: 0.012761, Test: 0.01327
# Фаза 9: Train: 0.012614, Test: 0.013477
# Фаза 10: Train: 0.012966, Test: 0.013613
# Фаза 11: Train: 0.012571, Test: 0.012554
# Фаза 12: Train: 0.012778, Test: 0.01229
# Прошло времени: 00:01:26
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0058245
# Epoch [14/600], learn_rate: [6.0395584540887963e-05], Train Loss: 0.012773, Test Loss: 0.012809
# Фаза 1: Train: 0.013019, Test: 0.01271
# Фаза 2: Train: 0.012637, Test: 0.013925
# Фаза 3: Train: 0.012717, Test: 0.011819
# Фаза 4: Train: 0.01281, Test: 0.012141
# Фаза 5: Train: 0.01302, Test: 0.012235
# Фаза 6: Train: 0.012443, Test: 0.012572
# Фаза 7: Train: 0.013196, Test: 0.012889
# Фаза 8: Train: 0.012526, Test: 0.013275
# Фаза 9: Train: 0.0128, Test: 0.01373
# Фаза 10: Train: 0.012719, Test: 0.013499
# Фаза 11: Train: 0.0125, Test: 0.01259
# Фаза 12: Train: 0.012886, Test: 0.012327
# Прошло времени: 00:01:33
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0069875
# Epoch [15/600], learn_rate: [5.522642316338268e-05], Train Loss: 0.01268, Test Loss: 0.012807
# Фаза 1: Train: 0.012752, Test: 0.012567
# Фаза 2: Train: 0.012607, Test: 0.013886
# Фаза 3: Train: 0.012806, Test: 0.011747
# Фаза 4: Train: 0.012753, Test: 0.012166
# Фаза 5: Train: 0.012555, Test: 0.01217
# Фаза 6: Train: 0.012739, Test: 0.012548
# Фаза 7: Train: 0.012367, Test: 0.012828
# Фаза 8: Train: 0.012788, Test: 0.013267
# Фаза 9: Train: 0.01253, Test: 0.013523
# Фаза 10: Train: 0.012861, Test: 0.013426
# Фаза 11: Train: 0.012429, Test: 0.012569
# Фаза 12: Train: 0.012971, Test: 0.01299
# Прошло времени: 00:01:40
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.006654
# Epoch [16/600], learn_rate: [5.0000000000000016e-05], Train Loss: 0.012682, Test Loss: 0.01276
# Фаза 1: Train: 0.012958, Test: 0.012676
# Фаза 2: Train: 0.01268, Test: 0.01374
# Фаза 3: Train: 0.01282, Test: 0.011602
# Фаза 4: Train: 0.012364, Test: 0.012097
# Фаза 5: Train: 0.012577, Test: 0.012291
# Фаза 6: Train: 0.012653, Test: 0.012508
# Фаза 7: Train: 0.012795, Test: 0.012761
# Фаза 8: Train: 0.012886, Test: 0.013381
# Фаза 9: Train: 0.012858, Test: 0.013672
# Фаза 10: Train: 0.012385, Test: 0.013496
# Фаза 11: Train: 0.012538, Test: 0.012627
# Фаза 12: Train: 0.012674, Test: 0.012263
# Прошло времени: 00:01:46
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0070941
# Epoch [17/600], learn_rate: [4.477357683661734e-05], Train Loss: 0.012647, Test Loss: 0.01278
# Фаза 1: Train: 0.012574, Test: 0.012632
# Фаза 2: Train: 0.012788, Test: 0.013775
# Фаза 3: Train: 0.012476, Test: 0.011648
# Фаза 4: Train: 0.012426, Test: 0.012198
# Фаза 5: Train: 0.012821, Test: 0.012315
# Фаза 6: Train: 0.012644, Test: 0.012562
# Фаза 7: Train: 0.012675, Test: 0.012939
# Фаза 8: Train: 0.012729, Test: 0.013388
# Фаза 9: Train: 0.012572, Test: 0.01349
# Фаза 10: Train: 0.012631, Test: 0.013405
# Фаза 11: Train: 0.012749, Test: 0.012708
# Фаза 12: Train: 0.012685, Test: 0.012302
# Прошло времени: 00:01:53
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0063638
# Epoch [18/600], learn_rate: [3.9604415459112035e-05], Train Loss: 0.01257, Test Loss: 0.012758
# Фаза 1: Train: 0.012688, Test: 0.012614
# Фаза 2: Train: 0.012457, Test: 0.013789
# Фаза 3: Train: 0.012316, Test: 0.011672
# Фаза 4: Train: 0.012482, Test: 0.012147
# Фаза 5: Train: 0.012704, Test: 0.012314
# Фаза 6: Train: 0.012468, Test: 0.012531
# Фаза 7: Train: 0.01267, Test: 0.013045
# Фаза 8: Train: 0.012585, Test: 0.013237
# Фаза 9: Train: 0.012873, Test: 0.013504
# Фаза 10: Train: 0.012387, Test: 0.013459
# Фаза 11: Train: 0.012734, Test: 0.012509
# Фаза 12: Train: 0.012474, Test: 0.01227
# Прошло времени: 00:02:00
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0080073
# Epoch [19/600], learn_rate: [3.4549150281252636e-05], Train Loss: 0.012597, Test Loss: 0.012727
# Фаза 1: Train: 0.012498, Test: 0.01256
# Фаза 2: Train: 0.012483, Test: 0.013838
# Фаза 3: Train: 0.012861, Test: 0.011639
# Фаза 4: Train: 0.012282, Test: 0.012134
# Фаза 5: Train: 0.012923, Test: 0.012215
# Фаза 6: Train: 0.012497, Test: 0.012527
# Фаза 7: Train: 0.012513, Test: 0.01277
# Фаза 8: Train: 0.012587, Test: 0.013331
# Фаза 9: Train: 0.012566, Test: 0.013435
# Фаза 10: Train: 0.012779, Test: 0.013473
# Фаза 11: Train: 0.012632, Test: 0.012541
# Фаза 12: Train: 0.012537, Test: 0.01226
# Прошло времени: 00:02:07
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0053095
# Epoch [20/600], learn_rate: [2.9663167846209998e-05], Train Loss: 0.012587, Test Loss: 0.012714
# Фаза 1: Train: 0.012678, Test: 0.012649
# Фаза 2: Train: 0.012768, Test: 0.013773
# Фаза 3: Train: 0.012392, Test: 0.011683
# Фаза 4: Train: 0.012378, Test: 0.012135
# Фаза 5: Train: 0.012723, Test: 0.012157
# Фаза 6: Train: 0.012725, Test: 0.012506
# Фаза 7: Train: 0.012643, Test: 0.01275
# Фаза 8: Train: 0.012471, Test: 0.013252
# Фаза 9: Train: 0.012502, Test: 0.013527
# Фаза 10: Train: 0.012643, Test: 0.01338
# Фаза 11: Train: 0.012402, Test: 0.012563
# Фаза 12: Train: 0.012717, Test: 0.012197
# Прошло времени: 00:02:14
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0062894
# Epoch [21/600], learn_rate: [2.500000000000001e-05], Train Loss: 0.012551, Test Loss: 0.012717
# Фаза 1: Train: 0.012381, Test: 0.012604
# Фаза 2: Train: 0.012655, Test: 0.013726
# Фаза 3: Train: 0.012478, Test: 0.011674
# Фаза 4: Train: 0.012146, Test: 0.012139
# Фаза 5: Train: 0.013077, Test: 0.012256
# Фаза 6: Train: 0.012548, Test: 0.012499
# Фаза 7: Train: 0.012432, Test: 0.012809
# Фаза 8: Train: 0.012766, Test: 0.013218
# Фаза 9: Train: 0.012588, Test: 0.0135
# Фаза 10: Train: 0.012532, Test: 0.013401
# Фаза 11: Train: 0.012417, Test: 0.012556
# Фаза 12: Train: 0.012596, Test: 0.012227
# Прошло времени: 00:02:20
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0066582
# Epoch [22/600], learn_rate: [2.061073738537635e-05], Train Loss: 0.012667, Test Loss: 0.012729
# Фаза 1: Train: 0.012778, Test: 0.012596
# Фаза 2: Train: 0.012545, Test: 0.013729
# Фаза 3: Train: 0.012836, Test: 0.011634
# Фаза 4: Train: 0.012515, Test: 0.012155
# Фаза 5: Train: 0.012764, Test: 0.012228
# Фаза 6: Train: 0.012509, Test: 0.012548
# Фаза 7: Train: 0.012707, Test: 0.012753
# Фаза 8: Train: 0.012563, Test: 0.013264
# Фаза 9: Train: 0.012743, Test: 0.013519
# Фаза 10: Train: 0.012661, Test: 0.013446
# Фаза 11: Train: 0.012692, Test: 0.012643
# Фаза 12: Train: 0.012686, Test: 0.012239
# Прошло времени: 00:02:27
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0066896
# Epoch [23/600], learn_rate: [1.6543469682057106e-05], Train Loss: 0.012538, Test Loss: 0.012704
# Фаза 1: Train: 0.01246, Test: 0.012618
# Фаза 2: Train: 0.012982, Test: 0.013725
# Фаза 3: Train: 0.012807, Test: 0.011598
# Фаза 4: Train: 0.012123, Test: 0.01213
# Фаза 5: Train: 0.012554, Test: 0.012148
# Фаза 6: Train: 0.012468, Test: 0.012497
# Фаза 7: Train: 0.012375, Test: 0.01278
# Фаза 8: Train: 0.01279, Test: 0.013236
# Фаза 9: Train: 0.012514, Test: 0.013536
# Фаза 10: Train: 0.012559, Test: 0.013441
# Фаза 11: Train: 0.012343, Test: 0.01254
# Фаза 12: Train: 0.012482, Test: 0.0122
# Прошло времени: 00:02:34
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0070816
# Epoch [24/600], learn_rate: [1.2842758726130299e-05], Train Loss: 0.012558, Test Loss: 0.012699
# Фаза 1: Train: 0.012668, Test: 0.01257
# Фаза 2: Train: 0.012787, Test: 0.013726
# Фаза 3: Train: 0.012617, Test: 0.011582
# Фаза 4: Train: 0.012892, Test: 0.01214
# Фаза 5: Train: 0.012484, Test: 0.012136
# Фаза 6: Train: 0.012701, Test: 0.012496
# Фаза 7: Train: 0.012203, Test: 0.012762
# Фаза 8: Train: 0.012459, Test: 0.013293
# Фаза 9: Train: 0.012543, Test: 0.013474
# Фаза 10: Train: 0.012621, Test: 0.013412
# Фаза 11: Train: 0.012299, Test: 0.012571
# Фаза 12: Train: 0.012427, Test: 0.01222
# Прошло времени: 00:02:40
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0062997
# Epoch [25/600], learn_rate: [9.549150281252633e-06], Train Loss: 0.012536, Test Loss: 0.012699
# Фаза 1: Train: 0.012772, Test: 0.01255
# Фаза 2: Train: 0.012138, Test: 0.013739
# Фаза 3: Train: 0.01251, Test: 0.011585
# Фаза 4: Train: 0.012528, Test: 0.012155
# Фаза 5: Train: 0.012755, Test: 0.012132
# Фаза 6: Train: 0.012587, Test: 0.012496
# Фаза 7: Train: 0.012198, Test: 0.012766
# Фаза 8: Train: 0.012761, Test: 0.013242
# Фаза 9: Train: 0.012586, Test: 0.013473
# Фаза 10: Train: 0.012631, Test: 0.013467
# Фаза 11: Train: 0.012425, Test: 0.012525
# Фаза 12: Train: 0.012545, Test: 0.012262
# Прошло времени: 00:02:47
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0058711
# Epoch [26/600], learn_rate: [6.698729810778065e-06], Train Loss: 0.012558, Test Loss: 0.012695
# Фаза 1: Train: 0.01255, Test: 0.012552
# Фаза 2: Train: 0.012465, Test: 0.013724
# Фаза 3: Train: 0.012457, Test: 0.011628
# Фаза 4: Train: 0.012437, Test: 0.012114
# Фаза 5: Train: 0.012815, Test: 0.012145
# Фаза 6: Train: 0.012663, Test: 0.012533
# Фаза 7: Train: 0.012635, Test: 0.012764
# Фаза 8: Train: 0.012803, Test: 0.013235
# Фаза 9: Train: 0.012554, Test: 0.013455
# Фаза 10: Train: 0.012483, Test: 0.013437
# Фаза 11: Train: 0.012301, Test: 0.012536
# Фаза 12: Train: 0.012531, Test: 0.01222
# Прошло времени: 00:02:54
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0064866
# Epoch [27/600], learn_rate: [4.322727117869951e-06], Train Loss: 0.012499, Test Loss: 0.012692
# Фаза 1: Train: 0.012571, Test: 0.012551
# Фаза 2: Train: 0.012359, Test: 0.013735
# Фаза 3: Train: 0.012844, Test: 0.011593
# Фаза 4: Train: 0.012379, Test: 0.0121
# Фаза 5: Train: 0.012731, Test: 0.012141
# Фаза 6: Train: 0.012519, Test: 0.012507
# Фаза 7: Train: 0.012533, Test: 0.012769
# Фаза 8: Train: 0.012578, Test: 0.013235
# Фаза 9: Train: 0.01245, Test: 0.013453
# Фаза 10: Train: 0.012333, Test: 0.013438
# Фаза 11: Train: 0.012369, Test: 0.012532
# Фаза 12: Train: 0.012327, Test: 0.012249
# Прошло времени: 00:03:01
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0066132
# Epoch [28/600], learn_rate: [2.4471741852423237e-06], Train Loss: 0.012479, Test Loss: 0.012694
# Фаза 1: Train: 0.012388, Test: 0.012555
# Фаза 2: Train: 0.01264, Test: 0.01374
# Фаза 3: Train: 0.012356, Test: 0.011584
# Фаза 4: Train: 0.012322, Test: 0.012104
# Фаза 5: Train: 0.012885, Test: 0.012141
# Фаза 6: Train: 0.012585, Test: 0.012508
# Фаза 7: Train: 0.01216, Test: 0.012771
# Фаза 8: Train: 0.012483, Test: 0.013229
# Фаза 9: Train: 0.012481, Test: 0.013457
# Фаза 10: Train: 0.012392, Test: 0.013431
# Фаза 11: Train: 0.012483, Test: 0.012535
# Фаза 12: Train: 0.012568, Test: 0.012273
# Прошло времени: 00:03:08
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0065017
# Epoch [29/600], learn_rate: [1.0926199633097157e-06], Train Loss: 0.01247, Test Loss: 0.012693
# Фаза 1: Train: 0.01242, Test: 0.012561
# Фаза 2: Train: 0.012497, Test: 0.013717
# Фаза 3: Train: 0.012463, Test: 0.011585
# Фаза 4: Train: 0.012194, Test: 0.012108
# Фаза 5: Train: 0.01263, Test: 0.012139
# Фаза 6: Train: 0.012556, Test: 0.012506
# Фаза 7: Train: 0.012081, Test: 0.012774
# Фаза 8: Train: 0.012643, Test: 0.013238
# Фаза 9: Train: 0.012423, Test: 0.013465
# Фаза 10: Train: 0.012562, Test: 0.013426
# Фаза 11: Train: 0.012482, Test: 0.012537
# Фаза 12: Train: 0.012691, Test: 0.01226
# Прошло времени: 00:03:15
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0065075
# Epoch [30/600], learn_rate: [2.7390523158633e-07], Train Loss: 0.012519, Test Loss: 0.012693
# Фаза 1: Train: 0.012675, Test: 0.012556
# Фаза 2: Train: 0.012589, Test: 0.013725
# Фаза 3: Train: 0.012428, Test: 0.011584
# Фаза 4: Train: 0.012642, Test: 0.012111
# Фаза 5: Train: 0.012656, Test: 0.012139
# Фаза 6: Train: 0.012375, Test: 0.01251
# Фаза 7: Train: 0.012295, Test: 0.012772
# Фаза 8: Train: 0.012605, Test: 0.01324
# Фаза 9: Train: 0.01252, Test: 0.013462
# Фаза 10: Train: 0.012453, Test: 0.013425
# Фаза 11: Train: 0.012507, Test: 0.012536
# Фаза 12: Train: 0.012479, Test: 0.012254
# Прошло времени: 00:03:21
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0057786
# Epoch [31/600], learn_rate: [0.0001], Train Loss: 0.01269, Test Loss: 0.012817
# Фаза 1: Train: 0.012569, Test: 0.012608
# Фаза 2: Train: 0.012736, Test: 0.013779
# Фаза 3: Train: 0.012762, Test: 0.011679
# Фаза 4: Train: 0.012675, Test: 0.012479
# Фаза 5: Train: 0.012883, Test: 0.012201
# Фаза 6: Train: 0.012757, Test: 0.012644
# Фаза 7: Train: 0.012563, Test: 0.01295
# Фаза 8: Train: 0.013096, Test: 0.013362
# Фаза 9: Train: 0.012512, Test: 0.013492
# Фаза 10: Train: 0.012651, Test: 0.013574
# Фаза 11: Train: 0.012358, Test: 0.012679
# Фаза 12: Train: 0.012716, Test: 0.012362
# Прошло времени: 00:03:28
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0080976
# Epoch [32/600], learn_rate: [9.972609476841367e-05], Train Loss: 0.012693, Test Loss: 0.012851
# Фаза 1: Train: 0.01284, Test: 0.012716
# Фаза 2: Train: 0.012551, Test: 0.013792
# Фаза 3: Train: 0.012792, Test: 0.01167
# Фаза 4: Train: 0.012534, Test: 0.012196
# Фаза 5: Train: 0.012579, Test: 0.012196
# Фаза 6: Train: 0.012634, Test: 0.012548
# Фаза 7: Train: 0.0128, Test: 0.013364
# Фаза 8: Train: 0.012793, Test: 0.013336
# Фаза 9: Train: 0.012456, Test: 0.013501
# Фаза 10: Train: 0.01257, Test: 0.013511
# Фаза 11: Train: 0.012571, Test: 0.012656
# Фаза 12: Train: 0.013194, Test: 0.012727
# Прошло времени: 00:03:35
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.008155
# Epoch [33/600], learn_rate: [9.890738003669029e-05], Train Loss: 0.012631, Test Loss: 0.012869
# Фаза 1: Train: 0.012254, Test: 0.012548
# Фаза 2: Train: 0.012556, Test: 0.013993
# Фаза 3: Train: 0.012712, Test: 0.011629
# Фаза 4: Train: 0.012161, Test: 0.012199
# Фаза 5: Train: 0.012767, Test: 0.012255
# Фаза 6: Train: 0.012989, Test: 0.012993
# Фаза 7: Train: 0.013015, Test: 0.013208
# Фаза 8: Train: 0.01255, Test: 0.013598
# Фаза 9: Train: 0.012787, Test: 0.013618
# Фаза 10: Train: 0.012608, Test: 0.013399
# Фаза 11: Train: 0.012648, Test: 0.01268
# Фаза 12: Train: 0.012522, Test: 0.012311
# Прошло времени: 00:03:41
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0074401
# Epoch [34/600], learn_rate: [9.755282581475769e-05], Train Loss: 0.012649, Test Loss: 0.012807
# Фаза 1: Train: 0.012826, Test: 0.012717
# Фаза 2: Train: 0.012585, Test: 0.013781
# Фаза 3: Train: 0.012517, Test: 0.01163
# Фаза 4: Train: 0.012409, Test: 0.012311
# Фаза 5: Train: 0.012596, Test: 0.012201
# Фаза 6: Train: 0.012752, Test: 0.012658
# Фаза 7: Train: 0.012628, Test: 0.012871
# Фаза 8: Train: 0.012564, Test: 0.013357
# Фаза 9: Train: 0.013119, Test: 0.013765
# Фаза 10: Train: 0.012686, Test: 0.013442
# Фаза 11: Train: 0.012684, Test: 0.012631
# Фаза 12: Train: 0.01242, Test: 0.012322
# Прошло времени: 00:03:48
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0063594
# Epoch [35/600], learn_rate: [9.567727288213005e-05], Train Loss: 0.012561, Test Loss: 0.012772
# Фаза 1: Train: 0.012554, Test: 0.012582
# Фаза 2: Train: 0.012522, Test: 0.013902
# Фаза 3: Train: 0.012458, Test: 0.0116
# Фаза 4: Train: 0.012553, Test: 0.01219
# Фаза 5: Train: 0.012654, Test: 0.012201
# Фаза 6: Train: 0.01266, Test: 0.012544
# Фаза 7: Train: 0.01241, Test: 0.012902
# Фаза 8: Train: 0.012565, Test: 0.013326
# Фаза 9: Train: 0.01266, Test: 0.013545
# Фаза 10: Train: 0.01266, Test: 0.013404
# Фаза 11: Train: 0.012559, Test: 0.012662
# Фаза 12: Train: 0.012484, Test: 0.012403
# Прошло времени: 00:03:55
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0053982
# Epoch [36/600], learn_rate: [9.330127018922194e-05], Train Loss: 0.012535, Test Loss: 0.012779
# Фаза 1: Train: 0.012779, Test: 0.012649
# Фаза 2: Train: 0.012476, Test: 0.013759
# Фаза 3: Train: 0.012509, Test: 0.011713
# Фаза 4: Train: 0.012404, Test: 0.012266
# Фаза 5: Train: 0.012757, Test: 0.012276
# Фаза 6: Train: 0.012649, Test: 0.012571
# Фаза 7: Train: 0.012121, Test: 0.012916
# Фаза 8: Train: 0.013041, Test: 0.013407
# Фаза 9: Train: 0.012499, Test: 0.013511
# Фаза 10: Train: 0.01232, Test: 0.013514
# Фаза 11: Train: 0.012337, Test: 0.012533
# Фаза 12: Train: 0.012527, Test: 0.012238
# Прошло времени: 00:04:01
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0067349
# Epoch [37/600], learn_rate: [9.045084971874738e-05], Train Loss: 0.012527, Test Loss: 0.012739
# Фаза 1: Train: 0.012641, Test: 0.012688
# Фаза 2: Train: 0.012413, Test: 0.013726
# Фаза 3: Train: 0.012709, Test: 0.011676
# Фаза 4: Train: 0.012429, Test: 0.012136
# Фаза 5: Train: 0.012798, Test: 0.012268
# Фаза 6: Train: 0.012548, Test: 0.012533
# Фаза 7: Train: 0.012523, Test: 0.01273
# Фаза 8: Train: 0.012561, Test: 0.013259
# Фаза 9: Train: 0.012463, Test: 0.013533
# Фаза 10: Train: 0.012574, Test: 0.013498
# Фаза 11: Train: 0.012425, Test: 0.012532
# Фаза 12: Train: 0.012244, Test: 0.012293
# Прошло времени: 00:04:08
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0086984
# Epoch [38/600], learn_rate: [8.715724127386972e-05], Train Loss: 0.012631, Test Loss: 0.012803
# Фаза 1: Train: 0.012397, Test: 0.01261
# Фаза 2: Train: 0.013286, Test: 0.014195
# Фаза 3: Train: 0.012877, Test: 0.011708
# Фаза 4: Train: 0.012295, Test: 0.012165
# Фаза 5: Train: 0.012666, Test: 0.012294
# Фаза 6: Train: 0.012513, Test: 0.012547
# Фаза 7: Train: 0.012402, Test: 0.012803
# Фаза 8: Train: 0.012633, Test: 0.013362
# Фаза 9: Train: 0.012702, Test: 0.013588
# Фаза 10: Train: 0.012542, Test: 0.013548
# Фаза 11: Train: 0.012556, Test: 0.012588
# Фаза 12: Train: 0.012708, Test: 0.012226
# Прошло времени: 00:04:14
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0077969
# Epoch [39/600], learn_rate: [8.345653031794292e-05], Train Loss: 0.012609, Test Loss: 0.01276
# Фаза 1: Train: 0.012513, Test: 0.012559
# Фаза 2: Train: 0.012816, Test: 0.013707
# Фаза 3: Train: 0.012647, Test: 0.011616
# Фаза 4: Train: 0.012677, Test: 0.012272
# Фаза 5: Train: 0.012859, Test: 0.012329
# Фаза 6: Train: 0.012438, Test: 0.012555
# Фаза 7: Train: 0.012426, Test: 0.012963
# Фаза 8: Train: 0.012585, Test: 0.013221
# Фаза 9: Train: 0.012459, Test: 0.013515
# Фаза 10: Train: 0.012509, Test: 0.01338
# Фаза 11: Train: 0.012714, Test: 0.012614
# Фаза 12: Train: 0.012664, Test: 0.012387
# Прошло времени: 00:04:21
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0067975
# Epoch [40/600], learn_rate: [7.938926261462366e-05], Train Loss: 0.012572, Test Loss: 0.012787
# Фаза 1: Train: 0.012913, Test: 0.012861
# Фаза 2: Train: 0.012575, Test: 0.013745
# Фаза 3: Train: 0.012549, Test: 0.011618
# Фаза 4: Train: 0.012528, Test: 0.012385
# Фаза 5: Train: 0.012855, Test: 0.01229
# Фаза 6: Train: 0.012464, Test: 0.012574
# Фаза 7: Train: 0.012468, Test: 0.012915
# Фаза 8: Train: 0.012252, Test: 0.0133
# Фаза 9: Train: 0.012627, Test: 0.013489
# Фаза 10: Train: 0.012701, Test: 0.013446
# Фаза 11: Train: 0.012634, Test: 0.012637
# Фаза 12: Train: 0.012297, Test: 0.012181
# Прошло времени: 00:04:27
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0072486
# Epoch [41/600], learn_rate: [7.500000000000001e-05], Train Loss: 0.012587, Test Loss: 0.012743
# Фаза 1: Train: 0.012654, Test: 0.012627
# Фаза 2: Train: 0.012605, Test: 0.013746
# Фаза 3: Train: 0.012437, Test: 0.011608
# Фаза 4: Train: 0.01248, Test: 0.012111
# Фаза 5: Train: 0.01284, Test: 0.012217
# Фаза 6: Train: 0.012692, Test: 0.012631
# Фаза 7: Train: 0.012687, Test: 0.012754
# Фаза 8: Train: 0.012504, Test: 0.013369
# Фаза 9: Train: 0.012706, Test: 0.013673
# Фаза 10: Train: 0.01238, Test: 0.013373
# Фаза 11: Train: 0.012449, Test: 0.012541
# Фаза 12: Train: 0.012605, Test: 0.01227
# Прошло времени: 00:04:33
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0075411
# Epoch [42/600], learn_rate: [7.033683215379002e-05], Train Loss: 0.012582, Test Loss: 0.012732
# Фаза 1: Train: 0.012395, Test: 0.012603
# Фаза 2: Train: 0.012736, Test: 0.013757
# Фаза 3: Train: 0.012275, Test: 0.011629
# Фаза 4: Train: 0.012479, Test: 0.012174
# Фаза 5: Train: 0.012773, Test: 0.012171
# Фаза 6: Train: 0.012422, Test: 0.012533
# Фаза 7: Train: 0.01243, Test: 0.012799
# Фаза 8: Train: 0.012721, Test: 0.013386
# Фаза 9: Train: 0.012766, Test: 0.013532
# Фаза 10: Train: 0.012453, Test: 0.013395
# Фаза 11: Train: 0.012625, Test: 0.012626
# Фаза 12: Train: 0.01291, Test: 0.012186
# Прошло времени: 00:04:40
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.005824
# Epoch [43/600], learn_rate: [6.545084971874738e-05], Train Loss: 0.012505, Test Loss: 0.012749
# Фаза 1: Train: 0.012311, Test: 0.012582
# Фаза 2: Train: 0.012549, Test: 0.013814
# Фаза 3: Train: 0.012467, Test: 0.011628
# Фаза 4: Train: 0.012384, Test: 0.012263
# Фаза 5: Train: 0.012717, Test: 0.012162
# Фаза 6: Train: 0.012389, Test: 0.012571
# Фаза 7: Train: 0.012571, Test: 0.012866
# Фаза 8: Train: 0.012702, Test: 0.013269
# Фаза 9: Train: 0.012373, Test: 0.013531
# Фаза 10: Train: 0.012703, Test: 0.013473
# Фаза 11: Train: 0.012512, Test: 0.012522
# Фаза 12: Train: 0.012381, Test: 0.012306
# Прошло времени: 00:04:46
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0075441
# Epoch [44/600], learn_rate: [6.0395584540887963e-05], Train Loss: 0.012508, Test Loss: 0.012735
# Фаза 1: Train: 0.012701, Test: 0.012578
# Фаза 2: Train: 0.012335, Test: 0.013734
# Фаза 3: Train: 0.012424, Test: 0.01161
# Фаза 4: Train: 0.012293, Test: 0.012185
# Фаза 5: Train: 0.012851, Test: 0.012298
# Фаза 6: Train: 0.01217, Test: 0.012565
# Фаза 7: Train: 0.012453, Test: 0.01277
# Фаза 8: Train: 0.012662, Test: 0.013348
# Фаза 9: Train: 0.012676, Test: 0.01352
# Фаза 10: Train: 0.012613, Test: 0.013399
# Фаза 11: Train: 0.012548, Test: 0.012566
# Фаза 12: Train: 0.012373, Test: 0.012249
# Прошло времени: 00:04:53
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0070737
# Epoch [45/600], learn_rate: [5.522642316338268e-05], Train Loss: 0.012491, Test Loss: 0.012783
# Фаза 1: Train: 0.012777, Test: 0.012713
# Фаза 2: Train: 0.012493, Test: 0.013896
# Фаза 3: Train: 0.012372, Test: 0.011599
# Фаза 4: Train: 0.012364, Test: 0.01217
# Фаза 5: Train: 0.012414, Test: 0.012175
# Фаза 6: Train: 0.01263, Test: 0.012608
# Фаза 7: Train: 0.012217, Test: 0.012796
# Фаза 8: Train: 0.012523, Test: 0.013385
# Фаза 9: Train: 0.012565, Test: 0.013476
# Фаза 10: Train: 0.012508, Test: 0.013458
# Фаза 11: Train: 0.012673, Test: 0.012853
# Фаза 12: Train: 0.012362, Test: 0.012269
# Прошло времени: 00:04:59
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0053439
# Epoch [46/600], learn_rate: [5.0000000000000016e-05], Train Loss: 0.012539, Test Loss: 0.012739
# Фаза 1: Train: 0.012677, Test: 0.012583
# Фаза 2: Train: 0.012364, Test: 0.013723
# Фаза 3: Train: 0.012775, Test: 0.011688
# Фаза 4: Train: 0.012278, Test: 0.012178
# Фаза 5: Train: 0.012794, Test: 0.012146
# Фаза 6: Train: 0.012711, Test: 0.012637
# Фаза 7: Train: 0.012272, Test: 0.012801
# Фаза 8: Train: 0.012383, Test: 0.013304
# Фаза 9: Train: 0.01263, Test: 0.013554
# Фаза 10: Train: 0.012556, Test: 0.013425
# Фаза 11: Train: 0.012683, Test: 0.012577
# Фаза 12: Train: 0.012347, Test: 0.012259
# Прошло времени: 00:05:06
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0078991
# Epoch [47/600], learn_rate: [4.477357683661734e-05], Train Loss: 0.012537, Test Loss: 0.012731
# Фаза 1: Train: 0.012671, Test: 0.012599
# Фаза 2: Train: 0.012503, Test: 0.013716
# Фаза 3: Train: 0.012635, Test: 0.011639
# Фаза 4: Train: 0.012504, Test: 0.012099
# Фаза 5: Train: 0.012652, Test: 0.01223
# Фаза 6: Train: 0.012499, Test: 0.012614
# Фаза 7: Train: 0.012568, Test: 0.01276
# Фаза 8: Train: 0.012605, Test: 0.01326
# Фаза 9: Train: 0.012712, Test: 0.013503
# Фаза 10: Train: 0.012494, Test: 0.013426
# Фаза 11: Train: 0.012368, Test: 0.012544
# Фаза 12: Train: 0.012238, Test: 0.012387
# Прошло времени: 00:05:13
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0067717
# Epoch [48/600], learn_rate: [3.9604415459112035e-05], Train Loss: 0.01248, Test Loss: 0.012754
# Фаза 1: Train: 0.012444, Test: 0.012629
# Фаза 2: Train: 0.012599, Test: 0.013752
# Фаза 3: Train: 0.012754, Test: 0.011596
# Фаза 4: Train: 0.012234, Test: 0.01217
# Фаза 5: Train: 0.012702, Test: 0.012176
# Фаза 6: Train: 0.012603, Test: 0.012553
# Фаза 7: Train: 0.012223, Test: 0.012907
# Фаза 8: Train: 0.012507, Test: 0.013331
# Фаза 9: Train: 0.012584, Test: 0.013509
# Фаза 10: Train: 0.012651, Test: 0.0135
# Фаза 11: Train: 0.012321, Test: 0.012656
# Фаза 12: Train: 0.012137, Test: 0.012271
# Прошло времени: 00:05:20
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0059964
# Epoch [49/600], learn_rate: [3.4549150281252636e-05], Train Loss: 0.012534, Test Loss: 0.012735
# Фаза 1: Train: 0.012884, Test: 0.012583
# Фаза 2: Train: 0.012393, Test: 0.013755
# Фаза 3: Train: 0.012409, Test: 0.011708
# Фаза 4: Train: 0.012502, Test: 0.012116
# Фаза 5: Train: 0.012646, Test: 0.012171
# Фаза 6: Train: 0.012684, Test: 0.012604
# Фаза 7: Train: 0.012657, Test: 0.012744
# Фаза 8: Train: 0.012568, Test: 0.01334
# Фаза 9: Train: 0.012611, Test: 0.013497
# Фаза 10: Train: 0.012629, Test: 0.013413
# Фаза 11: Train: 0.012226, Test: 0.012565
# Фаза 12: Train: 0.012199, Test: 0.012321
# Прошло времени: 00:05:28
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0056362
# Epoch [50/600], learn_rate: [2.9663167846209998e-05], Train Loss: 0.012483, Test Loss: 0.01273
# Фаза 1: Train: 0.012333, Test: 0.012601
# Фаза 2: Train: 0.012585, Test: 0.013732
# Фаза 3: Train: 0.012769, Test: 0.011671
# Фаза 4: Train: 0.01257, Test: 0.012124
# Фаза 5: Train: 0.012777, Test: 0.012142
# Фаза 6: Train: 0.0127, Test: 0.012599
# Фаза 7: Train: 0.012148, Test: 0.012804
# Фаза 8: Train: 0.012681, Test: 0.013268
# Фаза 9: Train: 0.012474, Test: 0.013448
# Фаза 10: Train: 0.01233, Test: 0.013462
# Фаза 11: Train: 0.012222, Test: 0.012579
# Фаза 12: Train: 0.012209, Test: 0.012331
# Прошло времени: 00:05:35
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0079887
# Epoch [51/600], learn_rate: [2.500000000000001e-05], Train Loss: 0.012496, Test Loss: 0.01274
# Фаза 1: Train: 0.012523, Test: 0.012576
# Фаза 2: Train: 0.012641, Test: 0.013807
# Фаза 3: Train: 0.012653, Test: 0.011665
# Фаза 4: Train: 0.012421, Test: 0.012138
# Фаза 5: Train: 0.012824, Test: 0.012196
# Фаза 6: Train: 0.012297, Test: 0.012558
# Фаза 7: Train: 0.012048, Test: 0.012832
# Фаза 8: Train: 0.012499, Test: 0.01332
# Фаза 9: Train: 0.012533, Test: 0.013502
# Фаза 10: Train: 0.012704, Test: 0.013466
# Фаза 11: Train: 0.012453, Test: 0.012562
# Фаза 12: Train: 0.012354, Test: 0.012262
# Прошло времени: 00:05:41
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0064514
# Epoch [52/600], learn_rate: [2.061073738537635e-05], Train Loss: 0.012508, Test Loss: 0.012728
# Фаза 1: Train: 0.0125, Test: 0.012573
# Фаза 2: Train: 0.012551, Test: 0.013732
# Фаза 3: Train: 0.012451, Test: 0.011603
# Фаза 4: Train: 0.012606, Test: 0.012098
# Фаза 5: Train: 0.012754, Test: 0.012183
# Фаза 6: Train: 0.012557, Test: 0.012572
# Фаза 7: Train: 0.012409, Test: 0.012798
# Фаза 8: Train: 0.012439, Test: 0.01332
# Фаза 9: Train: 0.012655, Test: 0.013519
# Фаза 10: Train: 0.012288, Test: 0.013492
# Фаза 11: Train: 0.012505, Test: 0.012537
# Фаза 12: Train: 0.012378, Test: 0.012306
# Прошло времени: 00:05:48
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0067365
# Epoch [53/600], learn_rate: [1.6543469682057106e-05], Train Loss: 0.012509, Test Loss: 0.012728
# Фаза 1: Train: 0.012516, Test: 0.012603
# Фаза 2: Train: 0.012498, Test: 0.013753
# Фаза 3: Train: 0.012139, Test: 0.011601
# Фаза 4: Train: 0.012472, Test: 0.012123
# Фаза 5: Train: 0.012461, Test: 0.012193
# Фаза 6: Train: 0.012458, Test: 0.012553
# Фаза 7: Train: 0.012413, Test: 0.012854
# Фаза 8: Train: 0.01277, Test: 0.013288
# Фаза 9: Train: 0.012968, Test: 0.013481
# Фаза 10: Train: 0.012628, Test: 0.013457
# Фаза 11: Train: 0.012327, Test: 0.012558
# Фаза 12: Train: 0.012465, Test: 0.012268
# Прошло времени: 00:05:55
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0063381
# Epoch [54/600], learn_rate: [1.2842758726130299e-05], Train Loss: 0.012442, Test Loss: 0.012721
# Фаза 1: Train: 0.012665, Test: 0.012583
# Фаза 2: Train: 0.012437, Test: 0.013739
# Фаза 3: Train: 0.012506, Test: 0.01164
# Фаза 4: Train: 0.01226, Test: 0.012115
# Фаза 5: Train: 0.012405, Test: 0.012191
# Фаза 6: Train: 0.012485, Test: 0.012582
# Фаза 7: Train: 0.012202, Test: 0.012779
# Фаза 8: Train: 0.012534, Test: 0.013275
# Фаза 9: Train: 0.012402, Test: 0.013465
# Фаза 10: Train: 0.012595, Test: 0.01345
# Фаза 11: Train: 0.012549, Test: 0.012532
# Фаза 12: Train: 0.012265, Test: 0.012299
# Прошло времени: 00:06:02
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0067422
# Epoch [55/600], learn_rate: [9.549150281252633e-06], Train Loss: 0.012479, Test Loss: 0.01272
# Фаза 1: Train: 0.012563, Test: 0.012578
# Фаза 2: Train: 0.012739, Test: 0.013735
# Фаза 3: Train: 0.012547, Test: 0.011605
# Фаза 4: Train: 0.012151, Test: 0.012108
# Фаза 5: Train: 0.012454, Test: 0.012207
# Фаза 6: Train: 0.012432, Test: 0.012572
# Фаза 7: Train: 0.012173, Test: 0.012828
# Фаза 8: Train: 0.012508, Test: 0.013292
# Фаза 9: Train: 0.012752, Test: 0.013493
# Фаза 10: Train: 0.012591, Test: 0.013417
# Фаза 11: Train: 0.012364, Test: 0.012535
# Фаза 12: Train: 0.012473, Test: 0.012265
# Прошло времени: 00:06:09
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0057479
# Epoch [56/600], learn_rate: [6.698729810778065e-06], Train Loss: 0.012447, Test Loss: 0.012718
# Фаза 1: Train: 0.012494, Test: 0.012574
# Фаза 2: Train: 0.012282, Test: 0.013746
# Фаза 3: Train: 0.012481, Test: 0.011623
# Фаза 4: Train: 0.012724, Test: 0.012114
# Фаза 5: Train: 0.012422, Test: 0.012172
# Фаза 6: Train: 0.012692, Test: 0.012559
# Фаза 7: Train: 0.012189, Test: 0.012818
# Фаза 8: Train: 0.012302, Test: 0.013311
# Фаза 9: Train: 0.01255, Test: 0.013469
# Фаза 10: Train: 0.01247, Test: 0.013401
# Фаза 11: Train: 0.012342, Test: 0.012548
# Фаза 12: Train: 0.012418, Test: 0.012284
# Прошло времени: 00:06:16
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0061589
# Epoch [57/600], learn_rate: [4.322727117869951e-06], Train Loss: 0.012481, Test Loss: 0.012707
# Фаза 1: Train: 0.012631, Test: 0.012578
# Фаза 2: Train: 0.012253, Test: 0.013727
# Фаза 3: Train: 0.012663, Test: 0.011598
# Фаза 4: Train: 0.012145, Test: 0.012115
# Фаза 5: Train: 0.012844, Test: 0.012167
# Фаза 6: Train: 0.01257, Test: 0.012561
# Фаза 7: Train: 0.012151, Test: 0.012788
# Фаза 8: Train: 0.012608, Test: 0.013294
# Фаза 9: Train: 0.012461, Test: 0.013456
# Фаза 10: Train: 0.012542, Test: 0.013411
# Фаза 11: Train: 0.012433, Test: 0.012532
# Фаза 12: Train: 0.012475, Test: 0.012258
# Прошло времени: 00:06:23
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0058701
# Epoch [58/600], learn_rate: [2.4471741852423237e-06], Train Loss: 0.012455, Test Loss: 0.012712
# Фаза 1: Train: 0.012512, Test: 0.012586
# Фаза 2: Train: 0.012396, Test: 0.013723
# Фаза 3: Train: 0.012532, Test: 0.011607
# Фаза 4: Train: 0.012235, Test: 0.012103
# Фаза 5: Train: 0.012424, Test: 0.012172
# Фаза 6: Train: 0.01255, Test: 0.012562
# Фаза 7: Train: 0.012242, Test: 0.01278
# Фаза 8: Train: 0.012608, Test: 0.01331
# Фаза 9: Train: 0.012425, Test: 0.013462
# Фаза 10: Train: 0.012533, Test: 0.013432
# Фаза 11: Train: 0.012693, Test: 0.012527
# Фаза 12: Train: 0.012307, Test: 0.012277
# Прошло времени: 00:06:30
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0058325
# Epoch [59/600], learn_rate: [1.0926199633097157e-06], Train Loss: 0.01248, Test Loss: 0.012712
# Фаза 1: Train: 0.012374, Test: 0.012584
# Фаза 2: Train: 0.012316, Test: 0.013719
# Фаза 3: Train: 0.012706, Test: 0.011607
# Фаза 4: Train: 0.012327, Test: 0.012112
# Фаза 5: Train: 0.012813, Test: 0.012171
# Фаза 6: Train: 0.012705, Test: 0.012555
# Фаза 7: Train: 0.012308, Test: 0.012802
# Фаза 8: Train: 0.012412, Test: 0.013311
# Фаза 9: Train: 0.012404, Test: 0.013466
# Фаза 10: Train: 0.012657, Test: 0.013421
# Фаза 11: Train: 0.012398, Test: 0.012527
# Фаза 12: Train: 0.01234, Test: 0.012276
# Прошло времени: 00:06:36
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0058661
# Epoch [60/600], learn_rate: [2.7390523158633e-07], Train Loss: 0.012427, Test Loss: 0.012712
# Фаза 1: Train: 0.012751, Test: 0.012581
# Фаза 2: Train: 0.012531, Test: 0.013722
# Фаза 3: Train: 0.012332, Test: 0.011607
# Фаза 4: Train: 0.012229, Test: 0.012107
# Фаза 5: Train: 0.012421, Test: 0.012173
# Фаза 6: Train: 0.012464, Test: 0.012558
# Фаза 7: Train: 0.012388, Test: 0.012795
# Фаза 8: Train: 0.012404, Test: 0.01331
# Фаза 9: Train: 0.012553, Test: 0.013465
# Фаза 10: Train: 0.012244, Test: 0.013424
# Фаза 11: Train: 0.012503, Test: 0.012528
# Фаза 12: Train: 0.012302, Test: 0.012275
# Прошло времени: 00:06:43
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0070689
# Epoch [61/600], learn_rate: [0.0001], Train Loss: 0.012507, Test Loss: 0.012757
# Фаза 1: Train: 0.012565, Test: 0.012631
# Фаза 2: Train: 0.012572, Test: 0.013849
# Фаза 3: Train: 0.012347, Test: 0.011673
# Фаза 4: Train: 0.012372, Test: 0.012285
# Фаза 5: Train: 0.012648, Test: 0.012206
# Фаза 6: Train: 0.012566, Test: 0.012608
# Фаза 7: Train: 0.012258, Test: 0.012803
# Фаза 8: Train: 0.012598, Test: 0.013379
# Фаза 9: Train: 0.012452, Test: 0.013514
# Фаза 10: Train: 0.012559, Test: 0.013357
# Фаза 11: Train: 0.012677, Test: 0.012538
# Фаза 12: Train: 0.012474, Test: 0.012242
# Прошло времени: 00:06:49
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0064012
# Epoch [62/600], learn_rate: [9.972609476841367e-05], Train Loss: 0.012472, Test Loss: 0.012732
# Фаза 1: Train: 0.012357, Test: 0.012634
# Фаза 2: Train: 0.012596, Test: 0.01375
# Фаза 3: Train: 0.012532, Test: 0.011638
# Фаза 4: Train: 0.012497, Test: 0.012115
# Фаза 5: Train: 0.012499, Test: 0.012138
# Фаза 6: Train: 0.01266, Test: 0.012616
# Фаза 7: Train: 0.012161, Test: 0.012823
# Фаза 8: Train: 0.012568, Test: 0.013303
# Фаза 9: Train: 0.012286, Test: 0.013522
# Фаза 10: Train: 0.012654, Test: 0.013384
# Фаза 11: Train: 0.012527, Test: 0.01262
# Фаза 12: Train: 0.012332, Test: 0.012235
# Прошло времени: 00:06:55
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0083774
# Epoch [63/600], learn_rate: [9.890738003669029e-05], Train Loss: 0.012552, Test Loss: 0.012759
# Фаза 1: Train: 0.012599, Test: 0.012593
# Фаза 2: Train: 0.012576, Test: 0.013744
# Фаза 3: Train: 0.012573, Test: 0.011687
# Фаза 4: Train: 0.01233, Test: 0.012109
# Фаза 5: Train: 0.012657, Test: 0.012299
# Фаза 6: Train: 0.012669, Test: 0.012619
# Фаза 7: Train: 0.012628, Test: 0.012913
# Фаза 8: Train: 0.012616, Test: 0.013278
# Фаза 9: Train: 0.012382, Test: 0.013496
# Фаза 10: Train: 0.012841, Test: 0.013425
# Фаза 11: Train: 0.0123, Test: 0.012516
# Фаза 12: Train: 0.012458, Test: 0.012429
# Прошло времени: 00:07:02
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0067918
# Epoch [64/600], learn_rate: [9.755282581475769e-05], Train Loss: 0.012498, Test Loss: 0.012774
# Фаза 1: Train: 0.01253, Test: 0.012629
# Фаза 2: Train: 0.012459, Test: 0.013865
# Фаза 3: Train: 0.012703, Test: 0.01166
# Фаза 4: Train: 0.012289, Test: 0.012129
# Фаза 5: Train: 0.0126, Test: 0.012309
# Фаза 6: Train: 0.01249, Test: 0.012538
# Фаза 7: Train: 0.01236, Test: 0.012993
# Фаза 8: Train: 0.012438, Test: 0.013303
# Фаза 9: Train: 0.012783, Test: 0.013498
# Фаза 10: Train: 0.012424, Test: 0.013415
# Фаза 11: Train: 0.01258, Test: 0.012593
# Фаза 12: Train: 0.012317, Test: 0.012356
# Прошло времени: 00:07:08
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0050179
# Epoch [65/600], learn_rate: [9.567727288213005e-05], Train Loss: 0.012483, Test Loss: 0.012801
# Фаза 1: Train: 0.012608, Test: 0.012578
# Фаза 2: Train: 0.012464, Test: 0.01375
# Фаза 3: Train: 0.012522, Test: 0.01166
# Фаза 4: Train: 0.012332, Test: 0.012391
# Фаза 5: Train: 0.01211, Test: 0.012216
# Фаза 6: Train: 0.012787, Test: 0.012551
# Фаза 7: Train: 0.012448, Test: 0.012995
# Фаза 8: Train: 0.012393, Test: 0.01334
# Фаза 9: Train: 0.012401, Test: 0.013576
# Фаза 10: Train: 0.012729, Test: 0.013435
# Фаза 11: Train: 0.012666, Test: 0.012764
# Фаза 12: Train: 0.012338, Test: 0.012356
# Прошло времени: 00:07:15
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0059033
# Epoch [66/600], learn_rate: [9.330127018922194e-05], Train Loss: 0.012612, Test Loss: 0.012848
# Фаза 1: Train: 0.012595, Test: 0.012679
# Фаза 2: Train: 0.012508, Test: 0.014045
# Фаза 3: Train: 0.012742, Test: 0.011709
# Фаза 4: Train: 0.012507, Test: 0.01215
# Фаза 5: Train: 0.012678, Test: 0.012285
# Фаза 6: Train: 0.012779, Test: 0.012587
# Фаза 7: Train: 0.012328, Test: 0.01301
# Фаза 8: Train: 0.012623, Test: 0.013391
# Фаза 9: Train: 0.012623, Test: 0.013485
# Фаза 10: Train: 0.012876, Test: 0.013438
# Фаза 11: Train: 0.012554, Test: 0.012587
# Фаза 12: Train: 0.012534, Test: 0.012813
# Прошло времени: 00:07:21
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0053544
# Epoch [67/600], learn_rate: [9.045084971874738e-05], Train Loss: 0.012521, Test Loss: 0.012773
# Фаза 1: Train: 0.012728, Test: 0.012648
# Фаза 2: Train: 0.01262, Test: 0.013816
# Фаза 3: Train: 0.012657, Test: 0.011625
# Фаза 4: Train: 0.012284, Test: 0.01221
# Фаза 5: Train: 0.012667, Test: 0.012255
# Фаза 6: Train: 0.012528, Test: 0.012594
# Фаза 7: Train: 0.012336, Test: 0.012734
# Фаза 8: Train: 0.012591, Test: 0.013494
# Фаза 9: Train: 0.012427, Test: 0.013527
# Фаза 10: Train: 0.012545, Test: 0.013446
# Фаза 11: Train: 0.0124, Test: 0.012566
# Фаза 12: Train: 0.012474, Test: 0.012363
# Прошло времени: 00:07:28
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0064433
# Epoch [68/600], learn_rate: [8.715724127386972e-05], Train Loss: 0.012474, Test Loss: 0.012802
# Фаза 1: Train: 0.012707, Test: 0.012718
# Фаза 2: Train: 0.012452, Test: 0.013916
# Фаза 3: Train: 0.012585, Test: 0.011588
# Фаза 4: Train: 0.01203, Test: 0.012132
# Фаза 5: Train: 0.012536, Test: 0.012225
# Фаза 6: Train: 0.012337, Test: 0.012686
# Фаза 7: Train: 0.012338, Test: 0.012891
# Фаза 8: Train: 0.012527, Test: 0.013296
# Фаза 9: Train: 0.012796, Test: 0.013624
# Фаза 10: Train: 0.012611, Test: 0.013484
# Фаза 11: Train: 0.012422, Test: 0.012656
# Фаза 12: Train: 0.012345, Test: 0.012404
# Прошло времени: 00:07:35
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0064396
# Epoch [69/600], learn_rate: [8.345653031794292e-05], Train Loss: 0.012365, Test Loss: 0.012756
# Фаза 1: Train: 0.012535, Test: 0.012596
# Фаза 2: Train: 0.012131, Test: 0.013808
# Фаза 3: Train: 0.012351, Test: 0.01161
# Фаза 4: Train: 0.012215, Test: 0.012171
# Фаза 5: Train: 0.012452, Test: 0.012157
# Фаза 6: Train: 0.012276, Test: 0.01268
# Фаза 7: Train: 0.012412, Test: 0.012861
# Фаза 8: Train: 0.012494, Test: 0.01337
# Фаза 9: Train: 0.012403, Test: 0.013504
# Фаза 10: Train: 0.012071, Test: 0.013429
# Фаза 11: Train: 0.01258, Test: 0.012587
# Фаза 12: Train: 0.012459, Test: 0.012299
# Прошло времени: 00:07:42
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0061921
# Epoch [70/600], learn_rate: [7.938926261462366e-05], Train Loss: 0.012548, Test Loss: 0.012821
# Фаза 1: Train: 0.012625, Test: 0.012607
# Фаза 2: Train: 0.012486, Test: 0.013864
# Фаза 3: Train: 0.01281, Test: 0.011636
# Фаза 4: Train: 0.012312, Test: 0.012139
# Фаза 5: Train: 0.012564, Test: 0.012205
# Фаза 6: Train: 0.012379, Test: 0.012645
# Фаза 7: Train: 0.012765, Test: 0.013047
# Фаза 8: Train: 0.012583, Test: 0.013439
# Фаза 9: Train: 0.012401, Test: 0.013477
# Фаза 10: Train: 0.012456, Test: 0.013709
# Фаза 11: Train: 0.012299, Test: 0.012591
# Фаза 12: Train: 0.012894, Test: 0.012488
# Прошло времени: 00:07:49
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0056086
# Epoch [71/600], learn_rate: [7.500000000000001e-05], Train Loss: 0.012432, Test Loss: 0.012827
# Фаза 1: Train: 0.012625, Test: 0.012613
# Фаза 2: Train: 0.012123, Test: 0.013866
# Фаза 3: Train: 0.012451, Test: 0.011724
# Фаза 4: Train: 0.012521, Test: 0.012284
# Фаза 5: Train: 0.012568, Test: 0.012184
# Фаза 6: Train: 0.012937, Test: 0.012749
# Фаза 7: Train: 0.012322, Test: 0.013065
# Фаза 8: Train: 0.012428, Test: 0.013465
# Фаза 9: Train: 0.012118, Test: 0.013525
# Фаза 10: Train: 0.012245, Test: 0.013517
# Фаза 11: Train: 0.012513, Test: 0.012583
# Фаза 12: Train: 0.012338, Test: 0.012348
# Прошло времени: 00:07:56
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0047797
# Epoch [72/600], learn_rate: [7.033683215379002e-05], Train Loss: 0.012502, Test Loss: 0.012771
# ...
# Фаза 2: Train: 0.011061, Test: 0.014468
# Фаза 3: Train: 0.011652, Test: 0.012129
# Фаза 4: Train: 0.010791, Test: 0.01308
# Фаза 5: Train: 0.010993, Test: 0.013625
# Фаза 6: Train: 0.011562, Test: 0.013306
# Фаза 7: Train: 0.010643, Test: 0.013885
# Фаза 8: Train: 0.011532, Test: 0.014004
# Фаза 9: Train: 0.01111, Test: 0.014634
# Фаза 10: Train: 0.010864, Test: 0.014023
# Фаза 11: Train: 0.011596, Test: 0.013207
# Фаза 12: Train: 0.0105, Test: 0.013796
# Прошло времени: 01:03:04
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.004372
# Epoch [578/600], learn_rate: [8.715724127386972e-05], Train Loss: 0.011106, Test Loss: 0.013641
# Фаза 1: Train: 0.011367, Test: 0.013251
# Фаза 2: Train: 0.011043, Test: 0.014425
# Фаза 3: Train: 0.011439, Test: 0.012352
# Фаза 4: Train: 0.010823, Test: 0.012872
# Фаза 5: Train: 0.011077, Test: 0.013456
# Фаза 6: Train: 0.011664, Test: 0.01329
# Фаза 7: Train: 0.010519, Test: 0.014024
# Фаза 8: Train: 0.011348, Test: 0.014386
# Фаза 9: Train: 0.011239, Test: 0.01462
# Фаза 10: Train: 0.010816, Test: 0.014012
# Фаза 11: Train: 0.011302, Test: 0.013165
# Фаза 12: Train: 0.010637, Test: 0.013843
# Прошло времени: 01:03:11
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0050301
# Epoch [579/600], learn_rate: [8.345653031794292e-05], Train Loss: 0.011061, Test Loss: 0.013575
# Фаза 1: Train: 0.011264, Test: 0.013351
# Фаза 2: Train: 0.011103, Test: 0.014445
# Фаза 3: Train: 0.011494, Test: 0.012192
# Фаза 4: Train: 0.010817, Test: 0.01278
# Фаза 5: Train: 0.011067, Test: 0.013277
# Фаза 6: Train: 0.01144, Test: 0.013292
# Фаза 7: Train: 0.010589, Test: 0.01393
# Фаза 8: Train: 0.011604, Test: 0.014373
# Фаза 9: Train: 0.010908, Test: 0.014466
# Фаза 10: Train: 0.010877, Test: 0.01403
# Фаза 11: Train: 0.011364, Test: 0.012941
# Фаза 12: Train: 0.01021, Test: 0.013824
# Прошло времени: 01:03:17
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0066493
# Epoch [580/600], learn_rate: [7.938926261462366e-05], Train Loss: 0.011096, Test Loss: 0.013574
# Фаза 1: Train: 0.011244, Test: 0.013357
# Фаза 2: Train: 0.011263, Test: 0.014457
# Фаза 3: Train: 0.011547, Test: 0.012191
# Фаза 4: Train: 0.01104, Test: 0.012827
# Фаза 5: Train: 0.010863, Test: 0.013271
# Фаза 6: Train: 0.011522, Test: 0.013134
# Фаза 7: Train: 0.010703, Test: 0.013861
# Фаза 8: Train: 0.011304, Test: 0.01404
# Фаза 9: Train: 0.011027, Test: 0.01478
# Фаза 10: Train: 0.010655, Test: 0.014286
# Фаза 11: Train: 0.011197, Test: 0.012964
# Фаза 12: Train: 0.010784, Test: 0.013721
# Прошло времени: 01:03:24
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.004881
# Epoch [581/600], learn_rate: [7.500000000000001e-05], Train Loss: 0.011063, Test Loss: 0.013612
# Фаза 1: Train: 0.0114, Test: 0.013356
# Фаза 2: Train: 0.010971, Test: 0.014402
# Фаза 3: Train: 0.011392, Test: 0.012299
# Фаза 4: Train: 0.010947, Test: 0.01304
# Фаза 5: Train: 0.010863, Test: 0.013191
# Фаза 6: Train: 0.011537, Test: 0.013179
# Фаза 7: Train: 0.01053, Test: 0.014083
# Фаза 8: Train: 0.011337, Test: 0.014129
# Фаза 9: Train: 0.010779, Test: 0.014486
# Фаза 10: Train: 0.011045, Test: 0.014392
# Фаза 11: Train: 0.011295, Test: 0.012978
# Фаза 12: Train: 0.010664, Test: 0.013805
# Прошло времени: 01:03:30
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0049541
# Epoch [582/600], learn_rate: [7.033683215379002e-05], Train Loss: 0.011023, Test Loss: 0.013568
# Фаза 1: Train: 0.011347, Test: 0.013452
# Фаза 2: Train: 0.011239, Test: 0.014465
# Фаза 3: Train: 0.011415, Test: 0.01206
# Фаза 4: Train: 0.010843, Test: 0.012912
# Фаза 5: Train: 0.010855, Test: 0.013363
# Фаза 6: Train: 0.011742, Test: 0.013188
# Фаза 7: Train: 0.010324, Test: 0.013857
# Фаза 8: Train: 0.011232, Test: 0.014152
# Фаза 9: Train: 0.010943, Test: 0.014506
# Фаза 10: Train: 0.010659, Test: 0.013979
# Фаза 11: Train: 0.011305, Test: 0.012998
# Фаза 12: Train: 0.01037, Test: 0.013889
# Прошло времени: 01:03:37
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.006066
# Epoch [583/600], learn_rate: [6.545084971874738e-05], Train Loss: 0.01108, Test Loss: 0.013541
# Фаза 1: Train: 0.011278, Test: 0.01324
# Фаза 2: Train: 0.01106, Test: 0.014436
# Фаза 3: Train: 0.01122, Test: 0.012062
# Фаза 4: Train: 0.010919, Test: 0.012787
# Фаза 5: Train: 0.010997, Test: 0.013176
# Фаза 6: Train: 0.011674, Test: 0.013164
# Фаза 7: Train: 0.010457, Test: 0.013879
# Фаза 8: Train: 0.011101, Test: 0.014193
# Фаза 9: Train: 0.011199, Test: 0.014559
# Фаза 10: Train: 0.010871, Test: 0.014289
# Фаза 11: Train: 0.011411, Test: 0.012967
# Фаза 12: Train: 0.010769, Test: 0.013739
# Прошло времени: 01:03:43
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0055332
# Epoch [584/600], learn_rate: [6.0395584540887963e-05], Train Loss: 0.011091, Test Loss: 0.0136
# Фаза 1: Train: 0.01146, Test: 0.013451
# Фаза 2: Train: 0.01096, Test: 0.014516
# Фаза 3: Train: 0.011336, Test: 0.012155
# Фаза 4: Train: 0.010876, Test: 0.013007
# Фаза 5: Train: 0.011034, Test: 0.013314
# Фаза 6: Train: 0.011695, Test: 0.01307
# Фаза 7: Train: 0.010669, Test: 0.014034
# Фаза 8: Train: 0.011244, Test: 0.014067
# Фаза 9: Train: 0.011041, Test: 0.014367
# Фаза 10: Train: 0.01083, Test: 0.014375
# Фаза 11: Train: 0.011346, Test: 0.013015
# Фаза 12: Train: 0.010605, Test: 0.013836
# Прошло времени: 01:03:50
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0048457
# Epoch [585/600], learn_rate: [5.522642316338268e-05], Train Loss: 0.011084, Test Loss: 0.013576
# Фаза 1: Train: 0.011132, Test: 0.013315
# Фаза 2: Train: 0.011071, Test: 0.014447
# Фаза 3: Train: 0.011278, Test: 0.012172
# Фаза 4: Train: 0.010942, Test: 0.012904
# Фаза 5: Train: 0.011117, Test: 0.013248
# Фаза 6: Train: 0.011565, Test: 0.013157
# Фаза 7: Train: 0.010681, Test: 0.01396
# Фаза 8: Train: 0.011355, Test: 0.014077
# Фаза 9: Train: 0.011072, Test: 0.014477
# Фаза 10: Train: 0.011084, Test: 0.01427
# Фаза 11: Train: 0.011206, Test: 0.013056
# Фаза 12: Train: 0.010499, Test: 0.013827
# Прошло времени: 01:03:56
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0050254
# Epoch [586/600], learn_rate: [5.0000000000000016e-05], Train Loss: 0.010964, Test Loss: 0.013694
# Фаза 1: Train: 0.011356, Test: 0.01356
# Фаза 2: Train: 0.010986, Test: 0.014566
# Фаза 3: Train: 0.011421, Test: 0.012117
# Фаза 4: Train: 0.010673, Test: 0.012866
# Фаза 5: Train: 0.011067, Test: 0.013466
# Фаза 6: Train: 0.011316, Test: 0.013162
# Фаза 7: Train: 0.010295, Test: 0.014024
# Фаза 8: Train: 0.01104, Test: 0.014102
# Фаза 9: Train: 0.010831, Test: 0.014554
# Фаза 10: Train: 0.010917, Test: 0.014776
# Фаза 11: Train: 0.011193, Test: 0.013239
# Фаза 12: Train: 0.010477, Test: 0.013897
# Прошло времени: 01:04:03
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0045397
# Epoch [587/600], learn_rate: [4.477357683661734e-05], Train Loss: 0.011044, Test Loss: 0.013612
# Фаза 1: Train: 0.011364, Test: 0.013284
# Фаза 2: Train: 0.011119, Test: 0.014511
# Фаза 3: Train: 0.011194, Test: 0.0123
# Фаза 4: Train: 0.010852, Test: 0.01289
# Фаза 5: Train: 0.011087, Test: 0.013332
# Фаза 6: Train: 0.011515, Test: 0.013186
# Фаза 7: Train: 0.010552, Test: 0.013893
# Фаза 8: Train: 0.011339, Test: 0.014095
# Фаза 9: Train: 0.010981, Test: 0.014695
# Фаза 10: Train: 0.010828, Test: 0.014257
# Фаза 11: Train: 0.011357, Test: 0.013099
# Фаза 12: Train: 0.010338, Test: 0.013801
# Прошло времени: 01:04:09
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0047343
# Epoch [588/600], learn_rate: [3.9604415459112035e-05], Train Loss: 0.011004, Test Loss: 0.013597
# Фаза 1: Train: 0.011004, Test: 0.013295
# Фаза 2: Train: 0.01103, Test: 0.014431
# Фаза 3: Train: 0.011616, Test: 0.012304
# Фаза 4: Train: 0.010636, Test: 0.012895
# Фаза 5: Train: 0.011157, Test: 0.013401
# Фаза 6: Train: 0.011547, Test: 0.013228
# Фаза 7: Train: 0.01055, Test: 0.013871
# Фаза 8: Train: 0.011181, Test: 0.014254
# Фаза 9: Train: 0.010884, Test: 0.014441
# Фаза 10: Train: 0.010716, Test: 0.014149
# Фаза 11: Train: 0.011227, Test: 0.013007
# Фаза 12: Train: 0.010503, Test: 0.013889
# Прошло времени: 01:04:16
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0050613
# Epoch [589/600], learn_rate: [3.4549150281252636e-05], Train Loss: 0.01107, Test Loss: 0.013656
# Фаза 1: Train: 0.011026, Test: 0.013308
# Фаза 2: Train: 0.011138, Test: 0.014543
# Фаза 3: Train: 0.011359, Test: 0.012255
# Фаза 4: Train: 0.010962, Test: 0.01298
# Фаза 5: Train: 0.010964, Test: 0.0134
# Фаза 6: Train: 0.011948, Test: 0.013459
# Фаза 7: Train: 0.010687, Test: 0.013938
# Фаза 8: Train: 0.011053, Test: 0.014254
# Фаза 9: Train: 0.010893, Test: 0.014511
# Фаза 10: Train: 0.010733, Test: 0.014181
# Фаза 11: Train: 0.011514, Test: 0.0131
# Фаза 12: Train: 0.010561, Test: 0.013938
# Прошло времени: 01:04:22
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0050817
# Epoch [590/600], learn_rate: [2.9663167846209998e-05], Train Loss: 0.010952, Test Loss: 0.013601
# Фаза 1: Train: 0.011105, Test: 0.013282
# Фаза 2: Train: 0.011014, Test: 0.014536
# Фаза 3: Train: 0.011194, Test: 0.012194
# Фаза 4: Train: 0.011093, Test: 0.012861
# Фаза 5: Train: 0.010891, Test: 0.013408
# Фаза 6: Train: 0.011346, Test: 0.013257
# Фаза 7: Train: 0.01041, Test: 0.014056
# Фаза 8: Train: 0.011226, Test: 0.014151
# Фаза 9: Train: 0.010808, Test: 0.014509
# Фаза 10: Train: 0.010562, Test: 0.014054
# Фаза 11: Train: 0.011077, Test: 0.013042
# Фаза 12: Train: 0.010698, Test: 0.013868
# Прошло времени: 01:04:29
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0048874
# Epoch [591/600], learn_rate: [2.500000000000001e-05], Train Loss: 0.011026, Test Loss: 0.013592
# Фаза 1: Train: 0.011236, Test: 0.013273
# Фаза 2: Train: 0.011073, Test: 0.014502
# Фаза 3: Train: 0.011103, Test: 0.01218
# Фаза 4: Train: 0.010775, Test: 0.012878
# Фаза 5: Train: 0.010776, Test: 0.013375
# Фаза 6: Train: 0.011678, Test: 0.013241
# Фаза 7: Train: 0.010556, Test: 0.013953
# Фаза 8: Train: 0.011259, Test: 0.014194
# Фаза 9: Train: 0.010974, Test: 0.014402
# Фаза 10: Train: 0.01074, Test: 0.014233
# Фаза 11: Train: 0.011437, Test: 0.012999
# Фаза 12: Train: 0.010705, Test: 0.013868
# Прошло времени: 01:04:35
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0047918
# Epoch [592/600], learn_rate: [2.061073738537635e-05], Train Loss: 0.01095, Test Loss: 0.013578
# Фаза 1: Train: 0.01121, Test: 0.013307
# Фаза 2: Train: 0.010999, Test: 0.014446
# Фаза 3: Train: 0.011301, Test: 0.012192
# Фаза 4: Train: 0.010647, Test: 0.01298
# Фаза 5: Train: 0.01084, Test: 0.013354
# Фаза 6: Train: 0.011302, Test: 0.013194
# Фаза 7: Train: 0.010569, Test: 0.013894
# Фаза 8: Train: 0.011133, Test: 0.014213
# Фаза 9: Train: 0.010912, Test: 0.014438
# Фаза 10: Train: 0.010658, Test: 0.014103
# Фаза 11: Train: 0.011408, Test: 0.012985
# Фаза 12: Train: 0.010423, Test: 0.01383
# Прошло времени: 01:04:42
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0051217
# Epoch [593/600], learn_rate: [1.6543469682057106e-05], Train Loss: 0.010915, Test Loss: 0.0136
# Фаза 1: Train: 0.011173, Test: 0.013314
# Фаза 2: Train: 0.011021, Test: 0.014488
# Фаза 3: Train: 0.01119, Test: 0.012216
# Фаза 4: Train: 0.010735, Test: 0.01293
# Фаза 5: Train: 0.010721, Test: 0.013368
# Фаза 6: Train: 0.011346, Test: 0.013274
# Фаза 7: Train: 0.01057, Test: 0.01391
# Фаза 8: Train: 0.010914, Test: 0.014128
# Фаза 9: Train: 0.010795, Test: 0.014521
# Фаза 10: Train: 0.010751, Test: 0.014189
# Фаза 11: Train: 0.011189, Test: 0.012984
# Фаза 12: Train: 0.010571, Test: 0.013882
# Прошло времени: 01:04:48
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0051999
# Epoch [594/600], learn_rate: [1.2842758726130299e-05], Train Loss: 0.010965, Test Loss: 0.013605
# Фаза 1: Train: 0.011014, Test: 0.013327
# Фаза 2: Train: 0.010897, Test: 0.014521
# Фаза 3: Train: 0.011369, Test: 0.012158
# Фаза 4: Train: 0.010875, Test: 0.012937
# Фаза 5: Train: 0.011014, Test: 0.013347
# Фаза 6: Train: 0.011488, Test: 0.013262
# Фаза 7: Train: 0.010498, Test: 0.013975
# Фаза 8: Train: 0.011076, Test: 0.014128
# Фаза 9: Train: 0.010709, Test: 0.014444
# Фаза 10: Train: 0.01081, Test: 0.014214
# Фаза 11: Train: 0.011215, Test: 0.013039
# Фаза 12: Train: 0.010608, Test: 0.013906
# Прошло времени: 01:04:55
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.005006
# Epoch [595/600], learn_rate: [9.549150281252633e-06], Train Loss: 0.010975, Test Loss: 0.013596
# Фаза 1: Train: 0.011124, Test: 0.013342
# Фаза 2: Train: 0.010875, Test: 0.014492
# Фаза 3: Train: 0.011604, Test: 0.012184
# Фаза 4: Train: 0.010891, Test: 0.012922
# Фаза 5: Train: 0.010998, Test: 0.013353
# Фаза 6: Train: 0.011544, Test: 0.013233
# Фаза 7: Train: 0.010354, Test: 0.013952
# Фаза 8: Train: 0.011156, Test: 0.014129
# Фаза 9: Train: 0.010971, Test: 0.014447
# Фаза 10: Train: 0.010479, Test: 0.014174
# Фаза 11: Train: 0.011501, Test: 0.01304
# Фаза 12: Train: 0.010203, Test: 0.01388
# Прошло времени: 01:05:01
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.004935
# Epoch [596/600], learn_rate: [6.698729810778065e-06], Train Loss: 0.010983, Test Loss: 0.013617
# Фаза 1: Train: 0.011002, Test: 0.013377
# Фаза 2: Train: 0.011235, Test: 0.014518
# Фаза 3: Train: 0.011323, Test: 0.012187
# Фаза 4: Train: 0.010868, Test: 0.012945
# Фаза 5: Train: 0.010933, Test: 0.013339
# Фаза 6: Train: 0.011591, Test: 0.013239
# Фаза 7: Train: 0.010394, Test: 0.013974
# Фаза 8: Train: 0.01118, Test: 0.014138
# Фаза 9: Train: 0.010724, Test: 0.014495
# Фаза 10: Train: 0.01084, Test: 0.014178
# Фаза 11: Train: 0.011302, Test: 0.013114
# Фаза 12: Train: 0.010404, Test: 0.013893
# Прошло времени: 01:05:08
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.005274
# Epoch [597/600], learn_rate: [4.322727117869951e-06], Train Loss: 0.010942, Test Loss: 0.013583
# Фаза 1: Train: 0.010986, Test: 0.013332
# Фаза 2: Train: 0.010971, Test: 0.01447
# Фаза 3: Train: 0.011234, Test: 0.01215
# Фаза 4: Train: 0.01075, Test: 0.012907
# Фаза 5: Train: 0.01092, Test: 0.013354
# Фаза 6: Train: 0.011613, Test: 0.013202
# Фаза 7: Train: 0.010468, Test: 0.013939
# Фаза 8: Train: 0.011114, Test: 0.014109
# Фаза 9: Train: 0.010835, Test: 0.014471
# Фаза 10: Train: 0.010831, Test: 0.014172
# Фаза 11: Train: 0.011087, Test: 0.013071
# Фаза 12: Train: 0.010494, Test: 0.013819
# Прошло времени: 01:05:14
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0049755
# Epoch [598/600], learn_rate: [2.4471741852423237e-06], Train Loss: 0.010879, Test Loss: 0.013591
# Фаза 1: Train: 0.01103, Test: 0.01332
# Фаза 2: Train: 0.010995, Test: 0.014493
# Фаза 3: Train: 0.011419, Test: 0.012192
# Фаза 4: Train: 0.010651, Test: 0.0129
# Фаза 5: Train: 0.010782, Test: 0.013344
# Фаза 6: Train: 0.011357, Test: 0.013221
# Фаза 7: Train: 0.010371, Test: 0.013937
# Фаза 8: Train: 0.01092, Test: 0.01414
# Фаза 9: Train: 0.010533, Test: 0.014469
# Фаза 10: Train: 0.010762, Test: 0.014172
# Фаза 11: Train: 0.011047, Test: 0.013066
# Фаза 12: Train: 0.010678, Test: 0.013845
# Прошло времени: 01:05:21
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.0051048
# Epoch [599/600], learn_rate: [1.0926199633097157e-06], Train Loss: 0.01091, Test Loss: 0.013599
# Фаза 1: Train: 0.011301, Test: 0.013334
# Фаза 2: Train: 0.01109, Test: 0.014496
# Фаза 3: Train: 0.011315, Test: 0.012177
# Фаза 4: Train: 0.010721, Test: 0.012908
# Фаза 5: Train: 0.010637, Test: 0.013358
# Фаза 6: Train: 0.01128, Test: 0.01322
# Фаза 7: Train: 0.010277, Test: 0.013951
# Фаза 8: Train: 0.011072, Test: 0.014141
# Фаза 9: Train: 0.010667, Test: 0.014488
# Фаза 10: Train: 0.010769, Test: 0.01418
# Фаза 11: Train: 0.011504, Test: 0.01307
# Фаза 12: Train: 0.010289, Test: 0.01386
# Прошло времени: 01:05:27
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.005065
# Epoch [600/600], learn_rate: [2.7390523158633e-07], Train Loss: 0.011003, Test Loss: 0.013597
# Фаза 1: Train: 0.011274, Test: 0.013332
# Фаза 2: Train: 0.011129, Test: 0.014492
# Фаза 3: Train: 0.011342, Test: 0.012177
# Фаза 4: Train: 0.010993, Test: 0.012908
# Фаза 5: Train: 0.010917, Test: 0.013353
# Фаза 6: Train: 0.011337, Test: 0.013225
# Фаза 7: Train: 0.010443, Test: 0.013949
# Фаза 8: Train: 0.011256, Test: 0.014141
# Фаза 9: Train: 0.010861, Test: 0.014489
# Фаза 10: Train: 0.010873, Test: 0.014179
# Фаза 11: Train: 0.011386, Test: 0.013061
# Фаза 12: Train: 0.010225, Test: 0.013854
# Прошло времени: 01:05:34

# %%
np_train_all_losses = np.array(train_all_losses)
np_test_all_losses = np.array(test_all_losses)
print(np_train_all_losses.shape)
print(np_test_all_losses.shape)
len_train = np_train_all_losses.shape[1]*np_train_all_losses.shape[2]
print(len_train)
len_test = np_test_all_losses.shape[1]*np_test_all_losses.shape[2]
print(len_test)
np_train_all_losses = np_train_all_losses.reshape(np_train_all_losses.shape[0],len_train)
np_test_all_losses = np_test_all_losses.reshape(np_train_all_losses.shape[0],len_test)
inter1 = 299
print(np.mean(np_train_all_losses[inter1]))
print(np.std(np_train_all_losses[inter1]))
print(np.median(np_train_all_losses[inter1]))
print(np.mean(np_test_all_losses[inter1]))
print(np.std(np_test_all_losses[inter1]))
print(np.median(np_test_all_losses[inter1]))
x_scaled = np.arange(len_test)*len_train/len_test
print(x_scaled)
# Out:
# (600, 703, 128)
# (600, 78, 128)
# 89984
# 9984
# 0.011552018
# 0.012822883
# 0.0063307425
# 0.013196343
# 0.014398087
# 0.0076380875
# [0.00000000e+00 9.01282051e+00 1.80256410e+01 ... 8.99569615e+04
#  8.99659744e+04 8.99749872e+04]

# %%
plt.plot(np.sort(np_train_all_losses[inter1]))
plt.plot(x_scaled,np.sort(np_test_all_losses[inter1]),linestyle='-.')
plt.show()

# %%
plt.plot(train_losses,label='train_loss')
plt.plot(test_losses,label='test_loss')
plt.plot(experimental_losses,label='experimental_losses')
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()

# %%
df1 = pd.read_csv('OSO_ViT_8h_2L_d256_4040_12_1e-4.csv',delimiter=';')
df2 = pd.read_csv('OSO_CNN_ViT_W40_S20_8h_d256_8040_1e-4.csv',delimiter=';')
df3 = pd.read_csv('OSO_CNN_ViT_W40_S1_8h_d256_8040_1e-4.csv',delimiter=';')
#print(df1)

# %%
plt.plot((df1['Train Loss'].to_numpy()/100)**2,label='train_loss')
plt.plot((df1['Test Loss'].to_numpy()/100)**2,label='test_loss')
plt.plot(df1['Exp_Diff'].to_numpy(),label='experimental_losses')
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()

# %%
plt.plot((df2['Train Loss'].to_numpy()/100)**2,label='train_loss')
plt.plot((df2['Test Loss'].to_numpy()/100)**2,label='test_loss')
plt.plot(df2['Exp_Diff'].to_numpy(),label='experimental_losses')
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()

# %%
plt.plot((df3['Train Loss'].to_numpy()/100)**2,label='train_loss')
plt.plot((df3['Test Loss'].to_numpy()/100)**2,label='test_loss')
plt.plot(df3['Exp_Diff'].to_numpy(),label='experimental_losses')
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()

# %%
plt.plot(df1['Exp_Diff'].to_numpy(),label='experimental_losses_ViT')
plt.plot(df2['Exp_Diff'].to_numpy(),label='experimental_losses_CNN_Transformer')
plt.plot(df3['Exp_Diff'].to_numpy(),label='experimental_losses_CNN_Transformer-stride1')
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()

# %%
def time_to_seconds(time_str):
    hours, minutes, seconds = map(int, time_str.split(':'))
    return hours * 3600 + minutes * 60 + seconds

# %%
t1 = []
t2 = []
for t in df1['Time'].to_numpy():
    t1.append(time_to_seconds(t))
for t in df2['Time'].to_numpy():
    t2.append(time_to_seconds(t))
plt.plot(t1,label='experimental_losses_CNN')
plt.plot(t2,label='experimental_losses_ViT')
plt.legend()
#plt.yscale('log')
plt.grid(True)
plt.show()
