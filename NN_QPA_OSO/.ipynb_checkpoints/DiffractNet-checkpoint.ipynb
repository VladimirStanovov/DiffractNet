# %%
import os
import struct
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, WeightedRandomSampler
import torch.optim.lr_scheduler as lr_scheduler
import time
import csv
import glob
from diffraction_utils import load_experimental_data
from load_xml_phases import *
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
difr_dir = "../../nn_data/"
os.makedirs(difr_dir, exist_ok=True)

# Автовыбор вычислительного устройства
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('device =', device)

# Вычисляем размер входа для свертки
input_size = 4001
num_phases = 12

xml_name = 'OSO'
model_ver = 'light_3'
wghts_fname = f'weights3_{xml_name}_{model_ver}.pth'
csv_res_fname = f"{xml_name}_{model_ver}.csv"

inp_data = []
out_data = []

PHASES_INFO = []

experiment_folder = 'XY_OSO_midKO'
# Out:
# device = cuda:0

# %%
# Создаем словарь для сопоставления имен файлов и целевых значений
target_values = {
    'Бо1125_180121.xy': np.array([0.42, 0.25, 42.72, 44.65, 2.22, 8.05, 0.00, 1.40, 0.28, 0.00, 0.01, 0.00]),
    'Бо2074_200121.xy': np.array([0.50, 0.24, 58.48, 27.85, 2.88, 7.90, 0.05, 1.62, 0.48, 0.00, 0.01, 0.00]),
    'Бо2077_200121.xy': np.array([0.40, 0.93, 67.24, 18.25, 3.63, 7.51, 0.03, 1.60, 0.42, 0.00, 0.00, 0.00]),
    'Бр1026_181220.xy': np.array([2.72, 2.78, 47.84, 28.73, 1.20, 14.57, 0.07, 2.06, 0.03, 0.00, 0.00, 0.00]),
    'Бр1071_241220.xy': np.array([1.22, 0.63, 50.30, 30.39, 1.60, 13.97, 0.06, 1.84, 0.00, 0.00, 0.00, 0.00]),
    'Бр1307_2_181220.xy': np.array([0.68, 1.17, 86.07, 0.94, 3.65, 1.29, 4.55, 0.31, 0.79, 0.05, 0.52, 0.00]),
    'Бр1356_251220.xy': np.array([1.67, 2.21, 78.72, 2.34, 7.51, 3.22, 2.43, 1.09, 0.51, 0.28, 0.02, 0.00]),
    'Бр1425_241220.xy': np.array([0.90, 1.56, 81.95, 1.43, 6.32, 2.76, 3.40, 0.85, 0.68, 0.16, 0.00, 0.00]),
    'Бр1428_241220.xy': np.array([1.07, 2.47, 63.14, 15.82, 0.80, 14.47, 0.66, 1.58, 0.00, 0.00, 0.00, 0.00]),
    'Бр1566_281220.xy': np.array([0.72, 3.95, 70.88, 5.65, 6.65, 9.87, 0.12, 2.14, 0.00, 0.00, 0.01, 0.00]),
    'В506_140121.xy': np.array([2.11, 2.59, 54.29, 21.35, 2.26, 15.51, 0.06, 1.59, 0.24, 0.00, 0.01, 0.00]),
    'В508_140121.xy': np.array([2.12, 3.48, 48.43, 27.17, 1.62, 15.24, 0.05, 1.63, 0.26, 0.00, 0.01, 0.00]),
    'В549_150121.xy': np.array([1.01, 3.74, 78.07, 0.43, 13.37, 0.44, 1.63, 0.24, 0.17, 0.00, 0.89, 0.00]),
    'В574_150121.xy': np.array([0.52, 1.16, 52.24, 24.86, 1.70, 16.05, 0.03, 3.32, 0.11, 0.00, 0.00, 0.00]),
    'В583_180121.xy': np.array([0.45, 1.25, 52.71, 24.86, 2.10, 16.14, 0.06, 2.38, 0.04, 0.00, 0.01, 0.00]),
    'И103_291220.xy': np.array([1.02, 3.74, 53.23, 30.05, 1.25, 5.35, 4.20, 1.05, 0.00, 0.11, 0.00, 0.00]),
    'И128_120121.xy': np.array([1.16, 3.16, 59.49, 23.44, 1.06, 7.46, 2.84, 1.33, 0.00, 0.06, 0.00, 0.00]),
    'И538_110121.xy': np.array([1.42, 0.97, 72.78, 9.48, 2.78, 10.23, 0.42, 1.19, 0.00, 0.72, 0.00, 0.00]),
    'И644_110121.xy': np.array([1.24, 4.00, 73.64, 6.08, 7.94, 4.33, 1.11, 0.93, 0.00, 0.63, 0.00, 0.00]),
    'И743_211220.xy': np.array([0.39, 1.37, 88.97, 0.92, 2.73, 0.32, 4.03, 0.12, 0.42, 0.28, 0.44, 0.00]),
    'И9085_130121.xy': np.array([0.48, 0.14, 42.95, 44.21, 1.04, 10.34, 0.07, 0.71, 0.06, 0.00, 0.00, 0.00]),
    'К173_210121.xy': np.array([0.68, 2.13, 45.16, 36.51, 1.06, 10.94, 0.07, 2.73, 0.29, 0.43, 0.00, 0.00]),
    'К1898_270121.xy': np.array([1.89, 1.83, 55.79, 17.94, 2.05, 13.11, 0.43, 2.62, 0.14, 4.21, 0.00, 0.00]),
    'К2019_270121.xy': np.array([1.30, 3.43, 67.70, 7.81, 2.77, 10.36, 0.05, 2.19, 0.40, 4.00, 0.00, 0.00]),
    'К2022_280121.xy': np.array([1.18, 1.49, 58.94, 15.68, 2.12, 13.57, 0.08, 2.58, 0.46, 3.91, 0.00, 0.00]),
    'К2035_280121.xy': np.array([0.99, 1.88, 57.56, 16.03, 2.68, 12.59, 0.11, 2.36, 0.43, 5.37, 0.00, 0.00]),
    'К2041_280121.xy': np.array([0.95, 2.44, 49.16, 25.80, 1.25, 13.73, 0.07, 2.76, 0.22, 3.62, 0.00, 0.00]),
    'К2042_290121.xy': np.array([0.87, 0.92, 83.39, 0.71, 0.34, 0.11, 6.30, 0.00, 0.24, 4.62, 2.51, 0.00]),
    'С152_161220.xy': np.array([0.26, 1.65, 33.93, 52.38, 0.73, 9.34, 0.27, 0.99, 0.04, 0.38, 0.04, 0.00]),
    'С207_181220.xy': np.array([0.32, 0.61, 42.08, 44.57, 0.83, 9.56, 0.29, 1.31, 0.00, 0.42, 0.00, 0.00]),
    'С294_211220.xy': np.array([0.77, 2.01, 57.04, 26.08, 2.25, 8.96, 0.34, 1.74, 0.00, 0.83, 0.00, 0.00]),
    'С343_221220.xy': np.array([1.84, 1.80, 51.13, 33.75, 1.11, 7.74, 0.75, 1.31, 0.00, 0.56, 0.00, 0.00]),
    'С367_231220.xy': np.array([0.47, 1.94, 56.72, 26.99, 1.58, 9.51, 0.39, 1.60, 0.00, 0.81, 0.00, 0.00]),
    'С455_171220.xy': np.array([0.20, 2.09, 32.42, 53.03, 0.80, 9.33, 0.46, 1.01, 0.00, 0.28, 0.38, 0.00]),
    'С479_231220.xy': np.array([0.73, 1.32, 53.55, 31.52, 1.41, 9.09, 0.29, 1.45, 0.00, 0.63, 0.00, 0.00]),
    'С490_231220.xy': np.array([1.05, 2.49, 55.01, 30.80, 1.07, 4.45, 3.10, 1.48, 0.01, 0.55, 0.00, 0.00]),
    'дБо2058д_240521.xy': np.array([0.00, 0.74, 10.33, 59.61, 2.16, 5.09, 0.13, 21.81, 0.15, 0.00, 0.00, 0.00]),
    'дБо2082д_280521.xy': np.array([0.62, 0.35, 85.91, 0.00, 0.00, 0.00, 3.22, 0.00, 9.42, 0.06, 0.17, 0.00]),
    'дБр1307д_220421.xy': np.array([0.93, 0.36, 85.71, 0.39, 0.35, 0.03, 9.36, 0.00, 0.24, 0.00, 1.22, 1.43]),
    'дБр1552д_020621.xy': np.array([0.89, 0.00, 85.48, 0.25, 0.34, 0.00, 6.05, 0.03, 0.58, 0.00, 0.37, 6.00]),
    'дК1132д_180521.xy': np.array([2.42, 1.47, 75.98, 0.48, 0.61, 0.17, 9.58, 0.06, 4.70, 0.16, 2.08, 2.28]),
    'дК1585д_170521.xy': np.array([0.43, 1.17, 84.69, 0.00, 0.00, 0.00, 9.71, 0.00, 1.83, 1.65, 0.46, 0.00]),
    'дК180д_290421.xy': np.array([0.19, 1.93, 26.94, 42.17, 4.99, 17.44, 0.06, 5.90, 0.00, 0.40, 0.00, 0.00]),
    'дС132д_210421.xy': np.array([0.29, 2.38, 26.13, 41.49, 2.17, 16.56, 0.10, 10.58, 0.27, 0.03, 0.00, 0.00]),
    'дС321д_120521.xy': np.array([0.42, 1.90, 20.31, 38.45, 3.73, 20.36, 0.10, 14.56, 0.00, 0.02, 0.16, 0.00]),
    'дС323д_170521.xy': np.array([0.17, 1.65, 21.48, 30.25, 7.69, 19.54, 0.03, 18.75, 0.14, 0.07, 0.24, 0.00])
}

# %%
def predict_experimental_data(model, experimental_data, input_size):
    predictions = []
    total_difference = 0.0
    exp_samples_nb = 0

    diff_by_phases = []
    for i in range(num_phases):
        diff_by_phases.append(0)

    for filename, intensities in experimental_data.items():

        interpolated_intensities = torch.tensor(intensities, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)

        model.eval()
        with torch.no_grad():
            predicted_weights = model(interpolated_intensities)

        # Умножаем предсказанные веса на 100
        #predicted_weights *= 100
        
        predictions.append((filename, predicted_weights.squeeze().cpu().numpy()))

        # Сравнение с целевыми значениями, если они есть
        if filename in target_values:
            target = target_values[filename]
            curr_phases = np.square(predicted_weights.squeeze().cpu().numpy() - target*0.01)
            total_difference += curr_phases.sum()
            diff_by_phases += curr_phases  # Аккумулируем разности для каждой фазы
            exp_samples_nb += 1

    if exp_samples_nb > 0:
        total_difference = (total_difference / exp_samples_nb) / num_phases
        diff_by_phases /= exp_samples_nb  # Вычисляем средние значения для каждой фазы
    else:
        total_difference = 0.0
        diff_by_phases = np.zeros(num_phases)

    return total_difference, diff_by_phases, exp_samples_nb

def load_batch_inp_file(file_name):
    if os.path.exists(file_name):
        with open(file_name, 'rb') as f:
            while True:
                data = f.read(struct.calcsize(f'{input_size}f'))
                if not data:
                    break
                inp = struct.unpack(f'{input_size}f', data)
                inp_data.append(np.array(inp))


def load_batch_out_file(file_name):
    if os.path.exists(file_name):
        with open(file_name, 'rb') as f:
            while True:
                data = f.read(struct.calcsize(f'{num_phases}f'))
                if not data:
                    break
                out = struct.unpack(f'{num_phases}f', data)
                out_data.append(np.array(out))

# %%
# Загрузка данных
inp_files = glob.glob(f"{difr_dir}batch_inp_{xml_name}_{num_phases}ph_p*.bin")
out_files = glob.glob(f"{difr_dir}batch_out_{xml_name}_{num_phases}ph_p*.bin")

print('inp_files',inp_files)

for file in inp_files:
    load_batch_inp_file(file)

for file in out_files:
    load_batch_out_file(file)

print(f"Размер массива out_data: {len(out_data)}\n")

if len(out_data) < 1:
    print("Внимание - нет данных для обучения !")

lim_len = 500000
if len(inp_data) > lim_len:
    inp_data = inp_data[-lim_len:]
if len(out_data) > lim_len:
    out_data = out_data[-lim_len:]
# Out:
# inp_files ['../../nn_data/batch_inp_OSO_12ph_p1_50000.bin', '../../nn_data/batch_inp_OSO_12ph_p3_50000.bin', '../../nn_data/batch_inp_OSO_12ph_p2_50000.bin', '../../nn_data/batch_inp_OSO_12ph_p4_50000.bin']
# Размер массива out_data: 200000

# %%
out_data[0]
# Out:
# array([4.06117998e-02, 1.57209322e-01, 1.03501059e-01, 9.29933041e-02,
#        7.91798532e-02, 8.51616561e-02, 1.94989756e-01, 1.89948182e-08,
#        1.64288893e-01, 3.76141361e-06, 6.67450503e-02, 1.53155345e-02])

# %%
# Определение класса для датасета
class CandleDataset(Dataset):
    def __init__(self, inputs, outputs):
        self.inputs = inputs
        self.outputs = outputs

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        # Возвращаем данные без изменения формы
        return torch.tensor(self.inputs[idx], dtype=torch.float32).unsqueeze(0), torch.tensor(self.outputs[idx], dtype=torch.float32)

# %%
# Разделение данных на тренировочную и тестовую выборки
indices = list(range(len(inp_data)))
indices = np.array(indices)
np.random.shuffle(indices)
#test_indices = indices[::11]
#train_indices = [i for i in indices if i not in test_indices]
test_indices = indices[:int(0.1*len(indices))]
train_indices = indices[int(0.1*len(indices)):]

train_inputs = [inp_data[i] for i in train_indices]
train_outputs = [out_data[i] for i in train_indices]
test_inputs = [inp_data[i] for i in test_indices]
test_outputs = [out_data[i] for i in test_indices]

train_dataset = CandleDataset(train_inputs, train_outputs)
test_dataset = CandleDataset(test_inputs, test_outputs)

# %%
# Загружаем фазы из файлов .phase
sample_info, PHASES_INFO = parse_xml('XRD_Data/OSO_Topas_2022_stidy.tshx')
num_phases = len(PHASES_INFO)

# Загружаем экспериментальные данные
experimental_data = load_experimental_data(experiment_folder)
#print(f'Loaded {len(experimental_data)} experimental diffraction patterns.')
# Out:
# {'Name': 'alpha-Al2O3', 'SpaceGroup': 'R-3cH', 'CellPar': {'a': {'min': 4.755, 'max': 4.77, 'value': 4.7698}, 'b': {'min': None, 'max': None, 'value': 4.7698}, 'c': {'min': 13.0, 'max': 13.05, 'value': 13.0243}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 120.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 45.0, 'max': 150.0, 'value': 100.0}, 'Strain': {'min': 0.01, 'max': 0.35, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.35231}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O2-', 'X': {'min': None, 'max': None, 'value': 0.6936}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'gamma-Al2O3', 'SpaceGroup': 'Fd-3mZ', 'CellPar': {'a': {'min': 7.9, 'max': 7.937, 'value': 7.911}, 'b': {'min': None, 'max': None, 'value': 7.911}, 'c': {'min': None, 'max': None, 'value': 7.911}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 45.0, 'max': 300.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.35, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.2547}, 'Y': {'min': None, 'max': None, 'value': 0.2547}, 'Z': {'min': None, 'max': None, 'value': 0.2547}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 0.58}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.125}, 'Y': {'min': None, 'max': None, 'value': 0.125}, 'Z': {'min': None, 'max': None, 'value': 0.125}, 'Occ': {'min': None, 'max': None, 'value': 0.84}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0272}, 'Y': {'min': None, 'max': None, 'value': 0.0272}, 'Z': {'min': None, 'max': None, 'value': 0.0272}, 'Occ': {'min': None, 'max': None, 'value': 0.17}}], 'RIR': -1}
#
# {'Name': 'Cryolite', 'SpaceGroup': 'P121/c1', 'CellPar': {'a': {'min': 5.35095, 'max': 5.45905, 'value': 5.405}, 'b': {'min': 5.5242, 'max': 5.6358, 'value': 5.58}, 'c': {'min': 9.351936, 'max': 9.540864000000001, 'value': 9.4464}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': 123.51933, 'max': 126.01467, 'value': 124.767}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 70.0, 'max': 500.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [{'name': '1 1 1', 'min': 0.95, 'max': 1.1, 'value': 1.0}], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': 0.2638, 'max': 0.27, 'value': 0.2656}, 'Y': {'min': 0.448, 'max': 0.456, 'value': 0.448}, 'Z': {'min': 0.2501, 'max': 0.257, 'value': 0.2518}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.114, 'max': 0.12, 'value': 0.1152}, 'Y': {'min': 0.042, 'max': 0.05, 'value': 0.0436}, 'Z': {'min': 0.214, 'max': 0.223, 'value': 0.2182}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.22, 'max': 0.229, 'value': 0.2285}, 'Y': {'min': 0.73, 'max': 0.738, 'value': 0.7285}, 'Z': {'min': 0.057, 'max': 0.064, 'value': 0.0638}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.307, 'max': 0.319, 'value': 0.3215}, 'Y': {'min': 0.166, 'max': 0.18, 'value': 0.1765}, 'Z': {'min': 0.037, 'max': 0.048, 'value': 0.047}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Chiolite', 'SpaceGroup': 'P4/mnc', 'CellPar': {'a': {'min': 7.02, 'max': 7.06, 'value': 7.0138}, 'b': {'min': None, 'max': None, 'value': 7.0138}, 'c': {'min': 10.36, 'max': 10.403, 'value': 10.402}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 80.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [{'name': '0 0 1', 'min': 0.93, 'max': 1.0, 'value': 1.0}], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.277}, 'Y': {'min': None, 'max': None, 'value': 0.777}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': 0.17, 'max': 0.177, 'value': 0.1711}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.058, 'max': 0.064, 'value': 0.0642}, 'Y': {'min': 0.245, 'max': 0.252, 'value': 0.2477}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.176, 'max': 0.182, 'value': 0.1794}, 'Y': {'min': 0.532, 'max': 0.54, 'value': 0.5364}, 'Z': {'min': 0.118, 'max': 0.121, 'value': 0.1198}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'NaCa(AlF6)', 'SpaceGroup': 'P121/c1', 'CellPar': {'a': {'min': 8.715, 'max': 8.795, 'value': 8.7423}, 'b': {'min': 5.145, 'max': 5.21, 'value': 5.1927}, 'c': {'min': 20.3, 'max': 20.46, 'value': 20.35139}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': 90.85, 'max': 91.5, 'value': 91.499}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 30.0, 'max': 150.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Na1+', 'X': {'min': 0.9668, 'max': 0.9868, 'value': 0.9768}, 'Y': {'min': 0.2443, 'max': 0.2643, 'value': 0.2543}, 'Z': {'min': 0.1681, 'max': 0.1881, 'value': 0.1781}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': 0.9581, 'max': 0.9781, 'value': 0.9681}, 'Y': {'min': 0.2634, 'max': 0.2834, 'value': 0.2734}, 'Z': {'min': 0.4313, 'max': 0.4513, 'value': 0.4413}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Ca2+', 'X': {'min': 0.6303, 'max': 0.6503, 'value': 0.6403}, 'Y': {'min': 0.2275, 'max': 0.2475, 'value': 0.2375}, 'Z': {'min': 0.3008, 'max': 0.3208, 'value': 0.3108}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Ca2+', 'X': {'min': 0.6257, 'max': 0.6457, 'value': 0.6357}, 'Y': {'min': 0.3119, 'max': 0.3319, 'value': 0.3219}, 'Z': {'min': 0.5523, 'max': 0.5723, 'value': 0.5623}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': 0.2488, 'max': 0.2688, 'value': 0.2588}, 'Y': {'min': 0.2461, 'max': 0.2661, 'value': 0.2561}, 'Z': {'min': 0.3089, 'max': 0.3289, 'value': 0.3189}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': 0.2428, 'max': 0.2628, 'value': 0.2528}, 'Y': {'min': 0.1803, 'max': 0.2003, 'value': 0.1903}, 'Z': {'min': 0.5588, 'max': 0.5788, 'value': 0.5688}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.629}, 'Y': {'min': None, 'max': None, 'value': 0.6261}, 'Z': {'min': None, 'max': None, 'value': 0.4777}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.5863}, 'Y': {'min': None, 'max': None, 'value': 0.6137}, 'Z': {'min': None, 'max': None, 'value': 0.6397}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.7338}, 'Y': {'min': None, 'max': None, 'value': 0.0827}, 'Z': {'min': None, 'max': None, 'value': 0.4824}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.3809}, 'Y': {'min': None, 'max': None, 'value': 0.1003}, 'Z': {'min': None, 'max': None, 'value': 0.2626}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1625}, 'Y': {'min': None, 'max': None, 'value': -0.0247}, 'Z': {'min': None, 'max': None, 'value': 0.6328}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1643}, 'Y': {'min': None, 'max': None, 'value': 0.4377}, 'Z': {'min': None, 'max': None, 'value': 0.3814}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.2357}, 'Y': {'min': None, 'max': None, 'value': 0.4669}, 'Z': {'min': None, 'max': None, 'value': 0.6229}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.5786}, 'Y': {'min': None, 'max': None, 'value': 0.5944}, 'Z': {'min': None, 'max': None, 'value': 0.8821}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.9132}, 'Y': {'min': None, 'max': None, 'value': 0.6404}, 'Z': {'min': None, 'max': None, 'value': 0.226}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.7403}, 'Y': {'min': None, 'max': None, 'value': 0.0217}, 'Z': {'min': None, 'max': None,  ...
#
# {'Name': 'Na2Ca3Al2F14', 'SpaceGroup': 'I213', 'CellPar': {'a': {'min': 10.242, 'max': 10.254, 'value': 10.257}, 'b': {'min': None, 'max': None, 'value': 10.257}, 'c': {'min': None, 'max': None, 'value': 10.257}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 65.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [{'name': '1 1 1', 'min': 0.72, 'max': 1.0, 'value': 1.0}], 'Atoms': [{'Type': 'Ca2+', 'X': {'min': None, 'max': None, 'value': 0.4667}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.2482}, 'Y': {'min': None, 'max': None, 'value': 0.2482}, 'Z': {'min': None, 'max': None, 'value': 0.2482}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.0847}, 'Y': {'min': None, 'max': None, 'value': 0.0847}, 'Z': {'min': None, 'max': None, 'value': 0.0847}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1387}, 'Y': {'min': None, 'max': None, 'value': 0.3062}, 'Z': {'min': None, 'max': None, 'value': 0.1206}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.364}, 'Y': {'min': None, 'max': None, 'value': 0.3627}, 'Z': {'min': None, 'max': None, 'value': 0.1873}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.4614}, 'Y': {'min': None, 'max': None, 'value': 0.4614}, 'Z': {'min': None, 'max': None, 'value': 0.4614}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Fluorite', 'SpaceGroup': 'Fm-3m', 'CellPar': {'a': {'min': 5.463, 'max': 5.469, 'value': 5.462}, 'b': {'min': None, 'max': None, 'value': 5.462}, 'c': {'min': None, 'max': None, 'value': 5.462}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 60.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.38, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Ca2+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Weberite', 'SpaceGroup': 'Imma', 'CellPar': {'a': {'min': 7.05, 'max': 7.072, 'value': 7.05}, 'b': {'min': 9.98, 'max': 10.02, 'value': 9.979}, 'c': {'min': 7.29, 'max': 7.31, 'value': 7.297}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 150.0, 'max': 500.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.35, 'value': 0.1}}, 'MDtexDir': [{'name': '0 1 1', 'min': 0.9, 'max': 1.0, 'value': 1.0}], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.75}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Mg2+', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.1362}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.4144}, 'Z': {'min': None, 'max': None, 'value': 0.7213}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1845}, 'Y': {'min': None, 'max': None, 'value': 0.3874}, 'Z': {'min': None, 'max': None, 'value': 0.4304}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Neighborite', 'SpaceGroup': 'Pnma', 'CellPar': {'a': {'min': 5.488, 'max': 5.5, 'value': 5.4928}, 'b': {'min': 7.665, 'max': 7.69, 'value': 7.71}, 'c': {'min': 5.36, 'max': 5.387, 'value': 5.37645}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 100.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.3, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.03975}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.488}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Mg2+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.4547}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.58705}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.29105}, 'Y': {'min': None, 'max': None, 'value': 0.04897}, 'Z': {'min': None, 'max': None, 'value': 0.21265}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Elpasolite', 'SpaceGroup': 'Fm-3m', 'CellPar': {'a': {'min': 8.095, 'max': 8.112, 'value': 8.093}, 'b': {'min': None, 'max': None, 'value': 8.093}, 'c': {'min': None, 'max': None, 'value': 8.093}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 60.0, 'max': 200.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'K', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F', 'X': {'min': None, 'max': None, 'value': 0.2225}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'K1.58Al11O17', 'SpaceGroup': 'R-3mH', 'CellPar': {'a': {'min': 5.585, 'max': 5.62, 'value': 5.63}, 'b': {'min': None, 'max': None, 'value': 5.63}, 'c': {'min': 33.89, 'max': 34.17, 'value': 34.01}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 120.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 45.0, 'max': 150.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.37, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.16712}, 'Y': {'min': None, 'max': None, 'value': -0.16712}, 'Z': {'min': None, 'max': None, 'value': 0.9298}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.34988}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.44935}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.16419}, 'Y': {'min': None, 'max': None, 'value': -0.16419}, 'Z': {'min': None, 'max': None, 'value': 0.23615}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.15396}, 'Y': {'min': None, 'max': None, 'value': -0.15396}, 'Z': {'min': None, 'max': None, 'value': 0.03384}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.09512}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.2952}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'K', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': -0.17086}, 'Occ': {'min': None, 'max': None, 'value': 0.31}}, {'Type': 'K', 'X': {'min': None, 'max': None, 'value': 0.08717}, 'Y': {'min': None, 'max': None, 'value': -0.08717}, 'Z': {'min': None, 'max': None, 'value': -0.16784}, 'Occ': {'min': None, 'max': None, 'value': 0.16}}], 'RIR': -1}
#
# {'Name': 'Villiaumite', 'SpaceGroup': 'Fm-3m', 'CellPar': {'a': {'min': 4.633, 'max': 4.64, 'value': 4.634}, 'b': {'min': None, 'max': None, 'value': 4.634}, 'c': {'min': None, 'max': None, 'value': 4.634}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 90.0, 'max': 170.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.38, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Na', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}

# %%
#small
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()
        
        # Сверточные слои: уменьшены более агрессивно (в ~2.5 раза)
        self.conv_layers = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=32, kernel_size=7, stride=1, padding=3),  # Было 64
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=32, out_channels=64, kernel_size=5, stride=1, padding=2),  # Было 128
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1), # Было 256
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2)
        )
        
        reduced_size = input_size // 8
        
        # Трансформер: один слой + уменьшенная размерность
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=500, nhead=10, dim_feedforward=256, dropout=0.1, batch_first=True), # d_model и dim_feedforward уменьшены
            num_layers=1  # Один слой
        )
        
        # Полносвязные слои: значительно уменьшены
        self.fc_layers = nn.Sequential(
            nn.Linear(128 * reduced_size, 256),  # Было 1024
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(256, num_phases)
        )
    
    def forward(self, x):
        x = self.conv_layers(x)
        #x = x.permute(0, 2, 1)  # Критичный шаг сохранён
        x = self.transformer(x)
        x = x.reshape(x.size(0), -1)
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)
        return x

# %%
#big
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super(DiffractionNet, self).__init__()
        
        # Сверточные слои для извлечения локальных признаков
        self.conv_layers = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=64, kernel_size=7, stride=1, padding=3),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=64, out_channels=128, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2)
        )
        
        # Размер выхода после сверточных слоев
        reduced_size = input_size // 8  # Поскольку мы делаем три пулинга с шагом 2
        
        # Трансформер для глобального понимания
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=256, nhead=8, dim_feedforward=512, dropout=0.1, batch_first=True),
            num_layers=2
        )
        
        # Полносвязные слои для получения итогового предсказания
        self.fc_layers = nn.Sequential(
            nn.Linear(256 * reduced_size, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(1024, num_phases)
        )
    
    def forward(self, x):
        x = self.conv_layers(x)
        x = x.permute(0, 2, 1)  # Изменяем форму для трансформера (batch_size, sequence_length, features)
        x = self.transformer(x)
        x = x.reshape(x.size(0), -1)  # Флэттенинг с использованием reshape
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)  # Нормированные доли
        return x

# %%
#FFN
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()        
        
        # Полносвязные слои: значительно уменьшены
        self.fc_layers = nn.Sequential(
            nn.Linear(4001, 2048),  # Было 1024
            #nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(2048,1024),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(1024,256),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(256, num_phases)
        )
    
    def forward(self, x):
        #x = self.conv_layers(x)
        #x = x.permute(0, 2, 1)  # Критичный шаг сохранён
        #x = self.transformer(x)
        #x = x.reshape(x.size(0), -1)
        x = x.view(-1,4001)
        #print(x.shape)
        x = self.fc_layers(x)
        #print(x.shape)
        x = F.softmax(x, dim=1)
        #print(x.shape)
        return x

# %%
#conv_ff
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()
        self.fc_layers = nn.Sequential(            
            nn.Linear(4001, 256),
            nn.ReLU(),
            nn.Linear(256, num_phases)
        )
    
    def forward(self, x):
        x = x.reshape(x.size(0), -1)
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)
        return x

# %%
# Создание экземпляра модели
model = DiffractionNet(input_size, num_phases).to(device)
print(model)
pytorch_total_params = sum(p.numel() for p in model.parameters())
print(pytorch_total_params)
# Out:
# DiffractionNet(
#   (fc_layers): Sequential(
#     (0): Linear(in_features=4001, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=256, out_features=12, bias=True)
#   )
# )
# 1027596

# %%
# Проверяем, существует ли файл с весами, и загружаем его, если существует
#if os.path.exists(wghts_fname):
#    model.load_state_dict(torch.load(wghts_fname, map_location=device, weights_only=True))
#    print(f"Модель загружена из файла {wghts_fname}")
#else:
#    print(f'No weights file found. Starting training from scratch.')

# %%
print('Start training')
learn_rate = 1E-4
# Определяем критерий потерь и оптимизатор
criterion = nn.MSELoss(reduction='none')  # Используем reduction='none' для получения ошибки для каждого элемента в батче
optimizer = optim.AdamW(model.parameters(), lr=learn_rate, weight_decay=learn_rate*0.1)
def find_index_of_max(float_array):
    max_index = np.argmax(float_array)
    return max_index

# Определяем категории для балансировки данных
def get_category(out):
    min_val = np.min(out)
    max_val = np.max(out)
    delta = min_val / max_val if max_val > 0 else 0.0
    if delta < 0.001:
        return 0
    elif 0.001 <= delta < 0.01:
        return 1
    elif 0.01 <= delta < 0.1:
        return 2
    else:
        return 3
# Определяем метки классов для балансировки
train_labels = np.array([find_index_of_max(out) for out in train_outputs])
print('train_labels',train_labels)
class_counts = np.bincount(train_labels.astype(np.int64))
print(f'Category class_counts = {class_counts}')
# Добавляем сглаживание для предотвращения деления на ноль
#smoothing_factor = 1e-3
#class_weights = 1. / (class_counts + smoothing_factor)
class_weights = 1. / class_counts
sample_weights = class_weights[train_labels]
sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(sample_weights), replacement=True)
# Загрузка данных
train_dataloader = DataLoader(train_dataset, batch_size=128, sampler=sampler)
test_dataloader = DataLoader(test_dataset, batch_size=128, shuffle=False)

n_train_iter = len(train_dataloader)
n_test_iter = len(test_dataloader)
print(f'train_iter: {n_train_iter}, test_iter: {n_test_iter}')
# Инициализация списков для хранения значений потерь
train_losses = []
test_losses = []

# Инициализация списков для хранения значений потерь для каждого параметра
train_param_losses = [[] for _ in range(num_phases)]
test_param_losses = [[] for _ in range(num_phases)]

# Создание и запись заголовков в CSV-файл
with open(csv_res_fname, mode='w', newline='') as file:
    writer = csv.writer(file, delimiter=';')
    header = ['Time', 'Epoch', 'Train Loss', 'Test Loss', 'Exp_Diff'] + \
             [f'Train_{i + 1}' for i in range(num_phases)] + \
             [f'Test_{i + 1}' for i in range(num_phases)] + \
             [f'Exp_{i + 1}' for i in range(num_phases)]
    writer.writerow(header)

num_epochs = 300

total_exp_diff = 0.0
ph_exp_diff = []

pre_fitness = 1E6

train_all_losses = []
test_all_losses = []
train_batch_losses = []
test_batch_losses = []
experimental_losses = []
# Out:
# Start training
# train_labels [10  4  3 ...  5  2  3]
# Category class_counts = [15000 14792 14940 15038 14870 14875 14842 15078 15160 15162 15198 15045]
# train_iter: 1407, test_iter: 157

# %%
scheduler = lr_scheduler.CosineAnnealingWarmRestarts(optimizer,T_0=30)

# %%
start_time = time.time()  # Запоминаем время начала обучения

for epoch in range(num_epochs):
    model.train()
    running_train_loss = 0.0
    running_train_param_losses = [0.0 for _ in range(num_phases)]
    iters = 0
    #train_batch_losses = []
    for inputs, outputs in train_dataloader:
        inputs, outputs = inputs.to(device), outputs.to(device)
        optimizer.zero_grad()
        predictions = model(inputs)        
        loss = criterion(predictions, outputs)
        loss.mean().backward()  # Средняя ошибка по всем элементам в батче
        # Градиенты масштабируются, если их общая норма > 1.0
        #torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        #running_train_loss += loss.mean().item()
        #for i in range(num_phases):
        #    running_train_param_losses[i] += loss[:, i].mean().item()
        iters += 1
        #train_batch_losses.append(loss.mean(axis=1).cpu().detach().numpy())

        if iters % 500 == 0:
            print(f"Iteration {iters}")
    #train_all_losses.append(np.array(train_batch_losses[:-1]))

    #train_loss = running_train_loss / n_train_iter
    #train_losses.append(train_loss)
    #for i in range(num_phases):
    #    train_param_losses[i].append(running_train_param_losses[i] / n_train_iter)

    if n_test_iter > 0:
        
        train_batch_losses = []
        model.eval()
        running_train_param_losses = [0.0 for _ in range(num_phases)]
        with torch.no_grad():
            for inputs, outputs in train_dataloader:
                inputs, outputs = inputs.to(device), outputs.to(device)
                predictions = model(inputs)
                loss = criterion(predictions, outputs)
                running_train_loss += loss.mean().item()
                for i in range(num_phases):
                    running_train_param_losses[i] += loss[:, i].mean().item()
                train_batch_losses.append(loss.mean(axis=1).cpu().detach().numpy())
        train_loss = running_train_loss / n_train_iter
        train_losses.append(train_loss)
        for i in range(num_phases):
            train_param_losses[i].append(running_train_param_losses[i] / n_train_iter)
        train_all_losses.append(np.array(train_batch_losses[:-1]))
        

        
        test_batch_losses = []
        model.eval()
        running_test_loss = 0.0
        running_test_param_losses = [0.0 for _ in range(num_phases)]
        with torch.no_grad():
            for inputs, outputs in test_dataloader:
                inputs, outputs = inputs.to(device), outputs.to(device)
                predictions = model(inputs)
                loss = criterion(predictions, outputs)
                running_test_loss += loss.mean().item()
                for i in range(num_phases):
                    running_test_param_losses[i] += loss[:, i].mean().item()
                test_batch_losses.append(loss.mean(axis=1).cpu().detach().numpy())
        test_loss = running_test_loss / n_test_iter
        test_losses.append(test_loss)
        for i in range(num_phases):
            test_param_losses[i].append(running_test_param_losses[i] / n_test_iter)
        test_all_losses.append(np.array(test_batch_losses[:-1]))

        

        total_exp_diff, ph_exp_diff, exp_samples_nb = predict_experimental_data(model, experimental_data, input_size)
        experimental_losses.append(total_exp_diff)

        # Вывод средней разницы, если были найдены соответствия
        if exp_samples_nb > 0:
            if total_exp_diff < pre_fitness:
                #torch.save(model.state_dict(), wghts_fname)
                #print(f'*** Weights are saved to {wghts_fname} after epoch {epoch + 1}')
                pre_fitness = total_exp_diff
            print(f' >>> Средняя разница между предсказанными и OSO: {total_exp_diff:.5g}')
        else:
            total_exp_diff = 0.0
            print('Нет соответствий для подсчета разницы.')

    else:
        test_loss = 0.0
        test_losses.append(test_loss)

    #print(f'Epoch [{epoch + 1}/{num_epochs}], learn_rate: {scheduler.get_last_lr()}, Train Loss: {100 * np.sqrt(train_loss):.5f}, Test Loss: {100 * np.sqrt(test_loss):.5f}')
    print(f'Epoch [{epoch + 1}/{num_epochs}], learn_rate: {scheduler.get_last_lr()}, Train Loss: {1 * (train_loss):.5g}, Test Loss: {1 * (test_loss):.5g}')

    # Вывод ошибок для каждого параметра
    for i in range(num_phases):
        print(f'Фаза {i + 1}: Train: {1 * (train_param_losses[i][-1]):.5g}, Test: {1 * (test_param_losses[i][-1]):.5g}')

    # Форматирование прошедшего времени в "hh:mm:ss"
    elapsed_time = time.time() - start_time  # Вычисляем прошедшее время
    hours, rem = divmod(elapsed_time, 3600)
    minutes, seconds = divmod(rem, 60)
    formatted_time = f"{int(hours):02d}:{int(minutes):02d}:{int(seconds):02d}"

    # Запись данных в CSV-файл
    with open(csv_res_fname, mode='a', newline='') as file:
        writer = csv.writer(file, delimiter=';')
        row = [formatted_time, epoch + 1, 100 * np.sqrt(train_loss), 100 * np.sqrt(test_loss), total_exp_diff] + \
              [100 * np.sqrt(train_param_losses[i][-1]) for i in range(num_phases)] + \
              [100 * np.sqrt(test_param_losses[i][-1]) for i in range(num_phases)] + \
              ph_exp_diff.tolist()
        writer.writerow(row)

    print(f'Прошло времени: {formatted_time}\n')

    scheduler.step()
# Out:
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.0017066
# Epoch [1/300], learn_rate: [0.0001], Train Loss: 0.0021485, Test Loss: 0.0021486
# Фаза 1: Train: 0.0028124, Test: 0.002892
# Фаза 2: Train: 0.002892, Test: 0.0029432
# Фаза 3: Train: 0.0026324, Test: 0.0026816
# Фаза 4: Train: 0.0019413, Test: 0.001929
# Фаза 5: Train: 0.0030041, Test: 0.0030549
# Фаза 6: Train: 0.0020482, Test: 0.0020512
# Фаза 7: Train: 0.0011184, Test: 0.0011119
# Фаза 8: Train: 0.0019638, Test: 0.0019265
# Фаза 9: Train: 0.0019103, Test: 0.0018728
# Фаза 10: Train: 0.0012877, Test: 0.0012097
# Фаза 11: Train: 0.0031089, Test: 0.0031022
# Фаза 12: Train: 0.0010628, Test: 0.001008
# Прошло времени: 00:00:03
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.0014878
# Epoch [2/300], learn_rate: [9.972609476841367e-05], Train Loss: 0.0016795, Test Loss: 0.0016914
# Фаза 1: Train: 0.0024947, Test: 0.0025585
# Фаза 2: Train: 0.0022646, Test: 0.0023391
# Фаза 3: Train: 0.0018542, Test: 0.0018745
# Фаза 4: Train: 0.0015906, Test: 0.0016058
# Фаза 5: Train: 0.0021891, Test: 0.0022678
# Фаза 6: Train: 0.0016448, Test: 0.0016191
# Фаза 7: Train: 0.00074073, Test: 0.00074657
# Фаза 8: Train: 0.0016233, Test: 0.001596
# Фаза 9: Train: 0.0014825, Test: 0.0014586
# Фаза 10: Train: 0.0010448, Test: 0.00097645
# Фаза 11: Train: 0.0024063, Test: 0.0024449
# Фаза 12: Train: 0.00081867, Test: 0.00080946
# Прошло времени: 00:00:07
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.0013942
# Epoch [3/300], learn_rate: [9.890738003669029e-05], Train Loss: 0.0014027, Test Loss: 0.0014102
# Фаза 1: Train: 0.0016464, Test: 0.0016436
# Фаза 2: Train: 0.0019674, Test: 0.0020256
# Фаза 3: Train: 0.0016759, Test: 0.0016989
# Фаза 4: Train: 0.0014097, Test: 0.0014258
# Фаза 5: Train: 0.0018253, Test: 0.0018831
# Фаза 6: Train: 0.0014465, Test: 0.0014284
# Фаза 7: Train: 0.00065958, Test: 0.00066037
# Фаза 8: Train: 0.001398, Test: 0.0013824
# Фаза 9: Train: 0.0012735, Test: 0.0012698
# Фаза 10: Train: 0.00092102, Test: 0.00087214
# Фаза 11: Train: 0.0018582, Test: 0.0018866
# Фаза 12: Train: 0.00075136, Test: 0.00074533
# Прошло времени: 00:00:10
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.0014277
# Epoch [4/300], learn_rate: [9.755282581475769e-05], Train Loss: 0.0013085, Test Loss: 0.0013119
# Фаза 1: Train: 0.0014148, Test: 0.0014031
# Фаза 2: Train: 0.00188, Test: 0.0019409
# Фаза 3: Train: 0.0015454, Test: 0.0015638
# Фаза 4: Train: 0.0013733, Test: 0.0013667
# Фаза 5: Train: 0.0017646, Test: 0.0017883
# Фаза 6: Train: 0.001364, Test: 0.0013402
# Фаза 7: Train: 0.00065161, Test: 0.00064153
# Фаза 8: Train: 0.0013092, Test: 0.0012823
# Фаза 9: Train: 0.0011585, Test: 0.0011797
# Фаза 10: Train: 0.00084973, Test: 0.00082156
# Фаза 11: Train: 0.0016907, Test: 0.0017123
# Фаза 12: Train: 0.00069947, Test: 0.00070278
# Прошло времени: 00:00:14
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.0014366
# Epoch [5/300], learn_rate: [9.567727288213005e-05], Train Loss: 0.0012225, Test Loss: 0.0012275
# Фаза 1: Train: 0.0014195, Test: 0.0013831
# Фаза 2: Train: 0.0017195, Test: 0.0017844
# Фаза 3: Train: 0.0015943, Test: 0.0016242
# Фаза 4: Train: 0.0012718, Test: 0.0012662
# Фаза 5: Train: 0.0014994, Test: 0.0015361
# Фаза 6: Train: 0.0013016, Test: 0.0012816
# Фаза 7: Train: 0.00056566, Test: 0.00056694
# Фаза 8: Train: 0.0012289, Test: 0.0012071
# Фаза 9: Train: 0.0010383, Test: 0.0010525
# Фаза 10: Train: 0.00078247, Test: 0.00075118
# Фаза 11: Train: 0.0015832, Test: 0.0016045
# Фаза 12: Train: 0.00066544, Test: 0.00067275
# Прошло времени: 00:00:18
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.001385
# Epoch [6/300], learn_rate: [9.330127018922194e-05], Train Loss: 0.0010569, Test Loss: 0.0010636
# Фаза 1: Train: 0.0011396, Test: 0.001121
# Фаза 2: Train: 0.0013833, Test: 0.0014382
# Фаза 3: Train: 0.0015019, Test: 0.0015368
# Фаза 4: Train: 0.0011191, Test: 0.0011124
# Фаза 5: Train: 0.001163, Test: 0.0011787
# Фаза 6: Train: 0.001223, Test: 0.0012123
# Фаза 7: Train: 0.00052882, Test: 0.00053074
# Фаза 8: Train: 0.0011417, Test: 0.0011303
# Фаза 9: Train: 0.00088682, Test: 0.00089684
# Фаза 10: Train: 0.0006115, Test: 0.00059786
# Фаза 11: Train: 0.0013315, Test: 0.0013531
# Фаза 12: Train: 0.0006528, Test: 0.00065496
# Прошло времени: 00:00:22
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00093125
# Epoch [7/300], learn_rate: [9.045084971874738e-05], Train Loss: 0.00087379, Test Loss: 0.00087443
# Фаза 1: Train: 0.00083997, Test: 0.00082351
# Фаза 2: Train: 0.0010024, Test: 0.0010338
# Фаза 3: Train: 0.0012119, Test: 0.0012327
# Фаза 4: Train: 0.00091201, Test: 0.00089649
# Фаза 5: Train: 0.00094803, Test: 0.00095493
# Фаза 6: Train: 0.001007, Test: 0.00099211
# Фаза 7: Train: 0.00055996, Test: 0.00055793
# Фаза 8: Train: 0.0010766, Test: 0.0010587
# Фаза 9: Train: 0.00076221, Test: 0.00078048
# Фаза 10: Train: 0.00056099, Test: 0.00055036
# Фаза 11: Train: 0.00091368, Test: 0.00091946
# Фаза 12: Train: 0.00069078, Test: 0.0006928
# Прошло времени: 00:00:25
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00069613
# Epoch [8/300], learn_rate: [8.715724127386972e-05], Train Loss: 0.00074293, Test Loss: 0.00074552
# Фаза 1: Train: 0.00064086, Test: 0.00063527
# Фаза 2: Train: 0.00079133, Test: 0.00082526
# Фаза 3: Train: 0.0010539, Test: 0.0010698
# Фаза 4: Train: 0.00078733, Test: 0.00077844
# Фаза 5: Train: 0.00085724, Test: 0.00085662
# Фаза 6: Train: 0.00087353, Test: 0.00087299
# Фаза 7: Train: 0.00050859, Test: 0.00051885
# Фаза 8: Train: 0.00080129, Test: 0.00080235
# Фаза 9: Train: 0.00072013, Test: 0.0007214
# Фаза 10: Train: 0.00045998, Test: 0.00044715
# Фаза 11: Train: 0.00083468, Test: 0.00083074
# Фаза 12: Train: 0.00058639, Test: 0.00058747
# Прошло времени: 00:00:29
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00050241
# Epoch [9/300], learn_rate: [8.345653031794292e-05], Train Loss: 0.00063019, Test Loss: 0.00063171
# Фаза 1: Train: 0.00054288, Test: 0.00054174
# Фаза 2: Train: 0.00062977, Test: 0.00066263
# Фаза 3: Train: 0.00088402, Test: 0.00089128
# Фаза 4: Train: 0.00070087, Test: 0.00069347
# Фаза 5: Train: 0.00068937, Test: 0.00069308
# Фаза 6: Train: 0.00066619, Test: 0.00065935
# Фаза 7: Train: 0.00049878, Test: 0.00050418
# Фаза 8: Train: 0.00058842, Test: 0.00058835
# Фаза 9: Train: 0.00062587, Test: 0.00063118
# Фаза 10: Train: 0.00043675, Test: 0.0004297
# Фаза 11: Train: 0.0006209, Test: 0.00062125
# Фаза 12: Train: 0.00067848, Test: 0.00066432
# Прошло времени: 00:00:32
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00034851
# Epoch [10/300], learn_rate: [7.938926261462366e-05], Train Loss: 0.00053118, Test Loss: 0.00053549
# Фаза 1: Train: 0.00048845, Test: 0.00048943
# Фаза 2: Train: 0.00054578, Test: 0.00057765
# Фаза 3: Train: 0.00064654, Test: 0.00065574
# Фаза 4: Train: 0.00061594, Test: 0.00062021
# Фаза 5: Train: 0.00058463, Test: 0.00059286
# Фаза 6: Train: 0.00048649, Test: 0.0004797
# Фаза 7: Train: 0.00047021, Test: 0.00047395
# Фаза 8: Train: 0.0004691, Test: 0.00046648
# Фаза 9: Train: 0.00054554, Test: 0.00055244
# Фаза 10: Train: 0.0004255, Test: 0.00041839
# Фаза 11: Train: 0.00055348, Test: 0.00055872
# Фаза 12: Train: 0.0005425, Test: 0.00054034
# Прошло времени: 00:00:36
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00026852
# Epoch [11/300], learn_rate: [7.500000000000001e-05], Train Loss: 0.00045166, Test Loss: 0.00045748
# Фаза 1: Train: 0.00044545, Test: 0.00045225
# Фаза 2: Train: 0.00048898, Test: 0.0005141
# Фаза 3: Train: 0.00049701, Test: 0.0005062
# Фаза 4: Train: 0.00049102, Test: 0.00049487
# Фаза 5: Train: 0.00045394, Test: 0.00046103
# Фаза 6: Train: 0.0003834, Test: 0.00037515
# Фаза 7: Train: 0.00044915, Test: 0.00045865
# Фаза 8: Train: 0.00040034, Test: 0.00039864
# Фаза 9: Train: 0.00044472, Test: 0.00045525
# Фаза 10: Train: 0.0003647, Test: 0.00035954
# Фаза 11: Train: 0.00050242, Test: 0.00051497
# Фаза 12: Train: 0.00049875, Test: 0.00049911
# Прошло времени: 00:00:40
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.0002452
# Epoch [12/300], learn_rate: [7.033683215379002e-05], Train Loss: 0.0003991, Test Loss: 0.00040323
# Фаза 1: Train: 0.00040731, Test: 0.00041653
# Фаза 2: Train: 0.0004581, Test: 0.00047568
# Фаза 3: Train: 0.00042552, Test: 0.00043224
# Фаза 4: Train: 0.0003907, Test: 0.00039541
# Фаза 5: Train: 0.00038535, Test: 0.0003921
# Фаза 6: Train: 0.0003172, Test: 0.00031172
# Фаза 7: Train: 0.00043828, Test: 0.00044072
# Фаза 8: Train: 0.00034903, Test: 0.00034922
# Фаза 9: Train: 0.00039948, Test: 0.00040913
# Фаза 10: Train: 0.00034239, Test: 0.00032863
# Фаза 11: Train: 0.00045054, Test: 0.00046752
# Фаза 12: Train: 0.00042526, Test: 0.00041983
# Прошло времени: 00:00:43
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00023018
# Epoch [13/300], learn_rate: [6.545084971874738e-05], Train Loss: 0.00035859, Test Loss: 0.0003623
# Фаза 1: Train: 0.0003685, Test: 0.00037924
# Фаза 2: Train: 0.00042069, Test: 0.00044082
# Фаза 3: Train: 0.00036394, Test: 0.00037349
# Фаза 4: Train: 0.00031683, Test: 0.00032067
# Фаза 5: Train: 0.00034121, Test: 0.00034547
# Фаза 6: Train: 0.00027158, Test: 0.0002681
# Фаза 7: Train: 0.000369, Test: 0.00036454
# Фаза 8: Train: 0.00033189, Test: 0.00033113
# Фаза 9: Train: 0.00036618, Test: 0.00036854
# Фаза 10: Train: 0.00032658, Test: 0.00032095
# Фаза 11: Train: 0.0004375, Test: 0.00045086
# Фаза 12: Train: 0.00038916, Test: 0.00038382
# Прошло времени: 00:00:47
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00021998
# Epoch [14/300], learn_rate: [6.0395584540887963e-05], Train Loss: 0.00031622, Test Loss: 0.00032077
# Фаза 1: Train: 0.00032512, Test: 0.00033038
# Фаза 2: Train: 0.00039908, Test: 0.00041498
# Фаза 3: Train: 0.00032288, Test: 0.00033052
# Фаза 4: Train: 0.00028149, Test: 0.00028699
# Фаза 5: Train: 0.00030871, Test: 0.0003153
# Фаза 6: Train: 0.00024326, Test: 0.00023978
# Фаза 7: Train: 0.00031974, Test: 0.00031898
# Фаза 8: Train: 0.00030339, Test: 0.00030485
# Фаза 9: Train: 0.00031214, Test: 0.0003203
# Фаза 10: Train: 0.0002952, Test: 0.0002919
# Фаза 11: Train: 0.00038093, Test: 0.00039574
# Фаза 12: Train: 0.00030266, Test: 0.00029948
# Прошло времени: 00:00:51
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00018778
# Epoch [15/300], learn_rate: [5.522642316338268e-05], Train Loss: 0.00028047, Test Loss: 0.00028318
# Фаза 1: Train: 0.00028, Test: 0.00028396
# Фаза 2: Train: 0.0003665, Test: 0.00037984
# Фаза 3: Train: 0.00029384, Test: 0.00029572
# Фаза 4: Train: 0.00023189, Test: 0.00023564
# Фаза 5: Train: 0.00026476, Test: 0.00027156
# Фаза 6: Train: 0.00021824, Test: 0.00021268
# Фаза 7: Train: 0.00027192, Test: 0.00026707
# Фаза 8: Train: 0.00027345, Test: 0.00027438
# Фаза 9: Train: 0.00028125, Test: 0.00028648
# Фаза 10: Train: 0.00026089, Test: 0.00025696
# Фаза 11: Train: 0.00036028, Test: 0.00037571
# Фаза 12: Train: 0.00026256, Test: 0.00025814
# Прошло времени: 00:00:54
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00017446
# Epoch [16/300], learn_rate: [5.0000000000000016e-05], Train Loss: 0.00025248, Test Loss: 0.00025603
# Фаза 1: Train: 0.00025077, Test: 0.00025442
# Фаза 2: Train: 0.00032385, Test: 0.00033822
# Фаза 3: Train: 0.0002736, Test: 0.00027849
# Фаза 4: Train: 0.00020615, Test: 0.0002098
# Фаза 5: Train: 0.00026182, Test: 0.00026578
# Фаза 6: Train: 0.00019652, Test: 0.00019614
# Фаза 7: Train: 0.00022534, Test: 0.00022354
# Фаза 8: Train: 0.00025821, Test: 0.00025956
# Фаза 9: Train: 0.00025612, Test: 0.00025768
# Фаза 10: Train: 0.00023281, Test: 0.00022994
# Фаза 11: Train: 0.00031663, Test: 0.00033557
# Фаза 12: Train: 0.000228, Test: 0.00022319
# Прошло времени: 00:00:58
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00018434
# Epoch [17/300], learn_rate: [4.477357683661734e-05], Train Loss: 0.000231, Test Loss: 0.00023395
# Фаза 1: Train: 0.00021851, Test: 0.00022377
# Фаза 2: Train: 0.00032325, Test: 0.00032926
# Фаза 3: Train: 0.00024144, Test: 0.00025038
# Фаза 4: Train: 0.00019531, Test: 0.00019578
# Фаза 5: Train: 0.00022702, Test: 0.00023102
# Фаза 6: Train: 0.00018196, Test: 0.0001784
# Фаза 7: Train: 0.00018299, Test: 0.00018032
# Фаза 8: Train: 0.00024878, Test: 0.00025285
# Фаза 9: Train: 0.00023874, Test: 0.00024093
# Фаза 10: Train: 0.00021183, Test: 0.0002105
# Фаза 11: Train: 0.00029571, Test: 0.00031223
# Фаза 12: Train: 0.00020644, Test: 0.00020198
# Прошло времени: 00:01:02
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00015623
# Epoch [18/300], learn_rate: [3.9604415459112035e-05], Train Loss: 0.000211, Test Loss: 0.00021439
# Фаза 1: Train: 0.00020436, Test: 0.00020874
# Фаза 2: Train: 0.00027693, Test: 0.00028507
# Фаза 3: Train: 0.00023291, Test: 0.00023948
# Фаза 4: Train: 0.00017213, Test: 0.00017564
# Фаза 5: Train: 0.00020634, Test: 0.00020984
# Фаза 6: Train: 0.00017549, Test: 0.00017561
# Фаза 7: Train: 0.00015835, Test: 0.00015848
# Фаза 8: Train: 0.00023716, Test: 0.00024022
# Фаза 9: Train: 0.00022114, Test: 0.00022215
# Фаза 10: Train: 0.00018597, Test: 0.00018377
# Фаза 11: Train: 0.00027668, Test: 0.00029159
# Фаза 12: Train: 0.00018459, Test: 0.00018207
# Прошло времени: 00:01:06
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00015534
# Epoch [19/300], learn_rate: [3.4549150281252636e-05], Train Loss: 0.00019777, Test Loss: 0.00020088
# Фаза 1: Train: 0.00019367, Test: 0.00019581
# Фаза 2: Train: 0.00025926, Test: 0.00026295
# Фаза 3: Train: 0.00021776, Test: 0.0002244
# Фаза 4: Train: 0.0001617, Test: 0.00016556
# Фаза 5: Train: 0.00019811, Test: 0.00019954
# Фаза 6: Train: 0.00016115, Test: 0.00016154
# Фаза 7: Train: 0.00014902, Test: 0.00015025
# Фаза 8: Train: 0.00022002, Test: 0.00022374
# Фаза 9: Train: 0.00020682, Test: 0.00020858
# Фаза 10: Train: 0.00017395, Test: 0.00017681
# Фаза 11: Train: 0.00026069, Test: 0.00027382
# Фаза 12: Train: 0.00017104, Test: 0.00016758
# Прошло времени: 00:01:09
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00014879
# Epoch [20/300], learn_rate: [2.9663167846209998e-05], Train Loss: 0.00018615, Test Loss: 0.00018868
# Фаза 1: Train: 0.00017757, Test: 0.00018208
# Фаза 2: Train: 0.00023923, Test: 0.00024218
# Фаза 3: Train: 0.00020972, Test: 0.00021474
# Фаза 4: Train: 0.00015634, Test: 0.00015752
# Фаза 5: Train: 0.00018538, Test: 0.00019042
# Фаза 6: Train: 0.00015337, Test: 0.00015309
# Фаза 7: Train: 0.00012742, Test: 0.00012949
# Фаза 8: Train: 0.00022072, Test: 0.00022219
# Фаза 9: Train: 0.0001994, Test: 0.00019915
# Фаза 10: Train: 0.00016092, Test: 0.00016155
# Фаза 11: Train: 0.00024528, Test: 0.00025594
# Фаза 12: Train: 0.00015847, Test: 0.00015584
# Прошло времени: 00:01:13
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00015554
# Epoch [21/300], learn_rate: [2.500000000000001e-05], Train Loss: 0.00017903, Test Loss: 0.00018137
# Фаза 1: Train: 0.00017828, Test: 0.00018169
# Фаза 2: Train: 0.00023119, Test: 0.00023371
# Фаза 3: Train: 0.00020451, Test: 0.00020752
# Фаза 4: Train: 0.00014609, Test: 0.00014906
# Фаза 5: Train: 0.0001824, Test: 0.00018454
# Фаза 6: Train: 0.00015267, Test: 0.00015111
# Фаза 7: Train: 0.00011835, Test: 0.00011974
# Фаза 8: Train: 0.00020662, Test: 0.0002098
# Фаза 9: Train: 0.00018409, Test: 0.00018572
# Фаза 10: Train: 0.00015322, Test: 0.0001546
# Фаза 11: Train: 0.00023834, Test: 0.00024847
# Фаза 12: Train: 0.00015253, Test: 0.00015046
# Прошло времени: 00:01:17
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00014255
# Epoch [22/300], learn_rate: [2.061073738537635e-05], Train Loss: 0.00017132, Test Loss: 0.00017357
# Фаза 1: Train: 0.00016986, Test: 0.00017268
# Фаза 2: Train: 0.00021732, Test: 0.00022061
# Фаза 3: Train: 0.00019822, Test: 0.0002028
# Фаза 4: Train: 0.0001399, Test: 0.00014299
# Фаза 5: Train: 0.00017766, Test: 0.00017997
# Фаза 6: Train: 0.0001451, Test: 0.00014335
# Фаза 7: Train: 0.00011163, Test: 0.00011113
# Фаза 8: Train: 0.00019818, Test: 0.00020169
# Фаза 9: Train: 0.0001789, Test: 0.00017961
# Фаза 10: Train: 0.00014609, Test: 0.00014712
# Фаза 11: Train: 0.00023174, Test: 0.00024096
# Фаза 12: Train: 0.00014126, Test: 0.00013993
# Прошло времени: 00:01:20
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.0001431
# Epoch [23/300], learn_rate: [1.6543469682057106e-05], Train Loss: 0.00016557, Test Loss: 0.00016828
# Фаза 1: Train: 0.00016021, Test: 0.00016544
# Фаза 2: Train: 0.00020958, Test: 0.0002107
# Фаза 3: Train: 0.00019231, Test: 0.00019864
# Фаза 4: Train: 0.00013967, Test: 0.00014087
# Фаза 5: Train: 0.00017128, Test: 0.0001746
# Фаза 6: Train: 0.00013939, Test: 0.00013942
# Фаза 7: Train: 0.0001084, Test: 0.00010903
# Фаза 8: Train: 0.00019723, Test: 0.00020047
# Фаза 9: Train: 0.00017339, Test: 0.00017302
# Фаза 10: Train: 0.00014089, Test: 0.00014256
# Фаза 11: Train: 0.00021888, Test: 0.00023039
# Фаза 12: Train: 0.00013557, Test: 0.00013416
# Прошло времени: 00:01:24
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00013937
# Epoch [24/300], learn_rate: [1.2842758726130299e-05], Train Loss: 0.00016201, Test Loss: 0.00016408
# Фаза 1: Train: 0.00015414, Test: 0.00015968
# Фаза 2: Train: 0.00020685, Test: 0.00020687
# Фаза 3: Train: 0.00018998, Test: 0.00019263
# Фаза 4: Train: 0.00013434, Test: 0.00013584
# Фаза 5: Train: 0.00016709, Test: 0.00017134
# Фаза 6: Train: 0.00013618, Test: 0.00013472
# Фаза 7: Train: 0.00010577, Test: 0.00010509
# Фаза 8: Train: 0.00019398, Test: 0.00019651
# Фаза 9: Train: 0.00016496, Test: 0.00016667
# Фаза 10: Train: 0.00013646, Test: 0.00013754
# Фаза 11: Train: 0.00022259, Test: 0.00023137
# Фаза 12: Train: 0.00013173, Test: 0.00013074
# Прошло времени: 00:01:28
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00013223
# Epoch [25/300], learn_rate: [9.549150281252633e-06], Train Loss: 0.00015878, Test Loss: 0.00016115
# Фаза 1: Train: 0.00015312, Test: 0.00015819
# Фаза 2: Train: 0.00020309, Test: 0.00020261
# Фаза 3: Train: 0.00018836, Test: 0.00019092
# Фаза 4: Train: 0.00013106, Test: 0.00013238
# Фаза 5: Train: 0.00016686, Test: 0.00017149
# Фаза 6: Train: 0.00013331, Test: 0.00013182
# Фаза 7: Train: 0.00010473, Test: 0.0001054
# Фаза 8: Train: 0.0001874, Test: 0.00019281
# Фаза 9: Train: 0.00016137, Test: 0.00016305
# Фаза 10: Train: 0.00013311, Test: 0.0001343
# Фаза 11: Train: 0.00021289, Test: 0.00022219
# Фаза 12: Train: 0.00013007, Test: 0.00012864
# Прошло времени: 00:01:32
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00013563
# Epoch [26/300], learn_rate: [6.698729810778065e-06], Train Loss: 0.0001565, Test Loss: 0.00015892
# Фаза 1: Train: 0.00015378, Test: 0.00015583
# Фаза 2: Train: 0.00019871, Test: 0.00019935
# Фаза 3: Train: 0.00018317, Test: 0.0001886
# Фаза 4: Train: 0.00012971, Test: 0.00013209
# Фаза 5: Train: 0.00016377, Test: 0.00016749
# Фаза 6: Train: 0.00013094, Test: 0.0001292
# Фаза 7: Train: 0.00010161, Test: 0.0001021
# Фаза 8: Train: 0.00018684, Test: 0.00019046
# Фаза 9: Train: 0.00015951, Test: 0.00016128
# Фаза 10: Train: 0.00013246, Test: 0.00013429
# Фаза 11: Train: 0.00021072, Test: 0.00022135
# Фаза 12: Train: 0.0001268, Test: 0.00012501
# Прошло времени: 00:01:35
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00014086
# Epoch [27/300], learn_rate: [4.322727117869951e-06], Train Loss: 0.00015519, Test Loss: 0.00015758
# Фаза 1: Train: 0.00014933, Test: 0.00015489
# Фаза 2: Train: 0.00019708, Test: 0.00019735
# Фаза 3: Train: 0.00018152, Test: 0.00018582
# Фаза 4: Train: 0.00012965, Test: 0.00013214
# Фаза 5: Train: 0.00016101, Test: 0.00016541
# Фаза 6: Train: 0.00012955, Test: 0.00012814
# Фаза 7: Train: 0.00010185, Test: 0.00010163
# Фаза 8: Train: 0.00018748, Test: 0.00018997
# Фаза 9: Train: 0.00016085, Test: 0.00016034
# Фаза 10: Train: 0.00013098, Test: 0.00013327
# Фаза 11: Train: 0.00020726, Test: 0.00021721
# Фаза 12: Train: 0.00012569, Test: 0.00012478
# Прошло времени: 00:01:39
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00013098
# Epoch [28/300], learn_rate: [2.4471741852423237e-06], Train Loss: 0.00015409, Test Loss: 0.00015659
# Фаза 1: Train: 0.00015014, Test: 0.00015364
# Фаза 2: Train: 0.00019618, Test: 0.00019616
# Фаза 3: Train: 0.00018139, Test: 0.00018598
# Фаза 4: Train: 0.00012802, Test: 0.00012968
# Фаза 5: Train: 0.00016146, Test: 0.00016547
# Фаза 6: Train: 0.00012923, Test: 0.00012773
# Фаза 7: Train: 0.00010188, Test: 0.00010268
# Фаза 8: Train: 0.0001829, Test: 0.00018749
# Фаза 9: Train: 0.0001567, Test: 0.00015918
# Фаза 10: Train: 0.00012891, Test: 0.0001322
# Фаза 11: Train: 0.00020694, Test: 0.00021517
# Фаза 12: Train: 0.00012537, Test: 0.00012368
# Прошло времени: 00:01:43
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00013267
# Epoch [29/300], learn_rate: [1.0926199633097157e-06], Train Loss: 0.00015387, Test Loss: 0.00015627
# Фаза 1: Train: 0.00015035, Test: 0.00015388
# Фаза 2: Train: 0.00019599, Test: 0.00019571
# Фаза 3: Train: 0.00018045, Test: 0.00018539
# Фаза 4: Train: 0.00012799, Test: 0.00012993
# Фаза 5: Train: 0.00016059, Test: 0.00016569
# Фаза 6: Train: 0.00012798, Test: 0.00012789
# Фаза 7: Train: 0.00010122, Test: 0.00010148
# Фаза 8: Train: 0.00018516, Test: 0.00018768
# Фаза 9: Train: 0.00015683, Test: 0.00015861
# Фаза 10: Train: 0.00013149, Test: 0.00013126
# Фаза 11: Train: 0.0002043, Test: 0.00021413
# Фаза 12: Train: 0.00012411, Test: 0.00012356
# Прошло времени: 00:01:47
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00013207
# Epoch [30/300], learn_rate: [2.7390523158633e-07], Train Loss: 0.00015356, Test Loss: 0.00015605
# Фаза 1: Train: 0.00014918, Test: 0.00015365
# Фаза 2: Train: 0.00019519, Test: 0.00019563
# Фаза 3: Train: 0.00018104, Test: 0.00018532
# Фаза 4: Train: 0.00012798, Test: 0.00012959
# Фаза 5: Train: 0.00016179, Test: 0.00016522
# Фаза 6: Train: 0.00012778, Test: 0.00012756
# Фаза 7: Train: 0.00010075, Test: 0.00010062
# Фаза 8: Train: 0.00018363, Test: 0.00018765
# Фаза 9: Train: 0.00015665, Test: 0.0001586
# Фаза 10: Train: 0.00012981, Test: 0.00013108
# Фаза 11: Train: 0.00020451, Test: 0.00021422
# Фаза 12: Train: 0.0001244, Test: 0.00012343
# Прошло времени: 00:01:51
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.00010824
# Epoch [31/300], learn_rate: [0.0001], Train Loss: 0.00013328, Test Loss: 0.00013637
# Фаза 1: Train: 0.00013412, Test: 0.00013804
# Фаза 2: Train: 0.00016452, Test: 0.00016787
# Фаза 3: Train: 0.00014837, Test: 0.00015275
# Фаза 4: Train: 0.00011165, Test: 0.00011385
# Фаза 5: Train: 0.00015026, Test: 0.00015537
# Фаза 6: Train: 0.00011074, Test: 0.0001095
# Фаза 7: Train: 8.3986e-05, Test: 8.5969e-05
# Фаза 8: Train: 0.00018142, Test: 0.00018658
# Фаза 9: Train: 0.00013138, Test: 0.00013203
# Фаза 10: Train: 0.00011168, Test: 0.00011269
# Фаза 11: Train: 0.00017389, Test: 0.0001858
# Фаза 12: Train: 9.7285e-05, Test: 9.6029e-05
# Прошло времени: 00:01:54
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 9.1713e-05
# Epoch [32/300], learn_rate: [9.972609476841367e-05], Train Loss: 0.00011484, Test Loss: 0.00011756
# Фаза 1: Train: 0.00011381, Test: 0.0001189
# Фаза 2: Train: 0.00014522, Test: 0.0001493
# Фаза 3: Train: 0.00012734, Test: 0.00012899
# Фаза 4: Train: 9.2992e-05, Test: 9.6169e-05
# Фаза 5: Train: 0.00013024, Test: 0.0001349
# Фаза 6: Train: 9.7976e-05, Test: 9.8328e-05
# Фаза 7: Train: 9.1881e-05, Test: 9.0802e-05
# Фаза 8: Train: 0.00013784, Test: 0.00014045
# Фаза 9: Train: 0.00012104, Test: 0.00012298
# Фаза 10: Train: 9.5876e-05, Test: 9.7144e-05
# Фаза 11: Train: 0.00014681, Test: 0.000156
# Фаза 12: Train: 7.7018e-05, Test: 7.6814e-05
# Прошло времени: 00:01:58
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 8.1402e-05
# Epoch [33/300], learn_rate: [9.890738003669029e-05], Train Loss: 0.00010155, Test Loss: 0.00010349
# Фаза 1: Train: 0.00010812, Test: 0.00011204
# Фаза 2: Train: 0.00012702, Test: 0.00013048
# Фаза 3: Train: 0.00011473, Test: 0.00011782
# Фаза 4: Train: 8.6562e-05, Test: 8.8025e-05
# Фаза 5: Train: 0.00012044, Test: 0.0001254
# Фаза 6: Train: 0.00010343, Test: 0.00010193
# Фаза 7: Train: 6.7551e-05, Test: 6.835e-05
# Фаза 8: Train: 0.00011276, Test: 0.00011347
# Фаза 9: Train: 9.6406e-05, Test: 9.7314e-05
# Фаза 10: Train: 8.2623e-05, Test: 8.3979e-05
# Фаза 11: Train: 0.00013193, Test: 0.00013731
# Фаза 12: Train: 6.7021e-05, Test: 6.573e-05
# Прошло времени: 00:02:02
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 7.7441e-05
# Epoch [34/300], learn_rate: [9.755282581475769e-05], Train Loss: 8.6778e-05, Test Loss: 8.8473e-05
# Фаза 1: Train: 0.00010004, Test: 0.00010295
# Фаза 2: Train: 0.00011534, Test: 0.00011902
# Фаза 3: Train: 9.5912e-05, Test: 9.8344e-05
# Фаза 4: Train: 7.3119e-05, Test: 7.4125e-05
# Фаза 5: Train: 0.00010414, Test: 0.00010849
# Фаза 6: Train: 6.8034e-05, Test: 6.8029e-05
# Фаза 7: Train: 6.3179e-05, Test: 6.1983e-05
# Фаза 8: Train: 9.2681e-05, Test: 9.1924e-05
# Фаза 9: Train: 8.4555e-05, Test: 8.5307e-05
# Фаза 10: Train: 7.0955e-05, Test: 7.3522e-05
# Фаза 11: Train: 0.00011596, Test: 0.00012164
# Фаза 12: Train: 5.743e-05, Test: 5.6333e-05
# Прошло времени: 00:02:05
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 7.0611e-05
# Epoch [35/300], learn_rate: [9.567727288213005e-05], Train Loss: 7.7463e-05, Test Loss: 7.9425e-05
# Фаза 1: Train: 8.8067e-05, Test: 9.1303e-05
# Фаза 2: Train: 0.00010227, Test: 0.00010585
# Фаза 3: Train: 9.4716e-05, Test: 9.6491e-05
# Фаза 4: Train: 6.3192e-05, Test: 6.479e-05
# Фаза 5: Train: 0.0001008, Test: 0.00010604
# Фаза 6: Train: 5.9905e-05, Test: 6.0054e-05
# Фаза 7: Train: 5.2657e-05, Test: 5.2291e-05
# Фаза 8: Train: 7.8714e-05, Test: 7.9232e-05
# Фаза 9: Train: 7.2481e-05, Test: 7.4521e-05
# Фаза 10: Train: 6.2951e-05, Test: 6.4807e-05
# Фаза 11: Train: 0.00010368, Test: 0.00010821
# Фаза 12: Train: 5.0135e-05, Test: 4.9502e-05
# Прошло времени: 00:02:09
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.956e-05
# Epoch [36/300], learn_rate: [9.330127018922194e-05], Train Loss: 7.3e-05, Test Loss: 7.4426e-05
# Фаза 1: Train: 7.4134e-05, Test: 7.6803e-05
# Фаза 2: Train: 9.118e-05, Test: 9.5e-05
# Фаза 3: Train: 8.0312e-05, Test: 8.2227e-05
# Фаза 4: Train: 5.7408e-05, Test: 5.8927e-05
# Фаза 5: Train: 8.9221e-05, Test: 9.3231e-05
# Фаза 6: Train: 6.7101e-05, Test: 6.7669e-05
# Фаза 7: Train: 5.6816e-05, Test: 5.5304e-05
# Фаза 8: Train: 7.1333e-05, Test: 7.1492e-05
# Фаза 9: Train: 6.5304e-05, Test: 6.6738e-05
# Фаза 10: Train: 6.7732e-05, Test: 6.7819e-05
# Фаза 11: Train: 0.00011076, Test: 0.0001133
# Фаза 12: Train: 4.4691e-05, Test: 4.4602e-05
# Прошло времени: 00:02:13
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.7502e-05
# Epoch [37/300], learn_rate: [9.045084971874738e-05], Train Loss: 6.226e-05, Test Loss: 6.3823e-05
# Фаза 1: Train: 7.98e-05, Test: 8.15e-05
# Фаза 2: Train: 7.8683e-05, Test: 8.2991e-05
# Фаза 3: Train: 7.5324e-05, Test: 7.7615e-05
# Фаза 4: Train: 5.0819e-05, Test: 5.1659e-05
# Фаза 5: Train: 7.633e-05, Test: 7.9059e-05
# Фаза 6: Train: 4.9389e-05, Test: 4.9469e-05
# Фаза 7: Train: 5.1809e-05, Test: 5.1053e-05
# Фаза 8: Train: 6.2283e-05, Test: 6.3547e-05
# Фаза 9: Train: 5.22e-05, Test: 5.3019e-05
# Фаза 10: Train: 4.9163e-05, Test: 5.0913e-05
# Фаза 11: Train: 8.1508e-05, Test: 8.6248e-05
# Фаза 12: Train: 3.9808e-05, Test: 3.8804e-05
# Прошло времени: 00:02:16
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.4992e-05
# Epoch [38/300], learn_rate: [8.715724127386972e-05], Train Loss: 5.4849e-05, Test Loss: 5.6011e-05
# Фаза 1: Train: 5.895e-05, Test: 6.1197e-05
# Фаза 2: Train: 6.8454e-05, Test: 7.1929e-05
# Фаза 3: Train: 6.9185e-05, Test: 7.0948e-05
# Фаза 4: Train: 4.7756e-05, Test: 4.841e-05
# Фаза 5: Train: 6.5685e-05, Test: 6.8178e-05
# Фаза 6: Train: 4.184e-05, Test: 4.2203e-05
# Фаза 7: Train: 4.6962e-05, Test: 4.6483e-05
# Фаза 8: Train: 5.2417e-05, Test: 5.2681e-05
# Фаза 9: Train: 4.7456e-05, Test: 4.7694e-05
# Фаза 10: Train: 5.333e-05, Test: 5.3138e-05
# Фаза 11: Train: 6.8925e-05, Test: 7.2586e-05
# Фаза 12: Train: 3.7226e-05, Test: 3.6689e-05
# Прошло времени: 00:02:20
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.1346e-05
# Epoch [39/300], learn_rate: [8.345653031794292e-05], Train Loss: 5.1852e-05, Test Loss: 5.3174e-05
# Фаза 1: Train: 5.5311e-05, Test: 5.7121e-05
# Фаза 2: Train: 6.2152e-05, Test: 6.5673e-05
# Фаза 3: Train: 6.2481e-05, Test: 6.4298e-05
# Фаза 4: Train: 4.2594e-05, Test: 4.3342e-05
# Фаза 5: Train: 7.5203e-05, Test: 7.8433e-05
# Фаза 6: Train: 4.2324e-05, Test: 4.3994e-05
# Фаза 7: Train: 4.2991e-05, Test: 4.1531e-05
# Фаза 8: Train: 4.778e-05, Test: 4.7155e-05
# Фаза 9: Train: 4.7495e-05, Test: 4.8169e-05
# Фаза 10: Train: 3.6622e-05, Test: 3.7326e-05
# Фаза 11: Train: 7.1353e-05, Test: 7.5058e-05
# Фаза 12: Train: 3.5917e-05, Test: 3.5983e-05
# Прошло времени: 00:02:24
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.0699e-05
# Epoch [40/300], learn_rate: [7.938926261462366e-05], Train Loss: 4.5569e-05, Test Loss: 4.6705e-05
# Фаза 1: Train: 4.7973e-05, Test: 4.9799e-05
# Фаза 2: Train: 5.7709e-05, Test: 6.0068e-05
# Фаза 3: Train: 5.9628e-05, Test: 6.1443e-05
# Фаза 4: Train: 3.9855e-05, Test: 4.0765e-05
# Фаза 5: Train: 5.7275e-05, Test: 5.994e-05
# Фаза 6: Train: 3.647e-05, Test: 3.7307e-05
# Фаза 7: Train: 3.949e-05, Test: 3.9451e-05
# Фаза 8: Train: 4.3431e-05, Test: 4.3085e-05
# Фаза 9: Train: 4.2199e-05, Test: 4.2343e-05
# Фаза 10: Train: 3.2662e-05, Test: 3.2979e-05
# Фаза 11: Train: 5.9573e-05, Test: 6.3519e-05
# Фаза 12: Train: 3.0562e-05, Test: 2.9765e-05
# Прошло времени: 00:02:28
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 4.6149e-05
# Epoch [41/300], learn_rate: [7.500000000000001e-05], Train Loss: 4.3738e-05, Test Loss: 4.4604e-05
# Фаза 1: Train: 4.5656e-05, Test: 4.7183e-05
# Фаза 2: Train: 5.4331e-05, Test: 5.6386e-05
# Фаза 3: Train: 5.458e-05, Test: 5.6095e-05
# Фаза 4: Train: 3.8648e-05, Test: 3.9393e-05
# Фаза 5: Train: 4.974e-05, Test: 5.2629e-05
# Фаза 6: Train: 3.7148e-05, Test: 3.7844e-05
# Фаза 7: Train: 3.5504e-05, Test: 3.4835e-05
# Фаза 8: Train: 4.0468e-05, Test: 4.0564e-05
# Фаза 9: Train: 3.9498e-05, Test: 3.9712e-05
# Фаза 10: Train: 3.2047e-05, Test: 3.161e-05
# Фаза 11: Train: 6.6419e-05, Test: 6.8605e-05
# Фаза 12: Train: 3.082e-05, Test: 3.0393e-05
# Прошло времени: 00:02:31
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 4.5633e-05
# Epoch [42/300], learn_rate: [7.033683215379002e-05], Train Loss: 3.9835e-05, Test Loss: 4.0851e-05
# Фаза 1: Train: 4.1597e-05, Test: 4.3095e-05
# Фаза 2: Train: 4.5309e-05, Test: 4.7153e-05
# Фаза 3: Train: 4.7517e-05, Test: 4.9322e-05
# Фаза 4: Train: 4.3986e-05, Test: 4.5393e-05
# Фаза 5: Train: 4.5912e-05, Test: 4.8306e-05
# Фаза 6: Train: 3.2847e-05, Test: 3.4214e-05
# Фаза 7: Train: 3.1996e-05, Test: 3.1076e-05
# Фаза 8: Train: 3.9188e-05, Test: 3.8982e-05
# Фаза 9: Train: 3.6827e-05, Test: 3.6833e-05
# Фаза 10: Train: 2.9962e-05, Test: 3.0087e-05
# Фаза 11: Train: 5.2005e-05, Test: 5.5385e-05
# Фаза 12: Train: 3.0877e-05, Test: 3.0368e-05
# Прошло времени: 00:02:35
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 4.6208e-05
# Epoch [43/300], learn_rate: [6.545084971874738e-05], Train Loss: 3.8058e-05, Test Loss: 3.9006e-05
# Фаза 1: Train: 4.0691e-05, Test: 4.2453e-05
# Фаза 2: Train: 4.7418e-05, Test: 4.8407e-05
# Фаза 3: Train: 4.7073e-05, Test: 4.8762e-05
# Фаза 4: Train: 3.611e-05, Test: 3.7246e-05
# Фаза 5: Train: 4.4571e-05, Test: 4.6378e-05
# Фаза 6: Train: 3.761e-05, Test: 3.8824e-05
# Фаза 7: Train: 3.0239e-05, Test: 2.9953e-05
# Фаза 8: Train: 3.5098e-05, Test: 3.5371e-05
# Фаза 9: Train: 3.5605e-05, Test: 3.5398e-05
# Фаза 10: Train: 2.8403e-05, Test: 2.8668e-05
# Фаза 11: Train: 4.8512e-05, Test: 5.1534e-05
# Фаза 12: Train: 2.5361e-05, Test: 2.5072e-05
# Прошло времени: 00:02:39
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 4.6226e-05
# Epoch [44/300], learn_rate: [6.0395584540887963e-05], Train Loss: 3.5372e-05, Test Loss: 3.6253e-05
# Фаза 1: Train: 3.6526e-05, Test: 3.7855e-05
# Фаза 2: Train: 3.9976e-05, Test: 4.1383e-05
# Фаза 3: Train: 4.2247e-05, Test: 4.3689e-05
# Фаза 4: Train: 3.1906e-05, Test: 3.2971e-05
# Фаза 5: Train: 4.0832e-05, Test: 4.2659e-05
# Фаза 6: Train: 2.9903e-05, Test: 3.0913e-05
# Фаза 7: Train: 4.0032e-05, Test: 4.0571e-05
# Фаза 8: Train: 3.3114e-05, Test: 3.342e-05
# Фаза 9: Train: 3.2871e-05, Test: 3.2509e-05
# Фаза 10: Train: 2.7063e-05, Test: 2.7065e-05
# Фаза 11: Train: 4.5452e-05, Test: 4.7849e-05
# Фаза 12: Train: 2.454e-05, Test: 2.4153e-05
# Прошло времени: 00:02:42
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 3.9212e-05
# Epoch [45/300], learn_rate: [5.522642316338268e-05], Train Loss: 3.3384e-05, Test Loss: 3.4159e-05
# Фаза 1: Train: 3.4116e-05, Test: 3.5521e-05
# Фаза 2: Train: 3.8153e-05, Test: 3.9326e-05
# Фаза 3: Train: 4.0469e-05, Test: 4.2237e-05
# Фаза 4: Train: 3.2261e-05, Test: 3.3171e-05
# Фаза 5: Train: 4.1104e-05, Test: 4.2378e-05
# Фаза 6: Train: 2.9474e-05, Test: 3.0228e-05
# Фаза 7: Train: 2.6659e-05, Test: 2.6743e-05
# Фаза 8: Train: 3.2485e-05, Test: 3.3019e-05
# Фаза 9: Train: 3.0839e-05, Test: 3.0266e-05
# Фаза 10: Train: 2.9492e-05, Test: 2.9332e-05
# Фаза 11: Train: 4.2214e-05, Test: 4.4925e-05
# Фаза 12: Train: 2.3341e-05, Test: 2.2755e-05
# Прошло времени: 00:02:46
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 4.0295e-05
# Epoch [46/300], learn_rate: [5.0000000000000016e-05], Train Loss: 3.1777e-05, Test Loss: 3.2503e-05
# Фаза 1: Train: 3.4301e-05, Test: 3.5791e-05
# Фаза 2: Train: 3.5257e-05, Test: 3.6216e-05
# Фаза 3: Train: 3.8246e-05, Test: 3.9723e-05
# Фаза 4: Train: 3.037e-05, Test: 3.1111e-05
# Фаза 5: Train: 3.5899e-05, Test: 3.7697e-05
# Фаза 6: Train: 2.873e-05, Test: 2.9256e-05
# Фаза 7: Train: 3.0661e-05, Test: 3.0923e-05
# Фаза 8: Train: 2.9796e-05, Test: 3.0108e-05
# Фаза 9: Train: 2.9677e-05, Test: 2.927e-05
# Фаза 10: Train: 2.6077e-05, Test: 2.5807e-05
# Фаза 11: Train: 3.9593e-05, Test: 4.2161e-05
# Фаза 12: Train: 2.2715e-05, Test: 2.1967e-05
# Прошло времени: 00:02:50
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 4.4771e-05
# Epoch [47/300], learn_rate: [4.477357683661734e-05], Train Loss: 3.1093e-05, Test Loss: 3.1734e-05
# Фаза 1: Train: 3.1329e-05, Test: 3.255e-05
# Фаза 2: Train: 3.77e-05, Test: 3.8157e-05
# Фаза 3: Train: 3.8408e-05, Test: 3.983e-05
# Фаза 4: Train: 3.0279e-05, Test: 3.1244e-05
# Фаза 5: Train: 3.7992e-05, Test: 3.9597e-05
# Фаза 6: Train: 2.859e-05, Test: 2.9149e-05
# Фаза 7: Train: 2.6651e-05, Test: 2.6637e-05
# Фаза 8: Train: 2.7469e-05, Test: 2.823e-05
# Фаза 9: Train: 2.7493e-05, Test: 2.7245e-05
# Фаза 10: Train: 2.4247e-05, Test: 2.4252e-05
# Фаза 11: Train: 4.062e-05, Test: 4.2415e-05
# Фаза 12: Train: 2.2339e-05, Test: 2.1506e-05
# Прошло времени: 00:02:53
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 4.3575e-05
# Epoch [48/300], learn_rate: [3.9604415459112035e-05], Train Loss: 2.9533e-05, Test Loss: 3.0059e-05
# Фаза 1: Train: 3.1357e-05, Test: 3.265e-05
# Фаза 2: Train: 3.3347e-05, Test: 3.41e-05
# Фаза 3: Train: 3.602e-05, Test: 3.7077e-05
# Фаза 4: Train: 2.9508e-05, Test: 3.0295e-05
# Фаза 5: Train: 3.3522e-05, Test: 3.4818e-05
# Фаза 6: Train: 2.7688e-05, Test: 2.8395e-05
# Фаза 7: Train: 2.5873e-05, Test: 2.539e-05
# Фаза 8: Train: 2.6563e-05, Test: 2.6838e-05
# Фаза 9: Train: 2.766e-05, Test: 2.7442e-05
# Фаза 10: Train: 2.3987e-05, Test: 2.3981e-05
# Фаза 11: Train: 3.8096e-05, Test: 3.9564e-05
# Фаза 12: Train: 2.0773e-05, Test: 2.0153e-05
# Прошло времени: 00:02:57
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 4.242e-05
# Epoch [49/300], learn_rate: [3.4549150281252636e-05], Train Loss: 2.8362e-05, Test Loss: 2.8958e-05
# Фаза 1: Train: 2.9493e-05, Test: 3.0758e-05
# Фаза 2: Train: 3.1657e-05, Test: 3.2809e-05
# Фаза 3: Train: 3.5274e-05, Test: 3.635e-05
# Фаза 4: Train: 2.7957e-05, Test: 2.9145e-05
# Фаза 5: Train: 3.2333e-05, Test: 3.3893e-05
# Фаза 6: Train: 2.6179e-05, Test: 2.6574e-05
# Фаза 7: Train: 2.6898e-05, Test: 2.6971e-05
# Фаза 8: Train: 2.4886e-05, Test: 2.5151e-05
# Фаза 9: Train: 2.6245e-05, Test: 2.5856e-05
# Фаза 10: Train: 2.2551e-05, Test: 2.2313e-05
# Фаза 11: Train: 3.6104e-05, Test: 3.7539e-05
# Фаза 12: Train: 2.0764e-05, Test: 2.0143e-05
# Прошло времени: 00:03:01
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 4.0043e-05
# Epoch [50/300], learn_rate: [2.9663167846209998e-05], Train Loss: 2.8125e-05, Test Loss: 2.8738e-05
# Фаза 1: Train: 2.8946e-05, Test: 3.0442e-05
# Фаза 2: Train: 3.18e-05, Test: 3.2559e-05
# Фаза 3: Train: 3.5573e-05, Test: 3.7076e-05
# Фаза 4: Train: 2.7843e-05, Test: 2.8717e-05
# Фаза 5: Train: 3.2191e-05, Test: 3.3382e-05
# Фаза 6: Train: 2.5597e-05, Test: 2.622e-05
# Фаза 7: Train: 2.6487e-05, Test: 2.6518e-05
# Фаза 8: Train: 2.513e-05, Test: 2.5369e-05
# Фаза 9: Train: 2.5469e-05, Test: 2.5111e-05
# Фаза 10: Train: 2.2089e-05, Test: 2.1997e-05
# Фаза 11: Train: 3.5476e-05, Test: 3.705e-05
# Фаза 12: Train: 2.0896e-05, Test: 2.0418e-05
# Прошло времени: 00:03:05
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 3.8034e-05
# Epoch [51/300], learn_rate: [2.500000000000001e-05], Train Loss: 2.7024e-05, Test Loss: 2.7786e-05
# Фаза 1: Train: 2.9922e-05, Test: 3.1299e-05
# Фаза 2: Train: 2.9766e-05, Test: 3.1267e-05
# Фаза 3: Train: 3.2292e-05, Test: 3.3803e-05
# Фаза 4: Train: 2.7356e-05, Test: 2.8792e-05
# Фаза 5: Train: 3.1534e-05, Test: 3.2638e-05
# Фаза 6: Train: 2.6249e-05, Test: 2.6956e-05
# Фаза 7: Train: 2.3823e-05, Test: 2.4318e-05
# Фаза 8: Train: 2.4009e-05, Test: 2.4188e-05
# Фаза 9: Train: 2.4628e-05, Test: 2.4271e-05
# Фаза 10: Train: 2.1343e-05, Test: 2.1326e-05
# Фаза 11: Train: 3.3891e-05, Test: 3.5636e-05
# Фаза 12: Train: 1.9472e-05, Test: 1.8938e-05
# Прошло времени: 00:03:08
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 4.3144e-05
# Epoch [52/300], learn_rate: [2.061073738537635e-05], Train Loss: 2.6457e-05, Test Loss: 2.7074e-05
# Фаза 1: Train: 2.8059e-05, Test: 2.8954e-05
# Фаза 2: Train: 2.8985e-05, Test: 2.9905e-05
# Фаза 3: Train: 3.1592e-05, Test: 3.2918e-05
# Фаза 4: Train: 2.7192e-05, Test: 2.8362e-05
# Фаза 5: Train: 3.0788e-05, Test: 3.2057e-05
# Фаза 6: Train: 2.5345e-05, Test: 2.5949e-05
# Фаза 7: Train: 2.4056e-05, Test: 2.4818e-05
# Фаза 8: Train: 2.3428e-05, Test: 2.3789e-05
# Фаза 9: Train: 2.3952e-05, Test: 2.3725e-05
# Фаза 10: Train: 2.1313e-05, Test: 2.1074e-05
# Фаза 11: Train: 3.3652e-05, Test: 3.5042e-05
# Фаза 12: Train: 1.9127e-05, Test: 1.8294e-05
# Прошло времени: 00:03:12
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 3.9582e-05
# Epoch [53/300], learn_rate: [1.6543469682057106e-05], Train Loss: 2.602e-05, Test Loss: 2.6698e-05
# Фаза 1: Train: 2.8128e-05, Test: 2.9558e-05
# Фаза 2: Train: 2.8289e-05, Test: 2.9339e-05
# Фаза 3: Train: 3.209e-05, Test: 3.3357e-05
# Фаза 4: Train: 2.6492e-05, Test: 2.7495e-05
# Фаза 5: Train: 3.0141e-05, Test: 3.1273e-05
# Фаза 6: Train: 2.4897e-05, Test: 2.5529e-05
# Фаза 7: Train: 2.5195e-05, Test: 2.5285e-05
# Фаза 8: Train: 2.2155e-05, Test: 2.2583e-05
# Фаза 9: Train: 2.3599e-05, Test: 2.3026e-05
# Фаза 10: Train: 2.0894e-05, Test: 2.086e-05
# Фаза 11: Train: 3.1999e-05, Test: 3.3812e-05
# Фаза 12: Train: 1.8359e-05, Test: 1.8264e-05
# Прошло времени: 00:03:16
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 3.7294e-05
# Epoch [54/300], learn_rate: [1.2842758726130299e-05], Train Loss: 2.5793e-05, Test Loss: 2.6323e-05
# Фаза 1: Train: 2.7133e-05, Test: 2.809e-05
# Фаза 2: Train: 2.861e-05, Test: 2.9173e-05
# Фаза 3: Train: 3.1067e-05, Test: 3.2246e-05
# Фаза 4: Train: 2.6319e-05, Test: 2.7339e-05
# Фаза 5: Train: 2.9665e-05, Test: 3.073e-05
# Фаза 6: Train: 2.5023e-05, Test: 2.5631e-05
# Фаза 7: Train: 2.2783e-05, Test: 2.2951e-05
# Фаза 8: Train: 2.2124e-05, Test: 2.2447e-05
# Фаза 9: Train: 2.3566e-05, Test: 2.31e-05
# Фаза 10: Train: 2.0459e-05, Test: 2.0261e-05
# Фаза 11: Train: 3.2823e-05, Test: 3.4827e-05
# Фаза 12: Train: 1.994e-05, Test: 1.9085e-05
# Прошло времени: 00:03:20
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 3.737e-05
# Epoch [55/300], learn_rate: [9.549150281252633e-06], Train Loss: 2.5478e-05, Test Loss: 2.5972e-05
# Фаза 1: Train: 2.6707e-05, Test: 2.7562e-05
# Фаза 2: Train: 2.8059e-05, Test: 2.8677e-05
# Фаза 3: Train: 3.0362e-05, Test: 3.183e-05
# Фаза 4: Train: 2.6277e-05, Test: 2.7398e-05
# Фаза 5: Train: 2.9951e-05, Test: 3.0969e-05
# Фаза 6: Train: 2.4224e-05, Test: 2.4642e-05
# Фаза 7: Train: 2.2123e-05, Test: 2.2061e-05
# Фаза 8: Train: 2.2998e-05, Test: 2.304e-05
# Фаза 9: Train: 2.266e-05, Test: 2.2459e-05
# Фаза 10: Train: 2.1464e-05, Test: 2.126e-05
# Фаза 11: Train: 3.2218e-05, Test: 3.3909e-05
# Фаза 12: Train: 1.8692e-05, Test: 1.7853e-05
# Прошло времени: 00:03:23
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 3.6484e-05
# Epoch [56/300], learn_rate: [6.698729810778065e-06], Train Loss: 2.5221e-05, Test Loss: 2.5803e-05
# Фаза 1: Train: 2.7436e-05, Test: 2.8422e-05
# Фаза 2: Train: 2.8209e-05, Test: 2.8951e-05
# Фаза 3: Train: 3.0603e-05, Test: 3.2045e-05
# Фаза 4: Train: 2.6661e-05, Test: 2.7806e-05
# Фаза 5: Train: 2.853e-05, Test: 2.9861e-05
# Фаза 6: Train: 2.3592e-05, Test: 2.4294e-05
# Фаза 7: Train: 2.2731e-05, Test: 2.2602e-05
# Фаза 8: Train: 2.1914e-05, Test: 2.2003e-05
# Фаза 9: Train: 2.2771e-05, Test: 2.2296e-05
# Фаза 10: Train: 2.0134e-05, Test: 2.0125e-05
# Фаза 11: Train: 3.1762e-05, Test: 3.333e-05
# Фаза 12: Train: 1.8308e-05, Test: 1.7895e-05
# Прошло времени: 00:03:27
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 3.9053e-05
# Epoch [57/300], learn_rate: [4.322727117869951e-06], Train Loss: 2.5003e-05, Test Loss: 2.5589e-05
# Фаза 1: Train: 2.6282e-05, Test: 2.7409e-05
# Фаза 2: Train: 2.7762e-05, Test: 2.8609e-05
# Фаза 3: Train: 3.0859e-05, Test: 3.1996e-05
# Фаза 4: Train: 2.6261e-05, Test: 2.7256e-05
# Фаза 5: Train: 2.8504e-05, Test: 2.9679e-05
# Фаза 6: Train: 2.3678e-05, Test: 2.4276e-05
# Фаза 7: Train: 2.1594e-05, Test: 2.1661e-05
# Фаза 8: Train: 2.1676e-05, Test: 2.2091e-05
# Фаза 9: Train: 2.2428e-05, Test: 2.1893e-05
# Фаза 10: Train: 1.9931e-05, Test: 1.9977e-05
# Фаза 11: Train: 3.1434e-05, Test: 3.3193e-05
# Фаза 12: Train: 1.9629e-05, Test: 1.9028e-05
# Прошло времени: 00:03:31
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 3.9211e-05
# Epoch [58/300], learn_rate: [2.4471741852423237e-06], Train Loss: 2.499e-05, Test Loss: 2.5456e-05
# Фаза 1: Train: 2.63e-05, Test: 2.7384e-05
# Фаза 2: Train: 2.8154e-05, Test: 2.8533e-05
# Фаза 3: Train: 3.0038e-05, Test: 3.1379e-05
# Фаза 4: Train: 2.647e-05, Test: 2.7395e-05
# Фаза 5: Train: 2.8527e-05, Test: 2.9554e-05
# Фаза 6: Train: 2.348e-05, Test: 2.4108e-05
# Фаза 7: Train: 2.2236e-05, Test: 2.2013e-05
# Фаза 8: Train: 2.1994e-05, Test: 2.2178e-05
# Фаза 9: Train: 2.2374e-05, Test: 2.1768e-05
# Фаза 10: Train: 2.0099e-05, Test: 2.0024e-05
# Фаза 11: Train: 3.154e-05, Test: 3.287e-05
# Фаза 12: Train: 1.8669e-05, Test: 1.8266e-05
# Прошло времени: 00:03:34
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 3.8216e-05
# Epoch [59/300], learn_rate: [1.0926199633097157e-06], Train Loss: 2.489e-05, Test Loss: 2.5408e-05
# Фаза 1: Train: 2.6447e-05, Test: 2.7247e-05
# Фаза 2: Train: 2.7501e-05, Test: 2.8335e-05
# Фаза 3: Train: 3.0114e-05, Test: 3.1362e-05
# Фаза 4: Train: 2.6191e-05, Test: 2.7076e-05
# Фаза 5: Train: 2.8159e-05, Test: 2.956e-05
# Фаза 6: Train: 2.353e-05, Test: 2.409e-05
# Фаза 7: Train: 2.2195e-05, Test: 2.229e-05
# Фаза 8: Train: 2.1686e-05, Test: 2.2046e-05
# Фаза 9: Train: 2.2142e-05, Test: 2.1754e-05
# Фаза 10: Train: 2.0084e-05, Test: 1.995e-05
# Фаза 11: Train: 3.1752e-05, Test: 3.3173e-05
# Фаза 12: Train: 1.888e-05, Test: 1.801e-05
# Прошло времени: 00:03:38
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 3.8523e-05
# Epoch [60/300], learn_rate: [2.7390523158633e-07], Train Loss: 2.4827e-05, Test Loss: 2.5372e-05
# Фаза 1: Train: 2.6234e-05, Test: 2.7123e-05
# Фаза 2: Train: 2.7407e-05, Test: 2.8208e-05
# Фаза 3: Train: 3.0074e-05, Test: 3.1335e-05
# Фаза 4: Train: 2.6115e-05, Test: 2.7133e-05
# Фаза 5: Train: 2.8307e-05, Test: 2.9556e-05
# Фаза 6: Train: 2.3682e-05, Test: 2.4259e-05
# Фаза 7: Train: 2.2334e-05, Test: 2.2152e-05
# Фаза 8: Train: 2.1931e-05, Test: 2.2039e-05
# Фаза 9: Train: 2.2044e-05, Test: 2.1767e-05
# Фаза 10: Train: 1.9986e-05, Test: 2.0053e-05
# Фаза 11: Train: 3.1328e-05, Test: 3.2769e-05
# Фаза 12: Train: 1.8487e-05, Test: 1.8072e-05
# Прошло времени: 00:03:42
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 3.7304e-05
# Epoch [61/300], learn_rate: [0.0001], Train Loss: 2.7544e-05, Test Loss: 2.8128e-05
# Фаза 1: Train: 3.5531e-05, Test: 3.6992e-05
# Фаза 2: Train: 2.7371e-05, Test: 2.8175e-05
# Фаза 3: Train: 3.3456e-05, Test: 3.539e-05
# Фаза 4: Train: 2.8444e-05, Test: 2.9512e-05
# Фаза 5: Train: 2.9749e-05, Test: 3.1098e-05
# Фаза 6: Train: 2.5799e-05, Test: 2.6127e-05
# Фаза 7: Train: 2.0221e-05, Test: 2.0473e-05
# Фаза 8: Train: 2.5804e-05, Test: 2.6115e-05
# Фаза 9: Train: 2.0914e-05, Test: 2.0768e-05
# Фаза 10: Train: 2.2575e-05, Test: 2.2172e-05
# Фаза 11: Train: 4.1972e-05, Test: 4.3022e-05
# Фаза 12: Train: 1.8689e-05, Test: 1.7695e-05
# Прошло времени: 00:03:45
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 4.4076e-05
# Epoch [62/300], learn_rate: [9.972609476841367e-05], Train Loss: 2.4875e-05, Test Loss: 2.5505e-05
# Фаза 1: Train: 2.4848e-05, Test: 2.5374e-05
# Фаза 2: Train: 2.5802e-05, Test: 2.651e-05
# Фаза 3: Train: 3.3266e-05, Test: 3.4618e-05
# Фаза 4: Train: 2.5565e-05, Test: 2.6705e-05
# Фаза 5: Train: 2.8993e-05, Test: 3.018e-05
# Фаза 6: Train: 2.248e-05, Test: 2.2917e-05
# Фаза 7: Train: 1.949e-05, Test: 1.9792e-05
# Фаза 8: Train: 2.0044e-05, Test: 2.0191e-05
# Фаза 9: Train: 2.1798e-05, Test: 2.1564e-05
# Фаза 10: Train: 2.2841e-05, Test: 2.302e-05
# Фаза 11: Train: 3.2461e-05, Test: 3.4782e-05
# Фаза 12: Train: 2.0913e-05, Test: 2.0407e-05
# Прошло времени: 00:03:49
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 3.2749e-05
# Epoch [63/300], learn_rate: [9.890738003669029e-05], Train Loss: 2.2427e-05, Test Loss: 2.2876e-05
# Фаза 1: Train: 2.2611e-05, Test: 2.3197e-05
# Фаза 2: Train: 2.499e-05, Test: 2.5574e-05
# Фаза 3: Train: 2.5766e-05, Test: 2.7017e-05
# Фаза 4: Train: 2.4192e-05, Test: 2.5201e-05
# Фаза 5: Train: 2.4498e-05, Test: 2.5614e-05
# Фаза 6: Train: 2.4116e-05, Test: 2.4152e-05
# Фаза 7: Train: 2.1011e-05, Test: 2.1167e-05
# Фаза 8: Train: 1.9887e-05, Test: 2.0148e-05
# Фаза 9: Train: 2.1298e-05, Test: 2.1104e-05
# Фаза 10: Train: 1.9058e-05, Test: 1.9077e-05
# Фаза 11: Train: 2.5333e-05, Test: 2.6392e-05
# Фаза 12: Train: 1.6362e-05, Test: 1.5874e-05
# Прошло времени: 00:03:53
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 3.0504e-05
# Epoch [64/300], learn_rate: [9.755282581475769e-05], Train Loss: 2.2118e-05, Test Loss: 2.2624e-05
# Фаза 1: Train: 2.3471e-05, Test: 2.4652e-05
# Фаза 2: Train: 2.4142e-05, Test: 2.4735e-05
# Фаза 3: Train: 2.5604e-05, Test: 2.6747e-05
# Фаза 4: Train: 3.3203e-05, Test: 3.3465e-05
# Фаза 5: Train: 2.3699e-05, Test: 2.509e-05
# Фаза 6: Train: 1.9608e-05, Test: 1.9988e-05
# Фаза 7: Train: 1.9863e-05, Test: 2.0485e-05
# Фаза 8: Train: 1.844e-05, Test: 1.862e-05
# Фаза 9: Train: 1.8497e-05, Test: 1.8227e-05
# Фаза 10: Train: 1.6071e-05, Test: 1.6174e-05
# Фаза 11: Train: 2.7088e-05, Test: 2.7989e-05
# Фаза 12: Train: 1.573e-05, Test: 1.5313e-05
# Прошло времени: 00:03:57
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 3.7823e-05
# Epoch [65/300], learn_rate: [9.567727288213005e-05], Train Loss: 2.0091e-05, Test Loss: 2.0472e-05
# Фаза 1: Train: 2.0128e-05, Test: 2.0426e-05
# Фаза 2: Train: 2.1387e-05, Test: 2.1787e-05
# Фаза 3: Train: 2.4788e-05, Test: 2.6227e-05
# Фаза 4: Train: 2.5693e-05, Test: 2.6196e-05
# Фаза 5: Train: 2.146e-05, Test: 2.2213e-05
# Фаза 6: Train: 1.8872e-05, Test: 1.9186e-05
# Фаза 7: Train: 1.751e-05, Test: 1.7857e-05
# Фаза 8: Train: 1.8454e-05, Test: 1.8957e-05
# Фаза 9: Train: 1.8561e-05, Test: 1.8354e-05
# Фаза 10: Train: 1.5233e-05, Test: 1.5216e-05
# Фаза 11: Train: 2.3383e-05, Test: 2.4165e-05
# ...
# Фаза 5: Train: 2.9942e-06, Test: 3.2919e-06
# Фаза 6: Train: 2.453e-06, Test: 2.6058e-06
# Фаза 7: Train: 2.5263e-06, Test: 2.9353e-06
# Фаза 8: Train: 5.2254e-06, Test: 5.38e-06
# Фаза 9: Train: 4.012e-06, Test: 4.2692e-06
# Фаза 10: Train: 2.9521e-06, Test: 3.0345e-06
# Фаза 11: Train: 3.919e-06, Test: 4.1397e-06
# Фаза 12: Train: 2.4183e-06, Test: 2.7013e-06
# Прошло времени: 00:17:11
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.4619e-05
# Epoch [280/300], learn_rate: [7.938926261462366e-05], Train Loss: 3.2754e-06, Test Loss: 3.5221e-06
# Фаза 1: Train: 3.2167e-06, Test: 3.4392e-06
# Фаза 2: Train: 3.926e-06, Test: 4.0733e-06
# Фаза 3: Train: 4.1553e-06, Test: 4.5888e-06
# Фаза 4: Train: 4.2077e-06, Test: 4.3756e-06
# Фаза 5: Train: 3.0561e-06, Test: 3.3821e-06
# Фаза 6: Train: 2.1504e-06, Test: 2.3125e-06
# Фаза 7: Train: 2.6863e-06, Test: 3.0877e-06
# Фаза 8: Train: 3.5059e-06, Test: 3.6896e-06
# Фаза 9: Train: 3.8695e-06, Test: 4.1513e-06
# Фаза 10: Train: 2.5947e-06, Test: 2.6232e-06
# Фаза 11: Train: 3.2167e-06, Test: 3.4916e-06
# Фаза 12: Train: 2.7197e-06, Test: 3.0499e-06
# Прошло времени: 00:17:15
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.1074e-05
# Epoch [281/300], learn_rate: [7.500000000000001e-05], Train Loss: 3.5401e-06, Test Loss: 3.8037e-06
# Фаза 1: Train: 2.5e-06, Test: 2.7446e-06
# Фаза 2: Train: 4.0741e-06, Test: 4.2541e-06
# Фаза 3: Train: 4.1384e-06, Test: 4.6151e-06
# Фаза 4: Train: 6.6142e-06, Test: 6.7763e-06
# Фаза 5: Train: 3.073e-06, Test: 3.4109e-06
# Фаза 6: Train: 2.2889e-06, Test: 2.472e-06
# Фаза 7: Train: 2.4936e-06, Test: 2.9692e-06
# Фаза 8: Train: 4.7661e-06, Test: 4.8617e-06
# Фаза 9: Train: 3.6755e-06, Test: 3.9893e-06
# Фаза 10: Train: 2.0736e-06, Test: 2.1924e-06
# Фаза 11: Train: 4.6776e-06, Test: 4.9792e-06
# Фаза 12: Train: 2.1062e-06, Test: 2.3791e-06
# Прошло времени: 00:17:19
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.4839e-05
# Epoch [282/300], learn_rate: [7.033683215379002e-05], Train Loss: 3.2525e-06, Test Loss: 3.4949e-06
# Фаза 1: Train: 2.9468e-06, Test: 3.1709e-06
# Фаза 2: Train: 3.7214e-06, Test: 3.9126e-06
# Фаза 3: Train: 4.4396e-06, Test: 4.8288e-06
# Фаза 4: Train: 4.2282e-06, Test: 4.3759e-06
# Фаза 5: Train: 3.2644e-06, Test: 3.5928e-06
# Фаза 6: Train: 2.1931e-06, Test: 2.3182e-06
# Фаза 7: Train: 2.4064e-06, Test: 2.8411e-06
# Фаза 8: Train: 3.6373e-06, Test: 3.8382e-06
# Фаза 9: Train: 4.7335e-06, Test: 4.9943e-06
# Фаза 10: Train: 2.1163e-06, Test: 2.2413e-06
# Фаза 11: Train: 3.2606e-06, Test: 3.5316e-06
# Фаза 12: Train: 2.0826e-06, Test: 2.2937e-06
# Прошло времени: 00:17:22
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.5988e-05
# Epoch [283/300], learn_rate: [6.545084971874738e-05], Train Loss: 3.1303e-06, Test Loss: 3.3826e-06
# Фаза 1: Train: 2.4869e-06, Test: 2.6534e-06
# Фаза 2: Train: 3.61e-06, Test: 3.8734e-06
# Фаза 3: Train: 4.3904e-06, Test: 4.859e-06
# Фаза 4: Train: 4.6259e-06, Test: 4.8231e-06
# Фаза 5: Train: 3.1958e-06, Test: 3.4721e-06
# Фаза 6: Train: 2.2475e-06, Test: 2.4073e-06
# Фаза 7: Train: 2.2977e-06, Test: 2.7722e-06
# Фаза 8: Train: 3.5548e-06, Test: 3.7312e-06
# Фаза 9: Train: 3.6973e-06, Test: 3.9522e-06
# Фаза 10: Train: 2.078e-06, Test: 2.2198e-06
# Фаза 11: Train: 3.2305e-06, Test: 3.4598e-06
# Фаза 12: Train: 2.1491e-06, Test: 2.3681e-06
# Прошло времени: 00:17:26
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.6687e-05
# Epoch [284/300], learn_rate: [6.0395584540887963e-05], Train Loss: 3.2413e-06, Test Loss: 3.4945e-06
# Фаза 1: Train: 2.4665e-06, Test: 2.7171e-06
# Фаза 2: Train: 3.6577e-06, Test: 3.8319e-06
# Фаза 3: Train: 4.0657e-06, Test: 4.4893e-06
# Фаза 4: Train: 4.2921e-06, Test: 4.4651e-06
# Фаза 5: Train: 3.4912e-06, Test: 3.8268e-06
# Фаза 6: Train: 2.1183e-06, Test: 2.2972e-06
# Фаза 7: Train: 2.4485e-06, Test: 2.9176e-06
# Фаза 8: Train: 3.6606e-06, Test: 3.7766e-06
# Фаза 9: Train: 4.4921e-06, Test: 4.778e-06
# Фаза 10: Train: 2.6335e-06, Test: 2.7957e-06
# Фаза 11: Train: 3.4335e-06, Test: 3.6627e-06
# Фаза 12: Train: 2.1356e-06, Test: 2.3759e-06
# Прошло времени: 00:17:30
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.0663e-05
# Epoch [285/300], learn_rate: [5.522642316338268e-05], Train Loss: 3.1415e-06, Test Loss: 3.3781e-06
# Фаза 1: Train: 2.314e-06, Test: 2.4858e-06
# Фаза 2: Train: 3.6346e-06, Test: 3.8009e-06
# Фаза 3: Train: 4.0878e-06, Test: 4.5082e-06
# Фаза 4: Train: 4.1551e-06, Test: 4.3542e-06
# Фаза 5: Train: 3.1043e-06, Test: 3.4089e-06
# Фаза 6: Train: 2.2227e-06, Test: 2.3883e-06
# Фаза 7: Train: 3.5068e-06, Test: 3.9503e-06
# Фаза 8: Train: 3.2985e-06, Test: 3.4445e-06
# Фаза 9: Train: 4.2164e-06, Test: 4.4747e-06
# Фаза 10: Train: 2.0121e-06, Test: 2.0965e-06
# Фаза 11: Train: 3.0353e-06, Test: 3.2635e-06
# Фаза 12: Train: 2.11e-06, Test: 2.3611e-06
# Прошло времени: 00:17:34
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.5834e-05
# Epoch [286/300], learn_rate: [5.0000000000000016e-05], Train Loss: 3.2455e-06, Test Loss: 3.5123e-06
# Фаза 1: Train: 2.6499e-06, Test: 2.8227e-06
# Фаза 2: Train: 3.5909e-06, Test: 3.7986e-06
# Фаза 3: Train: 4.3248e-06, Test: 4.767e-06
# Фаза 4: Train: 5.731e-06, Test: 5.9212e-06
# Фаза 5: Train: 2.9629e-06, Test: 3.2935e-06
# Фаза 6: Train: 2.1362e-06, Test: 2.3245e-06
# Фаза 7: Train: 2.7165e-06, Test: 3.1457e-06
# Фаза 8: Train: 3.671e-06, Test: 3.8221e-06
# Фаза 9: Train: 3.7599e-06, Test: 4.0929e-06
# Фаза 10: Train: 2.0995e-06, Test: 2.238e-06
# Фаза 11: Train: 3.2169e-06, Test: 3.5201e-06
# Фаза 12: Train: 2.0861e-06, Test: 2.4017e-06
# Прошло времени: 00:17:37
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.3207e-05
# Epoch [287/300], learn_rate: [4.477357683661734e-05], Train Loss: 3.0075e-06, Test Loss: 3.2695e-06
# Фаза 1: Train: 2.2828e-06, Test: 2.503e-06
# Фаза 2: Train: 3.5636e-06, Test: 3.7339e-06
# Фаза 3: Train: 4.2974e-06, Test: 4.7638e-06
# Фаза 4: Train: 4.0025e-06, Test: 4.1777e-06
# Фаза 5: Train: 2.8751e-06, Test: 3.1738e-06
# Фаза 6: Train: 2.1187e-06, Test: 2.2918e-06
# Фаза 7: Train: 2.2973e-06, Test: 2.812e-06
# Фаза 8: Train: 3.4413e-06, Test: 3.6364e-06
# Фаза 9: Train: 3.5456e-06, Test: 3.8274e-06
# Фаза 10: Train: 2.1498e-06, Test: 2.263e-06
# Фаза 11: Train: 3.1012e-06, Test: 3.3242e-06
# Фаза 12: Train: 2.415e-06, Test: 2.7269e-06
# Прошло времени: 00:17:41
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.0008e-05
# Epoch [288/300], learn_rate: [3.9604415459112035e-05], Train Loss: 3.0047e-06, Test Loss: 3.2777e-06
# Фаза 1: Train: 2.6257e-06, Test: 2.859e-06
# Фаза 2: Train: 3.7788e-06, Test: 4.004e-06
# Фаза 3: Train: 4.2607e-06, Test: 4.7086e-06
# Фаза 4: Train: 4.0454e-06, Test: 4.2425e-06
# Фаза 5: Train: 3.0104e-06, Test: 3.3071e-06
# Фаза 6: Train: 1.9866e-06, Test: 2.1847e-06
# Фаза 7: Train: 2.3729e-06, Test: 2.8349e-06
# Фаза 8: Train: 3.2731e-06, Test: 3.4974e-06
# Фаза 9: Train: 3.6484e-06, Test: 3.9586e-06
# Фаза 10: Train: 1.9219e-06, Test: 2.0554e-06
# Фаза 11: Train: 2.9893e-06, Test: 3.2661e-06
# Фаза 12: Train: 2.1428e-06, Test: 2.4147e-06
# Прошло времени: 00:17:45
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.3042e-05
# Epoch [289/300], learn_rate: [3.4549150281252636e-05], Train Loss: 2.9578e-06, Test Loss: 3.2147e-06
# Фаза 1: Train: 2.1773e-06, Test: 2.4027e-06
# Фаза 2: Train: 3.4556e-06, Test: 3.6575e-06
# Фаза 3: Train: 3.8974e-06, Test: 4.3484e-06
# Фаза 4: Train: 4.006e-06, Test: 4.214e-06
# Фаза 5: Train: 2.6864e-06, Test: 2.9769e-06
# Фаза 6: Train: 2.6382e-06, Test: 2.8027e-06
# Фаза 7: Train: 2.224e-06, Test: 2.7126e-06
# Фаза 8: Train: 3.4627e-06, Test: 3.663e-06
# Фаза 9: Train: 3.4284e-06, Test: 3.7528e-06
# Фаза 10: Train: 2.087e-06, Test: 2.1823e-06
# Фаза 11: Train: 2.9925e-06, Test: 3.2042e-06
# Фаза 12: Train: 2.4379e-06, Test: 2.659e-06
# Прошло времени: 00:17:48
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.4329e-05
# Epoch [290/300], learn_rate: [2.9663167846209998e-05], Train Loss: 3.0565e-06, Test Loss: 3.3085e-06
# Фаза 1: Train: 2.067e-06, Test: 2.301e-06
# Фаза 2: Train: 3.4681e-06, Test: 3.653e-06
# Фаза 3: Train: 4.7267e-06, Test: 5.1797e-06
# Фаза 4: Train: 4.1989e-06, Test: 4.3822e-06
# Фаза 5: Train: 3.1396e-06, Test: 3.392e-06
# Фаза 6: Train: 2.0399e-06, Test: 2.2056e-06
# Фаза 7: Train: 2.2758e-06, Test: 2.7531e-06
# Фаза 8: Train: 3.2772e-06, Test: 3.4363e-06
# Фаза 9: Train: 3.6634e-06, Test: 3.9523e-06
# Фаза 10: Train: 1.9594e-06, Test: 2.1046e-06
# Фаза 11: Train: 3.6803e-06, Test: 3.9634e-06
# Фаза 12: Train: 2.1812e-06, Test: 2.3789e-06
# Прошло времени: 00:17:52
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.5326e-05
# Epoch [291/300], learn_rate: [2.500000000000001e-05], Train Loss: 2.9255e-06, Test Loss: 3.1894e-06
# Фаза 1: Train: 2.1116e-06, Test: 2.3249e-06
# Фаза 2: Train: 3.2792e-06, Test: 3.5135e-06
# Фаза 3: Train: 3.7536e-06, Test: 4.2484e-06
# Фаза 4: Train: 3.9097e-06, Test: 4.1124e-06
# Фаза 5: Train: 2.9939e-06, Test: 3.2995e-06
# Фаза 6: Train: 2.1947e-06, Test: 2.3933e-06
# Фаза 7: Train: 2.5888e-06, Test: 3.0954e-06
# Фаза 8: Train: 3.3325e-06, Test: 3.5256e-06
# Фаза 9: Train: 3.5675e-06, Test: 3.8414e-06
# Фаза 10: Train: 1.9387e-06, Test: 2.0374e-06
# Фаза 11: Train: 3.0929e-06, Test: 3.3092e-06
# Фаза 12: Train: 2.3432e-06, Test: 2.5719e-06
# Прошло времени: 00:17:56
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.2753e-05
# Epoch [292/300], learn_rate: [2.061073738537635e-05], Train Loss: 2.8407e-06, Test Loss: 3.0899e-06
# Фаза 1: Train: 2.2901e-06, Test: 2.5159e-06
# Фаза 2: Train: 3.3923e-06, Test: 3.5795e-06
# Фаза 3: Train: 3.9378e-06, Test: 4.3511e-06
# Фаза 4: Train: 4.1257e-06, Test: 4.3533e-06
# Фаза 5: Train: 2.7293e-06, Test: 3.0217e-06
# Фаза 6: Train: 1.9201e-06, Test: 2.0926e-06
# Фаза 7: Train: 2.302e-06, Test: 2.7442e-06
# Фаза 8: Train: 3.216e-06, Test: 3.3391e-06
# Фаза 9: Train: 3.466e-06, Test: 3.7717e-06
# Фаза 10: Train: 1.8686e-06, Test: 1.9688e-06
# Фаза 11: Train: 2.9109e-06, Test: 3.13e-06
# Фаза 12: Train: 1.9296e-06, Test: 2.2113e-06
# Прошло времени: 00:17:59
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.7296e-05
# Epoch [293/300], learn_rate: [1.6543469682057106e-05], Train Loss: 2.7623e-06, Test Loss: 3.0376e-06
# Фаза 1: Train: 2.0146e-06, Test: 2.2541e-06
# Фаза 2: Train: 3.6036e-06, Test: 3.8073e-06
# Фаза 3: Train: 3.7661e-06, Test: 4.2271e-06
# Фаза 4: Train: 3.7673e-06, Test: 3.9811e-06
# Фаза 5: Train: 2.6887e-06, Test: 2.9925e-06
# Фаза 6: Train: 1.9002e-06, Test: 2.0697e-06
# Фаза 7: Train: 2.1462e-06, Test: 2.6228e-06
# Фаза 8: Train: 3.1655e-06, Test: 3.3785e-06
# Фаза 9: Train: 3.4592e-06, Test: 3.8007e-06
# Фаза 10: Train: 1.8391e-06, Test: 1.9628e-06
# Фаза 11: Train: 2.8574e-06, Test: 3.1602e-06
# Фаза 12: Train: 1.9393e-06, Test: 2.1945e-06
# Прошло времени: 00:18:03
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 6.2031e-05
# Epoch [294/300], learn_rate: [1.2842758726130299e-05], Train Loss: 2.7909e-06, Test Loss: 3.0478e-06
# Фаза 1: Train: 2.0549e-06, Test: 2.2897e-06
# Фаза 2: Train: 3.3098e-06, Test: 3.4751e-06
# Фаза 3: Train: 3.9035e-06, Test: 4.3777e-06
# Фаза 4: Train: 3.7683e-06, Test: 3.9735e-06
# Фаза 5: Train: 2.6315e-06, Test: 2.9278e-06
# Фаза 6: Train: 1.9936e-06, Test: 2.1895e-06
# Фаза 7: Train: 2.2298e-06, Test: 2.6346e-06
# Фаза 8: Train: 3.3369e-06, Test: 3.4975e-06
# Фаза 9: Train: 3.5354e-06, Test: 3.8308e-06
# Фаза 10: Train: 1.8285e-06, Test: 1.9554e-06
# Фаза 11: Train: 2.8735e-06, Test: 3.1082e-06
# Фаза 12: Train: 2.0256e-06, Test: 2.3141e-06
# Прошло времени: 00:18:07
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.8434e-05
# Epoch [295/300], learn_rate: [9.549150281252633e-06], Train Loss: 2.7301e-06, Test Loss: 2.9888e-06
# Фаза 1: Train: 1.972e-06, Test: 2.2075e-06
# Фаза 2: Train: 3.3445e-06, Test: 3.5372e-06
# Фаза 3: Train: 3.6943e-06, Test: 4.1461e-06
# Фаза 4: Train: 3.8071e-06, Test: 3.9938e-06
# Фаза 5: Train: 2.5342e-06, Test: 2.827e-06
# Фаза 6: Train: 1.913e-06, Test: 2.0806e-06
# Фаза 7: Train: 2.2753e-06, Test: 2.7284e-06
# Фаза 8: Train: 3.1803e-06, Test: 3.3288e-06
# Фаза 9: Train: 3.3851e-06, Test: 3.6539e-06
# Фаза 10: Train: 1.8469e-06, Test: 1.9718e-06
# Фаза 11: Train: 2.7991e-06, Test: 3.0705e-06
# Фаза 12: Train: 2.0092e-06, Test: 2.3199e-06
# Прошло времени: 00:18:11
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.7571e-05
# Epoch [296/300], learn_rate: [6.698729810778065e-06], Train Loss: 2.7065e-06, Test Loss: 2.9821e-06
# Фаза 1: Train: 1.9785e-06, Test: 2.2227e-06
# Фаза 2: Train: 3.3548e-06, Test: 3.5598e-06
# Фаза 3: Train: 3.7233e-06, Test: 4.159e-06
# Фаза 4: Train: 3.7975e-06, Test: 4.0247e-06
# Фаза 5: Train: 2.622e-06, Test: 2.9128e-06
# Фаза 6: Train: 1.84e-06, Test: 2.0362e-06
# Фаза 7: Train: 2.165e-06, Test: 2.7016e-06
# Фаза 8: Train: 3.1071e-06, Test: 3.2932e-06
# Фаза 9: Train: 3.3432e-06, Test: 3.6396e-06
# Фаза 10: Train: 1.8145e-06, Test: 1.9444e-06
# Фаза 11: Train: 2.8718e-06, Test: 3.111e-06
# Фаза 12: Train: 1.8599e-06, Test: 2.1796e-06
# Прошло времени: 00:18:14
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.8955e-05
# Epoch [297/300], learn_rate: [4.322727117869951e-06], Train Loss: 2.7092e-06, Test Loss: 2.9615e-06
# Фаза 1: Train: 1.9796e-06, Test: 2.1915e-06
# Фаза 2: Train: 3.246e-06, Test: 3.4653e-06
# Фаза 3: Train: 3.6941e-06, Test: 4.147e-06
# Фаза 4: Train: 3.8458e-06, Test: 4.0093e-06
# Фаза 5: Train: 2.5654e-06, Test: 2.8553e-06
# Фаза 6: Train: 1.8271e-06, Test: 2.0116e-06
# Фаза 7: Train: 2.2203e-06, Test: 2.6531e-06
# Фаза 8: Train: 3.1786e-06, Test: 3.3371e-06
# Фаза 9: Train: 3.3438e-06, Test: 3.6354e-06
# Фаза 10: Train: 1.8426e-06, Test: 1.95e-06
# Фаза 11: Train: 2.852e-06, Test: 3.1128e-06
# Фаза 12: Train: 1.9152e-06, Test: 2.17e-06
# Прошло времени: 00:18:18
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.8246e-05
# Epoch [298/300], learn_rate: [2.4471741852423237e-06], Train Loss: 2.6849e-06, Test Loss: 2.9434e-06
# Фаза 1: Train: 1.9438e-06, Test: 2.1788e-06
# Фаза 2: Train: 3.2691e-06, Test: 3.469e-06
# Фаза 3: Train: 3.6474e-06, Test: 4.1116e-06
# Фаза 4: Train: 3.7307e-06, Test: 3.9445e-06
# Фаза 5: Train: 2.5445e-06, Test: 2.8346e-06
# Фаза 6: Train: 1.8435e-06, Test: 2.0146e-06
# Фаза 7: Train: 2.1527e-06, Test: 2.6258e-06
# Фаза 8: Train: 3.1524e-06, Test: 3.2952e-06
# Фаза 9: Train: 3.3613e-06, Test: 3.6427e-06
# Фаза 10: Train: 1.8064e-06, Test: 1.9473e-06
# Фаза 11: Train: 2.772e-06, Test: 3.0325e-06
# Фаза 12: Train: 1.9942e-06, Test: 2.2245e-06
# Прошло времени: 00:18:22
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.8504e-05
# Epoch [299/300], learn_rate: [1.0926199633097157e-06], Train Loss: 2.6727e-06, Test Loss: 2.932e-06
# Фаза 1: Train: 1.9622e-06, Test: 2.1824e-06
# Фаза 2: Train: 3.2303e-06, Test: 3.4384e-06
# Фаза 3: Train: 3.6547e-06, Test: 4.1101e-06
# Фаза 4: Train: 3.7435e-06, Test: 3.9577e-06
# Фаза 5: Train: 2.5036e-06, Test: 2.7951e-06
# Фаза 6: Train: 1.8348e-06, Test: 2.0075e-06
# Фаза 7: Train: 2.1967e-06, Test: 2.6331e-06
# Фаза 8: Train: 3.099e-06, Test: 3.2954e-06
# Фаза 9: Train: 3.3298e-06, Test: 3.6129e-06
# Фаза 10: Train: 1.8041e-06, Test: 1.9233e-06
# Фаза 11: Train: 2.7956e-06, Test: 3.0479e-06
# Фаза 12: Train: 1.9184e-06, Test: 2.1801e-06
# Прошло времени: 00:18:26
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 5.9102e-05
# Epoch [300/300], learn_rate: [2.7390523158633e-07], Train Loss: 2.6608e-06, Test Loss: 2.9282e-06
# Фаза 1: Train: 1.9337e-06, Test: 2.1751e-06
# Фаза 2: Train: 3.226e-06, Test: 3.4279e-06
# Фаза 3: Train: 3.651e-06, Test: 4.1302e-06
# Фаза 4: Train: 3.7045e-06, Test: 3.9507e-06
# Фаза 5: Train: 2.5069e-06, Test: 2.7894e-06
# Фаза 6: Train: 1.8293e-06, Test: 2.0053e-06
# Фаза 7: Train: 2.1716e-06, Test: 2.611e-06
# Фаза 8: Train: 3.1051e-06, Test: 3.2984e-06
# Фаза 9: Train: 3.3336e-06, Test: 3.6212e-06
# Фаза 10: Train: 1.7814e-06, Test: 1.9253e-06
# Фаза 11: Train: 2.7727e-06, Test: 3.0339e-06
# Фаза 12: Train: 1.9135e-06, Test: 2.1703e-06
# Прошло времени: 00:18:29

# %%
np_train_all_losses = np.array(train_all_losses)
np_test_all_losses = np.array(test_all_losses)

# %%
np_train_all_losses.shape
# Out:
# (300, 1406, 128)

# %%
np_test_all_losses.shape
# Out:
# (300, 156, 128)

# %%
len_train = np_train_all_losses.shape[1]*np_train_all_losses.shape[2]
print(len_train)
len_test = np_test_all_losses.shape[1]*np_test_all_losses.shape[2]
print(len_test)
# Out:
# 179968
# 19968

# %%
np_train_all_losses = np_train_all_losses.reshape(np_train_all_losses.shape[0],len_train)
np_test_all_losses = np_test_all_losses.reshape(np_train_all_losses.shape[0],len_test)

# %%
inter1 = 299

# %%
print(np.mean(np_train_all_losses[inter1]))
print(np.std(np_train_all_losses[inter1]))
print(np.median(np_train_all_losses[inter1]))
print(np.mean(np_test_all_losses[inter1]))
print(np.std(np_test_all_losses[inter1]))
print(np.median(np_test_all_losses[inter1]))
# Out:
# 2.6604125e-06
# 2.8811776e-06
# 1.8402104e-06
# 2.9291032e-06
# 3.4080692e-06
# 1.9605468e-06

# %%
x_scaled = np.arange(len_test)*len_train/len_test
print(x_scaled)
# Out:
# [0.00000000e+00 9.01282051e+00 1.80256410e+01 ... 1.79940962e+05
#  1.79949974e+05 1.79958987e+05]

# %%
plt.plot(np.sort(np_train_all_losses[inter1]))
plt.plot(x_scaled,np.sort(np_test_all_losses[inter1]),linestyle='-.')
plt.show()

# %%
plt.plot(train_losses,label='train_loss')
plt.plot(test_losses,label='test_loss')
plt.plot(experimental_losses,label='experimental_losses')
plt.legend()
plt.yscale('log')
plt.show()

# %%
total_exp_diff
# Out:
# np.float64(2.083497464985141)

# %%
ph_exp_diff
# Out:
# array([0.84043431, 0.88694988, 3.81381666, 4.1681766 , 1.18502402,
#        3.92548832, 1.11403623, 1.56812977, 2.89230732, 1.4214449 ,
#        1.76875685, 1.41740472])

# %%
exp_samples_nb
# Out:
# 41
