# %%
import os
import struct
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, WeightedRandomSampler
import torch.optim.lr_scheduler as lr_scheduler
import time
import csv
import glob
from diffraction_utils import load_experimental_data
from load_xml_phases import *
import torch.nn.functional as F
import matplotlib.pyplot as plt
import pandas as pd

# %%
difr_dir = "../../nn_data_2.5/"
os.makedirs(difr_dir, exist_ok=True)

# Автовыбор вычислительного устройства
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('device =', device)

# Вычисляем размер входа для свертки
input_size = 4001
num_phases = 12

xml_name = 'OSO'
model_ver = 'light_3'
wghts_fname = f'weights3_{xml_name}_{model_ver}.pth'
csv_res_fname = f"{xml_name}_{model_ver}.csv"

inp_data = []
out_data = []

PHASES_INFO = []

experiment_folder = 'XY_OSO_midKO'
# Out:
# device = cuda:0

# %%
# Создаем словарь для сопоставления имен файлов и целевых значений
target_values = {
    'Бо1125_180121.xy': np.array([0.42, 0.25, 42.72, 44.65, 2.22, 8.05, 0.00, 1.40, 0.28, 0.00, 0.01, 0.00]),
    'Бо2074_200121.xy': np.array([0.50, 0.24, 58.48, 27.85, 2.88, 7.90, 0.05, 1.62, 0.48, 0.00, 0.01, 0.00]),
    'Бо2077_200121.xy': np.array([0.40, 0.93, 67.24, 18.25, 3.63, 7.51, 0.03, 1.60, 0.42, 0.00, 0.00, 0.00]),
    'Бр1026_181220.xy': np.array([2.72, 2.78, 47.84, 28.73, 1.20, 14.57, 0.07, 2.06, 0.03, 0.00, 0.00, 0.00]),
    'Бр1071_241220.xy': np.array([1.22, 0.63, 50.30, 30.39, 1.60, 13.97, 0.06, 1.84, 0.00, 0.00, 0.00, 0.00]),
    'Бр1307_2_181220.xy': np.array([0.68, 1.17, 86.07, 0.94, 3.65, 1.29, 4.55, 0.31, 0.79, 0.05, 0.52, 0.00]),
    'Бр1356_251220.xy': np.array([1.67, 2.21, 78.72, 2.34, 7.51, 3.22, 2.43, 1.09, 0.51, 0.28, 0.02, 0.00]),
    'Бр1425_241220.xy': np.array([0.90, 1.56, 81.95, 1.43, 6.32, 2.76, 3.40, 0.85, 0.68, 0.16, 0.00, 0.00]),
    'Бр1428_241220.xy': np.array([1.07, 2.47, 63.14, 15.82, 0.80, 14.47, 0.66, 1.58, 0.00, 0.00, 0.00, 0.00]),
    'Бр1566_281220.xy': np.array([0.72, 3.95, 70.88, 5.65, 6.65, 9.87, 0.12, 2.14, 0.00, 0.00, 0.01, 0.00]),
    'В506_140121.xy': np.array([2.11, 2.59, 54.29, 21.35, 2.26, 15.51, 0.06, 1.59, 0.24, 0.00, 0.01, 0.00]),
    'В508_140121.xy': np.array([2.12, 3.48, 48.43, 27.17, 1.62, 15.24, 0.05, 1.63, 0.26, 0.00, 0.01, 0.00]),
    'В549_150121.xy': np.array([1.01, 3.74, 78.07, 0.43, 13.37, 0.44, 1.63, 0.24, 0.17, 0.00, 0.89, 0.00]),
    'В574_150121.xy': np.array([0.52, 1.16, 52.24, 24.86, 1.70, 16.05, 0.03, 3.32, 0.11, 0.00, 0.00, 0.00]),
    'В583_180121.xy': np.array([0.45, 1.25, 52.71, 24.86, 2.10, 16.14, 0.06, 2.38, 0.04, 0.00, 0.01, 0.00]),
    'И103_291220.xy': np.array([1.02, 3.74, 53.23, 30.05, 1.25, 5.35, 4.20, 1.05, 0.00, 0.11, 0.00, 0.00]),
    'И128_120121.xy': np.array([1.16, 3.16, 59.49, 23.44, 1.06, 7.46, 2.84, 1.33, 0.00, 0.06, 0.00, 0.00]),
    'И538_110121.xy': np.array([1.42, 0.97, 72.78, 9.48, 2.78, 10.23, 0.42, 1.19, 0.00, 0.72, 0.00, 0.00]),
    'И644_110121.xy': np.array([1.24, 4.00, 73.64, 6.08, 7.94, 4.33, 1.11, 0.93, 0.00, 0.63, 0.00, 0.00]),
    'И743_211220.xy': np.array([0.39, 1.37, 88.97, 0.92, 2.73, 0.32, 4.03, 0.12, 0.42, 0.28, 0.44, 0.00]),
    'И9085_130121.xy': np.array([0.48, 0.14, 42.95, 44.21, 1.04, 10.34, 0.07, 0.71, 0.06, 0.00, 0.00, 0.00]),
    'К173_210121.xy': np.array([0.68, 2.13, 45.16, 36.51, 1.06, 10.94, 0.07, 2.73, 0.29, 0.43, 0.00, 0.00]),
    'К1898_270121.xy': np.array([1.89, 1.83, 55.79, 17.94, 2.05, 13.11, 0.43, 2.62, 0.14, 4.21, 0.00, 0.00]),
    'К2019_270121.xy': np.array([1.30, 3.43, 67.70, 7.81, 2.77, 10.36, 0.05, 2.19, 0.40, 4.00, 0.00, 0.00]),
    'К2022_280121.xy': np.array([1.18, 1.49, 58.94, 15.68, 2.12, 13.57, 0.08, 2.58, 0.46, 3.91, 0.00, 0.00]),
    'К2035_280121.xy': np.array([0.99, 1.88, 57.56, 16.03, 2.68, 12.59, 0.11, 2.36, 0.43, 5.37, 0.00, 0.00]),
    'К2041_280121.xy': np.array([0.95, 2.44, 49.16, 25.80, 1.25, 13.73, 0.07, 2.76, 0.22, 3.62, 0.00, 0.00]),
    'К2042_290121.xy': np.array([0.87, 0.92, 83.39, 0.71, 0.34, 0.11, 6.30, 0.00, 0.24, 4.62, 2.51, 0.00]),
    'С152_161220.xy': np.array([0.26, 1.65, 33.93, 52.38, 0.73, 9.34, 0.27, 0.99, 0.04, 0.38, 0.04, 0.00]),
    'С207_181220.xy': np.array([0.32, 0.61, 42.08, 44.57, 0.83, 9.56, 0.29, 1.31, 0.00, 0.42, 0.00, 0.00]),
    'С294_211220.xy': np.array([0.77, 2.01, 57.04, 26.08, 2.25, 8.96, 0.34, 1.74, 0.00, 0.83, 0.00, 0.00]),
    'С343_221220.xy': np.array([1.84, 1.80, 51.13, 33.75, 1.11, 7.74, 0.75, 1.31, 0.00, 0.56, 0.00, 0.00]),
    'С367_231220.xy': np.array([0.47, 1.94, 56.72, 26.99, 1.58, 9.51, 0.39, 1.60, 0.00, 0.81, 0.00, 0.00]),
    'С455_171220.xy': np.array([0.20, 2.09, 32.42, 53.03, 0.80, 9.33, 0.46, 1.01, 0.00, 0.28, 0.38, 0.00]),
    'С479_231220.xy': np.array([0.73, 1.32, 53.55, 31.52, 1.41, 9.09, 0.29, 1.45, 0.00, 0.63, 0.00, 0.00]),
    'С490_231220.xy': np.array([1.05, 2.49, 55.01, 30.80, 1.07, 4.45, 3.10, 1.48, 0.01, 0.55, 0.00, 0.00]),
    'дБо2058д_240521.xy': np.array([0.00, 0.74, 10.33, 59.61, 2.16, 5.09, 0.13, 21.81, 0.15, 0.00, 0.00, 0.00]),
    'дБо2082д_280521.xy': np.array([0.62, 0.35, 85.91, 0.00, 0.00, 0.00, 3.22, 0.00, 9.42, 0.06, 0.17, 0.00]),
    'дБр1307д_220421.xy': np.array([0.93, 0.36, 85.71, 0.39, 0.35, 0.03, 9.36, 0.00, 0.24, 0.00, 1.22, 1.43]),
    'дБр1552д_020621.xy': np.array([0.89, 0.00, 85.48, 0.25, 0.34, 0.00, 6.05, 0.03, 0.58, 0.00, 0.37, 6.00]),
    'дК1132д_180521.xy': np.array([2.42, 1.47, 75.98, 0.48, 0.61, 0.17, 9.58, 0.06, 4.70, 0.16, 2.08, 2.28]),
    'дК1585д_170521.xy': np.array([0.43, 1.17, 84.69, 0.00, 0.00, 0.00, 9.71, 0.00, 1.83, 1.65, 0.46, 0.00]),
    'дК180д_290421.xy': np.array([0.19, 1.93, 26.94, 42.17, 4.99, 17.44, 0.06, 5.90, 0.00, 0.40, 0.00, 0.00]),
    'дС132д_210421.xy': np.array([0.29, 2.38, 26.13, 41.49, 2.17, 16.56, 0.10, 10.58, 0.27, 0.03, 0.00, 0.00]),
    'дС321д_120521.xy': np.array([0.42, 1.90, 20.31, 38.45, 3.73, 20.36, 0.10, 14.56, 0.00, 0.02, 0.16, 0.00]),
    'дС323д_170521.xy': np.array([0.17, 1.65, 21.48, 30.25, 7.69, 19.54, 0.03, 18.75, 0.14, 0.07, 0.24, 0.00])
}

# %%
def predict_experimental_data(model, experimental_data, input_size):
    predictions = []
    total_difference = 0.0
    exp_samples_nb = 0

    diff_by_phases = []
    for i in range(num_phases):
        diff_by_phases.append(0)

    for filename, intensities in experimental_data.items():

        interpolated_intensities = torch.tensor(intensities, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)[:,:,1:]
        model.eval()
        with torch.no_grad():
            predicted_weights = model(interpolated_intensities)

        # Умножаем предсказанные веса на 100
        #predicted_weights *= 100
        
        predictions.append((filename, predicted_weights.squeeze().cpu().numpy()))

        # Сравнение с целевыми значениями, если они есть
        if filename in target_values:
            target = target_values[filename]
            curr_phases = np.square(predicted_weights.squeeze().cpu().numpy() - target*0.01)
            total_difference += curr_phases.sum()
            diff_by_phases += curr_phases  # Аккумулируем разности для каждой фазы
            exp_samples_nb += 1

    if exp_samples_nb > 0:
        total_difference = (total_difference / exp_samples_nb) / num_phases
        diff_by_phases /= exp_samples_nb  # Вычисляем средние значения для каждой фазы
    else:
        total_difference = 0.0
        diff_by_phases = np.zeros(num_phases)

    return total_difference, diff_by_phases, exp_samples_nb

def load_batch_inp_file(file_name):
    if os.path.exists(file_name):
        with open(file_name, 'rb') as f:
            while True:
                data = f.read(struct.calcsize(f'{input_size}f'))
                if not data:
                    break
                inp = struct.unpack(f'{input_size}f', data)
                inp_data.append(np.array(inp))


def load_batch_out_file(file_name):
    if os.path.exists(file_name):
        with open(file_name, 'rb') as f:
            while True:
                data = f.read(struct.calcsize(f'{num_phases}f'))
                if not data:
                    break
                out = struct.unpack(f'{num_phases}f', data)
                out_data.append(np.array(out))

# %%
# Загрузка данных
inp_files = glob.glob(f"{difr_dir}batch_inp_{xml_name}_sd2.5_{num_phases}ph_p*.bin")
out_files = glob.glob(f"{difr_dir}batch_out_{xml_name}_sd2.5_{num_phases}ph_p*.bin")

inp_files = sorted(inp_files)
out_files = sorted(out_files)

print('inp_files',inp_files)
print('out_files',out_files)

for file in inp_files:
    load_batch_inp_file(file)

for file in out_files:
    load_batch_out_file(file)

print(f"Размер массива out_data: {len(out_data)}\n")

if len(out_data) < 1:
    print("Внимание - нет данных для обучения !")

lim_len = 500000
if len(inp_data) > lim_len:
    inp_data = inp_data[-lim_len:]
if len(out_data) > lim_len:
    out_data = out_data[-lim_len:]
# Out:
# inp_files ['../../nn_data_2.5/batch_inp_OSO_sd2.5_12ph_p1_25000.bin', '../../nn_data_2.5/batch_inp_OSO_sd2.5_12ph_p2_25000.bin', '../../nn_data_2.5/batch_inp_OSO_sd2.5_12ph_p3_25000.bin', '../../nn_data_2.5/batch_inp_OSO_sd2.5_12ph_p4_25000.bin']
# out_files ['../../nn_data_2.5/batch_out_OSO_sd2.5_12ph_p1_25000.bin', '../../nn_data_2.5/batch_out_OSO_sd2.5_12ph_p2_25000.bin', '../../nn_data_2.5/batch_out_OSO_sd2.5_12ph_p3_25000.bin', '../../nn_data_2.5/batch_out_OSO_sd2.5_12ph_p4_25000.bin']
# Размер массива out_data: 100000

# %%
out_data[0]
# Out:
# array([3.26506999e-08, 9.93896928e-03, 0.00000000e+00, 6.04183599e-02,
#        1.73202887e-01, 8.31474259e-04, 1.99009031e-01, 0.00000000e+00,
#        6.24747053e-02, 1.34024754e-01, 1.35469731e-04, 3.59964311e-01])

# %%
# Определение класса для датасета
class CandleDataset(Dataset):
    def __init__(self, inputs, outputs):
        self.inputs = inputs
        self.outputs = outputs

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        # Возвращаем данные без изменения формы
        return torch.tensor(self.inputs[idx], dtype=torch.float32).unsqueeze(0), torch.tensor(self.outputs[idx], dtype=torch.float32)

# %%
# Разделение данных на тренировочную и тестовую выборки
indices = list(range(len(inp_data)))
indices = np.array(indices)
np.random.shuffle(indices)
#test_indices = indices[::11]
#train_indices = [i for i in indices if i not in test_indices]
test_indices = indices[:int(0.1*len(indices))]
train_indices = indices[int(0.1*len(indices)):]

train_inputs = [inp_data[i] for i in train_indices]
train_outputs = [out_data[i] for i in train_indices]
test_inputs = [inp_data[i] for i in test_indices]
test_outputs = [out_data[i] for i in test_indices]

train_inputs_np = np.array(train_inputs)[:,1:]
test_inputs_np = np.array(test_inputs)[:,1:]

train_dataset = CandleDataset(train_inputs_np, train_outputs)
test_dataset = CandleDataset(test_inputs_np, test_outputs)

# %%
# Загружаем фазы из файлов .phase
sample_info, PHASES_INFO = parse_xml('XRD_Data/OSO_Topas_2022_stidy.tshx')
num_phases = len(PHASES_INFO)

# Загружаем экспериментальные данные
experimental_data = load_experimental_data(experiment_folder)
#print(f'Loaded {len(experimental_data)} experimental diffraction patterns.')
# Out:
# {'Name': 'alpha-Al2O3', 'SpaceGroup': 'R-3cH', 'CellPar': {'a': {'min': 4.755, 'max': 4.77, 'value': 4.7698}, 'b': {'min': None, 'max': None, 'value': 4.7698}, 'c': {'min': 13.0, 'max': 13.05, 'value': 13.0243}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 120.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 45.0, 'max': 150.0, 'value': 100.0}, 'Strain': {'min': 0.01, 'max': 0.35, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.35231}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O2-', 'X': {'min': None, 'max': None, 'value': 0.6936}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'gamma-Al2O3', 'SpaceGroup': 'Fd-3mZ', 'CellPar': {'a': {'min': 7.9, 'max': 7.937, 'value': 7.911}, 'b': {'min': None, 'max': None, 'value': 7.911}, 'c': {'min': None, 'max': None, 'value': 7.911}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 45.0, 'max': 300.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.35, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.2547}, 'Y': {'min': None, 'max': None, 'value': 0.2547}, 'Z': {'min': None, 'max': None, 'value': 0.2547}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 0.58}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.125}, 'Y': {'min': None, 'max': None, 'value': 0.125}, 'Z': {'min': None, 'max': None, 'value': 0.125}, 'Occ': {'min': None, 'max': None, 'value': 0.84}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0272}, 'Y': {'min': None, 'max': None, 'value': 0.0272}, 'Z': {'min': None, 'max': None, 'value': 0.0272}, 'Occ': {'min': None, 'max': None, 'value': 0.17}}], 'RIR': -1}
#
# {'Name': 'Cryolite', 'SpaceGroup': 'P121/c1', 'CellPar': {'a': {'min': 5.35095, 'max': 5.45905, 'value': 5.405}, 'b': {'min': 5.5242, 'max': 5.6358, 'value': 5.58}, 'c': {'min': 9.351936, 'max': 9.540864000000001, 'value': 9.4464}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': 123.51933, 'max': 126.01467, 'value': 124.767}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 70.0, 'max': 500.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [{'name': '1 1 1', 'min': 0.95, 'max': 1.1, 'value': 1.0}], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': 0.2638, 'max': 0.27, 'value': 0.2656}, 'Y': {'min': 0.448, 'max': 0.456, 'value': 0.448}, 'Z': {'min': 0.2501, 'max': 0.257, 'value': 0.2518}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.114, 'max': 0.12, 'value': 0.1152}, 'Y': {'min': 0.042, 'max': 0.05, 'value': 0.0436}, 'Z': {'min': 0.214, 'max': 0.223, 'value': 0.2182}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.22, 'max': 0.229, 'value': 0.2285}, 'Y': {'min': 0.73, 'max': 0.738, 'value': 0.7285}, 'Z': {'min': 0.057, 'max': 0.064, 'value': 0.0638}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.307, 'max': 0.319, 'value': 0.3215}, 'Y': {'min': 0.166, 'max': 0.18, 'value': 0.1765}, 'Z': {'min': 0.037, 'max': 0.048, 'value': 0.047}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Chiolite', 'SpaceGroup': 'P4/mnc', 'CellPar': {'a': {'min': 7.02, 'max': 7.06, 'value': 7.0138}, 'b': {'min': None, 'max': None, 'value': 7.0138}, 'c': {'min': 10.36, 'max': 10.403, 'value': 10.402}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 80.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [{'name': '0 0 1', 'min': 0.93, 'max': 1.0, 'value': 1.0}], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.277}, 'Y': {'min': None, 'max': None, 'value': 0.777}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': 0.17, 'max': 0.177, 'value': 0.1711}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.058, 'max': 0.064, 'value': 0.0642}, 'Y': {'min': 0.245, 'max': 0.252, 'value': 0.2477}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.176, 'max': 0.182, 'value': 0.1794}, 'Y': {'min': 0.532, 'max': 0.54, 'value': 0.5364}, 'Z': {'min': 0.118, 'max': 0.121, 'value': 0.1198}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'NaCa(AlF6)', 'SpaceGroup': 'P121/c1', 'CellPar': {'a': {'min': 8.715, 'max': 8.795, 'value': 8.7423}, 'b': {'min': 5.145, 'max': 5.21, 'value': 5.1927}, 'c': {'min': 20.3, 'max': 20.46, 'value': 20.35139}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': 90.85, 'max': 91.5, 'value': 91.499}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 30.0, 'max': 150.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Na1+', 'X': {'min': 0.9668, 'max': 0.9868, 'value': 0.9768}, 'Y': {'min': 0.2443, 'max': 0.2643, 'value': 0.2543}, 'Z': {'min': 0.1681, 'max': 0.1881, 'value': 0.1781}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': 0.9581, 'max': 0.9781, 'value': 0.9681}, 'Y': {'min': 0.2634, 'max': 0.2834, 'value': 0.2734}, 'Z': {'min': 0.4313, 'max': 0.4513, 'value': 0.4413}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Ca2+', 'X': {'min': 0.6303, 'max': 0.6503, 'value': 0.6403}, 'Y': {'min': 0.2275, 'max': 0.2475, 'value': 0.2375}, 'Z': {'min': 0.3008, 'max': 0.3208, 'value': 0.3108}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Ca2+', 'X': {'min': 0.6257, 'max': 0.6457, 'value': 0.6357}, 'Y': {'min': 0.3119, 'max': 0.3319, 'value': 0.3219}, 'Z': {'min': 0.5523, 'max': 0.5723, 'value': 0.5623}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': 0.2488, 'max': 0.2688, 'value': 0.2588}, 'Y': {'min': 0.2461, 'max': 0.2661, 'value': 0.2561}, 'Z': {'min': 0.3089, 'max': 0.3289, 'value': 0.3189}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': 0.2428, 'max': 0.2628, 'value': 0.2528}, 'Y': {'min': 0.1803, 'max': 0.2003, 'value': 0.1903}, 'Z': {'min': 0.5588, 'max': 0.5788, 'value': 0.5688}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.629}, 'Y': {'min': None, 'max': None, 'value': 0.6261}, 'Z': {'min': None, 'max': None, 'value': 0.4777}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.5863}, 'Y': {'min': None, 'max': None, 'value': 0.6137}, 'Z': {'min': None, 'max': None, 'value': 0.6397}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.7338}, 'Y': {'min': None, 'max': None, 'value': 0.0827}, 'Z': {'min': None, 'max': None, 'value': 0.4824}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.3809}, 'Y': {'min': None, 'max': None, 'value': 0.1003}, 'Z': {'min': None, 'max': None, 'value': 0.2626}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1625}, 'Y': {'min': None, 'max': None, 'value': -0.0247}, 'Z': {'min': None, 'max': None, 'value': 0.6328}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1643}, 'Y': {'min': None, 'max': None, 'value': 0.4377}, 'Z': {'min': None, 'max': None, 'value': 0.3814}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.2357}, 'Y': {'min': None, 'max': None, 'value': 0.4669}, 'Z': {'min': None, 'max': None, 'value': 0.6229}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.5786}, 'Y': {'min': None, 'max': None, 'value': 0.5944}, 'Z': {'min': None, 'max': None, 'value': 0.8821}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.9132}, 'Y': {'min': None, 'max': None, 'value': 0.6404}, 'Z': {'min': None, 'max': None, 'value': 0.226}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.7403}, 'Y': {'min': None, 'max': None, 'value': 0.0217}, 'Z': {'min': None, 'max': None,  ...
#
# {'Name': 'Na2Ca3Al2F14', 'SpaceGroup': 'I213', 'CellPar': {'a': {'min': 10.242, 'max': 10.254, 'value': 10.257}, 'b': {'min': None, 'max': None, 'value': 10.257}, 'c': {'min': None, 'max': None, 'value': 10.257}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 65.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [{'name': '1 1 1', 'min': 0.72, 'max': 1.0, 'value': 1.0}], 'Atoms': [{'Type': 'Ca2+', 'X': {'min': None, 'max': None, 'value': 0.4667}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.2482}, 'Y': {'min': None, 'max': None, 'value': 0.2482}, 'Z': {'min': None, 'max': None, 'value': 0.2482}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.0847}, 'Y': {'min': None, 'max': None, 'value': 0.0847}, 'Z': {'min': None, 'max': None, 'value': 0.0847}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1387}, 'Y': {'min': None, 'max': None, 'value': 0.3062}, 'Z': {'min': None, 'max': None, 'value': 0.1206}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.364}, 'Y': {'min': None, 'max': None, 'value': 0.3627}, 'Z': {'min': None, 'max': None, 'value': 0.1873}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.4614}, 'Y': {'min': None, 'max': None, 'value': 0.4614}, 'Z': {'min': None, 'max': None, 'value': 0.4614}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Fluorite', 'SpaceGroup': 'Fm-3m', 'CellPar': {'a': {'min': 5.463, 'max': 5.469, 'value': 5.462}, 'b': {'min': None, 'max': None, 'value': 5.462}, 'c': {'min': None, 'max': None, 'value': 5.462}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 60.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.38, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Ca2+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Weberite', 'SpaceGroup': 'Imma', 'CellPar': {'a': {'min': 7.05, 'max': 7.072, 'value': 7.05}, 'b': {'min': 9.98, 'max': 10.02, 'value': 9.979}, 'c': {'min': 7.29, 'max': 7.31, 'value': 7.297}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 150.0, 'max': 500.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.35, 'value': 0.1}}, 'MDtexDir': [{'name': '0 1 1', 'min': 0.9, 'max': 1.0, 'value': 1.0}], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.75}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Mg2+', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.1362}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.4144}, 'Z': {'min': None, 'max': None, 'value': 0.7213}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1845}, 'Y': {'min': None, 'max': None, 'value': 0.3874}, 'Z': {'min': None, 'max': None, 'value': 0.4304}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Neighborite', 'SpaceGroup': 'Pnma', 'CellPar': {'a': {'min': 5.488, 'max': 5.5, 'value': 5.4928}, 'b': {'min': 7.665, 'max': 7.69, 'value': 7.71}, 'c': {'min': 5.36, 'max': 5.387, 'value': 5.37645}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 100.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.3, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.03975}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.488}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Mg2+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.4547}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.58705}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.29105}, 'Y': {'min': None, 'max': None, 'value': 0.04897}, 'Z': {'min': None, 'max': None, 'value': 0.21265}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Elpasolite', 'SpaceGroup': 'Fm-3m', 'CellPar': {'a': {'min': 8.095, 'max': 8.112, 'value': 8.093}, 'b': {'min': None, 'max': None, 'value': 8.093}, 'c': {'min': None, 'max': None, 'value': 8.093}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 60.0, 'max': 200.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'K', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F', 'X': {'min': None, 'max': None, 'value': 0.2225}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'K1.58Al11O17', 'SpaceGroup': 'R-3mH', 'CellPar': {'a': {'min': 5.585, 'max': 5.62, 'value': 5.63}, 'b': {'min': None, 'max': None, 'value': 5.63}, 'c': {'min': 33.89, 'max': 34.17, 'value': 34.01}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 120.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 45.0, 'max': 150.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.37, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.16712}, 'Y': {'min': None, 'max': None, 'value': -0.16712}, 'Z': {'min': None, 'max': None, 'value': 0.9298}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.34988}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.44935}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.16419}, 'Y': {'min': None, 'max': None, 'value': -0.16419}, 'Z': {'min': None, 'max': None, 'value': 0.23615}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.15396}, 'Y': {'min': None, 'max': None, 'value': -0.15396}, 'Z': {'min': None, 'max': None, 'value': 0.03384}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.09512}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.2952}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'K', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': -0.17086}, 'Occ': {'min': None, 'max': None, 'value': 0.31}}, {'Type': 'K', 'X': {'min': None, 'max': None, 'value': 0.08717}, 'Y': {'min': None, 'max': None, 'value': -0.08717}, 'Z': {'min': None, 'max': None, 'value': -0.16784}, 'Occ': {'min': None, 'max': None, 'value': 0.16}}], 'RIR': -1}
#
# {'Name': 'Villiaumite', 'SpaceGroup': 'Fm-3m', 'CellPar': {'a': {'min': 4.633, 'max': 4.64, 'value': 4.634}, 'b': {'min': None, 'max': None, 'value': 4.634}, 'c': {'min': None, 'max': None, 'value': 4.634}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 90.0, 'max': 170.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.38, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Na', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}

# %%
#small
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()
        
        # Сверточные слои: уменьшены более агрессивно (в ~2.5 раза)
        self.conv_layers = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=32, kernel_size=7, stride=1, padding=3),  # Было 64
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=32, out_channels=64, kernel_size=5, stride=1, padding=2),  # Было 128
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1), # Было 256
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2)
        )
        
        reduced_size = input_size // 8
        
        # Трансформер: один слой + уменьшенная размерность
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=500, nhead=10, dim_feedforward=256, dropout=0.1, batch_first=True), # d_model и dim_feedforward уменьшены
            num_layers=1  # Один слой
        )
        
        # Полносвязные слои: значительно уменьшены
        self.fc_layers = nn.Sequential(
            nn.Linear(128 * reduced_size, 256),  # Было 1024
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(256, num_phases)
        )
    
    def forward(self, x):
        x = self.conv_layers(x)
        #x = x.permute(0, 2, 1)  # Критичный шаг сохранён
        x = self.transformer(x)
        x = x.reshape(x.size(0), -1)
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)
        return x

# %%
#big
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super(DiffractionNet, self).__init__()
        
        # Сверточные слои для извлечения локальных признаков
        self.conv_layers = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=64, kernel_size=7, stride=1, padding=3),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=64, out_channels=128, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2)
        )
        
        # Размер выхода после сверточных слоев
        reduced_size = input_size // 8  # Поскольку мы делаем три пулинга с шагом 2
        
        # Трансформер для глобального понимания
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=256, nhead=8, dim_feedforward=512, dropout=0.1, batch_first=True),
            num_layers=2
        )
        
        # Полносвязные слои для получения итогового предсказания
        self.fc_layers = nn.Sequential(
            nn.Linear(256 * reduced_size, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(1024, num_phases)
        )
    
    def forward(self, x):
        x = self.conv_layers(x)
        x = x.permute(0, 2, 1)  # Изменяем форму для трансформера (batch_size, sequence_length, features)
        x = self.transformer(x)
        x = x.reshape(x.size(0), -1)  # Флэттенинг с использованием reshape
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)  # Нормированные доли
        return x

# %%
#FFN
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()        
        
        # Полносвязные слои: значительно уменьшены
        self.fc_layers = nn.Sequential(
            nn.Linear(4001, 2048),  # Было 1024
            #nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(2048,1024),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(1024,256),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(256, num_phases)
        )
    
    def forward(self, x):
        #x = self.conv_layers(x)
        #x = x.permute(0, 2, 1)  # Критичный шаг сохранён
        #x = self.transformer(x)
        #x = x.reshape(x.size(0), -1)
        x = x.view(-1,4001)
        #print(x.shape)
        x = self.fc_layers(x)
        #print(x.shape)
        x = F.softmax(x, dim=1)
        #print(x.shape)
        return x

# %%
#conv_ff
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()
        self.fc_layers = nn.Sequential(            
            nn.Linear(4000, 256),
            nn.ReLU(),
            nn.Linear(256, num_phases)
        )
    
    def forward(self, x):
        x = x.reshape(x.size(0), -1)
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)
        return x

# %%
#ff_40_100
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()
        self.fc_layers = nn.Sequential(            
            nn.Linear(4040, num_phases)
        )
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=40, nhead=8, dim_feedforward=256, dropout=0.1, batch_first=True),
            num_layers=2
        )
        self.positional_embedding=nn.Parameter(torch.randn(1, 1, 40))
    
    def forward(self, x):
        x = x.view(-1,40,100).permute(0, 2, 1)
        positional_embeddings = self.positional_embedding.expand(x.shape[0], 1, 40)
        x = torch.cat((positional_embeddings, x), dim=1)
        x = self.transformer(x)
        x = x.view(-1,4040)
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)
        return x

# %%
#ff_40_100_3L_256
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()
        self.fc_layers = nn.Sequential(            
            nn.Linear(4040, num_phases)
        )
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=40, nhead=8, dim_feedforward=256, dropout=0.1, batch_first=True),
            num_layers=3
        )
        self.positional_embedding=nn.Parameter(torch.randn(1, 1, 40))
    
    def forward(self, x):
        x = x.view(-1,40,100).permute(0, 2, 1)
        positional_embeddings = self.positional_embedding.expand(x.shape[0], 1, 40)
        x = torch.cat((positional_embeddings, x), dim=1)
        x = self.transformer(x)
        x = x.view(-1,4040)
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)
        return x

# %%
#ff_CNN_40_100
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()
        self.conv_layers = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=40, kernel_size=40, stride=20, padding=10),         
            nn.ReLU(),
        )
        self.fc_layers = nn.Sequential(            
            nn.Linear(8040, num_phases)
        )
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=40, nhead=8, dim_feedforward=256, dropout=0.1, batch_first=True),
            num_layers=2
        )
        self.positional_embedding=nn.Parameter(torch.randn(1, 1, 40))
    
    def forward(self, x):
        x = self.conv_layers(x)
        x = x.permute(0, 2, 1)
        positional_embeddings = self.positional_embedding.expand(x.shape[0], 1, 40)
        x = torch.cat((positional_embeddings, x), dim=1)
        x = self.transformer(x)
        x = x.view(-1,8040)
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)
        return x

# %%
#ff_CNN_40_100_stride1
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()
        self.conv_layers = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=1, kernel_size=40, stride=1, padding=20),         
            nn.ReLU(),
        )
        self.fc_layers = nn.Sequential(            
            nn.Linear(4040, num_phases)
        )
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=40, nhead=8, dim_feedforward=256, dropout=0.1, batch_first=True),
            num_layers=2
        )
        self.positional_embedding=nn.Parameter(torch.randn(1, 1, 40))
    
    def forward(self, x):
        x = self.conv_layers(x)
        #print(x.shape)
        #x = x.permute(0, 2, 1)
        x = x[:,:,1:]
        #print(x.shape)
        x = x.view(-1,40,100).permute(0, 2, 1)
        #print(x.shape)
        positional_embeddings = self.positional_embedding.expand(x.shape[0], 1, 40)
        x = torch.cat((positional_embeddings, x), dim=1)
        x = self.transformer(x)
        x = x.view(-1,4040)
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)
        return x

# %%
# Создание экземпляра модели
model = DiffractionNet(input_size, num_phases).to(device)
print(model)
pytorch_total_params = sum(p.numel() for p in model.parameters())
print(pytorch_total_params)
# Out:
# DiffractionNet(
#   (fc_layers): Sequential(
#     (0): Linear(in_features=4040, out_features=12, bias=True)
#   )
#   (transformer): TransformerEncoder(
#     (layers): ModuleList(
#       (0-2): 3 x TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=40, out_features=40, bias=True)
#         )
#         (linear1): Linear(in_features=40, out_features=256, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=256, out_features=40, bias=True)
#         (norm1): LayerNorm((40,), eps=1e-05, elementwise_affine=True, bias=True)
#         (norm2): LayerNorm((40,), eps=1e-05, elementwise_affine=True, bias=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
# )
# 131020

# %%
print('Start training')
learn_rate = 1E-4
# Определяем критерий потерь и оптимизатор
criterion = nn.MSELoss(reduction='none')  # Используем reduction='none' для получения ошибки для каждого элемента в батче
optimizer = optim.AdamW(model.parameters(), lr=learn_rate, weight_decay=learn_rate*0.1)
def find_index_of_max(float_array):
    max_index = np.argmax(float_array)
    return max_index

# Определяем категории для балансировки данных
def get_category(out):
    min_val = np.min(out)
    max_val = np.max(out)
    delta = min_val / max_val if max_val > 0 else 0.0
    if delta < 0.001:
        return 0
    elif 0.001 <= delta < 0.01:
        return 1
    elif 0.01 <= delta < 0.1:
        return 2
    else:
        return 3
# Определяем метки классов для балансировки
train_labels = np.array([find_index_of_max(out) for out in train_outputs])
print('train_labels',train_labels)
class_counts = np.bincount(train_labels.astype(np.int64))
print(f'Category class_counts = {class_counts}')
# Добавляем сглаживание для предотвращения деления на ноль
#smoothing_factor = 1e-3
#class_weights = 1. / (class_counts + smoothing_factor)
class_weights = 1. / class_counts
sample_weights = class_weights[train_labels]
sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(sample_weights), replacement=True)
# Загрузка данных
train_dataloader = DataLoader(train_dataset, batch_size=128, sampler=sampler)
test_dataloader = DataLoader(test_dataset, batch_size=128, shuffle=False)

n_train_iter = len(train_dataloader)
n_test_iter = len(test_dataloader)
print(f'train_iter: {n_train_iter}, test_iter: {n_test_iter}')
# Инициализация списков для хранения значений потерь
train_losses = []
test_losses = []

# Инициализация списков для хранения значений потерь для каждого параметра
train_param_losses = [[] for _ in range(num_phases)]
test_param_losses = [[] for _ in range(num_phases)]

# Создание и запись заголовков в CSV-файл
with open(csv_res_fname, mode='w', newline='') as file:
    writer = csv.writer(file, delimiter=';')
    header = ['Time', 'Epoch', 'Train Loss', 'Test Loss', 'Exp_Diff'] + \
             [f'Train_{i + 1}' for i in range(num_phases)] + \
             [f'Test_{i + 1}' for i in range(num_phases)] + \
             [f'Exp_{i + 1}' for i in range(num_phases)]
    writer.writerow(header)

num_epochs = 600

total_exp_diff = 0.0
ph_exp_diff = []

pre_fitness = 1E6

train_all_losses = []
test_all_losses = []
train_batch_losses = []
test_batch_losses = []
experimental_losses = []

scheduler = lr_scheduler.CosineAnnealingWarmRestarts(optimizer,T_0=30)
# Out:
# Start training
# train_labels [ 8  7  8 ...  6 11  8]
# Category class_counts = [7578 7473 7423 7548 7484 7502 7524 7447 7490 7579 7539 7413]
# train_iter: 704, test_iter: 79

# %%
start_time = time.time()  # Запоминаем время начала обучения

for epoch in range(num_epochs):
    model.train()
    running_train_loss = 0.0
    running_train_param_losses = [0.0 for _ in range(num_phases)]
    iters = 0
    #train_batch_losses = []
    for inputs, outputs in train_dataloader:
        inputs, outputs = inputs.to(device), outputs.to(device)
        optimizer.zero_grad()
        predictions = model(inputs)        
        loss = criterion(predictions, outputs)
        loss.mean().backward()  # Средняя ошибка по всем элементам в батче
        # Градиенты масштабируются, если их общая норма > 1.0
        #torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        #running_train_loss += loss.mean().item()
        #for i in range(num_phases):
        #    running_train_param_losses[i] += loss[:, i].mean().item()
        iters += 1
        #train_batch_losses.append(loss.mean(axis=1).cpu().detach().numpy())

        if iters % 500 == 0:
            print(f"Iteration {iters}")
    #train_all_losses.append(np.array(train_batch_losses[:-1]))

    #train_loss = running_train_loss / n_train_iter
    #train_losses.append(train_loss)
    #for i in range(num_phases):
    #    train_param_losses[i].append(running_train_param_losses[i] / n_train_iter)

    if n_test_iter > 0:
        
        train_batch_losses = []
        model.eval()
        running_train_param_losses = [0.0 for _ in range(num_phases)]
        with torch.no_grad():
            for inputs, outputs in train_dataloader:
                inputs, outputs = inputs.to(device), outputs.to(device)
                predictions = model(inputs)
                loss = criterion(predictions, outputs)
                running_train_loss += loss.mean().item()
                for i in range(num_phases):
                    running_train_param_losses[i] += loss[:, i].mean().item()
                train_batch_losses.append(loss.mean(axis=1).cpu().detach().numpy())
        train_loss = running_train_loss / n_train_iter
        train_losses.append(train_loss)
        for i in range(num_phases):
            train_param_losses[i].append(running_train_param_losses[i] / n_train_iter)
        train_all_losses.append(np.array(train_batch_losses[:-1]))
        

        
        test_batch_losses = []
        model.eval()
        running_test_loss = 0.0
        running_test_param_losses = [0.0 for _ in range(num_phases)]
        with torch.no_grad():
            for inputs, outputs in test_dataloader:
                inputs, outputs = inputs.to(device), outputs.to(device)
                predictions = model(inputs)
                loss = criterion(predictions, outputs)
                running_test_loss += loss.mean().item()
                for i in range(num_phases):
                    running_test_param_losses[i] += loss[:, i].mean().item()
                test_batch_losses.append(loss.mean(axis=1).cpu().detach().numpy())
        test_loss = running_test_loss / n_test_iter
        test_losses.append(test_loss)
        for i in range(num_phases):
            test_param_losses[i].append(running_test_param_losses[i] / n_test_iter)
        test_all_losses.append(np.array(test_batch_losses[:-1]))

        

        total_exp_diff, ph_exp_diff, exp_samples_nb = predict_experimental_data(model, experimental_data, input_size)
        experimental_losses.append(total_exp_diff)

        # Вывод средней разницы, если были найдены соответствия
        if exp_samples_nb > 0:
            if total_exp_diff < pre_fitness:
                #torch.save(model.state_dict(), wghts_fname)
                #print(f'*** Weights are saved to {wghts_fname} after epoch {epoch + 1}')
                pre_fitness = total_exp_diff
            print(f' >>> Средняя разница между предсказанными и OSO: {total_exp_diff:.5g}')
        else:
            total_exp_diff = 0.0
            print('Нет соответствий для подсчета разницы.')

    else:
        test_loss = 0.0
        test_losses.append(test_loss)

    #print(f'Epoch [{epoch + 1}/{num_epochs}], learn_rate: {scheduler.get_last_lr()}, Train Loss: {100 * np.sqrt(train_loss):.5f}, Test Loss: {100 * np.sqrt(test_loss):.5f}')
    print(f'Epoch [{epoch + 1}/{num_epochs}], learn_rate: {scheduler.get_last_lr()}, Train Loss: {1 * (train_loss):.5g}, Test Loss: {1 * (test_loss):.5g}')

    # Вывод ошибок для каждого параметра
    for i in range(num_phases):
        print(f'Фаза {i + 1}: Train: {1 * (train_param_losses[i][-1]):.5g}, Test: {1 * (test_param_losses[i][-1]):.5g}')

    # Форматирование прошедшего времени в "hh:mm:ss"
    elapsed_time = time.time() - start_time  # Вычисляем прошедшее время
    hours, rem = divmod(elapsed_time, 3600)
    minutes, seconds = divmod(rem, 60)
    formatted_time = f"{int(hours):02d}:{int(minutes):02d}:{int(seconds):02d}"

    # Запись данных в CSV-файл
    with open(csv_res_fname, mode='a', newline='') as file:
        writer = csv.writer(file, delimiter=';')
        row = [formatted_time, epoch + 1, 100 * np.sqrt(train_loss), 100 * np.sqrt(test_loss), total_exp_diff] + \
              [100 * np.sqrt(train_param_losses[i][-1]) for i in range(num_phases)] + \
              [100 * np.sqrt(test_param_losses[i][-1]) for i in range(num_phases)] + \
              ph_exp_diff.tolist()
        writer.writerow(row)

    print(f'Прошло времени: {formatted_time}\n')

    scheduler.step()
# Out:
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.00088995
# Epoch [1/600], learn_rate: [0.0001], Train Loss: 0.00047707, Test Loss: 0.00048007
# Фаза 1: Train: 0.00042668, Test: 0.00042934
# Фаза 2: Train: 0.00050677, Test: 0.00049514
# Фаза 3: Train: 0.00068489, Test: 0.00068253
# Фаза 4: Train: 0.00058378, Test: 0.00059268
# Фаза 5: Train: 0.0005507, Test: 0.00053923
# Фаза 6: Train: 0.00053333, Test: 0.00054834
# Фаза 7: Train: 0.00022228, Test: 0.00023162
# Фаза 8: Train: 0.00048734, Test: 0.00051231
# Фаза 9: Train: 0.00055414, Test: 0.00054539
# Фаза 10: Train: 0.00033687, Test: 0.00034657
# Фаза 11: Train: 0.00050364, Test: 0.00051362
# Фаза 12: Train: 0.00033446, Test: 0.00032404
# Прошло времени: 00:00:08
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.00029137
# Epoch [2/600], learn_rate: [9.972609476841367e-05], Train Loss: 0.00032812, Test Loss: 0.00032963
# Фаза 1: Train: 0.00029038, Test: 0.00029516
# Фаза 2: Train: 0.00034722, Test: 0.00034514
# Фаза 3: Train: 0.00059278, Test: 0.00058716
# Фаза 4: Train: 0.0004299, Test: 0.00043114
# Фаза 5: Train: 0.00030745, Test: 0.00029878
# Фаза 6: Train: 0.00026198, Test: 0.00026522
# Фаза 7: Train: 0.00024181, Test: 0.00025318
# Фаза 8: Train: 0.00031971, Test: 0.00032578
# Фаза 9: Train: 0.00033388, Test: 0.00033866
# Фаза 10: Train: 0.0002374, Test: 0.00024014
# Фаза 11: Train: 0.00033147, Test: 0.00033592
# Фаза 12: Train: 0.0002435, Test: 0.00023933
# Прошло времени: 00:00:17
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.00031111
# Epoch [3/600], learn_rate: [9.890738003669029e-05], Train Loss: 0.00027831, Test Loss: 0.00027909
# Фаза 1: Train: 0.00032764, Test: 0.00032225
# Фаза 2: Train: 0.00026162, Test: 0.00025701
# Фаза 3: Train: 0.00032276, Test: 0.000317
# Фаза 4: Train: 0.0002677, Test: 0.00026203
# Фаза 5: Train: 0.00031079, Test: 0.00030798
# Фаза 6: Train: 0.00020076, Test: 0.00020505
# Фаза 7: Train: 0.00014349, Test: 0.00014783
# Фаза 8: Train: 0.00032232, Test: 0.00032778
# Фаза 9: Train: 0.00036784, Test: 0.00037085
# Фаза 10: Train: 0.00039845, Test: 0.00041013
# Фаза 11: Train: 0.00024545, Test: 0.00024917
# Фаза 12: Train: 0.00017087, Test: 0.00017198
# Прошло времени: 00:00:26
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.00029204
# Epoch [4/600], learn_rate: [9.755282581475769e-05], Train Loss: 0.00021974, Test Loss: 0.00021928
# Фаза 1: Train: 0.00022374, Test: 0.00021965
# Фаза 2: Train: 0.00025273, Test: 0.00024962
# Фаза 3: Train: 0.00027454, Test: 0.00026573
# Фаза 4: Train: 0.00041159, Test: 0.00039759
# Фаза 5: Train: 0.00018306, Test: 0.0001778
# Фаза 6: Train: 0.00018582, Test: 0.00018906
# Фаза 7: Train: 0.0001402, Test: 0.0001421
# Фаза 8: Train: 0.00021953, Test: 0.00022531
# Фаза 9: Train: 0.00025322, Test: 0.00026122
# Фаза 10: Train: 0.00013308, Test: 0.00013466
# Фаза 11: Train: 0.00020027, Test: 0.00020526
# Фаза 12: Train: 0.0001591, Test: 0.00016333
# Прошло времени: 00:00:35
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.00017253
# Epoch [5/600], learn_rate: [9.567727288213005e-05], Train Loss: 0.00018222, Test Loss: 0.00018512
# Фаза 1: Train: 0.00014887, Test: 0.00014853
# Фаза 2: Train: 0.00017784, Test: 0.00017896
# Фаза 3: Train: 0.00024307, Test: 0.00024368
# Фаза 4: Train: 0.00017134, Test: 0.00017263
# Фаза 5: Train: 0.00017812, Test: 0.00018193
# Фаза 6: Train: 0.00015648, Test: 0.00016022
# Фаза 7: Train: 0.00020654, Test: 0.00020762
# Фаза 8: Train: 0.00029948, Test: 0.00030344
# Фаза 9: Train: 0.00023458, Test: 0.00024159
# Фаза 10: Train: 0.00010757, Test: 0.0001119
# Фаза 11: Train: 0.00014556, Test: 0.00015126
# Фаза 12: Train: 0.00011722, Test: 0.00011969
# Прошло времени: 00:00:44
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.00028706
# Epoch [6/600], learn_rate: [9.330127018922194e-05], Train Loss: 0.0001623, Test Loss: 0.0001627
# Фаза 1: Train: 0.00016492, Test: 0.00016629
# Фаза 2: Train: 0.00019565, Test: 0.0001967
# Фаза 3: Train: 0.00020728, Test: 0.00020211
# Фаза 4: Train: 0.00019091, Test: 0.00018767
# Фаза 5: Train: 0.00013136, Test: 0.00012922
# Фаза 6: Train: 0.00022638, Test: 0.00022639
# Фаза 7: Train: 0.00010637, Test: 0.00010661
# Фаза 8: Train: 0.00016507, Test: 0.0001674
# Фаза 9: Train: 0.00017724, Test: 0.00018589
# Фаза 10: Train: 0.00010304, Test: 0.00010309
# Фаза 11: Train: 0.00017501, Test: 0.00017414
# Фаза 12: Train: 0.00010437, Test: 0.00010692
# Прошло времени: 00:00:53
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.00033391
# Epoch [7/600], learn_rate: [9.045084971874738e-05], Train Loss: 0.00014714, Test Loss: 0.00014787
# Фаза 1: Train: 0.00010377, Test: 0.00010465
# Фаза 2: Train: 0.00019734, Test: 0.00019906
# Фаза 3: Train: 0.00022339, Test: 0.00022069
# Фаза 4: Train: 0.00019407, Test: 0.00018936
# Фаза 5: Train: 0.00017292, Test: 0.0001701
# Фаза 6: Train: 0.00010873, Test: 0.00010989
# Фаза 7: Train: 8.9717e-05, Test: 9.0413e-05
# Фаза 8: Train: 0.00017008, Test: 0.00017249
# Фаза 9: Train: 0.0001567, Test: 0.00016106
# Фаза 10: Train: 0.00010605, Test: 0.00010923
# Фаза 11: Train: 0.00011052, Test: 0.00011354
# Фаза 12: Train: 0.00013244, Test: 0.00013398
# Прошло времени: 00:01:02
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.00013975
# Epoch [8/600], learn_rate: [8.715724127386972e-05], Train Loss: 0.00012738, Test Loss: 0.00012888
# Фаза 1: Train: 0.00010791, Test: 0.00010778
# Фаза 2: Train: 0.00013493, Test: 0.00013823
# Фаза 3: Train: 0.00021225, Test: 0.00021219
# Фаза 4: Train: 0.00014755, Test: 0.00014361
# Фаза 5: Train: 9.9047e-05, Test: 0.0001012
# Фаза 6: Train: 0.00011754, Test: 0.00012009
# Фаза 7: Train: 0.00010137, Test: 0.00010067
# Фаза 8: Train: 0.00014184, Test: 0.00014505
# Фаза 9: Train: 0.00016956, Test: 0.00017852
# Фаза 10: Train: 0.00010278, Test: 0.00010353
# Фаза 11: Train: 9.9652e-05, Test: 0.00010102
# Фаза 12: Train: 9.4165e-05, Test: 9.4683e-05
# Прошло времени: 00:01:12
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.00010981
# Epoch [9/600], learn_rate: [8.345653031794292e-05], Train Loss: 0.00010467, Test Loss: 0.00010668
# Фаза 1: Train: 8.6738e-05, Test: 8.7414e-05
# Фаза 2: Train: 0.00012403, Test: 0.00012594
# Фаза 3: Train: 0.00014079, Test: 0.0001422
# Фаза 4: Train: 0.00011294, Test: 0.00011201
# Фаза 5: Train: 9.1802e-05, Test: 9.3087e-05
# Фаза 6: Train: 8.6552e-05, Test: 8.8299e-05
# Фаза 7: Train: 8.0657e-05, Test: 8.2599e-05
# Фаза 8: Train: 0.00013673, Test: 0.00013807
# Фаза 9: Train: 0.00013639, Test: 0.00014032
# Фаза 10: Train: 8.8012e-05, Test: 9.1076e-05
# Фаза 11: Train: 9.3167e-05, Test: 9.6737e-05
# Фаза 12: Train: 7.8231e-05, Test: 8.2424e-05
# Прошло времени: 00:01:21
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 8.3541e-05
# Epoch [10/600], learn_rate: [7.938926261462366e-05], Train Loss: 0.00012112, Test Loss: 0.0001234
# Фаза 1: Train: 0.00013819, Test: 0.00013753
# Фаза 2: Train: 0.00019622, Test: 0.000202
# Фаза 3: Train: 0.00013572, Test: 0.00013425
# Фаза 4: Train: 0.00010606, Test: 0.00010746
# Фаза 5: Train: 9.3591e-05, Test: 9.4184e-05
# Фаза 6: Train: 0.00011053, Test: 0.00011274
# Фаза 7: Train: 7.8203e-05, Test: 7.8e-05
# Фаза 8: Train: 0.00023531, Test: 0.00023976
# Фаза 9: Train: 0.00012107, Test: 0.00012748
# Фаза 10: Train: 6.7546e-05, Test: 6.9904e-05
# Фаза 11: Train: 8.6766e-05, Test: 9.1376e-05
# Фаза 12: Train: 8.4258e-05, Test: 8.605e-05
# Прошло времени: 00:01:30
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.00010557
# Epoch [11/600], learn_rate: [7.500000000000001e-05], Train Loss: 0.00010011, Test Loss: 0.00010226
# Фаза 1: Train: 7.321e-05, Test: 7.265e-05
# Фаза 2: Train: 0.000109, Test: 0.00011239
# Фаза 3: Train: 0.0001491, Test: 0.000148
# Фаза 4: Train: 8.9764e-05, Test: 9.1176e-05
# Фаза 5: Train: 7.2056e-05, Test: 7.2966e-05
# Фаза 6: Train: 0.00017422, Test: 0.00017869
# Фаза 7: Train: 6.9646e-05, Test: 7.2762e-05
# Фаза 8: Train: 0.00012266, Test: 0.00012223
# Фаза 9: Train: 0.00011656, Test: 0.00012105
# Фаза 10: Train: 5.5657e-05, Test: 5.8562e-05
# Фаза 11: Train: 9.5672e-05, Test: 0.00010022
# Фаза 12: Train: 7.3746e-05, Test: 7.6461e-05
# Прошло времени: 00:01:39
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 6.6607e-05
# Epoch [12/600], learn_rate: [7.033683215379002e-05], Train Loss: 8.6788e-05, Test Loss: 8.8728e-05
# Фаза 1: Train: 7.7095e-05, Test: 7.9047e-05
# Фаза 2: Train: 0.00010384, Test: 0.00010565
# Фаза 3: Train: 0.00011431, Test: 0.00011292
# Фаза 4: Train: 8.4642e-05, Test: 8.7802e-05
# Фаза 5: Train: 6.7907e-05, Test: 6.9927e-05
# Фаза 6: Train: 8.784e-05, Test: 8.9545e-05
# Фаза 7: Train: 5.7122e-05, Test: 5.7136e-05
# Фаза 8: Train: 0.00010929, Test: 0.00011043
# Фаза 9: Train: 0.00014463, Test: 0.0001501
# Фаза 10: Train: 5.0427e-05, Test: 5.3502e-05
# Фаза 11: Train: 8.1817e-05, Test: 8.3923e-05
# Фаза 12: Train: 6.2539e-05, Test: 6.4757e-05
# Прошло времени: 00:01:48
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.00015301
# Epoch [13/600], learn_rate: [6.545084971874738e-05], Train Loss: 9.0808e-05, Test Loss: 9.284e-05
# Фаза 1: Train: 6.218e-05, Test: 6.1715e-05
# Фаза 2: Train: 9.9185e-05, Test: 0.00010122
# Фаза 3: Train: 0.00011286, Test: 0.00011577
# Фаза 4: Train: 9.1615e-05, Test: 9.3549e-05
# Фаза 5: Train: 6.2916e-05, Test: 6.4705e-05
# Фаза 6: Train: 8.219e-05, Test: 8.5291e-05
# Фаза 7: Train: 0.00010393, Test: 0.00010611
# Фаза 8: Train: 0.00011223, Test: 0.00011584
# Фаза 9: Train: 9.8418e-05, Test: 0.00010188
# Фаза 10: Train: 5.8114e-05, Test: 6.0197e-05
# Фаза 11: Train: 0.00011716, Test: 0.00011591
# Фаза 12: Train: 8.8888e-05, Test: 9.1885e-05
# Прошло времени: 00:01:57
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 7.8381e-05
# Epoch [14/600], learn_rate: [6.0395584540887963e-05], Train Loss: 8.4716e-05, Test Loss: 8.6312e-05
# Фаза 1: Train: 5.91e-05, Test: 5.8432e-05
# Фаза 2: Train: 0.00013508, Test: 0.00013722
# Фаза 3: Train: 0.00012644, Test: 0.00012916
# Фаза 4: Train: 7.437e-05, Test: 7.7426e-05
# Фаза 5: Train: 6.0378e-05, Test: 6.3234e-05
# Фаза 6: Train: 9.1696e-05, Test: 9.2321e-05
# Фаза 7: Train: 5.8219e-05, Test: 5.8559e-05
# Фаза 8: Train: 0.00012509, Test: 0.00012563
# Фаза 9: Train: 9.3136e-05, Test: 9.5838e-05
# Фаза 10: Train: 4.4375e-05, Test: 4.6994e-05
# Фаза 11: Train: 8.6847e-05, Test: 8.8251e-05
# Фаза 12: Train: 6.1866e-05, Test: 6.2687e-05
# Прошло времени: 00:02:06
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 6.0422e-05
# Epoch [15/600], learn_rate: [5.522642316338268e-05], Train Loss: 7.5421e-05, Test Loss: 7.7285e-05
# Фаза 1: Train: 5.4056e-05, Test: 5.3092e-05
# Фаза 2: Train: 9.044e-05, Test: 9.4255e-05
# Фаза 3: Train: 0.00010366, Test: 0.00010759
# Фаза 4: Train: 0.00011028, Test: 0.00010799
# Фаза 5: Train: 6.1266e-05, Test: 6.4239e-05
# Фаза 6: Train: 5.4721e-05, Test: 5.7002e-05
# Фаза 7: Train: 5.1484e-05, Test: 5.3103e-05
# Фаза 8: Train: 9.1511e-05, Test: 9.4031e-05
# Фаза 9: Train: 9.6408e-05, Test: 0.00010132
# Фаза 10: Train: 4.6201e-05, Test: 4.8056e-05
# Фаза 11: Train: 5.8736e-05, Test: 6.0301e-05
# Фаза 12: Train: 8.6286e-05, Test: 8.644e-05
# Прошло времени: 00:02:15
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 6.0043e-05
# Epoch [16/600], learn_rate: [5.0000000000000016e-05], Train Loss: 7.6317e-05, Test Loss: 7.7114e-05
# Фаза 1: Train: 5.148e-05, Test: 5.0265e-05
# Фаза 2: Train: 7.9389e-05, Test: 8.1323e-05
# Фаза 3: Train: 8.7794e-05, Test: 8.924e-05
# Фаза 4: Train: 8.1667e-05, Test: 8.1423e-05
# Фаза 5: Train: 8.5326e-05, Test: 8.3457e-05
# Фаза 6: Train: 5.0775e-05, Test: 5.3697e-05
# Фаза 7: Train: 5.9043e-05, Test: 5.9358e-05
# Фаза 8: Train: 0.00012053, Test: 0.00012167
# Фаза 9: Train: 9.0418e-05, Test: 9.4183e-05
# Фаза 10: Train: 4.2477e-05, Test: 4.3883e-05
# Фаза 11: Train: 6.6566e-05, Test: 6.8283e-05
# Фаза 12: Train: 0.00010034, Test: 9.8586e-05
# Прошло времени: 00:02:24
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.5951e-05
# Epoch [17/600], learn_rate: [4.477357683661734e-05], Train Loss: 6.7254e-05, Test Loss: 6.8872e-05
# Фаза 1: Train: 5.2231e-05, Test: 5.2455e-05
# Фаза 2: Train: 9.1827e-05, Test: 9.496e-05
# Фаза 3: Train: 8.3677e-05, Test: 8.5353e-05
# Фаза 4: Train: 7.7908e-05, Test: 7.8303e-05
# Фаза 5: Train: 5.2646e-05, Test: 5.4295e-05
# Фаза 6: Train: 5.2219e-05, Test: 5.3969e-05
# Фаза 7: Train: 5.3552e-05, Test: 5.4799e-05
# Фаза 8: Train: 8.6423e-05, Test: 8.7413e-05
# Фаза 9: Train: 8.0657e-05, Test: 8.6148e-05
# Фаза 10: Train: 4.3583e-05, Test: 4.4953e-05
# Фаза 11: Train: 6.361e-05, Test: 6.4728e-05
# Фаза 12: Train: 6.8719e-05, Test: 6.9092e-05
# Прошло времени: 00:02:33
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.9174e-05
# Epoch [18/600], learn_rate: [3.9604415459112035e-05], Train Loss: 6.096e-05, Test Loss: 6.2378e-05
# Фаза 1: Train: 4.6998e-05, Test: 4.7031e-05
# Фаза 2: Train: 7.3212e-05, Test: 7.4841e-05
# Фаза 3: Train: 8.3267e-05, Test: 8.5031e-05
# Фаза 4: Train: 7.2851e-05, Test: 7.2274e-05
# Фаза 5: Train: 5.7399e-05, Test: 5.8032e-05
# Фаза 6: Train: 4.767e-05, Test: 4.9688e-05
# Фаза 7: Train: 4.693e-05, Test: 4.8499e-05
# Фаза 8: Train: 8.492e-05, Test: 8.6514e-05
# Фаза 9: Train: 8.339e-05, Test: 8.6621e-05
# Фаза 10: Train: 3.9036e-05, Test: 4.1063e-05
# Фаза 11: Train: 4.9623e-05, Test: 5.1405e-05
# Фаза 12: Train: 4.6224e-05, Test: 4.753e-05
# Прошло времени: 00:02:42
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.7442e-05
# Epoch [19/600], learn_rate: [3.4549150281252636e-05], Train Loss: 6.4971e-05, Test Loss: 6.6101e-05
# Фаза 1: Train: 5.3178e-05, Test: 5.2904e-05
# Фаза 2: Train: 7.1953e-05, Test: 7.3895e-05
# Фаза 3: Train: 7.9364e-05, Test: 8.3079e-05
# Фаза 4: Train: 7.2165e-05, Test: 7.1985e-05
# Фаза 5: Train: 8.1255e-05, Test: 7.8815e-05
# Фаза 6: Train: 5.2916e-05, Test: 5.4765e-05
# Фаза 7: Train: 3.9297e-05, Test: 3.9867e-05
# Фаза 8: Train: 8.2243e-05, Test: 8.3201e-05
# Фаза 9: Train: 8.3821e-05, Test: 8.7255e-05
# Фаза 10: Train: 4.6303e-05, Test: 4.8302e-05
# Фаза 11: Train: 4.9792e-05, Test: 5.0537e-05
# Фаза 12: Train: 6.7366e-05, Test: 6.8603e-05
# Прошло времени: 00:02:51
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 7.0225e-05
# Epoch [20/600], learn_rate: [2.9663167846209998e-05], Train Loss: 6.3452e-05, Test Loss: 6.4328e-05
# Фаза 1: Train: 5.7204e-05, Test: 5.6556e-05
# Фаза 2: Train: 6.7279e-05, Test: 6.9096e-05
# Фаза 3: Train: 7.9732e-05, Test: 8.1082e-05
# Фаза 4: Train: 9.6143e-05, Test: 9.2659e-05
# Фаза 5: Train: 4.31e-05, Test: 4.4486e-05
# Фаза 6: Train: 5.6409e-05, Test: 5.8631e-05
# Фаза 7: Train: 5.503e-05, Test: 5.6713e-05
# Фаза 8: Train: 8.5364e-05, Test: 8.5534e-05
# Фаза 9: Train: 7.9926e-05, Test: 8.3685e-05
# Фаза 10: Train: 3.2875e-05, Test: 3.4354e-05
# Фаза 11: Train: 5.4702e-05, Test: 5.5691e-05
# Фаза 12: Train: 5.3664e-05, Test: 5.3452e-05
# Прошло времени: 00:03:00
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.1216e-05
# Epoch [21/600], learn_rate: [2.500000000000001e-05], Train Loss: 5.797e-05, Test Loss: 5.9422e-05
# Фаза 1: Train: 4.3883e-05, Test: 4.4573e-05
# Фаза 2: Train: 6.8978e-05, Test: 7.0104e-05
# Фаза 3: Train: 7.4843e-05, Test: 7.692e-05
# Фаза 4: Train: 8.0572e-05, Test: 7.8578e-05
# Фаза 5: Train: 4.1912e-05, Test: 4.4368e-05
# Фаза 6: Train: 4.2307e-05, Test: 4.3923e-05
# Фаза 7: Train: 3.9788e-05, Test: 4.1925e-05
# Фаза 8: Train: 8.2088e-05, Test: 8.2779e-05
# Фаза 9: Train: 7.114e-05, Test: 7.5382e-05
# Фаза 10: Train: 5.0027e-05, Test: 5.1182e-05
# Фаза 11: Train: 4.7935e-05, Test: 5.0285e-05
# Фаза 12: Train: 5.2168e-05, Test: 5.3045e-05
# Прошло времени: 00:03:09
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.6106e-05
# Epoch [22/600], learn_rate: [2.061073738537635e-05], Train Loss: 5.588e-05, Test Loss: 5.7109e-05
# Фаза 1: Train: 3.8341e-05, Test: 3.8174e-05
# Фаза 2: Train: 6.6206e-05, Test: 6.7826e-05
# Фаза 3: Train: 9.0732e-05, Test: 9.2274e-05
# Фаза 4: Train: 6.7916e-05, Test: 6.6926e-05
# Фаза 5: Train: 4.9119e-05, Test: 5.0272e-05
# Фаза 6: Train: 4.3259e-05, Test: 4.5438e-05
# Фаза 7: Train: 3.6723e-05, Test: 3.7374e-05
# Фаза 8: Train: 7.4669e-05, Test: 7.5096e-05
# Фаза 9: Train: 8.0516e-05, Test: 8.4534e-05
# Фаза 10: Train: 3.5915e-05, Test: 3.7604e-05
# Фаза 11: Train: 4.556e-05, Test: 4.6975e-05
# Фаза 12: Train: 4.1601e-05, Test: 4.2819e-05
# Прошло времени: 00:03:18
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.1846e-05
# Epoch [23/600], learn_rate: [1.6543469682057106e-05], Train Loss: 5.2703e-05, Test Loss: 5.3912e-05
# Фаза 1: Train: 4.2068e-05, Test: 4.0943e-05
# Фаза 2: Train: 6.2007e-05, Test: 6.4013e-05
# Фаза 3: Train: 6.9573e-05, Test: 7.0615e-05
# Фаза 4: Train: 6.3991e-05, Test: 6.434e-05
# Фаза 5: Train: 5.009e-05, Test: 5.1845e-05
# Фаза 6: Train: 4.018e-05, Test: 4.1982e-05
# Фаза 7: Train: 3.8649e-05, Test: 4.0257e-05
# Фаза 8: Train: 7.1719e-05, Test: 7.2421e-05
# Фаза 9: Train: 7.2751e-05, Test: 7.5735e-05
# Фаза 10: Train: 3.7497e-05, Test: 3.827e-05
# Фаза 11: Train: 4.329e-05, Test: 4.4892e-05
# Фаза 12: Train: 4.0623e-05, Test: 4.1629e-05
# Прошло времени: 00:03:27
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.5572e-05
# Epoch [24/600], learn_rate: [1.2842758726130299e-05], Train Loss: 5.2418e-05, Test Loss: 5.3936e-05
# Фаза 1: Train: 3.8476e-05, Test: 3.8439e-05
# Фаза 2: Train: 6.1872e-05, Test: 6.3656e-05
# Фаза 3: Train: 6.9514e-05, Test: 7.1224e-05
# Фаза 4: Train: 5.9495e-05, Test: 6.1004e-05
# Фаза 5: Train: 4.4256e-05, Test: 4.5846e-05
# Фаза 6: Train: 4.072e-05, Test: 4.2883e-05
# Фаза 7: Train: 3.6879e-05, Test: 3.8287e-05
# Фаза 8: Train: 7.2756e-05, Test: 7.3811e-05
# Фаза 9: Train: 7.7258e-05, Test: 8.1504e-05
# Фаза 10: Train: 4.339e-05, Test: 4.4709e-05
# Фаза 11: Train: 4.4888e-05, Test: 4.5431e-05
# Фаза 12: Train: 3.9514e-05, Test: 4.0437e-05
# Прошло времени: 00:03:36
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.219e-05
# Epoch [25/600], learn_rate: [9.549150281252633e-06], Train Loss: 5.1231e-05, Test Loss: 5.2866e-05
# Фаза 1: Train: 4.8447e-05, Test: 4.8279e-05
# Фаза 2: Train: 6.2753e-05, Test: 6.503e-05
# Фаза 3: Train: 7.1491e-05, Test: 7.3379e-05
# Фаза 4: Train: 5.884e-05, Test: 6.0881e-05
# Фаза 5: Train: 4.0837e-05, Test: 4.18e-05
# Фаза 6: Train: 3.9172e-05, Test: 4.0899e-05
# Фаза 7: Train: 3.5236e-05, Test: 3.6332e-05
# Фаза 8: Train: 7.0984e-05, Test: 7.1776e-05
# Фаза 9: Train: 6.5085e-05, Test: 6.9578e-05
# Фаза 10: Train: 3.3946e-05, Test: 3.6095e-05
# Фаза 11: Train: 4.6662e-05, Test: 4.7916e-05
# Фаза 12: Train: 4.1323e-05, Test: 4.2432e-05
# Прошло времени: 00:03:46
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.7183e-05
# Epoch [26/600], learn_rate: [6.698729810778065e-06], Train Loss: 5.0966e-05, Test Loss: 5.2406e-05
# Фаза 1: Train: 3.9322e-05, Test: 3.8739e-05
# Фаза 2: Train: 6.3139e-05, Test: 6.5553e-05
# Фаза 3: Train: 6.6592e-05, Test: 6.8909e-05
# Фаза 4: Train: 6.0257e-05, Test: 6.0583e-05
# Фаза 5: Train: 4.2185e-05, Test: 4.3603e-05
# Фаза 6: Train: 3.9305e-05, Test: 4.0724e-05
# Фаза 7: Train: 4.824e-05, Test: 5.0384e-05
# Фаза 8: Train: 7.0811e-05, Test: 7.175e-05
# Фаза 9: Train: 6.6324e-05, Test: 6.9926e-05
# Фаза 10: Train: 3.4202e-05, Test: 3.5505e-05
# Фаза 11: Train: 4.2152e-05, Test: 4.3187e-05
# Фаза 12: Train: 3.9067e-05, Test: 4.0004e-05
# Прошло времени: 00:03:55
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.3775e-05
# Epoch [27/600], learn_rate: [4.322727117869951e-06], Train Loss: 5.0063e-05, Test Loss: 5.1557e-05
# Фаза 1: Train: 3.6136e-05, Test: 3.5906e-05
# Фаза 2: Train: 6.3675e-05, Test: 6.6067e-05
# Фаза 3: Train: 6.6141e-05, Test: 6.7645e-05
# Фаза 4: Train: 6.0579e-05, Test: 6.1064e-05
# Фаза 5: Train: 3.9661e-05, Test: 4.0894e-05
# Фаза 6: Train: 4.1903e-05, Test: 4.4277e-05
# Фаза 7: Train: 3.7363e-05, Test: 3.9009e-05
# Фаза 8: Train: 7.6166e-05, Test: 7.7856e-05
# Фаза 9: Train: 6.6333e-05, Test: 6.9415e-05
# Фаза 10: Train: 3.1134e-05, Test: 3.2349e-05
# Фаза 11: Train: 4.3013e-05, Test: 4.454e-05
# Фаза 12: Train: 3.8647e-05, Test: 3.9663e-05
# Прошло времени: 00:04:04
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.3859e-05
# Epoch [28/600], learn_rate: [2.4471741852423237e-06], Train Loss: 4.9281e-05, Test Loss: 5.0823e-05
# Фаза 1: Train: 3.9977e-05, Test: 4.0034e-05
# Фаза 2: Train: 6.068e-05, Test: 6.2638e-05
# Фаза 3: Train: 6.6622e-05, Test: 6.8893e-05
# Фаза 4: Train: 5.8564e-05, Test: 5.9138e-05
# Фаза 5: Train: 4.0679e-05, Test: 4.1919e-05
# Фаза 6: Train: 3.7732e-05, Test: 3.9626e-05
# Фаза 7: Train: 3.6573e-05, Test: 3.8132e-05
# Фаза 8: Train: 6.905e-05, Test: 7.0258e-05
# Фаза 9: Train: 6.5983e-05, Test: 7.0688e-05
# Фаза 10: Train: 3.4215e-05, Test: 3.5596e-05
# Фаза 11: Train: 4.333e-05, Test: 4.4201e-05
# Фаза 12: Train: 3.7963e-05, Test: 3.8752e-05
# Прошло времени: 00:04:13
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.642e-05
# Epoch [29/600], learn_rate: [1.0926199633097157e-06], Train Loss: 4.9465e-05, Test Loss: 5.0815e-05
# Фаза 1: Train: 3.6231e-05, Test: 3.5447e-05
# Фаза 2: Train: 6.0516e-05, Test: 6.2689e-05
# Фаза 3: Train: 6.6986e-05, Test: 6.8594e-05
# Фаза 4: Train: 5.9512e-05, Test: 5.9263e-05
# Фаза 5: Train: 3.9824e-05, Test: 4.1458e-05
# Фаза 6: Train: 4.0042e-05, Test: 4.199e-05
# Фаза 7: Train: 4.2061e-05, Test: 4.3315e-05
# Фаза 8: Train: 7.1407e-05, Test: 7.2493e-05
# Фаза 9: Train: 6.4964e-05, Test: 6.8271e-05
# Фаза 10: Train: 3.2253e-05, Test: 3.4215e-05
# Фаза 11: Train: 4.1164e-05, Test: 4.26e-05
# Фаза 12: Train: 3.8618e-05, Test: 3.9447e-05
# Прошло времени: 00:04:22
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.3997e-05
# Epoch [30/600], learn_rate: [2.7390523158633e-07], Train Loss: 4.9039e-05, Test Loss: 5.0579e-05
# Фаза 1: Train: 3.7256e-05, Test: 3.7276e-05
# Фаза 2: Train: 6.0932e-05, Test: 6.3073e-05
# Фаза 3: Train: 6.5327e-05, Test: 6.7572e-05
# Фаза 4: Train: 5.8695e-05, Test: 5.9369e-05
# Фаза 5: Train: 3.9339e-05, Test: 4.079e-05
# Фаза 6: Train: 3.8978e-05, Test: 4.0691e-05
# Фаза 7: Train: 3.776e-05, Test: 3.9675e-05
# Фаза 8: Train: 7.2468e-05, Test: 7.3539e-05
# Фаза 9: Train: 6.3852e-05, Test: 6.768e-05
# Фаза 10: Train: 3.2143e-05, Test: 3.3623e-05
# Фаза 11: Train: 4.2322e-05, Test: 4.3409e-05
# Фаза 12: Train: 3.939e-05, Test: 4.0245e-05
# Прошло времени: 00:04:31
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 6.9109e-05
# Epoch [31/600], learn_rate: [0.0001], Train Loss: 5.9646e-05, Test Loss: 6.0884e-05
# Фаза 1: Train: 4.5935e-05, Test: 4.4803e-05
# Фаза 2: Train: 7.28e-05, Test: 7.489e-05
# Фаза 3: Train: 7.1827e-05, Test: 7.2854e-05
# Фаза 4: Train: 6.3431e-05, Test: 6.5053e-05
# Фаза 5: Train: 4.8282e-05, Test: 4.8975e-05
# Фаза 6: Train: 5.003e-05, Test: 5.1373e-05
# Фаза 7: Train: 3.982e-05, Test: 4.163e-05
# Фаза 8: Train: 9.2666e-05, Test: 9.3381e-05
# Фаза 9: Train: 8.5133e-05, Test: 8.8199e-05
# Фаза 10: Train: 6.2988e-05, Test: 6.4111e-05
# Фаза 11: Train: 4.3152e-05, Test: 4.4295e-05
# Фаза 12: Train: 3.9686e-05, Test: 4.1042e-05
# Прошло времени: 00:04:40
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 7.2684e-05
# Epoch [32/600], learn_rate: [9.972609476841367e-05], Train Loss: 6.5413e-05, Test Loss: 6.6667e-05
# Фаза 1: Train: 3.9663e-05, Test: 3.8649e-05
# Фаза 2: Train: 7.5923e-05, Test: 7.7148e-05
# Фаза 3: Train: 7.8421e-05, Test: 7.9311e-05
# Фаза 4: Train: 7.5239e-05, Test: 7.785e-05
# Фаза 5: Train: 7.2985e-05, Test: 7.5618e-05
# Фаза 6: Train: 8.3609e-05, Test: 8.7167e-05
# Фаза 7: Train: 7.1038e-05, Test: 7.2905e-05
# Фаза 8: Train: 7.5695e-05, Test: 7.6644e-05
# Фаза 9: Train: 6.5089e-05, Test: 6.6801e-05
# Фаза 10: Train: 4.4306e-05, Test: 4.5705e-05
# Фаза 11: Train: 5.6393e-05, Test: 5.6443e-05
# Фаза 12: Train: 4.6595e-05, Test: 4.5757e-05
# Прошло времени: 00:04:49
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 6.5279e-05
# Epoch [33/600], learn_rate: [9.890738003669029e-05], Train Loss: 6.3204e-05, Test Loss: 6.4127e-05
# Фаза 1: Train: 4.0444e-05, Test: 4.0271e-05
# Фаза 2: Train: 8.2201e-05, Test: 8.3481e-05
# Фаза 3: Train: 7.6444e-05, Test: 7.6661e-05
# Фаза 4: Train: 0.00011861, Test: 0.00011237
# Фаза 5: Train: 5.962e-05, Test: 6.1446e-05
# Фаза 6: Train: 5.0579e-05, Test: 5.2689e-05
# Фаза 7: Train: 5.0276e-05, Test: 5.3373e-05
# Фаза 8: Train: 6.906e-05, Test: 7.0276e-05
# Фаза 9: Train: 6.9924e-05, Test: 7.3209e-05
# Фаза 10: Train: 3.7998e-05, Test: 4.0046e-05
# Фаза 11: Train: 5.0761e-05, Test: 5.2355e-05
# Фаза 12: Train: 5.2528e-05, Test: 5.335e-05
# Прошло времени: 00:04:58
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 6.2516e-05
# Epoch [34/600], learn_rate: [9.755282581475769e-05], Train Loss: 5.8043e-05, Test Loss: 5.8666e-05
# Фаза 1: Train: 4.3945e-05, Test: 4.3301e-05
# Фаза 2: Train: 5.2139e-05, Test: 5.436e-05
# Фаза 3: Train: 6.7648e-05, Test: 6.8261e-05
# Фаза 4: Train: 6.59e-05, Test: 6.6066e-05
# Фаза 5: Train: 8.2251e-05, Test: 8.1535e-05
# Фаза 6: Train: 4.0939e-05, Test: 4.2615e-05
# Фаза 7: Train: 3.4437e-05, Test: 3.7118e-05
# Фаза 8: Train: 6.9603e-05, Test: 7.0595e-05
# Фаза 9: Train: 6.9196e-05, Test: 6.9699e-05
# Фаза 10: Train: 3.6275e-05, Test: 3.7487e-05
# Фаза 11: Train: 7.3506e-05, Test: 7.3226e-05
# Фаза 12: Train: 6.0681e-05, Test: 5.9725e-05
# Прошло времени: 00:05:07
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.00025557
# Epoch [35/600], learn_rate: [9.567727288213005e-05], Train Loss: 7.8422e-05, Test Loss: 8.03e-05
# Фаза 1: Train: 0.00017348, Test: 0.00017401
# Фаза 2: Train: 5.6023e-05, Test: 5.8538e-05
# Фаза 3: Train: 0.0002077, Test: 0.00021459
# Фаза 4: Train: 7.1519e-05, Test: 7.1187e-05
# Фаза 5: Train: 4.3599e-05, Test: 4.7154e-05
# Фаза 6: Train: 4.6445e-05, Test: 4.7237e-05
# Фаза 7: Train: 3.6613e-05, Test: 3.9199e-05
# Фаза 8: Train: 8.0753e-05, Test: 8.0947e-05
# Фаза 9: Train: 7.0933e-05, Test: 7.3433e-05
# Фаза 10: Train: 4.1075e-05, Test: 4.1835e-05
# Фаза 11: Train: 4.383e-05, Test: 4.447e-05
# Фаза 12: Train: 6.9092e-05, Test: 7.1003e-05
# Прошло времени: 00:05:16
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 7.7487e-05
# Epoch [36/600], learn_rate: [9.330127018922194e-05], Train Loss: 5.4351e-05, Test Loss: 5.528e-05
# Фаза 1: Train: 5.3107e-05, Test: 5.2159e-05
# Фаза 2: Train: 5.441e-05, Test: 5.566e-05
# Фаза 3: Train: 6.5183e-05, Test: 6.5844e-05
# Фаза 4: Train: 7.94e-05, Test: 7.7348e-05
# Фаза 5: Train: 4.4278e-05, Test: 4.5696e-05
# Фаза 6: Train: 3.4451e-05, Test: 3.6029e-05
# Фаза 7: Train: 2.8326e-05, Test: 2.9804e-05
# Фаза 8: Train: 7.9847e-05, Test: 8.2579e-05
# Фаза 9: Train: 5.4482e-05, Test: 5.7338e-05
# Фаза 10: Train: 7.6827e-05, Test: 7.7956e-05
# Фаза 11: Train: 4.0679e-05, Test: 4.1499e-05
# Фаза 12: Train: 4.1222e-05, Test: 4.1447e-05
# Прошло времени: 00:05:25
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.00013094
# Epoch [37/600], learn_rate: [9.045084971874738e-05], Train Loss: 4.9075e-05, Test Loss: 5.0402e-05
# Фаза 1: Train: 3.3531e-05, Test: 3.2941e-05
# Фаза 2: Train: 5.235e-05, Test: 5.2998e-05
# Фаза 3: Train: 7.3196e-05, Test: 7.5306e-05
# Фаза 4: Train: 6.1527e-05, Test: 6.3423e-05
# Фаза 5: Train: 4.0802e-05, Test: 4.2133e-05
# Фаза 6: Train: 3.3653e-05, Test: 3.505e-05
# Фаза 7: Train: 2.7713e-05, Test: 3.0068e-05
# Фаза 8: Train: 9.595e-05, Test: 9.9376e-05
# Фаза 9: Train: 6.4111e-05, Test: 6.5808e-05
# Фаза 10: Train: 3.0412e-05, Test: 3.2369e-05
# Фаза 11: Train: 3.8225e-05, Test: 3.7625e-05
# Фаза 12: Train: 3.7427e-05, Test: 3.7723e-05
# Прошло времени: 00:05:35
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 7.1166e-05
# Epoch [38/600], learn_rate: [8.715724127386972e-05], Train Loss: 5.9371e-05, Test Loss: 6.0417e-05
# Фаза 1: Train: 6.2554e-05, Test: 6.3145e-05
# Фаза 2: Train: 4.9023e-05, Test: 5.034e-05
# Фаза 3: Train: 6.6578e-05, Test: 6.8777e-05
# Фаза 4: Train: 5.9996e-05, Test: 6.0114e-05
# Фаза 5: Train: 4.1455e-05, Test: 4.3906e-05
# Фаза 6: Train: 3.5931e-05, Test: 3.7532e-05
# Фаза 7: Train: 4.6641e-05, Test: 4.8296e-05
# Фаза 8: Train: 7.505e-05, Test: 7.7303e-05
# Фаза 9: Train: 6.0689e-05, Test: 6.3048e-05
# Фаза 10: Train: 6.9813e-05, Test: 7.0221e-05
# Фаза 11: Train: 8.921e-05, Test: 8.7432e-05
# Фаза 12: Train: 5.5515e-05, Test: 5.4892e-05
# Прошло времени: 00:05:44
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 8.9482e-05
# Epoch [39/600], learn_rate: [8.345653031794292e-05], Train Loss: 5.4448e-05, Test Loss: 5.5956e-05
# Фаза 1: Train: 3.958e-05, Test: 3.9536e-05
# Фаза 2: Train: 6.6732e-05, Test: 6.9132e-05
# Фаза 3: Train: 6.0767e-05, Test: 6.107e-05
# Фаза 4: Train: 5.8751e-05, Test: 6.0272e-05
# Фаза 5: Train: 4.1231e-05, Test: 4.1996e-05
# Фаза 6: Train: 6.3501e-05, Test: 6.5138e-05
# Фаза 7: Train: 4.455e-05, Test: 4.7297e-05
# Фаза 8: Train: 9.8565e-05, Test: 9.8293e-05
# Фаза 9: Train: 6.7623e-05, Test: 7.1434e-05
# Фаза 10: Train: 3.7141e-05, Test: 3.9656e-05
# Фаза 11: Train: 4.1546e-05, Test: 4.4134e-05
# Фаза 12: Train: 3.3389e-05, Test: 3.3517e-05
# Прошло времени: 00:05:53
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 6.6965e-05
# Epoch [40/600], learn_rate: [7.938926261462366e-05], Train Loss: 5.3424e-05, Test Loss: 5.4572e-05
# Фаза 1: Train: 3.5757e-05, Test: 3.5407e-05
# Фаза 2: Train: 5.0318e-05, Test: 5.2795e-05
# Фаза 3: Train: 0.00010156, Test: 0.00010237
# Фаза 4: Train: 5.3093e-05, Test: 5.2505e-05
# Фаза 5: Train: 4.6438e-05, Test: 4.7204e-05
# Фаза 6: Train: 3.4872e-05, Test: 3.6023e-05
# Фаза 7: Train: 3.3644e-05, Test: 3.6003e-05
# Фаза 8: Train: 6.7938e-05, Test: 6.8881e-05
# Фаза 9: Train: 5.2934e-05, Test: 5.6098e-05
# Фаза 10: Train: 7.2467e-05, Test: 7.5071e-05
# Фаза 11: Train: 5.8785e-05, Test: 5.9129e-05
# Фаза 12: Train: 3.3278e-05, Test: 3.3367e-05
# Прошло времени: 00:06:02
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 3.9227e-05
# Epoch [41/600], learn_rate: [7.500000000000001e-05], Train Loss: 4.2961e-05, Test Loss: 4.3918e-05
# Фаза 1: Train: 4.7147e-05, Test: 4.6419e-05
# Фаза 2: Train: 4.2743e-05, Test: 4.4156e-05
# Фаза 3: Train: 4.8148e-05, Test: 4.9945e-05
# Фаза 4: Train: 5.1986e-05, Test: 5.2256e-05
# Фаза 5: Train: 5.1738e-05, Test: 5.2977e-05
# Фаза 6: Train: 3.3002e-05, Test: 3.4145e-05
# Фаза 7: Train: 2.4837e-05, Test: 2.5733e-05
# Фаза 8: Train: 5.0223e-05, Test: 5.1019e-05
# Фаза 9: Train: 6.1387e-05, Test: 6.2974e-05
# Фаза 10: Train: 2.7986e-05, Test: 3.0056e-05
# Фаза 11: Train: 4.8728e-05, Test: 4.9095e-05
# Фаза 12: Train: 2.7604e-05, Test: 2.824e-05
# Прошло времени: 00:06:11
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.0872e-05
# Epoch [42/600], learn_rate: [7.033683215379002e-05], Train Loss: 4.3351e-05, Test Loss: 4.543e-05
# Фаза 1: Train: 2.888e-05, Test: 2.8809e-05
# Фаза 2: Train: 4.1881e-05, Test: 4.4504e-05
# Фаза 3: Train: 4.7286e-05, Test: 4.9005e-05
# Фаза 4: Train: 5.0246e-05, Test: 5.4144e-05
# Фаза 5: Train: 3.1751e-05, Test: 3.5565e-05
# Фаза 6: Train: 2.8528e-05, Test: 2.9132e-05
# Фаза 7: Train: 2.9761e-05, Test: 3.1921e-05
# Фаза 8: Train: 4.979e-05, Test: 5.1766e-05
# Фаза 9: Train: 4.6752e-05, Test: 5.0039e-05
# Фаза 10: Train: 5.5894e-05, Test: 5.919e-05
# Фаза 11: Train: 7.436e-05, Test: 7.6298e-05
# Фаза 12: Train: 3.5087e-05, Test: 3.4788e-05
# Прошло времени: 00:06:20
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 6.3754e-05
# Epoch [43/600], learn_rate: [6.545084971874738e-05], Train Loss: 4.1794e-05, Test Loss: 4.317e-05
# Фаза 1: Train: 5.4297e-05, Test: 5.4239e-05
# Фаза 2: Train: 4.2699e-05, Test: 4.3898e-05
# Фаза 3: Train: 4.4135e-05, Test: 4.6073e-05
# Фаза 4: Train: 5.5699e-05, Test: 5.6781e-05
# Фаза 5: Train: 3.5272e-05, Test: 3.7772e-05
# Фаза 6: Train: 4.1368e-05, Test: 4.3809e-05
# Фаза 7: Train: 2.6212e-05, Test: 2.7664e-05
# Фаза 8: Train: 5.4541e-05, Test: 5.6006e-05
# Фаза 9: Train: 5.1062e-05, Test: 5.4157e-05
# Фаза 10: Train: 2.6649e-05, Test: 2.789e-05
# Фаза 11: Train: 3.9418e-05, Test: 4.0256e-05
# Фаза 12: Train: 3.0178e-05, Test: 2.9497e-05
# Прошло времени: 00:06:29
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.5548e-05
# Epoch [44/600], learn_rate: [6.0395584540887963e-05], Train Loss: 4.1402e-05, Test Loss: 4.2434e-05
# Фаза 1: Train: 3.4717e-05, Test: 3.4529e-05
# Фаза 2: Train: 3.9159e-05, Test: 4.0163e-05
# Фаза 3: Train: 4.4677e-05, Test: 4.5998e-05
# Фаза 4: Train: 4.7334e-05, Test: 4.7406e-05
# Фаза 5: Train: 3.2147e-05, Test: 3.4097e-05
# Фаза 6: Train: 5.8287e-05, Test: 6.1167e-05
# Фаза 7: Train: 2.8415e-05, Test: 2.9138e-05
# Фаза 8: Train: 5.7638e-05, Test: 5.7959e-05
# Фаза 9: Train: 4.4678e-05, Test: 4.697e-05
# Фаза 10: Train: 2.2943e-05, Test: 2.4468e-05
# Фаза 11: Train: 3.0345e-05, Test: 3.1744e-05
# Фаза 12: Train: 5.648e-05, Test: 5.5571e-05
# Прошло времени: 00:06:38
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 4.9294e-05
# Epoch [45/600], learn_rate: [5.522642316338268e-05], Train Loss: 3.7009e-05, Test Loss: 3.8253e-05
# Фаза 1: Train: 2.51e-05, Test: 2.4978e-05
# Фаза 2: Train: 3.7349e-05, Test: 3.9311e-05
# Фаза 3: Train: 5.0238e-05, Test: 5.1474e-05
# Фаза 4: Train: 4.7532e-05, Test: 4.8068e-05
# Фаза 5: Train: 2.8596e-05, Test: 3.0745e-05
# Фаза 6: Train: 2.5783e-05, Test: 2.672e-05
# Фаза 7: Train: 2.46e-05, Test: 2.598e-05
# Фаза 8: Train: 6.8961e-05, Test: 7.0821e-05
# Фаза 9: Train: 4.6478e-05, Test: 4.8491e-05
# Фаза 10: Train: 2.6772e-05, Test: 2.8541e-05
# Фаза 11: Train: 3.3951e-05, Test: 3.5285e-05
# Фаза 12: Train: 2.8745e-05, Test: 2.862e-05
# Прошло времени: 00:06:47
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.1414e-05
# Epoch [46/600], learn_rate: [5.0000000000000016e-05], Train Loss: 3.6715e-05, Test Loss: 3.7891e-05
# Фаза 1: Train: 4.6793e-05, Test: 4.6145e-05
# Фаза 2: Train: 3.9928e-05, Test: 4.0679e-05
# Фаза 3: Train: 4.4574e-05, Test: 4.5982e-05
# Фаза 4: Train: 4.732e-05, Test: 4.738e-05
# Фаза 5: Train: 2.6484e-05, Test: 2.8831e-05
# Фаза 6: Train: 2.9711e-05, Test: 3.1649e-05
# Фаза 7: Train: 2.0256e-05, Test: 2.1254e-05
# Фаза 8: Train: 4.4479e-05, Test: 4.6292e-05
# Фаза 9: Train: 4.1227e-05, Test: 4.3713e-05
# Фаза 10: Train: 4.5331e-05, Test: 4.6715e-05
# Фаза 11: Train: 2.9979e-05, Test: 3.1617e-05
# Фаза 12: Train: 2.4501e-05, Test: 2.4434e-05
# Прошло времени: 00:06:56
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.0895e-05
# Epoch [47/600], learn_rate: [4.477357683661734e-05], Train Loss: 3.8147e-05, Test Loss: 3.931e-05
# Фаза 1: Train: 2.4112e-05, Test: 2.4392e-05
# Фаза 2: Train: 3.5498e-05, Test: 3.6794e-05
# Фаза 3: Train: 4.8636e-05, Test: 4.985e-05
# Фаза 4: Train: 4.3882e-05, Test: 4.5114e-05
# Фаза 5: Train: 2.7166e-05, Test: 2.8129e-05
# Фаза 6: Train: 2.732e-05, Test: 2.7887e-05
# Фаза 7: Train: 3.36e-05, Test: 3.6251e-05
# Фаза 8: Train: 6.9077e-05, Test: 7.0982e-05
# Фаза 9: Train: 5.1783e-05, Test: 5.3772e-05
# Фаза 10: Train: 2.9624e-05, Test: 3.0269e-05
# Фаза 11: Train: 4.108e-05, Test: 4.1663e-05
# Фаза 12: Train: 2.599e-05, Test: 2.6618e-05
# Прошло времени: 00:07:05
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.3535e-05
# Epoch [48/600], learn_rate: [3.9604415459112035e-05], Train Loss: 3.582e-05, Test Loss: 3.6738e-05
# Фаза 1: Train: 3.6693e-05, Test: 3.623e-05
# Фаза 2: Train: 3.493e-05, Test: 3.6781e-05
# Фаза 3: Train: 4.1514e-05, Test: 4.3205e-05
# Фаза 4: Train: 7.3578e-05, Test: 7.1223e-05
# Фаза 5: Train: 2.7508e-05, Test: 2.8811e-05
# Фаза 6: Train: 2.7591e-05, Test: 2.8778e-05
# Фаза 7: Train: 2.8507e-05, Test: 2.9196e-05
# Фаза 8: Train: 4.8674e-05, Test: 5.0345e-05
# Фаза 9: Train: 3.8497e-05, Test: 4.1441e-05
# Фаза 10: Train: 1.8969e-05, Test: 2.0598e-05
# Фаза 11: Train: 2.7596e-05, Test: 2.8084e-05
# Фаза 12: Train: 2.5784e-05, Test: 2.616e-05
# Прошло времени: 00:07:14
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 4.5409e-05
# Epoch [49/600], learn_rate: [3.4549150281252636e-05], Train Loss: 3.1379e-05, Test Loss: 3.2542e-05
# Фаза 1: Train: 2.3365e-05, Test: 2.3617e-05
# Фаза 2: Train: 3.3967e-05, Test: 3.5456e-05
# Фаза 3: Train: 3.8671e-05, Test: 4.007e-05
# Фаза 4: Train: 4.4443e-05, Test: 4.4797e-05
# Фаза 5: Train: 2.9686e-05, Test: 3.0528e-05
# Фаза 6: Train: 2.2296e-05, Test: 2.3245e-05
# Фаза 7: Train: 1.8822e-05, Test: 2.0267e-05
# Фаза 8: Train: 4.2435e-05, Test: 4.3675e-05
# Фаза 9: Train: 3.9163e-05, Test: 4.1734e-05
# Фаза 10: Train: 2.2911e-05, Test: 2.4499e-05
# Фаза 11: Train: 3.4891e-05, Test: 3.6216e-05
# Фаза 12: Train: 2.5898e-05, Test: 2.6403e-05
# Прошло времени: 00:07:24
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 4.1092e-05
# Epoch [50/600], learn_rate: [2.9663167846209998e-05], Train Loss: 3.25e-05, Test Loss: 3.3645e-05
# Фаза 1: Train: 2.198e-05, Test: 2.1694e-05
# Фаза 2: Train: 3.3351e-05, Test: 3.4557e-05
# Фаза 3: Train: 3.8574e-05, Test: 4.0008e-05
# Фаза 4: Train: 4.423e-05, Test: 4.4677e-05
# Фаза 5: Train: 2.5838e-05, Test: 2.6768e-05
# Фаза 6: Train: 2.179e-05, Test: 2.2888e-05
# Фаза 7: Train: 3.9407e-05, Test: 4.1304e-05
# Фаза 8: Train: 4.1985e-05, Test: 4.3192e-05
# Фаза 9: Train: 4.3998e-05, Test: 4.6271e-05
# Фаза 10: Train: 2.6091e-05, Test: 2.8293e-05
# Фаза 11: Train: 2.2377e-05, Test: 2.3562e-05
# Фаза 12: Train: 3.0374e-05, Test: 3.0531e-05
# Прошло времени: 00:07:33
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 4.6058e-05
# Epoch [51/600], learn_rate: [2.500000000000001e-05], Train Loss: 3.2002e-05, Test Loss: 3.3369e-05
# Фаза 1: Train: 2.1626e-05, Test: 2.2289e-05
# Фаза 2: Train: 3.4463e-05, Test: 3.6037e-05
# Фаза 3: Train: 4.8335e-05, Test: 5.0476e-05
# Фаза 4: Train: 4.0698e-05, Test: 4.2219e-05
# Фаза 5: Train: 2.974e-05, Test: 3.107e-05
# Фаза 6: Train: 2.3068e-05, Test: 2.4386e-05
# Фаза 7: Train: 1.9608e-05, Test: 2.0916e-05
# Фаза 8: Train: 3.9702e-05, Test: 4.0775e-05
# Фаза 9: Train: 4.726e-05, Test: 5.0535e-05
# Фаза 10: Train: 3.1142e-05, Test: 3.2247e-05
# Фаза 11: Train: 2.4007e-05, Test: 2.4826e-05
# Фаза 12: Train: 2.4372e-05, Test: 2.4649e-05
# Прошло времени: 00:07:42
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 4.8945e-05
# Epoch [52/600], learn_rate: [2.061073738537635e-05], Train Loss: 2.9444e-05, Test Loss: 3.0475e-05
# Фаза 1: Train: 3.1286e-05, Test: 3.1132e-05
# Фаза 2: Train: 3.4316e-05, Test: 3.6074e-05
# Фаза 3: Train: 3.7588e-05, Test: 3.9071e-05
# Фаза 4: Train: 3.9798e-05, Test: 4.0299e-05
# Фаза 5: Train: 2.8123e-05, Test: 2.9207e-05
# Фаза 6: Train: 2.195e-05, Test: 2.3261e-05
# Фаза 7: Train: 1.7207e-05, Test: 1.8532e-05
# Фаза 8: Train: 4.0265e-05, Test: 4.1417e-05
# Фаза 9: Train: 3.746e-05, Test: 3.9021e-05
# Фаза 10: Train: 1.9318e-05, Test: 2.0918e-05
# Фаза 11: Train: 2.3124e-05, Test: 2.3873e-05
# Фаза 12: Train: 2.2888e-05, Test: 2.2901e-05
# Прошло времени: 00:07:51
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 4.8777e-05
# Epoch [53/600], learn_rate: [1.6543469682057106e-05], Train Loss: 2.9427e-05, Test Loss: 3.045e-05
# Фаза 1: Train: 2.0962e-05, Test: 2.0802e-05
# Фаза 2: Train: 3.1161e-05, Test: 3.2654e-05
# Фаза 3: Train: 3.9309e-05, Test: 4.1183e-05
# Фаза 4: Train: 4.044e-05, Test: 4.137e-05
# Фаза 5: Train: 2.6871e-05, Test: 2.7813e-05
# Фаза 6: Train: 2.2023e-05, Test: 2.3079e-05
# Фаза 7: Train: 2.7943e-05, Test: 2.9315e-05
# Фаза 8: Train: 3.7927e-05, Test: 3.8787e-05
# Фаза 9: Train: 3.6929e-05, Test: 3.8845e-05
# Фаза 10: Train: 2.0328e-05, Test: 2.1183e-05
# Фаза 11: Train: 2.595e-05, Test: 2.694e-05
# Фаза 12: Train: 2.3283e-05, Test: 2.3429e-05
# Прошло времени: 00:08:00
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.7312e-05
# Epoch [54/600], learn_rate: [1.2842758726130299e-05], Train Loss: 2.8469e-05, Test Loss: 2.9804e-05
# Фаза 1: Train: 2.3e-05, Test: 2.3434e-05
# Фаза 2: Train: 2.9688e-05, Test: 3.1074e-05
# Фаза 3: Train: 3.7873e-05, Test: 3.9536e-05
# Фаза 4: Train: 3.9073e-05, Test: 4.0002e-05
# Фаза 5: Train: 2.2173e-05, Test: 2.4385e-05
# Фаза 6: Train: 2.1394e-05, Test: 2.2222e-05
# Фаза 7: Train: 2.1799e-05, Test: 2.3403e-05
# Фаза 8: Train: 4.572e-05, Test: 4.7206e-05
# Фаза 9: Train: 3.5826e-05, Test: 3.8592e-05
# Фаза 10: Train: 2.3368e-05, Test: 2.4539e-05
# Фаза 11: Train: 2.1492e-05, Test: 2.2836e-05
# Фаза 12: Train: 2.0217e-05, Test: 2.0421e-05
# Прошло времени: 00:08:09
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 4.6505e-05
# Epoch [55/600], learn_rate: [9.549150281252633e-06], Train Loss: 2.7327e-05, Test Loss: 2.8541e-05
# Фаза 1: Train: 2.1396e-05, Test: 2.1179e-05
# Фаза 2: Train: 2.9105e-05, Test: 3.0727e-05
# Фаза 3: Train: 3.6284e-05, Test: 3.8153e-05
# Фаза 4: Train: 3.8908e-05, Test: 3.982e-05
# Фаза 5: Train: 2.4622e-05, Test: 2.594e-05
# Фаза 6: Train: 2.1931e-05, Test: 2.3007e-05
# Фаза 7: Train: 2.3771e-05, Test: 2.5052e-05
# Фаза 8: Train: 3.7668e-05, Test: 3.8799e-05
# Фаза 9: Train: 3.3657e-05, Test: 3.6556e-05
# Фаза 10: Train: 1.7868e-05, Test: 1.9072e-05
# Фаза 11: Train: 2.1281e-05, Test: 2.2667e-05
# Фаза 12: Train: 2.1428e-05, Test: 2.1514e-05
# Прошло времени: 00:08:18
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.2992e-05
# Epoch [56/600], learn_rate: [6.698729810778065e-06], Train Loss: 2.8073e-05, Test Loss: 2.9333e-05
# Фаза 1: Train: 1.9415e-05, Test: 1.9266e-05
# Фаза 2: Train: 2.9972e-05, Test: 3.1183e-05
# Фаза 3: Train: 3.5397e-05, Test: 3.7343e-05
# Фаза 4: Train: 3.8348e-05, Test: 3.8906e-05
# Фаза 5: Train: 2.2347e-05, Test: 2.3625e-05
# Фаза 6: Train: 1.9696e-05, Test: 2.0795e-05
# Фаза 7: Train: 2.1704e-05, Test: 2.3025e-05
# Фаза 8: Train: 5.114e-05, Test: 5.3483e-05
# Фаза 9: Train: 3.6741e-05, Test: 3.925e-05
# Фаза 10: Train: 1.8602e-05, Test: 2.0187e-05
# Фаза 11: Train: 2.2098e-05, Test: 2.353e-05
# Фаза 12: Train: 2.1414e-05, Test: 2.1405e-05
# Прошло времени: 00:08:27
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 4.5704e-05
# Epoch [57/600], learn_rate: [4.322727117869951e-06], Train Loss: 2.6876e-05, Test Loss: 2.8127e-05
# Фаза 1: Train: 1.9266e-05, Test: 1.931e-05
# Фаза 2: Train: 3.0487e-05, Test: 3.1681e-05
# Фаза 3: Train: 3.5341e-05, Test: 3.6824e-05
# Фаза 4: Train: 3.8212e-05, Test: 3.8867e-05
# Фаза 5: Train: 2.1758e-05, Test: 2.3493e-05
# Фаза 6: Train: 2.0408e-05, Test: 2.1656e-05
# Фаза 7: Train: 1.833e-05, Test: 1.9841e-05
# Фаза 8: Train: 3.8153e-05, Test: 3.9857e-05
# Фаза 9: Train: 3.4466e-05, Test: 3.7304e-05
# Фаза 10: Train: 2.1829e-05, Test: 2.3412e-05
# Фаза 11: Train: 2.3566e-05, Test: 2.4583e-05
# Фаза 12: Train: 2.0695e-05, Test: 2.0701e-05
# Прошло времени: 00:08:36
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 4.8142e-05
# Epoch [58/600], learn_rate: [2.4471741852423237e-06], Train Loss: 2.6858e-05, Test Loss: 2.8036e-05
# Фаза 1: Train: 2.0104e-05, Test: 2.0112e-05
# Фаза 2: Train: 2.9404e-05, Test: 3.041e-05
# Фаза 3: Train: 3.5178e-05, Test: 3.6672e-05
# Фаза 4: Train: 3.8246e-05, Test: 3.8965e-05
# Фаза 5: Train: 2.3511e-05, Test: 2.4607e-05
# Фаза 6: Train: 2.0099e-05, Test: 2.1165e-05
# Фаза 7: Train: 2.1028e-05, Test: 2.2704e-05
# Фаза 8: Train: 3.8132e-05, Test: 3.9121e-05
# Фаза 9: Train: 3.3838e-05, Test: 3.7212e-05
# Фаза 10: Train: 1.9065e-05, Test: 2.0414e-05
# Фаза 11: Train: 2.3097e-05, Test: 2.4261e-05
# Фаза 12: Train: 2.0595e-05, Test: 2.0789e-05
# Прошло времени: 00:08:45
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 4.8146e-05
# Epoch [59/600], learn_rate: [1.0926199633097157e-06], Train Loss: 2.6547e-05, Test Loss: 2.7863e-05
# Фаза 1: Train: 1.9495e-05, Test: 1.9515e-05
# Фаза 2: Train: 2.9631e-05, Test: 3.1199e-05
# Фаза 3: Train: 3.4723e-05, Test: 3.6578e-05
# Фаза 4: Train: 3.8242e-05, Test: 3.8572e-05
# Фаза 5: Train: 2.1278e-05, Test: 2.3257e-05
# Фаза 6: Train: 2.0059e-05, Test: 2.1173e-05
# Фаза 7: Train: 1.9802e-05, Test: 2.1188e-05
# Фаза 8: Train: 3.9049e-05, Test: 4.0595e-05
# Фаза 9: Train: 3.3684e-05, Test: 3.6602e-05
# Фаза 10: Train: 1.9838e-05, Test: 2.1261e-05
# Фаза 11: Train: 2.2466e-05, Test: 2.3709e-05
# Фаза 12: Train: 2.03e-05, Test: 2.0703e-05
# Прошло времени: 00:08:54
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 4.8575e-05
# Epoch [60/600], learn_rate: [2.7390523158633e-07], Train Loss: 2.6487e-05, Test Loss: 2.7673e-05
# Фаза 1: Train: 1.9626e-05, Test: 1.9766e-05
# Фаза 2: Train: 2.9872e-05, Test: 3.1391e-05
# Фаза 3: Train: 3.4628e-05, Test: 3.6656e-05
# Фаза 4: Train: 3.8037e-05, Test: 3.8675e-05
# Фаза 5: Train: 2.2427e-05, Test: 2.3593e-05
# Фаза 6: Train: 2.0046e-05, Test: 2.1083e-05
# Фаза 7: Train: 2.0025e-05, Test: 2.1111e-05
# Фаза 8: Train: 3.7904e-05, Test: 3.9467e-05
# Фаза 9: Train: 3.3775e-05, Test: 3.639e-05
# Фаза 10: Train: 1.8703e-05, Test: 1.9941e-05
# Фаза 11: Train: 2.2485e-05, Test: 2.3488e-05
# Фаза 12: Train: 2.0319e-05, Test: 2.0512e-05
# Прошло времени: 00:09:03
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 7.1341e-05
# Epoch [61/600], learn_rate: [0.0001], Train Loss: 4.1268e-05, Test Loss: 4.1878e-05
# Фаза 1: Train: 2.917e-05, Test: 3.0061e-05
# Фаза 2: Train: 3.9685e-05, Test: 4.0232e-05
# Фаза 3: Train: 6.5691e-05, Test: 6.6705e-05
# Фаза 4: Train: 5.9181e-05, Test: 5.7068e-05
# Фаза 5: Train: 2.6529e-05, Test: 2.7497e-05
# Фаза 6: Train: 2.4116e-05, Test: 2.5526e-05
# Фаза 7: Train: 2.3555e-05, Test: 2.4335e-05
# Фаза 8: Train: 5.5622e-05, Test: 5.5388e-05
# Фаза 9: Train: 6.1483e-05, Test: 6.3903e-05
# Фаза 10: Train: 4.8164e-05, Test: 4.9048e-05
# Фаза 11: Train: 3.7053e-05, Test: 3.8145e-05
# Фаза 12: Train: 2.4961e-05, Test: 2.4624e-05
# Прошло времени: 00:09:13
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.8494e-05
# Epoch [62/600], learn_rate: [9.972609476841367e-05], Train Loss: 3.964e-05, Test Loss: 4.0354e-05
# Фаза 1: Train: 4.4993e-05, Test: 4.4557e-05
# Фаза 2: Train: 4.4012e-05, Test: 4.4467e-05
# Фаза 3: Train: 5.6949e-05, Test: 5.7299e-05
# Фаза 4: Train: 4.5736e-05, Test: 4.469e-05
# Фаза 5: Train: 2.725e-05, Test: 2.9044e-05
# Фаза 6: Train: 2.555e-05, Test: 2.6274e-05
# Фаза 7: Train: 2.6195e-05, Test: 2.7061e-05
# Фаза 8: Train: 5.494e-05, Test: 5.6901e-05
# Фаза 9: Train: 3.8567e-05, Test: 4.1291e-05
# Фаза 10: Train: 2.599e-05, Test: 2.7267e-05
# Фаза 11: Train: 2.3301e-05, Test: 2.4483e-05
# Фаза 12: Train: 6.2201e-05, Test: 6.0917e-05
# Прошло времени: 00:09:22
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 4.0912e-05
# Epoch [63/600], learn_rate: [9.890738003669029e-05], Train Loss: 3.4627e-05, Test Loss: 3.5581e-05
# Фаза 1: Train: 2.4756e-05, Test: 2.5093e-05
# Фаза 2: Train: 3.8855e-05, Test: 4.08e-05
# Фаза 3: Train: 4.1962e-05, Test: 4.2329e-05
# Фаза 4: Train: 4.3417e-05, Test: 4.3392e-05
# Фаза 5: Train: 2.6262e-05, Test: 2.7543e-05
# Фаза 6: Train: 2.4777e-05, Test: 2.545e-05
# Фаза 7: Train: 2.1456e-05, Test: 2.2277e-05
# Фаза 8: Train: 4.9086e-05, Test: 5.036e-05
# Фаза 9: Train: 3.9324e-05, Test: 4.2175e-05
# Фаза 10: Train: 2.5029e-05, Test: 2.5861e-05
# Фаза 11: Train: 4.4085e-05, Test: 4.552e-05
# Фаза 12: Train: 3.6509e-05, Test: 3.6166e-05
# Прошло времени: 00:09:31
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 5.3018e-05
# Epoch [64/600], learn_rate: [9.755282581475769e-05], Train Loss: 3.952e-05, Test Loss: 4.0121e-05
# Фаза 1: Train: 2.8762e-05, Test: 2.8822e-05
# Фаза 2: Train: 6.138e-05, Test: 6.1946e-05
# Фаза 3: Train: 4.6275e-05, Test: 4.7265e-05
# Фаза 4: Train: 4.7246e-05, Test: 4.6354e-05
# Фаза 5: Train: 2.3504e-05, Test: 2.4049e-05
# Фаза 6: Train: 2.4028e-05, Test: 2.4841e-05
# Фаза 7: Train: 4.001e-05, Test: 4.1185e-05
# Фаза 8: Train: 4.2381e-05, Test: 4.2593e-05
# Фаза 9: Train: 4.2609e-05, Test: 4.507e-05
# Фаза 10: Train: 2.0199e-05, Test: 2.1839e-05
# Фаза 11: Train: 2.7748e-05, Test: 2.8325e-05
# Фаза 12: Train: 7.0093e-05, Test: 6.916e-05
# Прошло времени: 00:09:40
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 9.3194e-05
# Epoch [65/600], learn_rate: [9.567727288213005e-05], Train Loss: 3.9309e-05, Test Loss: 4.0454e-05
# Фаза 1: Train: 2.9882e-05, Test: 2.9615e-05
# Фаза 2: Train: 4.2899e-05, Test: 4.2995e-05
# Фаза 3: Train: 4.247e-05, Test: 4.396e-05
# Фаза 4: Train: 5.5681e-05, Test: 5.8805e-05
# Фаза 5: Train: 3.2004e-05, Test: 3.2907e-05
# Фаза 6: Train: 2.8699e-05, Test: 2.9894e-05
# Фаза 7: Train: 5.5906e-05, Test: 5.7289e-05
# Фаза 8: Train: 4.0194e-05, Test: 4.0902e-05
# Фаза 9: Train: 4.3153e-05, Test: 4.6091e-05
# Фаза 10: Train: 2.7123e-05, Test: 2.7935e-05
# Фаза 11: Train: 5.0471e-05, Test: 5.1317e-05
# Фаза 12: Train: 2.3226e-05, Test: 2.374e-05
# Прошло времени: 00:09:49
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 0.00019476
# Epoch [66/600], learn_rate: [9.330127018922194e-05], Train Loss: 4.1029e-05, Test Loss: 4.2482e-05
# Фаза 1: Train: 2.8092e-05, Test: 2.7194e-05
# Фаза 2: Train: 3.8969e-05, Test: 3.9915e-05
# Фаза 3: Train: 4.782e-05, Test: 4.9422e-05
# Фаза 4: Train: 7.6168e-05, Test: 7.8835e-05
# Фаза 5: Train: 2.6352e-05, Test: 2.8945e-05
# Фаза 6: Train: 4.7503e-05, Test: 4.9842e-05
# Фаза 7: Train: 7.0758e-05, Test: 7.2646e-05
# Фаза 8: Train: 4.0216e-05, Test: 4.1103e-05
# Фаза 9: Train: 4.0348e-05, Test: 4.269e-05
# Фаза 10: Train: 2.7453e-05, Test: 2.9575e-05
# Фаза 11: Train: 2.3241e-05, Test: 2.4403e-05
# Фаза 12: Train: 2.5432e-05, Test: 2.5214e-05
# Прошло времени: 00:09:58
#
# Iteration 500
# ...
# Epoch [579/600], learn_rate: [8.345653031794292e-05], Train Loss: 7.0501e-06, Test Loss: 7.7181e-06
# Фаза 1: Train: 5.5721e-06, Test: 5.9131e-06
# Фаза 2: Train: 7.9255e-06, Test: 8.6101e-06
# Фаза 3: Train: 7.6626e-06, Test: 8.5365e-06
# Фаза 4: Train: 1.1604e-05, Test: 1.2464e-05
# Фаза 5: Train: 5.5108e-06, Test: 6.4887e-06
# Фаза 6: Train: 7.0167e-06, Test: 7.4735e-06
# Фаза 7: Train: 5.0949e-06, Test: 5.6569e-06
# Фаза 8: Train: 7.0998e-06, Test: 7.9526e-06
# Фаза 9: Train: 6.7937e-06, Test: 8.01e-06
# Фаза 10: Train: 5.9613e-06, Test: 6.4066e-06
# Фаза 11: Train: 1.0442e-05, Test: 1.0629e-05
# Фаза 12: Train: 3.9182e-06, Test: 4.4756e-06
# Прошло времени: 01:30:02
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 3.5686e-05
# Epoch [580/600], learn_rate: [7.938926261462366e-05], Train Loss: 6.1341e-06, Test Loss: 6.8265e-06
# Фаза 1: Train: 4.516e-06, Test: 5.0066e-06
# Фаза 2: Train: 7.61e-06, Test: 8.4208e-06
# Фаза 3: Train: 7.0576e-06, Test: 7.7739e-06
# Фаза 4: Train: 8.4445e-06, Test: 9.4293e-06
# Фаза 5: Train: 6.4015e-06, Test: 7.0361e-06
# Фаза 6: Train: 5.0138e-06, Test: 5.527e-06
# Фаза 7: Train: 4.7308e-06, Test: 5.3739e-06
# Фаза 8: Train: 7.0006e-06, Test: 7.7732e-06
# Фаза 9: Train: 6.6764e-06, Test: 7.6272e-06
# Фаза 10: Train: 7.4956e-06, Test: 8.3085e-06
# Фаза 11: Train: 4.7057e-06, Test: 5.2939e-06
# Фаза 12: Train: 3.9565e-06, Test: 4.3476e-06
# Прошло времени: 01:30:11
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 4.0464e-05
# Epoch [581/600], learn_rate: [7.500000000000001e-05], Train Loss: 7.0846e-06, Test Loss: 7.8254e-06
# Фаза 1: Train: 6.525e-06, Test: 6.9744e-06
# Фаза 2: Train: 8.5288e-06, Test: 9.459e-06
# Фаза 3: Train: 9.4819e-06, Test: 1.0534e-05
# Фаза 4: Train: 9.0508e-06, Test: 1.0162e-05
# Фаза 5: Train: 1.0844e-05, Test: 1.1448e-05
# Фаза 6: Train: 4.3873e-06, Test: 4.9623e-06
# Фаза 7: Train: 4.2827e-06, Test: 5.1314e-06
# Фаза 8: Train: 7.0805e-06, Test: 7.8184e-06
# Фаза 9: Train: 6.8724e-06, Test: 7.7908e-06
# Фаза 10: Train: 8.3294e-06, Test: 9.1095e-06
# Фаза 11: Train: 4.7272e-06, Test: 5.2489e-06
# Фаза 12: Train: 4.9055e-06, Test: 5.2661e-06
# Прошло времени: 01:30:21
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 4.2944e-05
# Epoch [582/600], learn_rate: [7.033683215379002e-05], Train Loss: 5.8101e-06, Test Loss: 6.5335e-06
# Фаза 1: Train: 4.3932e-06, Test: 4.863e-06
# Фаза 2: Train: 6.6684e-06, Test: 7.3387e-06
# Фаза 3: Train: 7.1283e-06, Test: 8.1105e-06
# Фаза 4: Train: 7.8481e-06, Test: 9.0939e-06
# Фаза 5: Train: 5.2291e-06, Test: 6.1335e-06
# Фаза 6: Train: 4.4642e-06, Test: 5.0661e-06
# Фаза 7: Train: 5.7177e-06, Test: 6.3884e-06
# Фаза 8: Train: 7.0266e-06, Test: 7.9062e-06
# Фаза 9: Train: 6.9536e-06, Test: 8.0005e-06
# Фаза 10: Train: 3.9478e-06, Test: 4.1488e-06
# Фаза 11: Train: 5.8792e-06, Test: 6.4111e-06
# Фаза 12: Train: 4.4646e-06, Test: 4.9414e-06
# Прошло времени: 01:30:30
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 2.7579e-05
# Epoch [583/600], learn_rate: [6.545084971874738e-05], Train Loss: 6.7109e-06, Test Loss: 7.379e-06
# Фаза 1: Train: 6.3219e-06, Test: 6.8557e-06
# Фаза 2: Train: 6.944e-06, Test: 7.7856e-06
# Фаза 3: Train: 7.3344e-06, Test: 8.2325e-06
# Фаза 4: Train: 1.192e-05, Test: 1.288e-05
# Фаза 5: Train: 5.1e-06, Test: 5.8968e-06
# Фаза 6: Train: 5.4744e-06, Test: 6.0307e-06
# Фаза 7: Train: 4.9317e-06, Test: 5.7277e-06
# Фаза 8: Train: 6.6489e-06, Test: 7.2389e-06
# Фаза 9: Train: 6.8393e-06, Test: 7.7934e-06
# Фаза 10: Train: 4.0308e-06, Test: 4.4514e-06
# Фаза 11: Train: 1.0688e-05, Test: 1.0907e-05
# Фаза 12: Train: 4.298e-06, Test: 4.7486e-06
# Прошло времени: 01:30:39
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 3.1677e-05
# Epoch [584/600], learn_rate: [6.0395584540887963e-05], Train Loss: 6.5654e-06, Test Loss: 7.2685e-06
# Фаза 1: Train: 6.6902e-06, Test: 7.0491e-06
# Фаза 2: Train: 7.7194e-06, Test: 8.4816e-06
# Фаза 3: Train: 7.4011e-06, Test: 8.19e-06
# Фаза 4: Train: 8.2166e-06, Test: 9.299e-06
# Фаза 5: Train: 5.7941e-06, Test: 6.8238e-06
# Фаза 6: Train: 5.3305e-06, Test: 5.7859e-06
# Фаза 7: Train: 5.5257e-06, Test: 5.8964e-06
# Фаза 8: Train: 7.8036e-06, Test: 8.4782e-06
# Фаза 9: Train: 9.1474e-06, Test: 1.0373e-05
# Фаза 10: Train: 6.3608e-06, Test: 6.8521e-06
# Фаза 11: Train: 4.6415e-06, Test: 5.2666e-06
# Фаза 12: Train: 4.1536e-06, Test: 4.7262e-06
# Прошло времени: 01:30:49
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 3.0323e-05
# Epoch [585/600], learn_rate: [5.522642316338268e-05], Train Loss: 5.4705e-06, Test Loss: 6.1447e-06
# Фаза 1: Train: 3.9639e-06, Test: 4.3671e-06
# Фаза 2: Train: 6.0447e-06, Test: 6.8019e-06
# Фаза 3: Train: 7.1708e-06, Test: 8.0178e-06
# Фаза 4: Train: 8.9961e-06, Test: 9.8679e-06
# Фаза 5: Train: 5.3809e-06, Test: 6.2673e-06
# Фаза 6: Train: 3.9994e-06, Test: 4.5173e-06
# Фаза 7: Train: 2.7468e-06, Test: 3.2674e-06
# Фаза 8: Train: 7.2804e-06, Test: 8.034e-06
# Фаза 9: Train: 6.4054e-06, Test: 7.538e-06
# Фаза 10: Train: 3.4636e-06, Test: 3.8348e-06
# Фаза 11: Train: 5.1143e-06, Test: 5.5587e-06
# Фаза 12: Train: 5.0803e-06, Test: 5.6647e-06
# Прошло времени: 01:30:58
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 3.8515e-05
# Epoch [586/600], learn_rate: [5.0000000000000016e-05], Train Loss: 6.1162e-06, Test Loss: 6.8434e-06
# Фаза 1: Train: 3.9492e-06, Test: 4.4702e-06
# Фаза 2: Train: 7.7138e-06, Test: 8.6921e-06
# Фаза 3: Train: 6.9901e-06, Test: 7.8363e-06
# Фаза 4: Train: 8.5212e-06, Test: 9.5888e-06
# Фаза 5: Train: 5.3842e-06, Test: 6.2709e-06
# Фаза 6: Train: 6.5013e-06, Test: 6.9181e-06
# Фаза 7: Train: 4.9919e-06, Test: 5.5601e-06
# Фаза 8: Train: 6.9209e-06, Test: 7.6395e-06
# Фаза 9: Train: 8.1842e-06, Test: 9.3053e-06
# Фаза 10: Train: 4.8541e-06, Test: 5.3195e-06
# Фаза 11: Train: 5.4703e-06, Test: 6.0321e-06
# Фаза 12: Train: 3.9133e-06, Test: 4.4875e-06
# Прошло времени: 01:31:08
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 3.7227e-05
# Epoch [587/600], learn_rate: [4.477357683661734e-05], Train Loss: 5.6271e-06, Test Loss: 6.3614e-06
# Фаза 1: Train: 3.946e-06, Test: 4.413e-06
# Фаза 2: Train: 8.3602e-06, Test: 9.0026e-06
# Фаза 3: Train: 7.1781e-06, Test: 8.0574e-06
# Фаза 4: Train: 7.7128e-06, Test: 8.8061e-06
# Фаза 5: Train: 4.6606e-06, Test: 5.7136e-06
# Фаза 6: Train: 3.9894e-06, Test: 4.5684e-06
# Фаза 7: Train: 6.4095e-06, Test: 7.1483e-06
# Фаза 8: Train: 6.8432e-06, Test: 7.5831e-06
# Фаза 9: Train: 6.4071e-06, Test: 7.5405e-06
# Фаза 10: Train: 3.4519e-06, Test: 3.8159e-06
# Фаза 11: Train: 4.4618e-06, Test: 5.0868e-06
# Фаза 12: Train: 4.1051e-06, Test: 4.6015e-06
# Прошло времени: 01:31:17
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 4.0503e-05
# Epoch [588/600], learn_rate: [3.9604415459112035e-05], Train Loss: 5.6916e-06, Test Loss: 6.3842e-06
# Фаза 1: Train: 4.0636e-06, Test: 4.5724e-06
# Фаза 2: Train: 5.8726e-06, Test: 6.5803e-06
# Фаза 3: Train: 8.1828e-06, Test: 8.938e-06
# Фаза 4: Train: 8.2316e-06, Test: 9.2235e-06
# Фаза 5: Train: 5.0868e-06, Test: 6.0388e-06
# Фаза 6: Train: 5.9674e-06, Test: 6.5762e-06
# Фаза 7: Train: 4.5082e-06, Test: 5.1911e-06
# Фаза 8: Train: 6.5939e-06, Test: 7.2667e-06
# Фаза 9: Train: 7.4191e-06, Test: 8.4215e-06
# Фаза 10: Train: 3.8819e-06, Test: 4.4398e-06
# Фаза 11: Train: 4.3228e-06, Test: 4.7688e-06
# Фаза 12: Train: 4.1686e-06, Test: 4.5939e-06
# Прошло времени: 01:31:26
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 3.1598e-05
# Epoch [589/600], learn_rate: [3.4549150281252636e-05], Train Loss: 5.7031e-06, Test Loss: 6.4711e-06
# Фаза 1: Train: 4.5034e-06, Test: 5.0567e-06
# Фаза 2: Train: 5.9398e-06, Test: 6.7411e-06
# Фаза 3: Train: 9.3424e-06, Test: 1.0398e-05
# Фаза 4: Train: 8.1074e-06, Test: 9.2762e-06
# Фаза 5: Train: 5.6337e-06, Test: 6.5218e-06
# Фаза 6: Train: 3.8297e-06, Test: 4.4128e-06
# Фаза 7: Train: 2.8744e-06, Test: 3.5871e-06
# Фаза 8: Train: 8.6882e-06, Test: 9.4726e-06
# Фаза 9: Train: 6.3321e-06, Test: 7.4212e-06
# Фаза 10: Train: 4.2571e-06, Test: 4.7726e-06
# Фаза 11: Train: 4.101e-06, Test: 4.7371e-06
# Фаза 12: Train: 4.8283e-06, Test: 5.2553e-06
# Прошло времени: 01:31:36
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 3.3014e-05
# Epoch [590/600], learn_rate: [2.9663167846209998e-05], Train Loss: 5.1791e-06, Test Loss: 5.8772e-06
# Фаза 1: Train: 3.8267e-06, Test: 4.3078e-06
# Фаза 2: Train: 5.7744e-06, Test: 6.4956e-06
# Фаза 3: Train: 6.867e-06, Test: 7.7756e-06
# Фаза 4: Train: 8.0754e-06, Test: 9.0671e-06
# Фаза 5: Train: 5.1113e-06, Test: 6.0093e-06
# Фаза 6: Train: 4.2817e-06, Test: 4.8881e-06
# Фаза 7: Train: 2.7207e-06, Test: 3.396e-06
# Фаза 8: Train: 7.1944e-06, Test: 7.8714e-06
# Фаза 9: Train: 6.2001e-06, Test: 7.1694e-06
# Фаза 10: Train: 3.8617e-06, Test: 4.2765e-06
# Фаза 11: Train: 4.443e-06, Test: 4.9694e-06
# Фаза 12: Train: 3.7929e-06, Test: 4.2998e-06
# Прошло времени: 01:31:45
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 3.5217e-05
# Epoch [591/600], learn_rate: [2.500000000000001e-05], Train Loss: 5.1247e-06, Test Loss: 5.8389e-06
# Фаза 1: Train: 3.8532e-06, Test: 4.4472e-06
# Фаза 2: Train: 5.7263e-06, Test: 6.4609e-06
# Фаза 3: Train: 6.426e-06, Test: 7.312e-06
# Фаза 4: Train: 7.8291e-06, Test: 8.8944e-06
# Фаза 5: Train: 4.7918e-06, Test: 5.6722e-06
# Фаза 6: Train: 3.9786e-06, Test: 4.5148e-06
# Фаза 7: Train: 4.0641e-06, Test: 4.7524e-06
# Фаза 8: Train: 6.4671e-06, Test: 7.1732e-06
# Фаза 9: Train: 7.0926e-06, Test: 8.1461e-06
# Фаза 10: Train: 3.4448e-06, Test: 3.8746e-06
# Фаза 11: Train: 4.2517e-06, Test: 4.7933e-06
# Фаза 12: Train: 3.5715e-06, Test: 4.0253e-06
# Прошло времени: 01:31:54
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 3.205e-05
# Epoch [592/600], learn_rate: [2.061073738537635e-05], Train Loss: 5.0294e-06, Test Loss: 5.7617e-06
# Фаза 1: Train: 3.6123e-06, Test: 4.139e-06
# Фаза 2: Train: 5.7364e-06, Test: 6.5566e-06
# Фаза 3: Train: 6.7942e-06, Test: 7.7217e-06
# Фаза 4: Train: 7.9278e-06, Test: 9.009e-06
# Фаза 5: Train: 4.7189e-06, Test: 5.5373e-06
# Фаза 6: Train: 4.673e-06, Test: 5.2479e-06
# Фаза 7: Train: 3.8285e-06, Test: 4.5291e-06
# Фаза 8: Train: 6.1545e-06, Test: 6.9304e-06
# Фаза 9: Train: 5.8363e-06, Test: 6.855e-06
# Фаза 10: Train: 3.5714e-06, Test: 3.9309e-06
# Фаза 11: Train: 3.9957e-06, Test: 4.614e-06
# Фаза 12: Train: 3.504e-06, Test: 4.0699e-06
# Прошло времени: 01:32:04
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 3.4837e-05
# Epoch [593/600], learn_rate: [1.6543469682057106e-05], Train Loss: 5.0787e-06, Test Loss: 5.8118e-06
# Фаза 1: Train: 4.3089e-06, Test: 4.8375e-06
# Фаза 2: Train: 5.7617e-06, Test: 6.543e-06
# Фаза 3: Train: 6.5675e-06, Test: 7.4762e-06
# Фаза 4: Train: 7.6346e-06, Test: 8.8343e-06
# Фаза 5: Train: 4.9011e-06, Test: 5.843e-06
# Фаза 6: Train: 3.775e-06, Test: 4.3599e-06
# Фаза 7: Train: 3.9436e-06, Test: 4.5936e-06
# Фаза 8: Train: 6.2535e-06, Test: 7.0017e-06
# Фаза 9: Train: 5.8292e-06, Test: 6.9051e-06
# Фаза 10: Train: 3.3765e-06, Test: 3.7665e-06
# Фаза 11: Train: 4.3757e-06, Test: 4.9129e-06
# Фаза 12: Train: 4.2172e-06, Test: 4.6672e-06
# Прошло времени: 01:32:13
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 3.5922e-05
# Epoch [594/600], learn_rate: [1.2842758726130299e-05], Train Loss: 5.1612e-06, Test Loss: 5.8974e-06
# Фаза 1: Train: 3.9778e-06, Test: 4.489e-06
# Фаза 2: Train: 6.0966e-06, Test: 6.8889e-06
# Фаза 3: Train: 6.5975e-06, Test: 7.472e-06
# Фаза 4: Train: 7.5553e-06, Test: 8.6772e-06
# Фаза 5: Train: 4.6675e-06, Test: 5.6356e-06
# Фаза 6: Train: 4.5473e-06, Test: 5.0227e-06
# Фаза 7: Train: 4.4861e-06, Test: 5.2041e-06
# Фаза 8: Train: 6.7735e-06, Test: 7.561e-06
# Фаза 9: Train: 5.9375e-06, Test: 7.0049e-06
# Фаза 10: Train: 3.7109e-06, Test: 4.1581e-06
# Фаза 11: Train: 3.9931e-06, Test: 4.5516e-06
# Фаза 12: Train: 3.5917e-06, Test: 4.1035e-06
# Прошло времени: 01:32:23
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 3.7249e-05
# Epoch [595/600], learn_rate: [9.549150281252633e-06], Train Loss: 4.8043e-06, Test Loss: 5.5713e-06
# Фаза 1: Train: 3.855e-06, Test: 4.3958e-06
# Фаза 2: Train: 5.4196e-06, Test: 6.304e-06
# Фаза 3: Train: 6.3681e-06, Test: 7.2841e-06
# Фаза 4: Train: 7.4406e-06, Test: 8.5352e-06
# Фаза 5: Train: 4.6085e-06, Test: 5.5223e-06
# Фаза 6: Train: 3.9824e-06, Test: 4.5554e-06
# Фаза 7: Train: 3.2244e-06, Test: 3.9616e-06
# Фаза 8: Train: 6.1335e-06, Test: 6.8874e-06
# Фаза 9: Train: 6.0603e-06, Test: 7.1791e-06
# Фаза 10: Train: 3.3611e-06, Test: 3.7634e-06
# Фаза 11: Train: 3.9391e-06, Test: 4.5699e-06
# Фаза 12: Train: 3.2587e-06, Test: 3.8975e-06
# Прошло времени: 01:32:32
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 3.5241e-05
# Epoch [596/600], learn_rate: [6.698729810778065e-06], Train Loss: 4.9985e-06, Test Loss: 5.7188e-06
# Фаза 1: Train: 3.699e-06, Test: 4.2298e-06
# Фаза 2: Train: 5.5616e-06, Test: 6.3342e-06
# Фаза 3: Train: 6.6585e-06, Test: 7.5313e-06
# Фаза 4: Train: 7.4273e-06, Test: 8.5531e-06
# Фаза 5: Train: 4.755e-06, Test: 5.5715e-06
# Фаза 6: Train: 4.0818e-06, Test: 4.5478e-06
# Фаза 7: Train: 3.2556e-06, Test: 3.9775e-06
# Фаза 8: Train: 6.1851e-06, Test: 6.9409e-06
# Фаза 9: Train: 5.9391e-06, Test: 7.0209e-06
# Фаза 10: Train: 4.0352e-06, Test: 4.5106e-06
# Фаза 11: Train: 4.8933e-06, Test: 5.3639e-06
# Фаза 12: Train: 3.4904e-06, Test: 4.0439e-06
# Прошло времени: 01:32:42
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 3.4637e-05
# Epoch [597/600], learn_rate: [4.322727117869951e-06], Train Loss: 4.8229e-06, Test Loss: 5.5767e-06
# Фаза 1: Train: 3.8317e-06, Test: 4.3613e-06
# Фаза 2: Train: 5.5923e-06, Test: 6.3952e-06
# Фаза 3: Train: 6.2059e-06, Test: 7.1162e-06
# Фаза 4: Train: 7.4026e-06, Test: 8.4851e-06
# Фаза 5: Train: 4.5138e-06, Test: 5.4766e-06
# Фаза 6: Train: 4.0072e-06, Test: 4.5451e-06
# Фаза 7: Train: 3.1123e-06, Test: 3.7263e-06
# Фаза 8: Train: 6.2332e-06, Test: 7.0305e-06
# Фаза 9: Train: 5.8782e-06, Test: 7.0521e-06
# Фаза 10: Train: 3.7591e-06, Test: 4.2225e-06
# Фаза 11: Train: 3.9684e-06, Test: 4.5703e-06
# Фаза 12: Train: 3.3696e-06, Test: 3.9389e-06
# Прошло времени: 01:32:51
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 3.5422e-05
# Epoch [598/600], learn_rate: [2.4471741852423237e-06], Train Loss: 4.905e-06, Test Loss: 5.6204e-06
# Фаза 1: Train: 3.705e-06, Test: 4.2254e-06
# Фаза 2: Train: 5.7201e-06, Test: 6.4334e-06
# Фаза 3: Train: 6.1808e-06, Test: 7.1357e-06
# Фаза 4: Train: 7.5702e-06, Test: 8.6321e-06
# Фаза 5: Train: 5.0079e-06, Test: 5.8431e-06
# Фаза 6: Train: 4.257e-06, Test: 4.8149e-06
# Фаза 7: Train: 3.3548e-06, Test: 3.9834e-06
# Фаза 8: Train: 6.4067e-06, Test: 7.0558e-06
# Фаза 9: Train: 5.8316e-06, Test: 6.9225e-06
# Фаза 10: Train: 3.5295e-06, Test: 3.9885e-06
# Фаза 11: Train: 3.9063e-06, Test: 4.5004e-06
# Фаза 12: Train: 3.39e-06, Test: 3.9097e-06
# Прошло времени: 01:33:00
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 3.5614e-05
# Epoch [599/600], learn_rate: [1.0926199633097157e-06], Train Loss: 4.8546e-06, Test Loss: 5.5597e-06
# Фаза 1: Train: 3.6759e-06, Test: 4.1997e-06
# Фаза 2: Train: 5.484e-06, Test: 6.2038e-06
# Фаза 3: Train: 6.3462e-06, Test: 7.2167e-06
# Фаза 4: Train: 7.5959e-06, Test: 8.5825e-06
# Фаза 5: Train: 5.1533e-06, Test: 5.9464e-06
# Фаза 6: Train: 3.8552e-06, Test: 4.4042e-06
# Фаза 7: Train: 3.2683e-06, Test: 3.9225e-06
# Фаза 8: Train: 6.1627e-06, Test: 6.8402e-06
# Фаза 9: Train: 5.8311e-06, Test: 6.8819e-06
# Фаза 10: Train: 3.6265e-06, Test: 4.0734e-06
# Фаза 11: Train: 4.0846e-06, Test: 4.6448e-06
# Фаза 12: Train: 3.1719e-06, Test: 3.8e-06
# Прошло времени: 01:33:10
#
# Iteration 500
#  >>> Средняя разница между предсказанными и OSO: 3.5348e-05
# Epoch [600/600], learn_rate: [2.7390523158633e-07], Train Loss: 4.8014e-06, Test Loss: 5.5261e-06
# Фаза 1: Train: 3.708e-06, Test: 4.2088e-06
# Фаза 2: Train: 5.4647e-06, Test: 6.2662e-06
# Фаза 3: Train: 6.197e-06, Test: 7.1022e-06
# Фаза 4: Train: 7.56e-06, Test: 8.5576e-06
# Фаза 5: Train: 4.7372e-06, Test: 5.6251e-06
# Фаза 6: Train: 3.9853e-06, Test: 4.5489e-06
# Фаза 7: Train: 3.1859e-06, Test: 3.8492e-06
# Фаза 8: Train: 6.2012e-06, Test: 6.9508e-06
# Фаза 9: Train: 5.7818e-06, Test: 6.8244e-06
# Фаза 10: Train: 3.5739e-06, Test: 4.0318e-06
# Фаза 11: Train: 3.9803e-06, Test: 4.5145e-06
# Фаза 12: Train: 3.2414e-06, Test: 3.8343e-06
# Прошло времени: 01:33:19

# %%
np_train_all_losses = np.array(train_all_losses)
np_test_all_losses = np.array(test_all_losses)
print(np_train_all_losses.shape)
print(np_test_all_losses.shape)
len_train = np_train_all_losses.shape[1]*np_train_all_losses.shape[2]
print(len_train)
len_test = np_test_all_losses.shape[1]*np_test_all_losses.shape[2]
print(len_test)
np_train_all_losses = np_train_all_losses.reshape(np_train_all_losses.shape[0],len_train)
np_test_all_losses = np_test_all_losses.reshape(np_train_all_losses.shape[0],len_test)
inter1 = 299
print(np.mean(np_train_all_losses[inter1]))
print(np.std(np_train_all_losses[inter1]))
print(np.median(np_train_all_losses[inter1]))
print(np.mean(np_test_all_losses[inter1]))
print(np.std(np_test_all_losses[inter1]))
print(np.median(np_test_all_losses[inter1]))
x_scaled = np.arange(len_test)*len_train/len_test
print(x_scaled)
# Out:
# (600, 703, 128)
# (600, 78, 128)
# 89984
# 9984
# 7.951858e-06
# 5.912104e-06
# 6.4200735e-06
# 8.770263e-06
# 6.9873868e-06
# 6.845603e-06
# [0.00000000e+00 9.01282051e+00 1.80256410e+01 ... 8.99569615e+04
#  8.99659744e+04 8.99749872e+04]

# %%
plt.plot(np.sort(np_train_all_losses[inter1]))
plt.plot(x_scaled,np.sort(np_test_all_losses[inter1]),linestyle='-.')
plt.show()

# %%
plt.plot(train_losses,label='train_loss')
plt.plot(test_losses,label='test_loss')
plt.plot(experimental_losses,label='experimental_losses')
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()

# %%
df1 = pd.read_csv('OSO_s2.5_CNN_str20_ViT_8040_12.csv',delimiter=';')
df2 = pd.read_csv('OSO_s2.5_ViT_8h_d256_4040_12.csv',delimiter=';')
df3 = pd.read_csv('OSO_s2.5_FFN_4040_256_12.csv',delimiter=';')
#print(df1)

# %%
plt.plot((df1['Train Loss'].to_numpy()/100)**2,label='train_loss')
plt.plot((df1['Test Loss'].to_numpy()/100)**2,label='test_loss')
plt.plot(df1['Exp_Diff'].to_numpy(),label='experimental_losses')
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()

# %%
plt.plot((df2['Train Loss'].to_numpy()/100)**2,label='train_loss')
plt.plot((df2['Test Loss'].to_numpy()/100)**2,label='test_loss')
plt.plot(df2['Exp_Diff'].to_numpy(),label='experimental_losses')
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()

# %%
plt.plot((df3['Train Loss'].to_numpy()/100)**2,label='train_loss')
plt.plot((df3['Test Loss'].to_numpy()/100)**2,label='test_loss')
plt.plot(df3['Exp_Diff'].to_numpy(),label='experimental_losses')
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()

# %%
plt.plot(df1['Exp_Diff'].to_numpy(),label='CNN')
plt.plot(df2['Exp_Diff'].to_numpy(),label='ViT')
plt.plot(df3['Exp_Diff'].to_numpy(),label='FFN')
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()

# %%
plt.plot(df1['Train Loss'].to_numpy(),label='CNN')
plt.plot(df2['Train Loss'].to_numpy(),label='ViT')
plt.plot(df3['Train Loss'].to_numpy(),label='FFN')
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()

# %%
plt.plot(df1['Test Loss'].to_numpy(),label='CNN')
plt.plot(df2['Test Loss'].to_numpy(),label='ViT')
plt.plot(df3['Test Loss'].to_numpy(),label='FFN')
plt.legend()
plt.yscale('log')
plt.grid(True)
plt.show()

# %%
def time_to_seconds(time_str):
    hours, minutes, seconds = map(int, time_str.split(':'))
    return hours * 3600 + minutes * 60 + seconds

# %%
t1 = []
t2 = []
for t in df1['Time'].to_numpy():
    t1.append(time_to_seconds(t))
for t in df2['Time'].to_numpy():
    t2.append(time_to_seconds(t))
plt.plot(t1,label='experimental_losses_CNN')
plt.plot(t2,label='experimental_losses_ViT')
plt.legend()
#plt.yscale('log')
plt.grid(True)
plt.show()
