# %%
import os
import struct
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, WeightedRandomSampler
import time
import csv
import glob
from diffraction_utils import load_experimental_data
from load_xml_phases import *
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
difr_dir = "../nn_data/"
os.makedirs(difr_dir, exist_ok=True)

# Автовыбор вычислительного устройства
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('device =', device)

# Вычисляем размер входа для свертки
input_size = 4001
num_phases = 12

xml_name = 'OSO'
model_ver = 'light_3'
wghts_fname = f'weights3_{xml_name}_{model_ver}.pth'
csv_res_fname = f"{xml_name}_{model_ver}.csv"

inp_data = []
out_data = []

PHASES_INFO = []

experiment_folder = 'XY_OSO_midKO'
# Out:
# device = cuda:0

# %%
# Создаем словарь для сопоставления имен файлов и целевых значений
target_values = {
    'Бо1125_180121.xy': np.array([0.42, 0.25, 42.72, 44.65, 2.22, 8.05, 0.00, 1.40, 0.28, 0.00, 0.01, 0.00]),
    'Бо2074_200121.xy': np.array([0.50, 0.24, 58.48, 27.85, 2.88, 7.90, 0.05, 1.62, 0.48, 0.00, 0.01, 0.00]),
    'Бо2077_200121.xy': np.array([0.40, 0.93, 67.24, 18.25, 3.63, 7.51, 0.03, 1.60, 0.42, 0.00, 0.00, 0.00]),
    'Бр1026_181220.xy': np.array([2.72, 2.78, 47.84, 28.73, 1.20, 14.57, 0.07, 2.06, 0.03, 0.00, 0.00, 0.00]),
    'Бр1071_241220.xy': np.array([1.22, 0.63, 50.30, 30.39, 1.60, 13.97, 0.06, 1.84, 0.00, 0.00, 0.00, 0.00]),
    'Бр1307_2_181220.xy': np.array([0.68, 1.17, 86.07, 0.94, 3.65, 1.29, 4.55, 0.31, 0.79, 0.05, 0.52, 0.00]),
    'Бр1356_251220.xy': np.array([1.67, 2.21, 78.72, 2.34, 7.51, 3.22, 2.43, 1.09, 0.51, 0.28, 0.02, 0.00]),
    'Бр1425_241220.xy': np.array([0.90, 1.56, 81.95, 1.43, 6.32, 2.76, 3.40, 0.85, 0.68, 0.16, 0.00, 0.00]),
    'Бр1428_241220.xy': np.array([1.07, 2.47, 63.14, 15.82, 0.80, 14.47, 0.66, 1.58, 0.00, 0.00, 0.00, 0.00]),
    'Бр1566_281220.xy': np.array([0.72, 3.95, 70.88, 5.65, 6.65, 9.87, 0.12, 2.14, 0.00, 0.00, 0.01, 0.00]),
    'В506_140121.xy': np.array([2.11, 2.59, 54.29, 21.35, 2.26, 15.51, 0.06, 1.59, 0.24, 0.00, 0.01, 0.00]),
    'В508_140121.xy': np.array([2.12, 3.48, 48.43, 27.17, 1.62, 15.24, 0.05, 1.63, 0.26, 0.00, 0.01, 0.00]),
    'В549_150121.xy': np.array([1.01, 3.74, 78.07, 0.43, 13.37, 0.44, 1.63, 0.24, 0.17, 0.00, 0.89, 0.00]),
    'В574_150121.xy': np.array([0.52, 1.16, 52.24, 24.86, 1.70, 16.05, 0.03, 3.32, 0.11, 0.00, 0.00, 0.00]),
    'В583_180121.xy': np.array([0.45, 1.25, 52.71, 24.86, 2.10, 16.14, 0.06, 2.38, 0.04, 0.00, 0.01, 0.00]),
    'И103_291220.xy': np.array([1.02, 3.74, 53.23, 30.05, 1.25, 5.35, 4.20, 1.05, 0.00, 0.11, 0.00, 0.00]),
    'И128_120121.xy': np.array([1.16, 3.16, 59.49, 23.44, 1.06, 7.46, 2.84, 1.33, 0.00, 0.06, 0.00, 0.00]),
    'И538_110121.xy': np.array([1.42, 0.97, 72.78, 9.48, 2.78, 10.23, 0.42, 1.19, 0.00, 0.72, 0.00, 0.00]),
    'И644_110121.xy': np.array([1.24, 4.00, 73.64, 6.08, 7.94, 4.33, 1.11, 0.93, 0.00, 0.63, 0.00, 0.00]),
    'И743_211220.xy': np.array([0.39, 1.37, 88.97, 0.92, 2.73, 0.32, 4.03, 0.12, 0.42, 0.28, 0.44, 0.00]),
    'И9085_130121.xy': np.array([0.48, 0.14, 42.95, 44.21, 1.04, 10.34, 0.07, 0.71, 0.06, 0.00, 0.00, 0.00]),
    'К173_210121.xy': np.array([0.68, 2.13, 45.16, 36.51, 1.06, 10.94, 0.07, 2.73, 0.29, 0.43, 0.00, 0.00]),
    'К1898_270121.xy': np.array([1.89, 1.83, 55.79, 17.94, 2.05, 13.11, 0.43, 2.62, 0.14, 4.21, 0.00, 0.00]),
    'К2019_270121.xy': np.array([1.30, 3.43, 67.70, 7.81, 2.77, 10.36, 0.05, 2.19, 0.40, 4.00, 0.00, 0.00]),
    'К2022_280121.xy': np.array([1.18, 1.49, 58.94, 15.68, 2.12, 13.57, 0.08, 2.58, 0.46, 3.91, 0.00, 0.00]),
    'К2035_280121.xy': np.array([0.99, 1.88, 57.56, 16.03, 2.68, 12.59, 0.11, 2.36, 0.43, 5.37, 0.00, 0.00]),
    'К2041_280121.xy': np.array([0.95, 2.44, 49.16, 25.80, 1.25, 13.73, 0.07, 2.76, 0.22, 3.62, 0.00, 0.00]),
    'К2042_290121.xy': np.array([0.87, 0.92, 83.39, 0.71, 0.34, 0.11, 6.30, 0.00, 0.24, 4.62, 2.51, 0.00]),
    'С152_161220.xy': np.array([0.26, 1.65, 33.93, 52.38, 0.73, 9.34, 0.27, 0.99, 0.04, 0.38, 0.04, 0.00]),
    'С207_181220.xy': np.array([0.32, 0.61, 42.08, 44.57, 0.83, 9.56, 0.29, 1.31, 0.00, 0.42, 0.00, 0.00]),
    'С294_211220.xy': np.array([0.77, 2.01, 57.04, 26.08, 2.25, 8.96, 0.34, 1.74, 0.00, 0.83, 0.00, 0.00]),
    'С343_221220.xy': np.array([1.84, 1.80, 51.13, 33.75, 1.11, 7.74, 0.75, 1.31, 0.00, 0.56, 0.00, 0.00]),
    'С367_231220.xy': np.array([0.47, 1.94, 56.72, 26.99, 1.58, 9.51, 0.39, 1.60, 0.00, 0.81, 0.00, 0.00]),
    'С455_171220.xy': np.array([0.20, 2.09, 32.42, 53.03, 0.80, 9.33, 0.46, 1.01, 0.00, 0.28, 0.38, 0.00]),
    'С479_231220.xy': np.array([0.73, 1.32, 53.55, 31.52, 1.41, 9.09, 0.29, 1.45, 0.00, 0.63, 0.00, 0.00]),
    'С490_231220.xy': np.array([1.05, 2.49, 55.01, 30.80, 1.07, 4.45, 3.10, 1.48, 0.01, 0.55, 0.00, 0.00]),
    'дБо2058д_240521.xy': np.array([0.00, 0.74, 10.33, 59.61, 2.16, 5.09, 0.13, 21.81, 0.15, 0.00, 0.00, 0.00]),
    'дБо2082д_280521.xy': np.array([0.62, 0.35, 85.91, 0.00, 0.00, 0.00, 3.22, 0.00, 9.42, 0.06, 0.17, 0.00]),
    'дБр1307д_220421.xy': np.array([0.93, 0.36, 85.71, 0.39, 0.35, 0.03, 9.36, 0.00, 0.24, 0.00, 1.22, 1.43]),
    'дБр1552д_020621.xy': np.array([0.89, 0.00, 85.48, 0.25, 0.34, 0.00, 6.05, 0.03, 0.58, 0.00, 0.37, 6.00]),
    'дК1132д_180521.xy': np.array([2.42, 1.47, 75.98, 0.48, 0.61, 0.17, 9.58, 0.06, 4.70, 0.16, 2.08, 2.28]),
    'дК1585д_170521.xy': np.array([0.43, 1.17, 84.69, 0.00, 0.00, 0.00, 9.71, 0.00, 1.83, 1.65, 0.46, 0.00]),
    'дК180д_290421.xy': np.array([0.19, 1.93, 26.94, 42.17, 4.99, 17.44, 0.06, 5.90, 0.00, 0.40, 0.00, 0.00]),
    'дС132д_210421.xy': np.array([0.29, 2.38, 26.13, 41.49, 2.17, 16.56, 0.10, 10.58, 0.27, 0.03, 0.00, 0.00]),
    'дС321д_120521.xy': np.array([0.42, 1.90, 20.31, 38.45, 3.73, 20.36, 0.10, 14.56, 0.00, 0.02, 0.16, 0.00]),
    'дС323д_170521.xy': np.array([0.17, 1.65, 21.48, 30.25, 7.69, 19.54, 0.03, 18.75, 0.14, 0.07, 0.24, 0.00])
}

# %%
def predict_experimental_data(model, experimental_data, input_size):
    predictions = []
    total_difference = 0.0
    exp_samples_nb = 0

    diff_by_phases = []
    for i in range(num_phases):
        diff_by_phases.append(0)

    for filename, intensities in experimental_data.items():

        interpolated_intensities = torch.tensor(intensities, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)

        model.eval()
        with torch.no_grad():
            predicted_weights = model(interpolated_intensities)

        # Умножаем предсказанные веса на 100
        predicted_weights *= 100
        
        predictions.append((filename, predicted_weights.squeeze().cpu().numpy()))

        # Сравнение с целевыми значениями, если они есть
        if filename in target_values:
            target = target_values[filename]
            curr_phases = np.abs(predicted_weights.squeeze().cpu().numpy() - target)
            total_difference += curr_phases.sum()
            diff_by_phases += curr_phases  # Аккумулируем разности для каждой фазы
            exp_samples_nb += 1

    if exp_samples_nb > 0:
        total_difference = (total_difference / exp_samples_nb) / num_phases
        diff_by_phases /= exp_samples_nb  # Вычисляем средние значения для каждой фазы
    else:
        total_difference = 0.0
        diff_by_phases = np.zeros(num_phases)

    return total_difference, diff_by_phases, exp_samples_nb

def load_batch_inp_file(file_name):
    if os.path.exists(file_name):
        with open(file_name, 'rb') as f:
            while True:
                data = f.read(struct.calcsize(f'{input_size}f'))
                if not data:
                    break
                inp = struct.unpack(f'{input_size}f', data)
                inp_data.append(np.array(inp))


def load_batch_out_file(file_name):
    if os.path.exists(file_name):
        with open(file_name, 'rb') as f:
            while True:
                data = f.read(struct.calcsize(f'{num_phases}f'))
                if not data:
                    break
                out = struct.unpack(f'{num_phases}f', data)
                out_data.append(np.array(out))

# %%
# Загрузка данных
inp_files = glob.glob(f"{difr_dir}batch_inp_{xml_name}_{num_phases}ph_p*.bin")
out_files = glob.glob(f"{difr_dir}batch_out_{xml_name}_{num_phases}ph_p*.bin")

print('inp_files',inp_files)

for file in inp_files:
    load_batch_inp_file(file)

for file in out_files:
    load_batch_out_file(file)

print(f"Размер массива out_data: {len(out_data)}\n")

if len(out_data) < 1:
    print("Внимание - нет данных для обучения !")

lim_len = 500000
if len(inp_data) > lim_len:
    inp_data = inp_data[-lim_len:]
if len(out_data) > lim_len:
    out_data = out_data[-lim_len:]
# Out:
# inp_files ['../nn_data/batch_inp_OSO_12ph_p1_50000.bin', '../nn_data/batch_inp_OSO_12ph_p3_50000.bin', '../nn_data/batch_inp_OSO_12ph_p2_50000.bin', '../nn_data/batch_inp_OSO_12ph_p4_50000.bin']
# Размер массива out_data: 200000

# %%
out_data[0]
# Out:
# array([4.06117998e-02, 1.57209322e-01, 1.03501059e-01, 9.29933041e-02,
#        7.91798532e-02, 8.51616561e-02, 1.94989756e-01, 1.89948182e-08,
#        1.64288893e-01, 3.76141361e-06, 6.67450503e-02, 1.53155345e-02])

# %%
# Определение класса для датасета
class CandleDataset(Dataset):
    def __init__(self, inputs, outputs):
        self.inputs = inputs
        self.outputs = outputs

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        # Возвращаем данные без изменения формы
        return torch.tensor(self.inputs[idx], dtype=torch.float32).unsqueeze(0), torch.tensor(self.outputs[idx], dtype=torch.float32)

# %%
# Разделение данных на тренировочную и тестовую выборки
indices = list(range(len(inp_data)))
indices = np.array(indices)
np.random.shuffle(indices)
#test_indices = indices[::11]
#train_indices = [i for i in indices if i not in test_indices]
test_indices = indices[:int(0.1*len(indices))]
train_indices = indices[int(0.1*len(indices)):]

train_inputs = [inp_data[i] for i in train_indices]
train_outputs = [out_data[i] for i in train_indices]
test_inputs = [inp_data[i] for i in test_indices]
test_outputs = [out_data[i] for i in test_indices]

train_dataset = CandleDataset(train_inputs, train_outputs)
test_dataset = CandleDataset(test_inputs, test_outputs)

# %%
# Загружаем фазы из файлов .phase
sample_info, PHASES_INFO = parse_xml('XRD_Data/OSO_Topas_2022_stidy.tshx')
num_phases = len(PHASES_INFO)

# Загружаем экспериментальные данные
experimental_data = load_experimental_data(experiment_folder)
#print(f'Loaded {len(experimental_data)} experimental diffraction patterns.')
# Out:
# {'Name': 'alpha-Al2O3', 'SpaceGroup': 'R-3cH', 'CellPar': {'a': {'min': 4.755, 'max': 4.77, 'value': 4.7698}, 'b': {'min': None, 'max': None, 'value': 4.7698}, 'c': {'min': 13.0, 'max': 13.05, 'value': 13.0243}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 120.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 45.0, 'max': 150.0, 'value': 100.0}, 'Strain': {'min': 0.01, 'max': 0.35, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.35231}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O2-', 'X': {'min': None, 'max': None, 'value': 0.6936}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'gamma-Al2O3', 'SpaceGroup': 'Fd-3mZ', 'CellPar': {'a': {'min': 7.9, 'max': 7.937, 'value': 7.911}, 'b': {'min': None, 'max': None, 'value': 7.911}, 'c': {'min': None, 'max': None, 'value': 7.911}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 45.0, 'max': 300.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.35, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.2547}, 'Y': {'min': None, 'max': None, 'value': 0.2547}, 'Z': {'min': None, 'max': None, 'value': 0.2547}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 0.58}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.125}, 'Y': {'min': None, 'max': None, 'value': 0.125}, 'Z': {'min': None, 'max': None, 'value': 0.125}, 'Occ': {'min': None, 'max': None, 'value': 0.84}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0272}, 'Y': {'min': None, 'max': None, 'value': 0.0272}, 'Z': {'min': None, 'max': None, 'value': 0.0272}, 'Occ': {'min': None, 'max': None, 'value': 0.17}}], 'RIR': -1}
#
# {'Name': 'Cryolite', 'SpaceGroup': 'P121/c1', 'CellPar': {'a': {'min': 5.35095, 'max': 5.45905, 'value': 5.405}, 'b': {'min': 5.5242, 'max': 5.6358, 'value': 5.58}, 'c': {'min': 9.351936, 'max': 9.540864000000001, 'value': 9.4464}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': 123.51933, 'max': 126.01467, 'value': 124.767}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 70.0, 'max': 500.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [{'name': '1 1 1', 'min': 0.95, 'max': 1.1, 'value': 1.0}], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': 0.2638, 'max': 0.27, 'value': 0.2656}, 'Y': {'min': 0.448, 'max': 0.456, 'value': 0.448}, 'Z': {'min': 0.2501, 'max': 0.257, 'value': 0.2518}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.114, 'max': 0.12, 'value': 0.1152}, 'Y': {'min': 0.042, 'max': 0.05, 'value': 0.0436}, 'Z': {'min': 0.214, 'max': 0.223, 'value': 0.2182}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.22, 'max': 0.229, 'value': 0.2285}, 'Y': {'min': 0.73, 'max': 0.738, 'value': 0.7285}, 'Z': {'min': 0.057, 'max': 0.064, 'value': 0.0638}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.307, 'max': 0.319, 'value': 0.3215}, 'Y': {'min': 0.166, 'max': 0.18, 'value': 0.1765}, 'Z': {'min': 0.037, 'max': 0.048, 'value': 0.047}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Chiolite', 'SpaceGroup': 'P4/mnc', 'CellPar': {'a': {'min': 7.02, 'max': 7.06, 'value': 7.0138}, 'b': {'min': None, 'max': None, 'value': 7.0138}, 'c': {'min': 10.36, 'max': 10.403, 'value': 10.402}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 80.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [{'name': '0 0 1', 'min': 0.93, 'max': 1.0, 'value': 1.0}], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.277}, 'Y': {'min': None, 'max': None, 'value': 0.777}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': 0.17, 'max': 0.177, 'value': 0.1711}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.058, 'max': 0.064, 'value': 0.0642}, 'Y': {'min': 0.245, 'max': 0.252, 'value': 0.2477}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': 0.176, 'max': 0.182, 'value': 0.1794}, 'Y': {'min': 0.532, 'max': 0.54, 'value': 0.5364}, 'Z': {'min': 0.118, 'max': 0.121, 'value': 0.1198}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'NaCa(AlF6)', 'SpaceGroup': 'P121/c1', 'CellPar': {'a': {'min': 8.715, 'max': 8.795, 'value': 8.7423}, 'b': {'min': 5.145, 'max': 5.21, 'value': 5.1927}, 'c': {'min': 20.3, 'max': 20.46, 'value': 20.35139}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': 90.85, 'max': 91.5, 'value': 91.499}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 30.0, 'max': 150.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Na1+', 'X': {'min': 0.9668, 'max': 0.9868, 'value': 0.9768}, 'Y': {'min': 0.2443, 'max': 0.2643, 'value': 0.2543}, 'Z': {'min': 0.1681, 'max': 0.1881, 'value': 0.1781}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': 0.9581, 'max': 0.9781, 'value': 0.9681}, 'Y': {'min': 0.2634, 'max': 0.2834, 'value': 0.2734}, 'Z': {'min': 0.4313, 'max': 0.4513, 'value': 0.4413}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Ca2+', 'X': {'min': 0.6303, 'max': 0.6503, 'value': 0.6403}, 'Y': {'min': 0.2275, 'max': 0.2475, 'value': 0.2375}, 'Z': {'min': 0.3008, 'max': 0.3208, 'value': 0.3108}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Ca2+', 'X': {'min': 0.6257, 'max': 0.6457, 'value': 0.6357}, 'Y': {'min': 0.3119, 'max': 0.3319, 'value': 0.3219}, 'Z': {'min': 0.5523, 'max': 0.5723, 'value': 0.5623}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': 0.2488, 'max': 0.2688, 'value': 0.2588}, 'Y': {'min': 0.2461, 'max': 0.2661, 'value': 0.2561}, 'Z': {'min': 0.3089, 'max': 0.3289, 'value': 0.3189}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': 0.2428, 'max': 0.2628, 'value': 0.2528}, 'Y': {'min': 0.1803, 'max': 0.2003, 'value': 0.1903}, 'Z': {'min': 0.5588, 'max': 0.5788, 'value': 0.5688}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.629}, 'Y': {'min': None, 'max': None, 'value': 0.6261}, 'Z': {'min': None, 'max': None, 'value': 0.4777}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.5863}, 'Y': {'min': None, 'max': None, 'value': 0.6137}, 'Z': {'min': None, 'max': None, 'value': 0.6397}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.7338}, 'Y': {'min': None, 'max': None, 'value': 0.0827}, 'Z': {'min': None, 'max': None, 'value': 0.4824}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.3809}, 'Y': {'min': None, 'max': None, 'value': 0.1003}, 'Z': {'min': None, 'max': None, 'value': 0.2626}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1625}, 'Y': {'min': None, 'max': None, 'value': -0.0247}, 'Z': {'min': None, 'max': None, 'value': 0.6328}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1643}, 'Y': {'min': None, 'max': None, 'value': 0.4377}, 'Z': {'min': None, 'max': None, 'value': 0.3814}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.2357}, 'Y': {'min': None, 'max': None, 'value': 0.4669}, 'Z': {'min': None, 'max': None, 'value': 0.6229}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.5786}, 'Y': {'min': None, 'max': None, 'value': 0.5944}, 'Z': {'min': None, 'max': None, 'value': 0.8821}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.9132}, 'Y': {'min': None, 'max': None, 'value': 0.6404}, 'Z': {'min': None, 'max': None, 'value': 0.226}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.7403}, 'Y': {'min': None, 'max': None, 'value': 0.0217}, 'Z': {'min': None, 'max': None,  ...
#
# {'Name': 'Na2Ca3Al2F14', 'SpaceGroup': 'I213', 'CellPar': {'a': {'min': 10.242, 'max': 10.254, 'value': 10.257}, 'b': {'min': None, 'max': None, 'value': 10.257}, 'c': {'min': None, 'max': None, 'value': 10.257}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 65.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [{'name': '1 1 1', 'min': 0.72, 'max': 1.0, 'value': 1.0}], 'Atoms': [{'Type': 'Ca2+', 'X': {'min': None, 'max': None, 'value': 0.4667}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.2482}, 'Y': {'min': None, 'max': None, 'value': 0.2482}, 'Z': {'min': None, 'max': None, 'value': 0.2482}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.0847}, 'Y': {'min': None, 'max': None, 'value': 0.0847}, 'Z': {'min': None, 'max': None, 'value': 0.0847}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1387}, 'Y': {'min': None, 'max': None, 'value': 0.3062}, 'Z': {'min': None, 'max': None, 'value': 0.1206}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.364}, 'Y': {'min': None, 'max': None, 'value': 0.3627}, 'Z': {'min': None, 'max': None, 'value': 0.1873}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.4614}, 'Y': {'min': None, 'max': None, 'value': 0.4614}, 'Z': {'min': None, 'max': None, 'value': 0.4614}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Fluorite', 'SpaceGroup': 'Fm-3m', 'CellPar': {'a': {'min': 5.463, 'max': 5.469, 'value': 5.462}, 'b': {'min': None, 'max': None, 'value': 5.462}, 'c': {'min': None, 'max': None, 'value': 5.462}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 60.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.38, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Ca2+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Weberite', 'SpaceGroup': 'Imma', 'CellPar': {'a': {'min': 7.05, 'max': 7.072, 'value': 7.05}, 'b': {'min': 9.98, 'max': 10.02, 'value': 9.979}, 'c': {'min': 7.29, 'max': 7.31, 'value': 7.297}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 150.0, 'max': 500.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.35, 'value': 0.1}}, 'MDtexDir': [{'name': '0 1 1', 'min': 0.9, 'max': 1.0, 'value': 1.0}], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.75}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Mg2+', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al3+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.1362}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.4144}, 'Z': {'min': None, 'max': None, 'value': 0.7213}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.1845}, 'Y': {'min': None, 'max': None, 'value': 0.3874}, 'Z': {'min': None, 'max': None, 'value': 0.4304}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Neighborite', 'SpaceGroup': 'Pnma', 'CellPar': {'a': {'min': 5.488, 'max': 5.5, 'value': 5.4928}, 'b': {'min': 7.665, 'max': 7.69, 'value': 7.71}, 'c': {'min': 5.36, 'max': 5.387, 'value': 5.37645}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 100.0, 'max': 350.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.3, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Na1+', 'X': {'min': None, 'max': None, 'value': 0.03975}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.488}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Mg2+', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.4547}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.58705}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F1-', 'X': {'min': None, 'max': None, 'value': 0.29105}, 'Y': {'min': None, 'max': None, 'value': 0.04897}, 'Z': {'min': None, 'max': None, 'value': 0.21265}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'Elpasolite', 'SpaceGroup': 'Fm-3m', 'CellPar': {'a': {'min': 8.095, 'max': 8.112, 'value': 8.093}, 'b': {'min': None, 'max': None, 'value': 8.093}, 'c': {'min': None, 'max': None, 'value': 8.093}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 60.0, 'max': 200.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.4, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'K', 'X': {'min': None, 'max': None, 'value': 0.25}, 'Y': {'min': None, 'max': None, 'value': 0.25}, 'Z': {'min': None, 'max': None, 'value': 0.25}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Na', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F', 'X': {'min': None, 'max': None, 'value': 0.2225}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}
#
# {'Name': 'K1.58Al11O17', 'SpaceGroup': 'R-3mH', 'CellPar': {'a': {'min': 5.585, 'max': 5.62, 'value': 5.63}, 'b': {'min': None, 'max': None, 'value': 5.63}, 'c': {'min': 33.89, 'max': 34.17, 'value': 34.01}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 120.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 45.0, 'max': 150.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.37, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.16712}, 'Y': {'min': None, 'max': None, 'value': -0.16712}, 'Z': {'min': None, 'max': None, 'value': 0.9298}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.34988}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.44935}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'Al', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.16419}, 'Y': {'min': None, 'max': None, 'value': -0.16419}, 'Z': {'min': None, 'max': None, 'value': 0.23615}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.15396}, 'Y': {'min': None, 'max': None, 'value': -0.15396}, 'Z': {'min': None, 'max': None, 'value': 0.03384}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.09512}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.2952}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'O', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'K', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': -0.17086}, 'Occ': {'min': None, 'max': None, 'value': 0.31}}, {'Type': 'K', 'X': {'min': None, 'max': None, 'value': 0.08717}, 'Y': {'min': None, 'max': None, 'value': -0.08717}, 'Z': {'min': None, 'max': None, 'value': -0.16784}, 'Occ': {'min': None, 'max': None, 'value': 0.16}}], 'RIR': -1}
#
# {'Name': 'Villiaumite', 'SpaceGroup': 'Fm-3m', 'CellPar': {'a': {'min': 4.633, 'max': 4.64, 'value': 4.634}, 'b': {'min': None, 'max': None, 'value': 4.634}, 'c': {'min': None, 'max': None, 'value': 4.634}, 'alpha': {'min': None, 'max': None, 'value': 90.0}, 'beta': {'min': None, 'max': None, 'value': 90.0}, 'gamma': {'min': None, 'max': None, 'value': 90.0}}, 'ReflectionProfileScherrer': {'CS': {'min': 90.0, 'max': 170.0, 'value': 100.0}, 'Strain': {'min': 0.001, 'max': 0.38, 'value': 0.1}}, 'MDtexDir': [], 'Atoms': [{'Type': 'Na', 'X': {'min': None, 'max': None, 'value': 0.0}, 'Y': {'min': None, 'max': None, 'value': 0.0}, 'Z': {'min': None, 'max': None, 'value': 0.0}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}, {'Type': 'F', 'X': {'min': None, 'max': None, 'value': 0.5}, 'Y': {'min': None, 'max': None, 'value': 0.5}, 'Z': {'min': None, 'max': None, 'value': 0.5}, 'Occ': {'min': None, 'max': None, 'value': 1.0}}], 'RIR': -1}

# %%
#small
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()
        
        # Сверточные слои: уменьшены более агрессивно (в ~2.5 раза)
        self.conv_layers = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=32, kernel_size=7, stride=1, padding=3),  # Было 64
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=32, out_channels=64, kernel_size=5, stride=1, padding=2),  # Было 128
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1), # Было 256
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2)
        )
        
        reduced_size = input_size // 8
        
        # Трансформер: один слой + уменьшенная размерность
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=500, nhead=10, dim_feedforward=256, dropout=0.1, batch_first=True), # d_model и dim_feedforward уменьшены
            num_layers=1  # Один слой
        )
        
        # Полносвязные слои: значительно уменьшены
        self.fc_layers = nn.Sequential(
            nn.Linear(128 * reduced_size, 256),  # Было 1024
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(256, num_phases)
        )
    
    def forward(self, x):
        x = self.conv_layers(x)
        #x = x.permute(0, 2, 1)  # Критичный шаг сохранён
        x = self.transformer(x)
        x = x.reshape(x.size(0), -1)
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)
        return x

# %%
#big
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super(DiffractionNet, self).__init__()
        
        # Сверточные слои для извлечения локальных признаков
        self.conv_layers = nn.Sequential(
            nn.Conv1d(in_channels=1, out_channels=64, kernel_size=7, stride=1, padding=3),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=64, out_channels=128, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2),
            nn.Conv1d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2)
        )
        
        # Размер выхода после сверточных слоев
        reduced_size = input_size // 8  # Поскольку мы делаем три пулинга с шагом 2
        
        # Трансформер для глобального понимания
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=256, nhead=8, dim_feedforward=512, dropout=0.1, batch_first=True),
            num_layers=2
        )
        
        # Полносвязные слои для получения итогового предсказания
        self.fc_layers = nn.Sequential(
            nn.Linear(256 * reduced_size, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(1024, num_phases)
        )
    
    def forward(self, x):
        x = self.conv_layers(x)
        x = x.permute(0, 2, 1)  # Изменяем форму для трансформера (batch_size, sequence_length, features)
        x = self.transformer(x)
        x = x.reshape(x.size(0), -1)  # Флэттенинг с использованием reshape
        x = self.fc_layers(x)
        x = F.softmax(x, dim=1)  # Нормированные доли
        return x

# %%
#small
class DiffractionNet(nn.Module):
    def __init__(self, input_size, num_phases):
        super().__init__()        
        
        # Полносвязные слои: значительно уменьшены
        self.fc_layers = nn.Sequential(
            nn.Linear(4001, 2048),  # Было 1024
            #nn.BatchNorm1d(1024),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(2048,1024),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(1024,256),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(256, num_phases)
        )
    
    def forward(self, x):
        #x = self.conv_layers(x)
        #x = x.permute(0, 2, 1)  # Критичный шаг сохранён
        #x = self.transformer(x)
        #x = x.reshape(x.size(0), -1)
        x = x.view(-1,4001)
        #print(x.shape)
        x = self.fc_layers(x)
        #print(x.shape)
        x = F.softmax(x, dim=1)
        #print(x.shape)
        return x

# %%
# Создание экземпляра модели
model = DiffractionNet(input_size, num_phases).to(device)

# %%
print(model)
pytorch_total_params = sum(p.numel() for p in model.parameters())
print(pytorch_total_params)
# Out:
# DiffractionNet(
#   (fc_layers): Sequential(
#     (0): Linear(in_features=4001, out_features=2048, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=2048, out_features=1024, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.1, inplace=False)
#     (6): Linear(in_features=1024, out_features=256, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.1, inplace=False)
#     (9): Linear(in_features=256, out_features=12, bias=True)
#   )
# )
# 10559756

# %%
# Проверяем, существует ли файл с весами, и загружаем его, если существует
#if os.path.exists(wghts_fname):
#    model.load_state_dict(torch.load(wghts_fname, map_location=device, weights_only=True))
#    print(f"Модель загружена из файла {wghts_fname}")
#else:
#    print(f'No weights file found. Starting training from scratch.')

# %%
print('Start training')
learn_rate = 1E-5
# Определяем критерий потерь и оптимизатор
criterion = nn.MSELoss(reduction='none')  # Используем reduction='none' для получения ошибки для каждого элемента в батче
optimizer = optim.AdamW(model.parameters(), lr=learn_rate, weight_decay=learn_rate*0.1)
# Out:
# Start training

# %%
criterion
# Out:
# MSELoss()

# %%
def find_index_of_max(float_array):
    max_index = np.argmax(float_array)
    return max_index

# Определяем категории для балансировки данных
def get_category(out):
    min_val = np.min(out)
    max_val = np.max(out)
    delta = min_val / max_val if max_val > 0 else 0.0
    if delta < 0.001:
        return 0
    elif 0.001 <= delta < 0.01:
        return 1
    elif 0.01 <= delta < 0.1:
        return 2
    else:
        return 3

# %%
# Определяем метки классов для балансировки
train_labels = np.array([find_index_of_max(out) for out in train_outputs])
print('train_labels',train_labels)
class_counts = np.bincount(train_labels.astype(np.int64))
print(f'Category class_counts = {class_counts}')
# Добавляем сглаживание для предотвращения деления на ноль
#smoothing_factor = 1e-3
#class_weights = 1. / (class_counts + smoothing_factor)
class_weights = 1. / class_counts
sample_weights = class_weights[train_labels]
sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(sample_weights), replacement=True)
# Out:
# train_labels [ 6  8  9 ...  2  5 10]
# Category class_counts = [15052 14852 14950 14965 14922 14829 14919 15080 15076 15039 15249 15067]

# %%
# Загрузка данных
train_dataloader = DataLoader(train_dataset, batch_size=128, sampler=sampler)
test_dataloader = DataLoader(test_dataset, batch_size=128, shuffle=False)

n_train_iter = len(train_dataloader)
n_test_iter = len(test_dataloader)
print(f'train_iter: {n_train_iter}, test_iter: {n_test_iter}')
# Out:
# train_iter: 1407, test_iter: 157

# %%
# Инициализация списков для хранения значений потерь
train_losses = []
test_losses = []

# Инициализация списков для хранения значений потерь для каждого параметра
train_param_losses = [[] for _ in range(num_phases)]
test_param_losses = [[] for _ in range(num_phases)]

# Создание и запись заголовков в CSV-файл
with open(csv_res_fname, mode='w', newline='') as file:
    writer = csv.writer(file, delimiter=';')
    header = ['Time', 'Epoch', 'Train Loss', 'Test Loss', 'Exp_Diff'] + \
             [f'Train_{i + 1}' for i in range(num_phases)] + \
             [f'Test_{i + 1}' for i in range(num_phases)] + \
             [f'Exp_{i + 1}' for i in range(num_phases)]
    writer.writerow(header)

num_epochs = 300

total_exp_diff = 0.0
ph_exp_diff = []

pre_fitness = 1E6

# %%
train_all_losses = []
test_all_losses = []
train_batch_losses = []
test_batch_losses = []

# %%
start_time = time.time()  # Запоминаем время начала обучения

for epoch in range(num_epochs):
    model.train()
    running_train_loss = 0.0
    running_train_param_losses = [0.0 for _ in range(num_phases)]
    iters = 0
    #train_batch_losses = []
    for inputs, outputs in train_dataloader:
        inputs, outputs = inputs.to(device), outputs.to(device)
        optimizer.zero_grad()
        predictions = model(inputs)        
        loss = criterion(predictions, outputs)
        loss.mean().backward()  # Средняя ошибка по всем элементам в батче
        # Градиенты масштабируются, если их общая норма > 1.0
        #torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        #running_train_loss += loss.mean().item()
        #for i in range(num_phases):
        #    running_train_param_losses[i] += loss[:, i].mean().item()
        iters += 1
        #train_batch_losses.append(loss.mean(axis=1).cpu().detach().numpy())

        if iters % 500 == 0:
            print(f"Iteration {iters}")
    #train_all_losses.append(np.array(train_batch_losses[:-1]))

    #train_loss = running_train_loss / n_train_iter
    #train_losses.append(train_loss)
    #for i in range(num_phases):
    #    train_param_losses[i].append(running_train_param_losses[i] / n_train_iter)

    if n_test_iter > 0:
        
        train_batch_losses = []
        model.eval()
        running_train_param_losses = [0.0 for _ in range(num_phases)]
        with torch.no_grad():
            for inputs, outputs in train_dataloader:
                inputs, outputs = inputs.to(device), outputs.to(device)
                predictions = model(inputs)
                loss = criterion(predictions, outputs)
                running_train_loss += loss.mean().item()
                for i in range(num_phases):
                    running_train_param_losses[i] += loss[:, i].mean().item()
                train_batch_losses.append(loss.mean(axis=1).cpu().detach().numpy())
        train_loss = running_train_loss / n_train_iter
        train_losses.append(train_loss)
        for i in range(num_phases):
            train_param_losses[i].append(running_train_param_losses[i] / n_train_iter)
        train_all_losses.append(np.array(train_batch_losses[:-1]))
        

        
        test_batch_losses = []
        model.eval()
        running_test_loss = 0.0
        running_test_param_losses = [0.0 for _ in range(num_phases)]
        with torch.no_grad():
            for inputs, outputs in test_dataloader:
                inputs, outputs = inputs.to(device), outputs.to(device)
                predictions = model(inputs)
                loss = criterion(predictions, outputs)
                running_test_loss += loss.mean().item()
                for i in range(num_phases):
                    running_test_param_losses[i] += loss[:, i].mean().item()
                test_batch_losses.append(loss.mean(axis=1).cpu().detach().numpy())
        test_loss = running_test_loss / n_test_iter
        test_losses.append(test_loss)
        for i in range(num_phases):
            test_param_losses[i].append(running_test_param_losses[i] / n_test_iter)
        test_all_losses.append(np.array(test_batch_losses[:-1]))

        

        total_exp_diff, ph_exp_diff, exp_samples_nb = predict_experimental_data(model, experimental_data, input_size)

        # Вывод средней разницы, если были найдены соответствия
        if exp_samples_nb > 0:
            if total_exp_diff < pre_fitness:
                torch.save(model.state_dict(), wghts_fname)
                print(f'*** Weights are saved to {wghts_fname} after epoch {epoch + 1}')
                pre_fitness = total_exp_diff
            print(f' >>> Средняя разница между предсказанными и OSO: {total_exp_diff:.3f}')
        else:
            total_exp_diff = 0.0
            print('Нет соответствий для подсчета разницы.')

    else:
        test_loss = 0.0
        test_losses.append(test_loss)

    print(f'Epoch [{epoch + 1}/{num_epochs}], learn_rate: {learn_rate}, Train Loss: {100 * np.sqrt(train_loss):.5f}, Test Loss: {100 * np.sqrt(test_loss):.5f}')

    # Вывод ошибок для каждого параметра
    for i in range(num_phases):
        print(f'Фаза {i + 1}: Train: {100 * np.sqrt(train_param_losses[i][-1]):.5f}, Test: {100 * np.sqrt(test_param_losses[i][-1]):.5f}')

    # Форматирование прошедшего времени в "hh:mm:ss"
    elapsed_time = time.time() - start_time  # Вычисляем прошедшее время
    hours, rem = divmod(elapsed_time, 3600)
    minutes, seconds = divmod(rem, 60)
    formatted_time = f"{int(hours):02d}:{int(minutes):02d}:{int(seconds):02d}"

    # Запись данных в CSV-файл
    with open(csv_res_fname, mode='a', newline='') as file:
        writer = csv.writer(file, delimiter=';')
        row = [formatted_time, epoch + 1, 100 * np.sqrt(train_loss), 100 * np.sqrt(test_loss), total_exp_diff] + \
              [100 * np.sqrt(train_param_losses[i][-1]) for i in range(num_phases)] + \
              [100 * np.sqrt(test_param_losses[i][-1]) for i in range(num_phases)] + \
              ph_exp_diff.tolist()
        writer.writerow(row)

    print(f'Прошло времени: {formatted_time}\n')
# Out:
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 1
#  >>> Средняя разница между предсказанными и OSO: 3.076
# Epoch [1/300], learn_rate: 1e-05, Train Loss: 4.81054, Test Loss: 4.79354
# Фаза 1: Train: 5.38315, Test: 5.37647
# Фаза 2: Train: 5.49714, Test: 5.49035
# Фаза 3: Train: 5.32121, Test: 5.23554
# Фаза 4: Train: 4.74051, Test: 4.65753
# Фаза 5: Train: 5.53552, Test: 5.59938
# Фаза 6: Train: 4.78873, Test: 4.73232
# Фаза 7: Train: 3.57370, Test: 3.55641
# Фаза 8: Train: 4.62925, Test: 4.67078
# Фаза 9: Train: 4.50062, Test: 4.51997
# Фаза 10: Train: 3.79912, Test: 3.75419
# Фаза 11: Train: 5.70616, Test: 5.68532
# Фаза 12: Train: 3.56177, Test: 3.53886
# Прошло времени: 00:00:04
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 2
#  >>> Средняя разница между предсказанными и OSO: 3.055
# Epoch [2/300], learn_rate: 1e-05, Train Loss: 4.04839, Test Loss: 4.05223
# Фаза 1: Train: 4.34345, Test: 4.34839
# Фаза 2: Train: 4.57325, Test: 4.57347
# Фаза 3: Train: 4.50621, Test: 4.42440
# Фаза 4: Train: 4.07775, Test: 4.03419
# Фаза 5: Train: 4.65027, Test: 4.74423
# Фаза 6: Train: 4.16589, Test: 4.18316
# Фаза 7: Train: 2.74162, Test: 2.73966
# Фаза 8: Train: 4.08432, Test: 4.13991
# Фаза 9: Train: 3.94434, Test: 3.96642
# Фаза 10: Train: 3.25517, Test: 3.22949
# Фаза 11: Train: 4.69965, Test: 4.68481
# Фаза 12: Train: 2.92255, Test: 2.93443
# Прошло времени: 00:00:09
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 3
#  >>> Средняя разница между предсказанными и OSO: 2.585
# Epoch [3/300], learn_rate: 1e-05, Train Loss: 3.43320, Test Loss: 3.42851
# Фаза 1: Train: 3.52013, Test: 3.50600
# Фаза 2: Train: 3.71378, Test: 3.70820
# Фаза 3: Train: 3.79305, Test: 3.74337
# Фаза 4: Train: 3.60500, Test: 3.54391
# Фаза 5: Train: 3.71352, Test: 3.77259
# Фаза 6: Train: 3.56617, Test: 3.56438
# Фаза 7: Train: 2.38634, Test: 2.38713
# Фаза 8: Train: 3.56452, Test: 3.59841
# Фаза 9: Train: 3.49476, Test: 3.50855
# Фаза 10: Train: 3.01223, Test: 2.98267
# Фаза 11: Train: 3.83861, Test: 3.81627
# Фаза 12: Train: 2.63542, Test: 2.66213
# Прошло времени: 00:00:14
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 4
#  >>> Средняя разница между предсказанными и OSO: 2.091
# Epoch [4/300], learn_rate: 1e-05, Train Loss: 2.76341, Test Loss: 2.75685
# Фаза 1: Train: 2.74660, Test: 2.72960
# Фаза 2: Train: 2.89545, Test: 2.86128
# Фаза 3: Train: 2.99818, Test: 2.97102
# Фаза 4: Train: 2.92875, Test: 2.90643
# Фаза 5: Train: 2.82775, Test: 2.86719
# Фаза 6: Train: 2.84221, Test: 2.83304
# Фаза 7: Train: 2.15221, Test: 2.14245
# Фаза 8: Train: 2.81214, Test: 2.83013
# Фаза 9: Train: 2.88157, Test: 2.89518
# Фаза 10: Train: 2.63137, Test: 2.60785
# Фаза 11: Train: 2.94539, Test: 2.92511
# Фаза 12: Train: 2.37182, Test: 2.38844
# Прошло времени: 00:00:18
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 5
#  >>> Средняя разница между предсказанными и OSO: 1.678
# Epoch [5/300], learn_rate: 1e-05, Train Loss: 2.22352, Test Loss: 2.21734
# Фаза 1: Train: 2.23499, Test: 2.22673
# Фаза 2: Train: 2.35917, Test: 2.32752
# Фаза 3: Train: 2.36977, Test: 2.34008
# Фаза 4: Train: 2.32503, Test: 2.31463
# Фаза 5: Train: 2.29248, Test: 2.32955
# Фаза 6: Train: 2.18290, Test: 2.17950
# Фаза 7: Train: 1.77945, Test: 1.77431
# Фаза 8: Train: 2.24269, Test: 2.25459
# Фаза 9: Train: 2.39035, Test: 2.38913
# Фаза 10: Train: 2.05653, Test: 2.05448
# Фаза 11: Train: 2.37310, Test: 2.33593
# Фаза 12: Train: 1.98867, Test: 1.99904
# Прошло времени: 00:00:23
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 6
#  >>> Средняя разница между предсказанными и OSO: 1.466
# Epoch [6/300], learn_rate: 1e-05, Train Loss: 1.90650, Test Loss: 1.89750
# Фаза 1: Train: 1.88046, Test: 1.87949
# Фаза 2: Train: 2.04772, Test: 2.01373
# Фаза 3: Train: 1.97614, Test: 1.95299
# Фаза 4: Train: 1.95495, Test: 1.96128
# Фаза 5: Train: 2.00372, Test: 2.02950
# Фаза 6: Train: 1.87761, Test: 1.86799
# Фаза 7: Train: 1.53938, Test: 1.51353
# Фаза 8: Train: 1.94156, Test: 1.93204
# Фаза 9: Train: 2.08069, Test: 2.08207
# Фаза 10: Train: 1.91291, Test: 1.91100
# Фаза 11: Train: 1.90759, Test: 1.87665
# Фаза 12: Train: 1.68929, Test: 1.67848
# Прошло времени: 00:00:27
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 7
#  >>> Средняя разница между предсказанными и OSO: 1.319
# Epoch [7/300], learn_rate: 1e-05, Train Loss: 1.67555, Test Loss: 1.66938
# Фаза 1: Train: 1.66383, Test: 1.67259
# Фаза 2: Train: 1.77164, Test: 1.75463
# Фаза 3: Train: 1.71530, Test: 1.70653
# Фаза 4: Train: 1.73147, Test: 1.73346
# Фаза 5: Train: 1.73495, Test: 1.74905
# Фаза 6: Train: 1.64806, Test: 1.64573
# Фаза 7: Train: 1.47560, Test: 1.44954
# Фаза 8: Train: 1.66921, Test: 1.66045
# Фаза 9: Train: 1.74855, Test: 1.74119
# Фаза 10: Train: 1.65998, Test: 1.67985
# Фаза 11: Train: 1.75795, Test: 1.72717
# Фаза 12: Train: 1.49968, Test: 1.47844
# Прошло времени: 00:00:32
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 8
#  >>> Средняя разница между предсказанными и OSO: 1.240
# Epoch [8/300], learn_rate: 1e-05, Train Loss: 1.52248, Test Loss: 1.51523
# Фаза 1: Train: 1.58976, Test: 1.59741
# Фаза 2: Train: 1.68996, Test: 1.66690
# Фаза 3: Train: 1.53934, Test: 1.52454
# Фаза 4: Train: 1.51150, Test: 1.53064
# Фаза 5: Train: 1.57624, Test: 1.58005
# Фаза 6: Train: 1.54466, Test: 1.53588
# Фаза 7: Train: 1.31843, Test: 1.28716
# Фаза 8: Train: 1.50747, Test: 1.50980
# Фаза 9: Train: 1.57379, Test: 1.56473
# Фаза 10: Train: 1.40619, Test: 1.42185
# Фаза 11: Train: 1.57342, Test: 1.53962
# Фаза 12: Train: 1.40247, Test: 1.38616
# Прошло времени: 00:00:37
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 9
#  >>> Средняя разница между предсказанными и OSO: 1.065
# Epoch [9/300], learn_rate: 1e-05, Train Loss: 1.39717, Test Loss: 1.39471
# Фаза 1: Train: 1.47959, Test: 1.48491
# Фаза 2: Train: 1.45327, Test: 1.44485
# Фаза 3: Train: 1.49327, Test: 1.48043
# Фаза 4: Train: 1.39162, Test: 1.40209
# Фаза 5: Train: 1.45549, Test: 1.46726
# Фаза 6: Train: 1.38217, Test: 1.38503
# Фаза 7: Train: 1.24178, Test: 1.22553
# Фаза 8: Train: 1.35298, Test: 1.35104
# Фаза 9: Train: 1.43751, Test: 1.43187
# Фаза 10: Train: 1.32777, Test: 1.34513
# Фаза 11: Train: 1.46676, Test: 1.44200
# Фаза 12: Train: 1.25508, Test: 1.24711
# Прошло времени: 00:00:41
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 1.096
# Epoch [10/300], learn_rate: 1e-05, Train Loss: 1.30100, Test Loss: 1.30002
# Фаза 1: Train: 1.27214, Test: 1.27459
# Фаза 2: Train: 1.40630, Test: 1.39288
# Фаза 3: Train: 1.33556, Test: 1.32911
# Фаза 4: Train: 1.30702, Test: 1.31956
# Фаза 5: Train: 1.33085, Test: 1.33692
# Фаза 6: Train: 1.29029, Test: 1.29548
# Фаза 7: Train: 1.21679, Test: 1.20147
# Фаза 8: Train: 1.29348, Test: 1.29714
# Фаза 9: Train: 1.35650, Test: 1.35565
# Фаза 10: Train: 1.20507, Test: 1.23379
# Фаза 11: Train: 1.38744, Test: 1.36441
# Фаза 12: Train: 1.19011, Test: 1.18098
# Прошло времени: 00:00:46
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 11
#  >>> Средняя разница между предсказанными и OSO: 1.012
# Epoch [11/300], learn_rate: 1e-05, Train Loss: 1.21958, Test Loss: 1.21786
# Фаза 1: Train: 1.17740, Test: 1.18173
# Фаза 2: Train: 1.28653, Test: 1.27358
# Фаза 3: Train: 1.25830, Test: 1.24891
# Фаза 4: Train: 1.24820, Test: 1.25593
# Фаза 5: Train: 1.26230, Test: 1.28216
# Фаза 6: Train: 1.20924, Test: 1.20860
# Фаза 7: Train: 1.16488, Test: 1.14364
# Фаза 8: Train: 1.22309, Test: 1.22506
# Фаза 9: Train: 1.29210, Test: 1.28897
# Фаза 10: Train: 1.11309, Test: 1.13231
# Фаза 11: Train: 1.22926, Test: 1.21766
# Фаза 12: Train: 1.15652, Test: 1.14149
# Прошло времени: 00:00:51
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 12
#  >>> Средняя разница между предсказанными и OSO: 0.890
# Epoch [12/300], learn_rate: 1e-05, Train Loss: 1.16331, Test Loss: 1.16035
# Фаза 1: Train: 1.09407, Test: 1.10100
# Фаза 2: Train: 1.19896, Test: 1.18474
# Фаза 3: Train: 1.28552, Test: 1.27260
# Фаза 4: Train: 1.17750, Test: 1.17702
# Фаза 5: Train: 1.18478, Test: 1.20584
# Фаза 6: Train: 1.18456, Test: 1.17875
# Фаза 7: Train: 1.10499, Test: 1.08503
# Фаза 8: Train: 1.13484, Test: 1.13837
# Фаза 9: Train: 1.14501, Test: 1.14365
# Фаза 10: Train: 1.15381, Test: 1.17412
# Фаза 11: Train: 1.19325, Test: 1.17348
# Фаза 12: Train: 1.08814, Test: 1.07517
# Прошло времени: 00:00:55
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 13
#  >>> Средняя разница между предсказанными и OSO: 0.887
# Epoch [13/300], learn_rate: 1e-05, Train Loss: 1.09664, Test Loss: 1.09755
# Фаза 1: Train: 1.03468, Test: 1.03820
# Фаза 2: Train: 1.17321, Test: 1.15925
# Фаза 3: Train: 1.20313, Test: 1.20113
# Фаза 4: Train: 1.10787, Test: 1.11464
# Фаза 5: Train: 1.15340, Test: 1.17420
# Фаза 6: Train: 1.05637, Test: 1.05561
# Фаза 7: Train: 1.05213, Test: 1.03659
# Фаза 8: Train: 1.07845, Test: 1.08290
# Фаза 9: Train: 1.17095, Test: 1.17898
# Фаза 10: Train: 0.97938, Test: 0.99490
# Фаза 11: Train: 1.12229, Test: 1.11284
# Фаза 12: Train: 1.00174, Test: 0.99501
# Прошло времени: 00:01:00
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 14
#  >>> Средняя разница между предсказанными и OSO: 0.842
# Epoch [14/300], learn_rate: 1e-05, Train Loss: 1.04787, Test Loss: 1.04851
# Фаза 1: Train: 1.00768, Test: 1.01389
# Фаза 2: Train: 1.10349, Test: 1.09891
# Фаза 3: Train: 1.14970, Test: 1.14203
# Фаза 4: Train: 1.07360, Test: 1.08000
# Фаза 5: Train: 1.09371, Test: 1.10684
# Фаза 6: Train: 0.99520, Test: 1.00059
# Фаза 7: Train: 0.98188, Test: 0.96691
# Фаза 8: Train: 1.03057, Test: 1.03470
# Фаза 9: Train: 1.07767, Test: 1.08286
# Фаза 10: Train: 1.02328, Test: 1.03849
# Фаза 11: Train: 1.06497, Test: 1.05535
# Фаза 12: Train: 0.95570, Test: 0.94319
# Прошло времени: 00:01:05
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 15
#  >>> Средняя разница между предсказанными и OSO: 0.841
# Epoch [15/300], learn_rate: 1e-05, Train Loss: 1.00322, Test Loss: 1.00419
# Фаза 1: Train: 0.94106, Test: 0.94043
# Фаза 2: Train: 1.11507, Test: 1.10999
# Фаза 3: Train: 1.05395, Test: 1.05655
# Фаза 4: Train: 1.01274, Test: 1.02394
# Фаза 5: Train: 1.00937, Test: 1.02291
# Фаза 6: Train: 0.95043, Test: 0.95166
# Фаза 7: Train: 1.02237, Test: 1.01154
# Фаза 8: Train: 0.97280, Test: 0.98102
# Фаза 9: Train: 1.01548, Test: 1.02426
# Фаза 10: Train: 0.88458, Test: 0.90172
# Фаза 11: Train: 1.09812, Test: 1.08070
# Фаза 12: Train: 0.93738, Test: 0.92293
# Прошло времени: 00:01:09
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 16
#  >>> Средняя разница между предсказанными и OSO: 0.770
# Epoch [16/300], learn_rate: 1e-05, Train Loss: 0.96472, Test Loss: 0.96541
# Фаза 1: Train: 0.89913, Test: 0.90132
# Фаза 2: Train: 1.08488, Test: 1.07902
# Фаза 3: Train: 1.06569, Test: 1.06618
# Фаза 4: Train: 1.01004, Test: 1.00963
# Фаза 5: Train: 0.99059, Test: 1.00567
# Фаза 6: Train: 0.94018, Test: 0.94008
# Фаза 7: Train: 0.89775, Test: 0.89202
# Фаза 8: Train: 0.92970, Test: 0.93303
# Фаза 9: Train: 0.96481, Test: 0.97177
# Фаза 10: Train: 0.87605, Test: 0.88503
# Фаза 11: Train: 1.00700, Test: 1.00352
# Фаза 12: Train: 0.88265, Test: 0.86910
# Прошло времени: 00:01:14
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 17
#  >>> Средняя разница между предсказанными и OSO: 0.742
# Epoch [17/300], learn_rate: 1e-05, Train Loss: 0.92345, Test Loss: 0.92528
# Фаза 1: Train: 0.87742, Test: 0.87842
# Фаза 2: Train: 1.02538, Test: 1.02043
# Фаза 3: Train: 0.95997, Test: 0.95581
# Фаза 4: Train: 0.93581, Test: 0.94147
# Фаза 5: Train: 0.93739, Test: 0.95565
# Фаза 6: Train: 0.88156, Test: 0.88773
# Фаза 7: Train: 0.84473, Test: 0.83742
# Фаза 8: Train: 0.93922, Test: 0.95031
# Фаза 9: Train: 0.97110, Test: 0.97678
# Фаза 10: Train: 0.82886, Test: 0.84014
# Фаза 11: Train: 0.97342, Test: 0.96566
# Фаза 12: Train: 0.88621, Test: 0.87332
# Прошло времени: 00:01:19
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 18
#  >>> Средняя разница между предсказанными и OSO: 0.739
# Epoch [18/300], learn_rate: 1e-05, Train Loss: 0.89031, Test Loss: 0.89235
# Фаза 1: Train: 0.86358, Test: 0.86811
# Фаза 2: Train: 1.00700, Test: 1.00194
# Фаза 3: Train: 0.93153, Test: 0.93101
# Фаза 4: Train: 0.91268, Test: 0.91847
# Фаза 5: Train: 0.89720, Test: 0.91389
# Фаза 6: Train: 0.84724, Test: 0.85354
# Фаза 7: Train: 0.81528, Test: 0.81284
# Фаза 8: Train: 0.89888, Test: 0.90470
# Фаза 9: Train: 0.90446, Test: 0.91083
# Фаза 10: Train: 0.79112, Test: 0.80345
# Фаза 11: Train: 0.93051, Test: 0.91818
# Фаза 12: Train: 0.86370, Test: 0.85235
# Прошло времени: 00:01:24
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 19
#  >>> Средняя разница между предсказанными и OSO: 0.734
# Epoch [19/300], learn_rate: 1e-05, Train Loss: 0.85659, Test Loss: 0.85923
# Фаза 1: Train: 0.82194, Test: 0.82391
# Фаза 2: Train: 0.93025, Test: 0.92552
# Фаза 3: Train: 0.89558, Test: 0.89923
# Фаза 4: Train: 0.90065, Test: 0.90285
# Фаза 5: Train: 0.86543, Test: 0.87849
# Фаза 6: Train: 0.83897, Test: 0.83813
# Фаза 7: Train: 0.79247, Test: 0.78901
# Фаза 8: Train: 0.85101, Test: 0.86017
# Фаза 9: Train: 0.87509, Test: 0.88575
# Фаза 10: Train: 0.77336, Test: 0.78391
# Фаза 11: Train: 0.88850, Test: 0.88518
# Фаза 12: Train: 0.83212, Test: 0.82522
# Прошло времени: 00:01:28
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 20
#  >>> Средняя разница между предсказанными и OSO: 0.696
# Epoch [20/300], learn_rate: 1e-05, Train Loss: 0.84604, Test Loss: 0.84820
# Фаза 1: Train: 0.80958, Test: 0.81731
# Фаза 2: Train: 0.87478, Test: 0.87827
# Фаза 3: Train: 0.89523, Test: 0.89120
# Фаза 4: Train: 0.92736, Test: 0.93151
# Фаза 5: Train: 0.86859, Test: 0.88157
# Фаза 6: Train: 0.80725, Test: 0.80578
# Фаза 7: Train: 0.80171, Test: 0.79803
# Фаза 8: Train: 0.81508, Test: 0.82353
# Фаза 9: Train: 0.85068, Test: 0.86070
# Фаза 10: Train: 0.75518, Test: 0.76176
# Фаза 11: Train: 0.96021, Test: 0.94772
# Фаза 12: Train: 0.76032, Test: 0.75586
# Прошло времени: 00:01:33
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 21
#  >>> Средняя разница между предсказанными и OSO: 0.640
# Epoch [21/300], learn_rate: 1e-05, Train Loss: 0.80379, Test Loss: 0.80745
# Фаза 1: Train: 0.76582, Test: 0.77119
# Фаза 2: Train: 0.85630, Test: 0.86020
# Фаза 3: Train: 0.90169, Test: 0.90069
# Фаза 4: Train: 0.82541, Test: 0.82989
# Фаза 5: Train: 0.80820, Test: 0.82635
# Фаза 6: Train: 0.78185, Test: 0.78508
# Фаза 7: Train: 0.77856, Test: 0.77231
# Фаза 8: Train: 0.78578, Test: 0.79356
# Фаза 9: Train: 0.80947, Test: 0.81839
# Фаза 10: Train: 0.71388, Test: 0.72768
# Фаза 11: Train: 0.85079, Test: 0.84464
# Фаза 12: Train: 0.74967, Test: 0.74231
# Прошло времени: 00:01:38
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 22
#  >>> Средняя разница между предсказанными и OSO: 0.628
# Epoch [22/300], learn_rate: 1e-05, Train Loss: 0.78666, Test Loss: 0.79087
# Фаза 1: Train: 0.76427, Test: 0.76770
# Фаза 2: Train: 0.84867, Test: 0.85216
# Фаза 3: Train: 0.83218, Test: 0.83189
# Фаза 4: Train: 0.81615, Test: 0.82060
# Фаза 5: Train: 0.83444, Test: 0.85071
# Фаза 6: Train: 0.76525, Test: 0.76942
# Фаза 7: Train: 0.72069, Test: 0.72523
# Фаза 8: Train: 0.75846, Test: 0.76713
# Фаза 9: Train: 0.79680, Test: 0.80396
# Фаза 10: Train: 0.71441, Test: 0.72330
# Фаза 11: Train: 0.83769, Test: 0.83005
# Фаза 12: Train: 0.73449, Test: 0.73221
# Прошло времени: 00:01:42
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 23
#  >>> Средняя разница между предсказанными и OSO: 0.612
# Epoch [23/300], learn_rate: 1e-05, Train Loss: 0.76298, Test Loss: 0.76629
# Фаза 1: Train: 0.74760, Test: 0.75875
# Фаза 2: Train: 0.82833, Test: 0.82840
# Фаза 3: Train: 0.80911, Test: 0.81093
# Фаза 4: Train: 0.78875, Test: 0.79605
# Фаза 5: Train: 0.75518, Test: 0.77259
# Фаза 6: Train: 0.74412, Test: 0.74970
# Фаза 7: Train: 0.69210, Test: 0.68782
# Фаза 8: Train: 0.79416, Test: 0.79896
# Фаза 9: Train: 0.74781, Test: 0.75442
# Фаза 10: Train: 0.67054, Test: 0.67886
# Фаза 11: Train: 0.83490, Test: 0.82650
# Фаза 12: Train: 0.72408, Test: 0.71391
# Прошло времени: 00:01:47
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.695
# Epoch [24/300], learn_rate: 1e-05, Train Loss: 0.75570, Test Loss: 0.76039
# Фаза 1: Train: 0.71071, Test: 0.71400
# Фаза 2: Train: 0.81348, Test: 0.82077
# Фаза 3: Train: 0.78008, Test: 0.78529
# Фаза 4: Train: 0.76074, Test: 0.76876
# Фаза 5: Train: 0.81366, Test: 0.83442
# Фаза 6: Train: 0.77549, Test: 0.77646
# Фаза 7: Train: 0.74701, Test: 0.74802
# Фаза 8: Train: 0.76842, Test: 0.77319
# Фаза 9: Train: 0.74287, Test: 0.75328
# Фаза 10: Train: 0.65626, Test: 0.66248
# Фаза 11: Train: 0.78989, Test: 0.78369
# Фаза 12: Train: 0.69314, Test: 0.68567
# Прошло времени: 00:01:52
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 25
#  >>> Средняя разница между предсказанными и OSO: 0.593
# Epoch [25/300], learn_rate: 1e-05, Train Loss: 0.72132, Test Loss: 0.72632
# Фаза 1: Train: 0.68206, Test: 0.69008
# Фаза 2: Train: 0.79120, Test: 0.79549
# Фаза 3: Train: 0.76508, Test: 0.76492
# Фаза 4: Train: 0.74089, Test: 0.74984
# Фаза 5: Train: 0.74240, Test: 0.76224
# Фаза 6: Train: 0.69696, Test: 0.70191
# Фаза 7: Train: 0.72221, Test: 0.71845
# Фаза 8: Train: 0.70559, Test: 0.71495
# Фаза 9: Train: 0.73276, Test: 0.74585
# Фаза 10: Train: 0.64410, Test: 0.65070
# Фаза 11: Train: 0.76935, Test: 0.76241
# Фаза 12: Train: 0.64664, Test: 0.64197
# Прошло времени: 00:01:57
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.604
# Epoch [26/300], learn_rate: 1e-05, Train Loss: 0.71540, Test Loss: 0.72213
# Фаза 1: Train: 0.74243, Test: 0.75089
# Фаза 2: Train: 0.75096, Test: 0.75911
# Фаза 3: Train: 0.74934, Test: 0.75392
# Фаза 4: Train: 0.80734, Test: 0.81586
# Фаза 5: Train: 0.74461, Test: 0.76254
# Фаза 6: Train: 0.67999, Test: 0.68611
# Фаза 7: Train: 0.64878, Test: 0.64896
# Фаза 8: Train: 0.69349, Test: 0.70093
# Фаза 9: Train: 0.73639, Test: 0.74962
# Фаза 10: Train: 0.62367, Test: 0.62893
# Фаза 11: Train: 0.74786, Test: 0.74674
# Фаза 12: Train: 0.63551, Test: 0.63541
# Прошло времени: 00:02:01
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 27
#  >>> Средняя разница между предсказанными и OSO: 0.574
# Epoch [27/300], learn_rate: 1e-05, Train Loss: 0.69064, Test Loss: 0.69560
# Фаза 1: Train: 0.63595, Test: 0.64733
# Фаза 2: Train: 0.75375, Test: 0.75788
# Фаза 3: Train: 0.79370, Test: 0.79560
# Фаза 4: Train: 0.71208, Test: 0.72314
# Фаза 5: Train: 0.69883, Test: 0.71599
# Фаза 6: Train: 0.65672, Test: 0.66312
# Фаза 7: Train: 0.66046, Test: 0.65547
# Фаза 8: Train: 0.68471, Test: 0.69172
# Фаза 9: Train: 0.68739, Test: 0.69492
# Фаза 10: Train: 0.63038, Test: 0.63695
# Фаза 11: Train: 0.71015, Test: 0.70801
# Фаза 12: Train: 0.64446, Test: 0.63766
# Прошло времени: 00:02:06
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 28
#  >>> Средняя разница между предсказанными и OSO: 0.566
# Epoch [28/300], learn_rate: 1e-05, Train Loss: 0.67468, Test Loss: 0.67900
# Фаза 1: Train: 0.65575, Test: 0.66375
# Фаза 2: Train: 0.72030, Test: 0.72275
# Фаза 3: Train: 0.69596, Test: 0.69822
# Фаза 4: Train: 0.69089, Test: 0.70358
# Фаза 5: Train: 0.68921, Test: 0.70539
# Фаза 6: Train: 0.65614, Test: 0.65892
# Фаза 7: Train: 0.63087, Test: 0.62689
# Фаза 8: Train: 0.68682, Test: 0.69345
# Фаза 9: Train: 0.67049, Test: 0.67827
# Фаза 10: Train: 0.62536, Test: 0.63105
# Фаза 11: Train: 0.73223, Test: 0.72916
# Фаза 12: Train: 0.63220, Test: 0.62568
# Прошло времени: 00:02:11
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 29
#  >>> Средняя разница между предсказанными и OSO: 0.529
# Epoch [29/300], learn_rate: 1e-05, Train Loss: 0.66720, Test Loss: 0.67285
# Фаза 1: Train: 0.66109, Test: 0.66747
# Фаза 2: Train: 0.70023, Test: 0.70413
# Фаза 3: Train: 0.74045, Test: 0.74540
# Фаза 4: Train: 0.73926, Test: 0.75088
# Фаза 5: Train: 0.67264, Test: 0.68923
# Фаза 6: Train: 0.62505, Test: 0.63429
# Фаза 7: Train: 0.60256, Test: 0.60442
# Фаза 8: Train: 0.67955, Test: 0.68565
# Фаза 9: Train: 0.65607, Test: 0.66056
# Фаза 10: Train: 0.59782, Test: 0.60281
# Фаза 11: Train: 0.70836, Test: 0.70471
# Фаза 12: Train: 0.60185, Test: 0.60237
# Прошло времени: 00:02:15
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.536
# Epoch [30/300], learn_rate: 1e-05, Train Loss: 0.65312, Test Loss: 0.65791
# Фаза 1: Train: 0.60804, Test: 0.61053
# Фаза 2: Train: 0.68740, Test: 0.68744
# Фаза 3: Train: 0.66605, Test: 0.66995
# Фаза 4: Train: 0.69290, Test: 0.69844
# Фаза 5: Train: 0.72781, Test: 0.74317
# Фаза 6: Train: 0.61981, Test: 0.62266
# Фаза 7: Train: 0.57368, Test: 0.57496
# Фаза 8: Train: 0.63564, Test: 0.64435
# Фаза 9: Train: 0.69085, Test: 0.70105
# Фаза 10: Train: 0.59959, Test: 0.60676
# Фаза 11: Train: 0.68188, Test: 0.67996
# Фаза 12: Train: 0.63565, Test: 0.63592
# Прошло времени: 00:02:20
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 31
#  >>> Средняя разница между предсказанными и OSO: 0.513
# Epoch [31/300], learn_rate: 1e-05, Train Loss: 0.63562, Test Loss: 0.64191
# Фаза 1: Train: 0.61937, Test: 0.62732
# Фаза 2: Train: 0.67223, Test: 0.67611
# Фаза 3: Train: 0.66993, Test: 0.67544
# Фаза 4: Train: 0.66467, Test: 0.67823
# Фаза 5: Train: 0.64524, Test: 0.66341
# Фаза 6: Train: 0.60003, Test: 0.60679
# Фаза 7: Train: 0.61846, Test: 0.61532
# Фаза 8: Train: 0.65811, Test: 0.66534
# Фаза 9: Train: 0.62880, Test: 0.64322
# Фаза 10: Train: 0.57115, Test: 0.57331
# Фаза 11: Train: 0.65100, Test: 0.65275
# Фаза 12: Train: 0.62022, Test: 0.61607
# Прошло времени: 00:02:25
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 32
#  >>> Средняя разница между предсказанными и OSO: 0.501
# Epoch [32/300], learn_rate: 1e-05, Train Loss: 0.62988, Test Loss: 0.63610
# Фаза 1: Train: 0.58094, Test: 0.58589
# Фаза 2: Train: 0.67574, Test: 0.67883
# Фаза 3: Train: 0.68304, Test: 0.68691
# Фаза 4: Train: 0.67889, Test: 0.68805
# Фаза 5: Train: 0.63759, Test: 0.65807
# Фаза 6: Train: 0.62177, Test: 0.62985
# Фаза 7: Train: 0.57653, Test: 0.57910
# Фаза 8: Train: 0.65314, Test: 0.65954
# Фаза 9: Train: 0.63020, Test: 0.63784
# Фаза 10: Train: 0.56570, Test: 0.57166
# Фаза 11: Train: 0.66766, Test: 0.66715
# Фаза 12: Train: 0.56961, Test: 0.57215
# Прошло времени: 00:02:29
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.559
# Epoch [33/300], learn_rate: 1e-05, Train Loss: 0.61553, Test Loss: 0.62077
# Фаза 1: Train: 0.56792, Test: 0.57343
# Фаза 2: Train: 0.67229, Test: 0.67754
# Фаза 3: Train: 0.63225, Test: 0.63426
# Фаза 4: Train: 0.67046, Test: 0.67756
# Фаза 5: Train: 0.62127, Test: 0.63943
# Фаза 6: Train: 0.59414, Test: 0.60098
# Фаза 7: Train: 0.54593, Test: 0.54716
# Фаза 8: Train: 0.63147, Test: 0.63871
# Фаза 9: Train: 0.59283, Test: 0.60197
# Фаза 10: Train: 0.55692, Test: 0.55862
# Фаза 11: Train: 0.70747, Test: 0.70885
# Фаза 12: Train: 0.56995, Test: 0.56628
# Прошло времени: 00:02:34
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 34
#  >>> Средняя разница между предсказанными и OSO: 0.474
# Epoch [34/300], learn_rate: 1e-05, Train Loss: 0.60581, Test Loss: 0.61198
# Фаза 1: Train: 0.60106, Test: 0.60845
# Фаза 2: Train: 0.65258, Test: 0.66324
# Фаза 3: Train: 0.63181, Test: 0.63471
# Фаза 4: Train: 0.63303, Test: 0.64366
# Фаза 5: Train: 0.59766, Test: 0.61748
# Фаза 6: Train: 0.62031, Test: 0.62753
# Фаза 7: Train: 0.57597, Test: 0.57339
# Фаза 8: Train: 0.63912, Test: 0.64605
# Фаза 9: Train: 0.58292, Test: 0.58795
# Фаза 10: Train: 0.53768, Test: 0.54422
# Фаза 11: Train: 0.61946, Test: 0.61928
# Фаза 12: Train: 0.56768, Test: 0.56601
# Прошло времени: 00:02:39
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.541
# Epoch [35/300], learn_rate: 1e-05, Train Loss: 0.61133, Test Loss: 0.61859
# Фаза 1: Train: 0.62007, Test: 0.62753
# Фаза 2: Train: 0.66314, Test: 0.66978
# Фаза 3: Train: 0.63973, Test: 0.64311
# Фаза 4: Train: 0.65330, Test: 0.66559
# Фаза 5: Train: 0.62769, Test: 0.64738
# Фаза 6: Train: 0.59354, Test: 0.59972
# Фаза 7: Train: 0.58209, Test: 0.58418
# Фаза 8: Train: 0.60833, Test: 0.61771
# Фаза 9: Train: 0.61028, Test: 0.61546
# Фаза 10: Train: 0.54036, Test: 0.54535
# Фаза 11: Train: 0.63272, Test: 0.63600
# Фаза 12: Train: 0.55182, Test: 0.55733
# Прошло времени: 00:02:43
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.474
# Epoch [36/300], learn_rate: 1e-05, Train Loss: 0.57963, Test Loss: 0.58706
# Фаза 1: Train: 0.57754, Test: 0.58537
# Фаза 2: Train: 0.61291, Test: 0.62109
# Фаза 3: Train: 0.66227, Test: 0.66507
# Фаза 4: Train: 0.61261, Test: 0.62470
# Фаза 5: Train: 0.59960, Test: 0.61889
# Фаза 6: Train: 0.56761, Test: 0.56995
# Фаза 7: Train: 0.50911, Test: 0.50934
# Фаза 8: Train: 0.58587, Test: 0.59117
# Фаза 9: Train: 0.57791, Test: 0.58861
# Фаза 10: Train: 0.51509, Test: 0.52456
# Фаза 11: Train: 0.59704, Test: 0.60339
# Фаза 12: Train: 0.51829, Test: 0.52178
# Прошло времени: 00:02:48
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.474
# Epoch [37/300], learn_rate: 1e-05, Train Loss: 0.57299, Test Loss: 0.57910
# Фаза 1: Train: 0.54204, Test: 0.54917
# Фаза 2: Train: 0.60144, Test: 0.60926
# Фаза 3: Train: 0.61714, Test: 0.62087
# Фаза 4: Train: 0.60542, Test: 0.61566
# Фаза 5: Train: 0.58440, Test: 0.60032
# Фаза 6: Train: 0.55848, Test: 0.56089
# Фаза 7: Train: 0.50552, Test: 0.50556
# Фаза 8: Train: 0.63480, Test: 0.63959
# Фаза 9: Train: 0.59481, Test: 0.60351
# Фаза 10: Train: 0.52454, Test: 0.52847
# Фаза 11: Train: 0.58367, Test: 0.58677
# Фаза 12: Train: 0.50532, Test: 0.50940
# Прошло времени: 00:02:53
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.484
# Epoch [38/300], learn_rate: 1e-05, Train Loss: 0.58929, Test Loss: 0.59609
# Фаза 1: Train: 0.60147, Test: 0.60997
# Фаза 2: Train: 0.65841, Test: 0.66554
# Фаза 3: Train: 0.62287, Test: 0.62736
# Фаза 4: Train: 0.63000, Test: 0.63753
# Фаза 5: Train: 0.58878, Test: 0.60841
# Фаза 6: Train: 0.57983, Test: 0.58809
# Фаза 7: Train: 0.54730, Test: 0.55143
# Фаза 8: Train: 0.58787, Test: 0.59669
# Фаза 9: Train: 0.58204, Test: 0.58243
# Фаза 10: Train: 0.54066, Test: 0.54590
# Фаза 11: Train: 0.60218, Test: 0.60402
# Фаза 12: Train: 0.51515, Test: 0.52025
# Прошло времени: 00:02:57
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 39
#  >>> Средняя разница между предсказанными и OSO: 0.458
# Epoch [39/300], learn_rate: 1e-05, Train Loss: 0.55805, Test Loss: 0.56508
# Фаза 1: Train: 0.53759, Test: 0.54965
# Фаза 2: Train: 0.59234, Test: 0.59594
# Фаза 3: Train: 0.59171, Test: 0.59562
# Фаза 4: Train: 0.60019, Test: 0.61343
# Фаза 5: Train: 0.57794, Test: 0.60061
# Фаза 6: Train: 0.55703, Test: 0.55853
# Фаза 7: Train: 0.51499, Test: 0.51440
# Фаза 8: Train: 0.55008, Test: 0.55645
# Фаза 9: Train: 0.57605, Test: 0.58549
# Фаза 10: Train: 0.50540, Test: 0.51157
# Фаза 11: Train: 0.57272, Test: 0.57647
# Фаза 12: Train: 0.50930, Test: 0.50955
# Прошло времени: 00:03:02
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.484
# Epoch [40/300], learn_rate: 1e-05, Train Loss: 0.54490, Test Loss: 0.55258
# Фаза 1: Train: 0.54844, Test: 0.55361
# Фаза 2: Train: 0.58061, Test: 0.58700
# Фаза 3: Train: 0.59179, Test: 0.59799
# Фаза 4: Train: 0.57858, Test: 0.59102
# Фаза 5: Train: 0.55853, Test: 0.57610
# Фаза 6: Train: 0.51844, Test: 0.52607
# Фаза 7: Train: 0.48448, Test: 0.48888
# Фаза 8: Train: 0.56020, Test: 0.56903
# Фаза 9: Train: 0.54323, Test: 0.55166
# Фаза 10: Train: 0.48797, Test: 0.49143
# Фаза 11: Train: 0.57176, Test: 0.57809
# Фаза 12: Train: 0.50075, Test: 0.50469
# Прошло времени: 00:03:07
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.461
# Epoch [41/300], learn_rate: 1e-05, Train Loss: 0.53799, Test Loss: 0.54499
# Фаза 1: Train: 0.51221, Test: 0.51862
# Фаза 2: Train: 0.58571, Test: 0.58969
# Фаза 3: Train: 0.56185, Test: 0.56688
# Фаза 4: Train: 0.56628, Test: 0.57785
# Фаза 5: Train: 0.53127, Test: 0.55259
# Фаза 6: Train: 0.57459, Test: 0.57881
# Фаза 7: Train: 0.48301, Test: 0.48382
# Фаза 8: Train: 0.53566, Test: 0.54538
# Фаза 9: Train: 0.54391, Test: 0.54788
# Фаза 10: Train: 0.48264, Test: 0.48999
# Фаза 11: Train: 0.55297, Test: 0.56114
# Фаза 12: Train: 0.51407, Test: 0.51491
# Прошло времени: 00:03:12
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 42
#  >>> Средняя разница между предсказанными и OSO: 0.431
# Epoch [42/300], learn_rate: 1e-05, Train Loss: 0.53180, Test Loss: 0.53870
# Фаза 1: Train: 0.51325, Test: 0.52300
# Фаза 2: Train: 0.55074, Test: 0.55642
# Фаза 3: Train: 0.57212, Test: 0.57876
# Фаза 4: Train: 0.55929, Test: 0.57163
# Фаза 5: Train: 0.51782, Test: 0.53526
# Фаза 6: Train: 0.54149, Test: 0.54368
# Фаза 7: Train: 0.47699, Test: 0.47866
# Фаза 8: Train: 0.53156, Test: 0.53860
# Фаза 9: Train: 0.52736, Test: 0.53454
# Фаза 10: Train: 0.52072, Test: 0.52752
# Фаза 11: Train: 0.57290, Test: 0.57719
# Фаза 12: Train: 0.48782, Test: 0.48899
# Прошло времени: 00:03:16
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.503
# Epoch [43/300], learn_rate: 1e-05, Train Loss: 0.52353, Test Loss: 0.53005
# Фаза 1: Train: 0.49620, Test: 0.50541
# Фаза 2: Train: 0.58887, Test: 0.59449
# Фаза 3: Train: 0.53510, Test: 0.53702
# Фаза 4: Train: 0.58647, Test: 0.59837
# Фаза 5: Train: 0.51927, Test: 0.53368
# Фаза 6: Train: 0.51743, Test: 0.52088
# Фаза 7: Train: 0.47519, Test: 0.47501
# Фаза 8: Train: 0.52629, Test: 0.53517
# Фаза 9: Train: 0.52036, Test: 0.52676
# Фаза 10: Train: 0.46927, Test: 0.47600
# Фаза 11: Train: 0.56982, Test: 0.57446
# Фаза 12: Train: 0.45811, Test: 0.46248
# Прошло времени: 00:03:21
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.502
# Epoch [44/300], learn_rate: 1e-05, Train Loss: 0.51910, Test Loss: 0.52633
# Фаза 1: Train: 0.49688, Test: 0.50227
# Фаза 2: Train: 0.56287, Test: 0.57103
# Фаза 3: Train: 0.58811, Test: 0.59418
# Фаза 4: Train: 0.53899, Test: 0.55497
# Фаза 5: Train: 0.51646, Test: 0.53245
# Фаза 6: Train: 0.51684, Test: 0.52010
# Фаза 7: Train: 0.45886, Test: 0.46100
# Фаза 8: Train: 0.53300, Test: 0.54108
# Фаза 9: Train: 0.52404, Test: 0.53186
# Фаза 10: Train: 0.46124, Test: 0.46596
# Фаза 11: Train: 0.55120, Test: 0.55230
# Фаза 12: Train: 0.46240, Test: 0.46965
# Прошло времени: 00:03:26
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.447
# Epoch [45/300], learn_rate: 1e-05, Train Loss: 0.50597, Test Loss: 0.51389
# Фаза 1: Train: 0.47591, Test: 0.48269
# Фаза 2: Train: 0.53693, Test: 0.54736
# Фаза 3: Train: 0.52298, Test: 0.53124
# Фаза 4: Train: 0.54329, Test: 0.55687
# Фаза 5: Train: 0.51235, Test: 0.53130
# Фаза 6: Train: 0.51247, Test: 0.51649
# Фаза 7: Train: 0.45980, Test: 0.45924
# Фаза 8: Train: 0.53043, Test: 0.54288
# Фаза 9: Train: 0.51809, Test: 0.52337
# Фаза 10: Train: 0.45485, Test: 0.46295
# Фаза 11: Train: 0.53024, Test: 0.53514
# Фаза 12: Train: 0.46292, Test: 0.46343
# Прошло времени: 00:03:31
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.465
# Epoch [46/300], learn_rate: 1e-05, Train Loss: 0.50077, Test Loss: 0.50897
# Фаза 1: Train: 0.49526, Test: 0.50460
# Фаза 2: Train: 0.52595, Test: 0.53090
# Фаза 3: Train: 0.55138, Test: 0.55992
# Фаза 4: Train: 0.54015, Test: 0.55397
# Фаза 5: Train: 0.48005, Test: 0.50082
# Фаза 6: Train: 0.47359, Test: 0.48091
# Фаза 7: Train: 0.45805, Test: 0.45745
# Фаза 8: Train: 0.51304, Test: 0.52240
# Фаза 9: Train: 0.49495, Test: 0.50190
# Фаза 10: Train: 0.51406, Test: 0.51943
# Фаза 11: Train: 0.50131, Test: 0.50930
# Фаза 12: Train: 0.45087, Test: 0.45425
# Прошло времени: 00:03:35
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 47
#  >>> Средняя разница между предсказанными и OSO: 0.411
# Epoch [47/300], learn_rate: 1e-05, Train Loss: 0.49881, Test Loss: 0.50664
# Фаза 1: Train: 0.46554, Test: 0.47191
# Фаза 2: Train: 0.53461, Test: 0.54095
# Фаза 3: Train: 0.51436, Test: 0.51788
# Фаза 4: Train: 0.53142, Test: 0.54920
# Фаза 5: Train: 0.52592, Test: 0.54297
# Фаза 6: Train: 0.47664, Test: 0.47763
# Фаза 7: Train: 0.44388, Test: 0.44914
# Фаза 8: Train: 0.51635, Test: 0.52483
# Фаза 9: Train: 0.50899, Test: 0.51341
# Фаза 10: Train: 0.48455, Test: 0.49431
# Фаза 11: Train: 0.51223, Test: 0.52083
# Фаза 12: Train: 0.46103, Test: 0.46447
# Прошло времени: 00:03:40
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 48
#  >>> Средняя разница между предсказанными и OSO: 0.399
# Epoch [48/300], learn_rate: 1e-05, Train Loss: 0.49019, Test Loss: 0.49830
# Фаза 1: Train: 0.48265, Test: 0.48999
# Фаза 2: Train: 0.54467, Test: 0.55142
# Фаза 3: Train: 0.53631, Test: 0.54133
# Фаза 4: Train: 0.51454, Test: 0.53004
# Фаза 5: Train: 0.49953, Test: 0.51646
# Фаза 6: Train: 0.46600, Test: 0.47238
# Фаза 7: Train: 0.45332, Test: 0.45678
# Фаза 8: Train: 0.49991, Test: 0.50829
# Фаза 9: Train: 0.47301, Test: 0.48227
# Фаза 10: Train: 0.43884, Test: 0.44824
# Фаза 11: Train: 0.51875, Test: 0.52446
# Фаза 12: Train: 0.44034, Test: 0.44281
# Прошло времени: 00:03:45
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.403
# Epoch [49/300], learn_rate: 1e-05, Train Loss: 0.48720, Test Loss: 0.49534
# Фаза 1: Train: 0.46482, Test: 0.47436
# Фаза 2: Train: 0.51488, Test: 0.52406
# Фаза 3: Train: 0.54004, Test: 0.54446
# Фаза 4: Train: 0.51278, Test: 0.52558
# Фаза 5: Train: 0.47870, Test: 0.49680
# Фаза 6: Train: 0.51933, Test: 0.52237
# Фаза 7: Train: 0.46031, Test: 0.46526
# Фаза 8: Train: 0.47989, Test: 0.48903
# Фаза 9: Train: 0.46956, Test: 0.47503
# Фаза 10: Train: 0.42650, Test: 0.43559
# Фаза 11: Train: 0.54080, Test: 0.54798
# Фаза 12: Train: 0.42046, Test: 0.42552
# Прошло времени: 00:03:49
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.568
# Epoch [50/300], learn_rate: 1e-05, Train Loss: 0.49371, Test Loss: 0.50206
# Фаза 1: Train: 0.45648, Test: 0.46363
# Фаза 2: Train: 0.52994, Test: 0.53832
# Фаза 3: Train: 0.55864, Test: 0.56238
# Фаза 4: Train: 0.52513, Test: 0.54098
# Фаза 5: Train: 0.52074, Test: 0.53686
# Фаза 6: Train: 0.47254, Test: 0.47715
# Фаза 7: Train: 0.44460, Test: 0.44893
# Фаза 8: Train: 0.52255, Test: 0.53155
# Фаза 9: Train: 0.49726, Test: 0.50121
# Фаза 10: Train: 0.44146, Test: 0.44999
# Фаза 11: Train: 0.48882, Test: 0.49969
# Фаза 12: Train: 0.44901, Test: 0.45579
# Прошло времени: 00:03:54
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.403
# Epoch [51/300], learn_rate: 1e-05, Train Loss: 0.47459, Test Loss: 0.48279
# Фаза 1: Train: 0.44553, Test: 0.45393
# Фаза 2: Train: 0.50414, Test: 0.51416
# Фаза 3: Train: 0.50467, Test: 0.51029
# Фаза 4: Train: 0.50255, Test: 0.52121
# Фаза 5: Train: 0.48647, Test: 0.50157
# Фаза 6: Train: 0.45643, Test: 0.45768
# Фаза 7: Train: 0.47424, Test: 0.47494
# Фаза 8: Train: 0.49430, Test: 0.50434
# Фаза 9: Train: 0.45436, Test: 0.45971
# Фаза 10: Train: 0.46913, Test: 0.47563
# Фаза 11: Train: 0.46583, Test: 0.47603
# Фаза 12: Train: 0.43029, Test: 0.43518
# Прошло времени: 00:03:59
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.416
# Epoch [52/300], learn_rate: 1e-05, Train Loss: 0.46772, Test Loss: 0.47712
# Фаза 1: Train: 0.43817, Test: 0.44525
# Фаза 2: Train: 0.51105, Test: 0.51951
# Фаза 3: Train: 0.48907, Test: 0.49498
# Фаза 4: Train: 0.49651, Test: 0.51302
# Фаза 5: Train: 0.45959, Test: 0.47946
# Фаза 6: Train: 0.47065, Test: 0.47440
# Фаза 7: Train: 0.43646, Test: 0.44119
# Фаза 8: Train: 0.46875, Test: 0.48031
# Фаза 9: Train: 0.50252, Test: 0.51074
# Фаза 10: Train: 0.42359, Test: 0.43329
# Фаза 11: Train: 0.48828, Test: 0.49628
# Фаза 12: Train: 0.41587, Test: 0.42445
# Прошло времени: 00:04:03
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.428
# Epoch [53/300], learn_rate: 1e-05, Train Loss: 0.47243, Test Loss: 0.48064
# Фаза 1: Train: 0.43834, Test: 0.44303
# Фаза 2: Train: 0.49855, Test: 0.50987
# Фаза 3: Train: 0.50970, Test: 0.51472
# Фаза 4: Train: 0.51113, Test: 0.52651
# Фаза 5: Train: 0.47189, Test: 0.48689
# Фаза 6: Train: 0.48861, Test: 0.49442
# Фаза 7: Train: 0.43994, Test: 0.44799
# Фаза 8: Train: 0.47764, Test: 0.48644
# Фаза 9: Train: 0.48239, Test: 0.48997
# Фаза 10: Train: 0.40849, Test: 0.41579
# Фаза 11: Train: 0.50350, Test: 0.50642
# Фаза 12: Train: 0.42470, Test: 0.43079
# Прошло времени: 00:04:08
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.419
# Epoch [54/300], learn_rate: 1e-05, Train Loss: 0.46575, Test Loss: 0.47377
# Фаза 1: Train: 0.42809, Test: 0.43638
# Фаза 2: Train: 0.51404, Test: 0.52049
# Фаза 3: Train: 0.46745, Test: 0.47367
# Фаза 4: Train: 0.49350, Test: 0.51119
# Фаза 5: Train: 0.48123, Test: 0.49600
# Фаза 6: Train: 0.50245, Test: 0.50427
# Фаза 7: Train: 0.41894, Test: 0.42092
# Фаза 8: Train: 0.47347, Test: 0.48300
# Фаза 9: Train: 0.47789, Test: 0.48296
# Фаза 10: Train: 0.41422, Test: 0.42533
# Фаза 11: Train: 0.46982, Test: 0.47645
# Фаза 12: Train: 0.43481, Test: 0.44114
# Прошло времени: 00:04:13
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.430
# Epoch [55/300], learn_rate: 1e-05, Train Loss: 0.45526, Test Loss: 0.46349
# Фаза 1: Train: 0.48021, Test: 0.49406
# Фаза 2: Train: 0.46261, Test: 0.47003
# Фаза 3: Train: 0.46242, Test: 0.46740
# Фаза 4: Train: 0.52692, Test: 0.53942
# Фаза 5: Train: 0.47952, Test: 0.49621
# Фаза 6: Train: 0.44132, Test: 0.44305
# Фаза 7: Train: 0.41521, Test: 0.41828
# Фаза 8: Train: 0.45553, Test: 0.46636
# Фаза 9: Train: 0.43934, Test: 0.44665
# Фаза 10: Train: 0.42031, Test: 0.42814
# Фаза 11: Train: 0.46037, Test: 0.46682
# Фаза 12: Train: 0.40597, Test: 0.40951
# Прошло времени: 00:04:17
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 56
#  >>> Средняя разница между предсказанными и OSO: 0.366
# Epoch [56/300], learn_rate: 1e-05, Train Loss: 0.44389, Test Loss: 0.45223
# Фаза 1: Train: 0.41515, Test: 0.42429
# Фаза 2: Train: 0.47104, Test: 0.47893
# Фаза 3: Train: 0.46668, Test: 0.47112
# Фаза 4: Train: 0.48340, Test: 0.49965
# Фаза 5: Train: 0.44307, Test: 0.45754
# Фаза 6: Train: 0.45968, Test: 0.46323
# Фаза 7: Train: 0.39630, Test: 0.40114
# Фаза 8: Train: 0.45592, Test: 0.46777
# Фаза 9: Train: 0.44745, Test: 0.45062
# Фаза 10: Train: 0.40906, Test: 0.41738
# Фаза 11: Train: 0.46268, Test: 0.47095
# Фаза 12: Train: 0.40574, Test: 0.41286
# Прошло времени: 00:04:22
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.383
# Epoch [57/300], learn_rate: 1e-05, Train Loss: 0.44879, Test Loss: 0.45720
# Фаза 1: Train: 0.40851, Test: 0.41826
# Фаза 2: Train: 0.47479, Test: 0.48700
# Фаза 3: Train: 0.47727, Test: 0.48350
# Фаза 4: Train: 0.48945, Test: 0.50137
# Фаза 5: Train: 0.44353, Test: 0.46109
# Фаза 6: Train: 0.46549, Test: 0.46754
# Фаза 7: Train: 0.39740, Test: 0.40279
# Фаза 8: Train: 0.46158, Test: 0.46844
# Фаза 9: Train: 0.45928, Test: 0.46305
# Фаза 10: Train: 0.39562, Test: 0.40593
# Фаза 11: Train: 0.46590, Test: 0.47372
# Фаза 12: Train: 0.43407, Test: 0.44124
# Прошло времени: 00:04:27
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.393
# Epoch [58/300], learn_rate: 1e-05, Train Loss: 0.43714, Test Loss: 0.44507
# Фаза 1: Train: 0.41351, Test: 0.41999
# Фаза 2: Train: 0.45985, Test: 0.46890
# Фаза 3: Train: 0.46549, Test: 0.47269
# Фаза 4: Train: 0.48861, Test: 0.50391
# Фаза 5: Train: 0.42291, Test: 0.43719
# Фаза 6: Train: 0.43234, Test: 0.43948
# Фаза 7: Train: 0.40203, Test: 0.40578
# Фаза 8: Train: 0.44994, Test: 0.46156
# Фаза 9: Train: 0.44129, Test: 0.44414
# Фаза 10: Train: 0.39283, Test: 0.40233
# Фаза 11: Train: 0.46592, Test: 0.46850
# Фаза 12: Train: 0.39900, Test: 0.40349
# Прошло времени: 00:04:31
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 59
#  >>> Средняя разница между предсказанными и OSO: 0.356
# Epoch [59/300], learn_rate: 1e-05, Train Loss: 0.43216, Test Loss: 0.44099
# Фаза 1: Train: 0.45976, Test: 0.46766
# Фаза 2: Train: 0.48543, Test: 0.49285
# Фаза 3: Train: 0.44820, Test: 0.45436
# Фаза 4: Train: 0.45160, Test: 0.46718
# Фаза 5: Train: 0.41461, Test: 0.43189
# Фаза 6: Train: 0.42250, Test: 0.42681
# Фаза 7: Train: 0.37866, Test: 0.38155
# Фаза 8: Train: 0.43684, Test: 0.44675
# Фаза 9: Train: 0.44167, Test: 0.44986
# Фаза 10: Train: 0.41423, Test: 0.42328
# Фаза 11: Train: 0.42808, Test: 0.43944
# Фаза 12: Train: 0.39335, Test: 0.39858
# Прошло времени: 00:04:36
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.410
# Epoch [60/300], learn_rate: 1e-05, Train Loss: 0.43029, Test Loss: 0.43903
# Фаза 1: Train: 0.43232, Test: 0.44124
# Фаза 2: Train: 0.45799, Test: 0.46722
# Фаза 3: Train: 0.44949, Test: 0.45495
# Фаза 4: Train: 0.47430, Test: 0.49040
# Фаза 5: Train: 0.42800, Test: 0.44263
# Фаза 6: Train: 0.42236, Test: 0.42679
# Фаза 7: Train: 0.38210, Test: 0.38569
# Фаза 8: Train: 0.43839, Test: 0.44978
# Фаза 9: Train: 0.43742, Test: 0.44550
# Фаза 10: Train: 0.39614, Test: 0.40414
# Фаза 11: Train: 0.44332, Test: 0.45211
# Фаза 12: Train: 0.39186, Test: 0.39648
# Прошло времени: 00:04:41
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.434
# Epoch [61/300], learn_rate: 1e-05, Train Loss: 0.43028, Test Loss: 0.43912
# Фаза 1: Train: 0.40008, Test: 0.40963
# Фаза 2: Train: 0.44928, Test: 0.45998
# Фаза 3: Train: 0.45730, Test: 0.46386
# Фаза 4: Train: 0.46125, Test: 0.47698
# Фаза 5: Train: 0.44876, Test: 0.46325
# Фаза 6: Train: 0.44137, Test: 0.44377
# Фаза 7: Train: 0.38641, Test: 0.39249
# Фаза 8: Train: 0.44442, Test: 0.45394
# Фаза 9: Train: 0.43044, Test: 0.43853
# Фаза 10: Train: 0.42269, Test: 0.42972
# Фаза 11: Train: 0.43232, Test: 0.43978
# Фаза 12: Train: 0.37957, Test: 0.38703
# Прошло времени: 00:04:45
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.409
# Epoch [62/300], learn_rate: 1e-05, Train Loss: 0.43031, Test Loss: 0.43947
# Фаза 1: Train: 0.40279, Test: 0.41065
# Фаза 2: Train: 0.46369, Test: 0.47364
# Фаза 3: Train: 0.46428, Test: 0.47378
# Фаза 4: Train: 0.45217, Test: 0.46814
# Фаза 5: Train: 0.44474, Test: 0.45883
# Фаза 6: Train: 0.41052, Test: 0.41936
# Фаза 7: Train: 0.39590, Test: 0.40077
# Фаза 8: Train: 0.44590, Test: 0.45462
# Фаза 9: Train: 0.42579, Test: 0.43181
# Фаза 10: Train: 0.41132, Test: 0.42045
# Фаза 11: Train: 0.44544, Test: 0.45387
# Фаза 12: Train: 0.39233, Test: 0.39766
# Прошло времени: 00:04:50
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.463
# Epoch [63/300], learn_rate: 1e-05, Train Loss: 0.41804, Test Loss: 0.42670
# Фаза 1: Train: 0.39857, Test: 0.40929
# Фаза 2: Train: 0.45054, Test: 0.46152
# Фаза 3: Train: 0.44232, Test: 0.44946
# Фаза 4: Train: 0.48259, Test: 0.49636
# Фаза 5: Train: 0.40907, Test: 0.42425
# Фаза 6: Train: 0.39075, Test: 0.39675
# Фаза 7: Train: 0.41693, Test: 0.41833
# Фаза 8: Train: 0.42163, Test: 0.43297
# Фаза 9: Train: 0.40969, Test: 0.41480
# Фаза 10: Train: 0.36895, Test: 0.37895
# Фаза 11: Train: 0.43338, Test: 0.44246
# Фаза 12: Train: 0.37850, Test: 0.38031
# Прошло времени: 00:04:54
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.361
# Epoch [64/300], learn_rate: 1e-05, Train Loss: 0.41880, Test Loss: 0.42721
# Фаза 1: Train: 0.39809, Test: 0.40767
# Фаза 2: Train: 0.45778, Test: 0.46720
# Фаза 3: Train: 0.42810, Test: 0.43563
# Фаза 4: Train: 0.45493, Test: 0.47224
# Фаза 5: Train: 0.40746, Test: 0.42118
# Фаза 6: Train: 0.42022, Test: 0.42627
# Фаза 7: Train: 0.37148, Test: 0.37399
# Фаза 8: Train: 0.43088, Test: 0.43872
# Фаза 9: Train: 0.42337, Test: 0.43194
# Фаза 10: Train: 0.41308, Test: 0.41914
# Фаза 11: Train: 0.42712, Test: 0.43370
# Фаза 12: Train: 0.38455, Test: 0.38861
# Прошло времени: 00:04:59
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 65
#  >>> Средняя разница между предсказанными и OSO: 0.347
# Epoch [65/300], learn_rate: 1e-05, Train Loss: 0.40817, Test Loss: 0.41779
# Фаза 1: Train: 0.41620, Test: 0.42723
# Фаза 2: Train: 0.43243, Test: 0.44194
# Фаза 3: Train: 0.42676, Test: 0.43519
# Фаза 4: Train: 0.44161, Test: 0.45606
# Фаза 5: Train: 0.40307, Test: 0.42025
# Фаза 6: Train: 0.40948, Test: 0.41460
# Фаза 7: Train: 0.37870, Test: 0.38477
# Фаза 8: Train: 0.43262, Test: 0.44350
# Фаза 9: Train: 0.40283, Test: 0.41086
# Фаза 10: Train: 0.37205, Test: 0.38002
# Фаза 11: Train: 0.41040, Test: 0.41715
# Фаза 12: Train: 0.36339, Test: 0.37266
# Прошло времени: 00:05:04
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.400
# Epoch [66/300], learn_rate: 1e-05, Train Loss: 0.43034, Test Loss: 0.43872
# Фаза 1: Train: 0.41695, Test: 0.42529
# Фаза 2: Train: 0.43238, Test: 0.44314
# Фаза 3: Train: 0.45381, Test: 0.46035
# Фаза 4: Train: 0.46069, Test: 0.47743
# Фаза 5: Train: 0.48587, Test: 0.49922
# Фаза 6: Train: 0.38995, Test: 0.39470
# Фаза 7: Train: 0.40831, Test: 0.41139
# Фаза 8: Train: 0.43866, Test: 0.45149
# Фаза 9: Train: 0.43243, Test: 0.43673
# Фаза 10: Train: 0.40667, Test: 0.41237
# Фаза 11: Train: 0.43166, Test: 0.43635
# Фаза 12: Train: 0.39669, Test: 0.40406
# Прошло времени: 00:05:08
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.376
# Epoch [67/300], learn_rate: 1e-05, Train Loss: 0.40816, Test Loss: 0.41793
# Фаза 1: Train: 0.37100, Test: 0.37924
# Фаза 2: Train: 0.43581, Test: 0.44743
# Фаза 3: Train: 0.41689, Test: 0.42358
# Фаза 4: Train: 0.44653, Test: 0.46544
# Фаза 5: Train: 0.39922, Test: 0.41244
# Фаза 6: Train: 0.39665, Test: 0.40324
# Фаза 7: Train: 0.37536, Test: 0.37980
# Фаза 8: Train: 0.43914, Test: 0.45171
# Фаза 9: Train: 0.45674, Test: 0.46231
# Фаза 10: Train: 0.36658, Test: 0.37672
# Фаза 11: Train: 0.39480, Test: 0.40520
# Фаза 12: Train: 0.38610, Test: 0.39381
# Прошло времени: 00:05:13
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.356
# Epoch [68/300], learn_rate: 1e-05, Train Loss: 0.40574, Test Loss: 0.41540
# Фаза 1: Train: 0.37397, Test: 0.38221
# Фаза 2: Train: 0.42414, Test: 0.43536
# Фаза 3: Train: 0.42363, Test: 0.42990
# Фаза 4: Train: 0.46510, Test: 0.48311
# Фаза 5: Train: 0.39238, Test: 0.40916
# Фаза 6: Train: 0.40712, Test: 0.41033
# Фаза 7: Train: 0.38734, Test: 0.39204
# Фаза 8: Train: 0.43631, Test: 0.44825
# Фаза 9: Train: 0.40454, Test: 0.40878
# Фаза 10: Train: 0.37158, Test: 0.38116
# Фаза 11: Train: 0.39423, Test: 0.40680
# Фаза 12: Train: 0.37776, Test: 0.38540
# Прошло времени: 00:05:18
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.354
# Epoch [69/300], learn_rate: 1e-05, Train Loss: 0.40165, Test Loss: 0.41127
# Фаза 1: Train: 0.38745, Test: 0.39686
# Фаза 2: Train: 0.47387, Test: 0.48352
# Фаза 3: Train: 0.42119, Test: 0.42782
# Фаза 4: Train: 0.43361, Test: 0.44661
# Фаза 5: Train: 0.38730, Test: 0.40417
# Фаза 6: Train: 0.37885, Test: 0.38305
# Фаза 7: Train: 0.35173, Test: 0.35964
# Фаза 8: Train: 0.41588, Test: 0.42957
# Фаза 9: Train: 0.39403, Test: 0.40041
# Фаза 10: Train: 0.39540, Test: 0.40555
# Фаза 11: Train: 0.40162, Test: 0.41240
# Фаза 12: Train: 0.36423, Test: 0.37023
# Прошло времени: 00:05:22
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 70
#  >>> Средняя разница между предсказанными и OSO: 0.325
# Epoch [70/300], learn_rate: 1e-05, Train Loss: 0.39855, Test Loss: 0.40783
# Фаза 1: Train: 0.37549, Test: 0.38257
# Фаза 2: Train: 0.42399, Test: 0.43437
# Фаза 3: Train: 0.42046, Test: 0.42686
# Фаза 4: Train: 0.43047, Test: 0.44746
# Фаза 5: Train: 0.37279, Test: 0.38891
# Фаза 6: Train: 0.38737, Test: 0.39117
# Фаза 7: Train: 0.37430, Test: 0.38229
# Фаза 8: Train: 0.41404, Test: 0.42530
# Фаза 9: Train: 0.39924, Test: 0.40556
# Фаза 10: Train: 0.38037, Test: 0.38932
# Фаза 11: Train: 0.40504, Test: 0.41306
# Фаза 12: Train: 0.39320, Test: 0.40057
# Прошло времени: 00:05:27
#
# Iteration 500
# Iteration 1000
# *** Weights are saved to weights3_OSO_light_3.pth after epoch 71
#  >>> Средняя разница между предсказанными и OSO: 0.322
# Epoch [71/300], learn_rate: 1e-05, Train Loss: 0.41452, Test Loss: 0.42424
# Фаза 1: Train: 0.44741, Test: 0.46405
# Фаза 2: Train: 0.41645, Test: 0.42683
# Фаза 3: Train: 0.47059, Test: 0.48182
# Фаза 4: Train: 0.42567, Test: 0.44178
# Фаза 5: Train: 0.45960, Test: 0.47636
# Фаза 6: Train: 0.40101, Test: 0.40258
# Фаза 7: Train: 0.37702, Test: 0.38258
# Фаза 8: Train: 0.41654, Test: 0.42582
# ...
# Фаза 1: Train: 0.24069, Test: 0.25297
# Фаза 2: Train: 0.26851, Test: 0.28130
# Фаза 3: Train: 0.26183, Test: 0.27455
# Фаза 4: Train: 0.26711, Test: 0.28404
# Фаза 5: Train: 0.30803, Test: 0.32219
# Фаза 6: Train: 0.21408, Test: 0.22165
# Фаза 7: Train: 0.22629, Test: 0.23428
# Фаза 8: Train: 0.24421, Test: 0.25429
# Фаза 9: Train: 0.24739, Test: 0.26313
# Фаза 10: Train: 0.21933, Test: 0.23209
# Фаза 11: Train: 0.28341, Test: 0.29375
# Фаза 12: Train: 0.21685, Test: 0.22391
# Прошло времени: 00:21:19
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.330
# Epoch [277/300], learn_rate: 1e-05, Train Loss: 0.22434, Test Loss: 0.23741
# Фаза 1: Train: 0.23160, Test: 0.24252
# Фаза 2: Train: 0.24745, Test: 0.25972
# Фаза 3: Train: 0.23582, Test: 0.25041
# Фаза 4: Train: 0.25096, Test: 0.27259
# Фаза 5: Train: 0.21350, Test: 0.22875
# Фаза 6: Train: 0.19864, Test: 0.20949
# Фаза 7: Train: 0.18821, Test: 0.19754
# Фаза 8: Train: 0.24519, Test: 0.25614
# Фаза 9: Train: 0.22680, Test: 0.24099
# Фаза 10: Train: 0.19452, Test: 0.20770
# Фаза 11: Train: 0.23482, Test: 0.24788
# Фаза 12: Train: 0.21327, Test: 0.22262
# Прошло времени: 00:21:23
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.313
# Epoch [278/300], learn_rate: 1e-05, Train Loss: 0.23354, Test Loss: 0.24570
# Фаза 1: Train: 0.21603, Test: 0.22543
# Фаза 2: Train: 0.23628, Test: 0.25128
# Фаза 3: Train: 0.25114, Test: 0.26216
# Фаза 4: Train: 0.27767, Test: 0.29689
# Фаза 5: Train: 0.23063, Test: 0.24682
# Фаза 6: Train: 0.20970, Test: 0.21854
# Фаза 7: Train: 0.19185, Test: 0.20272
# Фаза 8: Train: 0.23444, Test: 0.24798
# Фаза 9: Train: 0.27391, Test: 0.28558
# Фаза 10: Train: 0.21458, Test: 0.22674
# Фаза 11: Train: 0.23385, Test: 0.24380
# Фаза 12: Train: 0.21712, Test: 0.22349
# Прошло времени: 00:21:28
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.335
# Epoch [279/300], learn_rate: 1e-05, Train Loss: 0.22169, Test Loss: 0.23383
# Фаза 1: Train: 0.22413, Test: 0.23228
# Фаза 2: Train: 0.23128, Test: 0.24675
# Фаза 3: Train: 0.23363, Test: 0.24440
# Фаза 4: Train: 0.24673, Test: 0.26720
# Фаза 5: Train: 0.22187, Test: 0.23799
# Фаза 6: Train: 0.20129, Test: 0.20908
# Фаза 7: Train: 0.19256, Test: 0.20224
# Фаза 8: Train: 0.24195, Test: 0.25423
# Фаза 9: Train: 0.23492, Test: 0.24810
# Фаза 10: Train: 0.19987, Test: 0.21131
# Фаза 11: Train: 0.22092, Test: 0.23232
# Фаза 12: Train: 0.20319, Test: 0.21001
# Прошло времени: 00:21:32
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.340
# Epoch [280/300], learn_rate: 1e-05, Train Loss: 0.22947, Test Loss: 0.24197
# Фаза 1: Train: 0.21607, Test: 0.22866
# Фаза 2: Train: 0.24568, Test: 0.25856
# Фаза 3: Train: 0.24873, Test: 0.26006
# Фаза 4: Train: 0.27291, Test: 0.29153
# Фаза 5: Train: 0.21830, Test: 0.23612
# Фаза 6: Train: 0.21296, Test: 0.22086
# Фаза 7: Train: 0.19602, Test: 0.20565
# Фаза 8: Train: 0.22749, Test: 0.24138
# Фаза 9: Train: 0.23056, Test: 0.24275
# Фаза 10: Train: 0.20490, Test: 0.21711
# Фаза 11: Train: 0.22528, Test: 0.23753
# Фаза 12: Train: 0.24372, Test: 0.25154
# Прошло времени: 00:21:37
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.334
# Epoch [281/300], learn_rate: 1e-05, Train Loss: 0.23553, Test Loss: 0.24653
# Фаза 1: Train: 0.24619, Test: 0.25750
# Фаза 2: Train: 0.23527, Test: 0.24911
# Фаза 3: Train: 0.23644, Test: 0.24857
# Фаза 4: Train: 0.25516, Test: 0.27457
# Фаза 5: Train: 0.23233, Test: 0.24683
# Фаза 6: Train: 0.24525, Test: 0.25083
# Фаза 7: Train: 0.24382, Test: 0.24535
# Фаза 8: Train: 0.23749, Test: 0.24964
# Фаза 9: Train: 0.22679, Test: 0.24118
# Фаза 10: Train: 0.21243, Test: 0.22260
# Фаза 11: Train: 0.24465, Test: 0.25383
# Фаза 12: Train: 0.20573, Test: 0.21284
# Прошло времени: 00:21:42
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.328
# Epoch [282/300], learn_rate: 1e-05, Train Loss: 0.22815, Test Loss: 0.24022
# Фаза 1: Train: 0.21107, Test: 0.22189
# Фаза 2: Train: 0.24790, Test: 0.26113
# Фаза 3: Train: 0.25979, Test: 0.27007
# Фаза 4: Train: 0.24552, Test: 0.26513
# Фаза 5: Train: 0.27226, Test: 0.28392
# Фаза 6: Train: 0.20473, Test: 0.21386
# Фаза 7: Train: 0.18570, Test: 0.19538
# Фаза 8: Train: 0.22393, Test: 0.23866
# Фаза 9: Train: 0.24073, Test: 0.25363
# Фаза 10: Train: 0.19424, Test: 0.20632
# Фаза 11: Train: 0.23313, Test: 0.24462
# Фаза 12: Train: 0.20042, Test: 0.20880
# Прошло времени: 00:21:46
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.363
# Epoch [283/300], learn_rate: 1e-05, Train Loss: 0.23676, Test Loss: 0.24810
# Фаза 1: Train: 0.22263, Test: 0.23219
# Фаза 2: Train: 0.24781, Test: 0.26050
# Фаза 3: Train: 0.25898, Test: 0.27152
# Фаза 4: Train: 0.26142, Test: 0.27949
# Фаза 5: Train: 0.23556, Test: 0.24857
# Фаза 6: Train: 0.21840, Test: 0.22663
# Фаза 7: Train: 0.20885, Test: 0.21636
# Фаза 8: Train: 0.23773, Test: 0.24948
# Фаза 9: Train: 0.23697, Test: 0.24920
# Фаза 10: Train: 0.21025, Test: 0.22206
# Фаза 11: Train: 0.24488, Test: 0.25489
# Фаза 12: Train: 0.25022, Test: 0.25775
# Прошло времени: 00:21:51
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.328
# Epoch [284/300], learn_rate: 1e-05, Train Loss: 0.23405, Test Loss: 0.24673
# Фаза 1: Train: 0.22920, Test: 0.24128
# Фаза 2: Train: 0.23571, Test: 0.25101
# Фаза 3: Train: 0.24244, Test: 0.25468
# Фаза 4: Train: 0.25545, Test: 0.27494
# Фаза 5: Train: 0.23645, Test: 0.25270
# Фаза 6: Train: 0.23471, Test: 0.24358
# Фаза 7: Train: 0.20388, Test: 0.21331
# Фаза 8: Train: 0.23326, Test: 0.24623
# Фаза 9: Train: 0.25916, Test: 0.27206
# Фаза 10: Train: 0.21468, Test: 0.22769
# Фаза 11: Train: 0.23538, Test: 0.24508
# Фаза 12: Train: 0.22276, Test: 0.23145
# Прошло времени: 00:21:55
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.339
# Epoch [285/300], learn_rate: 1e-05, Train Loss: 0.25558, Test Loss: 0.26693
# Фаза 1: Train: 0.22868, Test: 0.23568
# Фаза 2: Train: 0.24986, Test: 0.26586
# Фаза 3: Train: 0.24929, Test: 0.26211
# Фаза 4: Train: 0.27441, Test: 0.29443
# Фаза 5: Train: 0.27455, Test: 0.28607
# Фаза 6: Train: 0.28209, Test: 0.28752
# Фаза 7: Train: 0.28935, Test: 0.29972
# Фаза 8: Train: 0.25929, Test: 0.27068
# Фаза 9: Train: 0.26150, Test: 0.27293
# Фаза 10: Train: 0.22256, Test: 0.23424
# Фаза 11: Train: 0.23382, Test: 0.24193
# Фаза 12: Train: 0.23060, Test: 0.24066
# Прошло времени: 00:22:00
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.354
# Epoch [286/300], learn_rate: 1e-05, Train Loss: 0.22998, Test Loss: 0.24195
# Фаза 1: Train: 0.21323, Test: 0.22153
# Фаза 2: Train: 0.25048, Test: 0.26356
# Фаза 3: Train: 0.24373, Test: 0.25527
# Фаза 4: Train: 0.25256, Test: 0.27277
# Фаза 5: Train: 0.24063, Test: 0.25565
# Фаза 6: Train: 0.23916, Test: 0.24396
# Фаза 7: Train: 0.20357, Test: 0.21287
# Фаза 8: Train: 0.23090, Test: 0.24459
# Фаза 9: Train: 0.23821, Test: 0.25023
# Фаза 10: Train: 0.20165, Test: 0.21481
# Фаза 11: Train: 0.22809, Test: 0.23939
# Фаза 12: Train: 0.20981, Test: 0.21977
# Прошло времени: 00:22:05
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.318
# Epoch [287/300], learn_rate: 1e-05, Train Loss: 0.23373, Test Loss: 0.24580
# Фаза 1: Train: 0.22816, Test: 0.23624
# Фаза 2: Train: 0.26479, Test: 0.27794
# Фаза 3: Train: 0.24697, Test: 0.25968
# Фаза 4: Train: 0.26795, Test: 0.28516
# Фаза 5: Train: 0.24117, Test: 0.25763
# Фаза 6: Train: 0.22130, Test: 0.22946
# Фаза 7: Train: 0.19875, Test: 0.20914
# Фаза 8: Train: 0.23208, Test: 0.24406
# Фаза 9: Train: 0.23719, Test: 0.24998
# Фаза 10: Train: 0.21035, Test: 0.22408
# Фаза 11: Train: 0.24066, Test: 0.25241
# Фаза 12: Train: 0.20414, Test: 0.21092
# Прошло времени: 00:22:09
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.344
# Epoch [288/300], learn_rate: 1e-05, Train Loss: 0.22716, Test Loss: 0.23925
# Фаза 1: Train: 0.22161, Test: 0.23141
# Фаза 2: Train: 0.23285, Test: 0.24662
# Фаза 3: Train: 0.24732, Test: 0.25939
# Фаза 4: Train: 0.25212, Test: 0.26991
# Фаза 5: Train: 0.24239, Test: 0.25800
# Фаза 6: Train: 0.21514, Test: 0.22341
# Фаза 7: Train: 0.19352, Test: 0.20079
# Фаза 8: Train: 0.22836, Test: 0.24236
# Фаза 9: Train: 0.22935, Test: 0.24460
# Фаза 10: Train: 0.20958, Test: 0.22123
# Фаза 11: Train: 0.22141, Test: 0.23173
# Фаза 12: Train: 0.22576, Test: 0.23322
# Прошло времени: 00:22:14
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.325
# Epoch [289/300], learn_rate: 1e-05, Train Loss: 0.22702, Test Loss: 0.24024
# Фаза 1: Train: 0.21056, Test: 0.22026
# Фаза 2: Train: 0.23488, Test: 0.24762
# Фаза 3: Train: 0.25463, Test: 0.26764
# Фаза 4: Train: 0.26388, Test: 0.28478
# Фаза 5: Train: 0.22901, Test: 0.24744
# Фаза 6: Train: 0.21038, Test: 0.22170
# Фаза 7: Train: 0.19968, Test: 0.20982
# Фаза 8: Train: 0.22459, Test: 0.23901
# Фаза 9: Train: 0.22666, Test: 0.23908
# Фаза 10: Train: 0.21622, Test: 0.22788
# Фаза 11: Train: 0.22581, Test: 0.23971
# Фаза 12: Train: 0.21988, Test: 0.22791
# Прошло времени: 00:22:19
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.329
# Epoch [290/300], learn_rate: 1e-05, Train Loss: 0.22645, Test Loss: 0.23856
# Фаза 1: Train: 0.20173, Test: 0.21328
# Фаза 2: Train: 0.24411, Test: 0.25813
# Фаза 3: Train: 0.26605, Test: 0.27418
# Фаза 4: Train: 0.24391, Test: 0.26266
# Фаза 5: Train: 0.21511, Test: 0.23266
# Фаза 6: Train: 0.22115, Test: 0.22945
# Фаза 7: Train: 0.20688, Test: 0.21665
# Фаза 8: Train: 0.22343, Test: 0.23497
# Фаза 9: Train: 0.25006, Test: 0.26150
# Фаза 10: Train: 0.19734, Test: 0.21098
# Фаза 11: Train: 0.23145, Test: 0.24242
# Фаза 12: Train: 0.20454, Test: 0.21468
# Прошло времени: 00:22:23
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.348
# Epoch [291/300], learn_rate: 1e-05, Train Loss: 0.22773, Test Loss: 0.24036
# Фаза 1: Train: 0.21768, Test: 0.22800
# Фаза 2: Train: 0.24338, Test: 0.25814
# Фаза 3: Train: 0.24219, Test: 0.25581
# Фаза 4: Train: 0.25785, Test: 0.27571
# Фаза 5: Train: 0.23094, Test: 0.24695
# Фаза 6: Train: 0.19795, Test: 0.20795
# Фаза 7: Train: 0.21470, Test: 0.22378
# Фаза 8: Train: 0.23418, Test: 0.24632
# Фаза 9: Train: 0.23710, Test: 0.25066
# Фаза 10: Train: 0.19859, Test: 0.21102
# Фаза 11: Train: 0.24378, Test: 0.25229
# Фаза 12: Train: 0.20507, Test: 0.21726
# Прошло времени: 00:22:28
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.331
# Epoch [292/300], learn_rate: 1e-05, Train Loss: 0.23717, Test Loss: 0.24936
# Фаза 1: Train: 0.21545, Test: 0.22416
# Фаза 2: Train: 0.23116, Test: 0.24534
# Фаза 3: Train: 0.24899, Test: 0.26139
# Фаза 4: Train: 0.26068, Test: 0.28231
# Фаза 5: Train: 0.24659, Test: 0.26275
# Фаза 6: Train: 0.23278, Test: 0.24139
# Фаза 7: Train: 0.19809, Test: 0.20635
# Фаза 8: Train: 0.24364, Test: 0.25805
# Фаза 9: Train: 0.26247, Test: 0.27482
# Фаза 10: Train: 0.21370, Test: 0.22427
# Фаза 11: Train: 0.26792, Test: 0.27666
# Фаза 12: Train: 0.21274, Test: 0.22109
# Прошло времени: 00:22:32
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.314
# Epoch [293/300], learn_rate: 1e-05, Train Loss: 0.23390, Test Loss: 0.24637
# Фаза 1: Train: 0.21808, Test: 0.22866
# Фаза 2: Train: 0.23781, Test: 0.25379
# Фаза 3: Train: 0.26225, Test: 0.27265
# Фаза 4: Train: 0.24510, Test: 0.26424
# Фаза 5: Train: 0.23952, Test: 0.25741
# Фаза 6: Train: 0.20938, Test: 0.21656
# Фаза 7: Train: 0.21514, Test: 0.22753
# Фаза 8: Train: 0.23741, Test: 0.25030
# Фаза 9: Train: 0.26731, Test: 0.27994
# Фаза 10: Train: 0.22378, Test: 0.23528
# Фаза 11: Train: 0.23226, Test: 0.24223
# Фаза 12: Train: 0.21025, Test: 0.21811
# Прошло времени: 00:22:37
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.335
# Epoch [294/300], learn_rate: 1e-05, Train Loss: 0.22360, Test Loss: 0.23761
# Фаза 1: Train: 0.22427, Test: 0.23901
# Фаза 2: Train: 0.22387, Test: 0.23919
# Фаза 3: Train: 0.24347, Test: 0.25637
# Фаза 4: Train: 0.24581, Test: 0.26741
# Фаза 5: Train: 0.23409, Test: 0.24912
# Фаза 6: Train: 0.20901, Test: 0.21831
# Фаза 7: Train: 0.20622, Test: 0.21624
# Фаза 8: Train: 0.22586, Test: 0.24097
# Фаза 9: Train: 0.22466, Test: 0.24049
# Фаза 10: Train: 0.19963, Test: 0.21407
# Фаза 11: Train: 0.23672, Test: 0.24961
# Фаза 12: Train: 0.20361, Test: 0.21317
# Прошло времени: 00:22:42
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.371
# Epoch [295/300], learn_rate: 1e-05, Train Loss: 0.23119, Test Loss: 0.24383
# Фаза 1: Train: 0.20510, Test: 0.21561
# Фаза 2: Train: 0.26418, Test: 0.27846
# Фаза 3: Train: 0.24676, Test: 0.26012
# Фаза 4: Train: 0.25829, Test: 0.27883
# Фаза 5: Train: 0.23791, Test: 0.25380
# Фаза 6: Train: 0.22809, Test: 0.23671
# Фаза 7: Train: 0.21290, Test: 0.22310
# Фаза 8: Train: 0.23447, Test: 0.24614
# Фаза 9: Train: 0.23479, Test: 0.24990
# Фаза 10: Train: 0.19862, Test: 0.21177
# Фаза 11: Train: 0.22441, Test: 0.23486
# Фаза 12: Train: 0.21925, Test: 0.22524
# Прошло времени: 00:22:46
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.372
# Epoch [296/300], learn_rate: 1e-05, Train Loss: 0.23032, Test Loss: 0.24307
# Фаза 1: Train: 0.21417, Test: 0.22305
# Фаза 2: Train: 0.23468, Test: 0.25159
# Фаза 3: Train: 0.23738, Test: 0.24866
# Фаза 4: Train: 0.26796, Test: 0.28708
# Фаза 5: Train: 0.22926, Test: 0.24527
# Фаза 6: Train: 0.21679, Test: 0.22690
# Фаза 7: Train: 0.19627, Test: 0.20611
# Фаза 8: Train: 0.25388, Test: 0.26865
# Фаза 9: Train: 0.23037, Test: 0.24456
# Фаза 10: Train: 0.23040, Test: 0.24159
# Фаза 11: Train: 0.23781, Test: 0.24821
# Фаза 12: Train: 0.20549, Test: 0.21363
# Прошло времени: 00:22:51
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.367
# Epoch [297/300], learn_rate: 1e-05, Train Loss: 0.23225, Test Loss: 0.24525
# Фаза 1: Train: 0.22272, Test: 0.23095
# Фаза 2: Train: 0.25243, Test: 0.26589
# Фаза 3: Train: 0.24552, Test: 0.26013
# Фаза 4: Train: 0.24370, Test: 0.26589
# Фаза 5: Train: 0.22851, Test: 0.24521
# Фаза 6: Train: 0.22691, Test: 0.23604
# Фаза 7: Train: 0.21482, Test: 0.22412
# Фаза 8: Train: 0.23639, Test: 0.25145
# Фаза 9: Train: 0.25663, Test: 0.26973
# Фаза 10: Train: 0.21636, Test: 0.22952
# Фаза 11: Train: 0.22786, Test: 0.23896
# Фаза 12: Train: 0.20970, Test: 0.21797
# Прошло времени: 00:22:55
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.313
# Epoch [298/300], learn_rate: 1e-05, Train Loss: 0.23943, Test Loss: 0.25161
# Фаза 1: Train: 0.22435, Test: 0.23358
# Фаза 2: Train: 0.27124, Test: 0.28448
# Фаза 3: Train: 0.24115, Test: 0.25230
# Фаза 4: Train: 0.25785, Test: 0.27768
# Фаза 5: Train: 0.22721, Test: 0.24209
# Фаза 6: Train: 0.23294, Test: 0.24100
# Фаза 7: Train: 0.23158, Test: 0.24297
# Фаза 8: Train: 0.22730, Test: 0.24122
# Фаза 9: Train: 0.27628, Test: 0.28625
# Фаза 10: Train: 0.24920, Test: 0.25965
# Фаза 11: Train: 0.21644, Test: 0.23158
# Фаза 12: Train: 0.20719, Test: 0.21580
# Прошло времени: 00:23:00
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.368
# Epoch [299/300], learn_rate: 1e-05, Train Loss: 0.22654, Test Loss: 0.23988
# Фаза 1: Train: 0.21986, Test: 0.22905
# Фаза 2: Train: 0.23109, Test: 0.24609
# Фаза 3: Train: 0.25640, Test: 0.26990
# Фаза 4: Train: 0.25530, Test: 0.27689
# Фаза 5: Train: 0.22046, Test: 0.23819
# Фаза 6: Train: 0.23022, Test: 0.23744
# Фаза 7: Train: 0.22150, Test: 0.23199
# Фаза 8: Train: 0.22321, Test: 0.24020
# Фаза 9: Train: 0.22592, Test: 0.23957
# Фаза 10: Train: 0.19636, Test: 0.20943
# Фаза 11: Train: 0.22948, Test: 0.24021
# Фаза 12: Train: 0.20112, Test: 0.21065
# Прошло времени: 00:23:05
#
# Iteration 500
# Iteration 1000
#  >>> Средняя разница между предсказанными и OSO: 0.350
# Epoch [300/300], learn_rate: 1e-05, Train Loss: 0.22087, Test Loss: 0.23426
# Фаза 1: Train: 0.20947, Test: 0.21958
# Фаза 2: Train: 0.22421, Test: 0.23888
# Фаза 3: Train: 0.24371, Test: 0.25612
# Фаза 4: Train: 0.23679, Test: 0.25857
# Фаза 5: Train: 0.21517, Test: 0.23210
# Фаза 6: Train: 0.21779, Test: 0.22785
# Фаза 7: Train: 0.21153, Test: 0.22079
# Фаза 8: Train: 0.22763, Test: 0.24209
# Фаза 9: Train: 0.23243, Test: 0.24643
# Фаза 10: Train: 0.20548, Test: 0.22063
# Фаза 11: Train: 0.22289, Test: 0.23449
# Фаза 12: Train: 0.19889, Test: 0.20804
# Прошло времени: 00:23:09

# %%
np_train_all_losses = np.array(train_all_losses)
np_test_all_losses = np.array(test_all_losses)

# %%
np_train_all_losses.shape
# Out:
# (300, 1406, 128)

# %%
np_test_all_losses.shape
# Out:
# (300, 156, 128)

# %%
len_train = np_train_all_losses.shape[1]*np_train_all_losses.shape[2]
print(len_train)
len_test = np_test_all_losses.shape[1]*np_test_all_losses.shape[2]
print(len_test)
# Out:
# 179968
# 19968

# %%
np_train_all_losses = np_train_all_losses.reshape(np_train_all_losses.shape[0],len_train)
np_test_all_losses = np_test_all_losses.reshape(np_train_all_losses.shape[0],len_test)

# %%
inter1 = 299

# %%
print(np.mean(np_train_all_losses[inter1]))
print(np.std(np_train_all_losses[inter1]))
print(np.median(np_train_all_losses[inter1]))
print(np.mean(np_test_all_losses[inter1]))
print(np.std(np_test_all_losses[inter1]))
print(np.median(np_test_all_losses[inter1]))
# Out:
# 4.87753e-06
# 3.370751e-06
# 4.124866e-06
# 5.4844854e-06
# 3.9405627e-06
# 4.573487e-06

# %%
x_scaled = np.arange(len_test)*len_train/len_test
print(x_scaled)
# Out:
# [0.00000000e+00 9.01282051e+00 1.80256410e+01 ... 1.79940962e+05
#  1.79949974e+05 1.79958987e+05]

# %%
plt.plot(np.sort(np_train_all_losses[inter1]))
plt.plot(x_scaled,np.sort(np_test_all_losses[inter1]),linestyle='-.')
plt.show()

# %%
plt.plot(train_losses,label='train_loss')
plt.plot(test_losses,label='test_loss')
plt.legend()
plt.yscale('log')
plt.show()
